# %%
import pandas as pd
import numpy as np
import re
import string
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# %%
# ===== Bagian B: Load Dataset dan Kamus Slang / Stopword =====
df = pd.read_csv("ulasan_goride.csv")
slang_dict = dict(line.strip().split(':') for line in open("kamus_slang.txt", encoding='utf-8'))
stopword_custom = set(open("stopwordsID.txt", encoding='utf-8').read().splitlines())

# %%
# ===== Bagian C: Preprocessing =====
print("\n=== Preprocessing Data ===")
factory = StemmerFactory()
stemmer = factory.create_stemmer()

def print_step(step_name, before, after):
    """Utility untuk menampilkan before-after"""
    print(f"\n=== {step_name.upper()} ===")
    print(f"Before: {before}")
    print(f"After:  {after}")
# Out:
# === Preprocessing Data ===

# %%
# Langkah 1: Cleaning Text
print("\n=== Langkah 1: Text Cleaning ===")
def clean_text(text):
    """Fungsi cleaning text"""
    before = text
    after = text.lower()
    after = re.sub(r'http\S+|www\S+', '', after)
    after = re.sub(r'[^a-zA-Z\s]', ' ', after)
    after = re.sub(r'\s+', ' ', after).strip()
    print_step("Text Cleaning", before, after)
    return after

df['after_clean'] = df['ulasan'].astype(str).apply(clean_text)
print("\nHasil setelah cleaning:")
df[['ulasan', 'after_clean']].head(3)
# Out:
# === Langkah 1: Text Cleaning ===
#
# === TEXT CLEANING ===
# Before: Matikan Fitur Order ganda pemesanan GoRide. Seharusnya kalau sudah Order GoRide tidak bisa order GoRide lagi sekaligus, harus dibatalkan dulu baru bisa pesan lagi
# After:  matikan fitur order ganda pemesanan goride seharusnya kalau sudah order goride tidak bisa order goride lagi sekaligus harus dibatalkan dulu baru bisa pesan lagi
#
# === TEXT CLEANING ===
# Before: Tolong ya..Pleeeeease...buat CUSTOMER yg Pesen Gibride....Tolong itu Jempol Jangan Dikit2 cansel....Dikit2 Cansel.....Kalian Beratus Ratus kali Cansel nggak ngaruh ..nggak ngefek ..kitw2 yg driver yg kena ampas nanti Ama aplikator.....Emang Kalian Bayar Tarif nya Super Mahal ...tapi Kita dibpitong Gede super Gede Potongannya.....tolong Kasihani Kami ya Driver Ojol....
# After:  tolong ya pleeeeease buat customer yg pesen gibride tolong itu jempol jangan dikit cansel dikit cansel kalian beratus ratus kali cansel nggak ngaruh nggak ngefek kitw yg driver yg kena ampas nanti ama aplikator emang kalian bayar tarif nya super mahal tapi kita dibpitong gede super gede potongannya tolong kasihani kami ya driver ojol
#
# === TEXT CLEANING ===
# Before: Saya harap di update kedepanya saat pesan go food muncul notifikasi, jangan go ride aja yang muncul
# After:  saya harap di update kedepanya saat pesan go food muncul notifikasi jangan go ride aja yang muncul
#
# === TEXT CLEANING ===
# Before: Buatku yg tinggal agak jauh dr kota,ini aplikasi yg paling cpat utk kita dpat driver,mau pesan goride,ataupun pesan gofood,nunggu gk pake lama,kendaraan driver nya jg oke,dan drivernya sopan,sukses selalu gojek :)
# After:  buatku yg tinggal agak jauh dr kota ini aplikasi yg paling cpat utk kita dpat driver mau pesan goride ataupun pesan gofood nunggu gk pake lama kendaraan driver nya jg oke dan drivernya sopan sukses selalu gojek
#
# === TEXT CLEANING ===
# Before: Layanan Goride sangat membantu untuk aktifitas sehari" di saat motor sedang perbaikan di bengkel, masukan nya mgkin cuman kalo cuaca sedang hujan dlm situasi urgent butuh transport, masih sering lama dpt driver nya.
# After:  layanan goride sangat membantu untuk aktifitas sehari di saat motor sedang perbaikan di bengkel masukan nya mgkin cuman kalo cuaca sedang hujan dlm situasi urgent butuh transport masih sering lama dpt driver nya
#
# === TEXT CLEANING ===
# Before: ini gojek kenapa ya sekarang, saya pakai akun baru, biasanya suka ada voucher, tapi voucher goride sekarang tidak ada, tapi giliran saya beralih ke gocar, ada 2 voucher tapi pas giliran saya buka voucher, ternyata tidak ada voucher, apakah bug? tolong di perbaiki lahi
# After:  ini gojek kenapa ya sekarang saya pakai akun baru biasanya suka ada voucher tapi voucher goride sekarang tidak ada tapi giliran saya beralih ke gocar ada voucher tapi pas giliran saya buka voucher ternyata tidak ada voucher apakah bug tolong di perbaiki lahi
#
# === TEXT CLEANING ===
# Before: Kalau terima rider seleksi dulu lah, setiap naik gojek rider-nya emosian Mulu.
# After:  kalau terima rider seleksi dulu lah setiap naik gojek rider nya emosian mulu
#
# === TEXT CLEANING ===
# Before: Gojek sekarang mahal meskipun pakai voucher, perjalanan 7,7 km biasanya dg harga 9500 pake voucher go ride aja pot. 10rb, sekarang jadi 14500, alhasil beralih ke ojol sebelah
# After:  gojek sekarang mahal meskipun pakai voucher perjalanan km biasanya dg harga pake voucher go ride aja pot rb sekarang jadi alhasil beralih ke ojol sebelah
#
# === TEXT CLEANING ===
# Before: cepat dan murah
# After:  cepat dan murah
#
# === TEXT CLEANING ===
# Before: Keren dah murah
# After:  keren dah murah
#
# === TEXT CLEANING ===
# Before: Drivernya banyak alesan, bilang ga bawa helm trs ngapain ambil pesenan goride saya????? Pas sy minta cancel aja dari dianya, gamau dianya mo ambil helm dulu, knapa ga mau cancel???? Takut poinnya turun???? Klo gitu ngapain ambil pesenan saya!!!! Mana ngajak ribut lagi!!!!! Kurang ajar!!!!!
# After:  drivernya banyak alesan bilang ga bawa helm trs ngapain ambil pesenan goride saya pas sy minta cancel aja dari dianya gamau dianya mo ambil helm dulu knapa ga mau cancel takut poinnya turun klo gitu ngapain ambil pesenan saya mana ngajak ribut lagi kurang ajar
#
# === TEXT CLEANING ===
# Before: 1rmh beda hp.ee pesen go ride dng ttik dan tujuan sama knp nominal beda.sya kena 42k.pake hp ponakan 25k tunai jg.blm gofood.klu py sy mehongggg.knp bs begitu.1rmh lho.pdhl sy setia memakai gojeck utk order makanan.
# After:  rmh beda hp ee pesen go ride dng ttik dan tujuan sama knp nominal beda sya kena k pake hp ponakan k tunai jg blm gofood klu py sy mehongggg knp bs begitu rmh lho pdhl sy setia memakai gojeck utk order makanan
#
# === TEXT CLEANING ===
# Before: Drivernya mengemudikan kendaraan dengan aman dan nyaman, terimakasih.
# After:  drivernya mengemudikan kendaraan dengan aman dan nyaman terimakasih
#
# === TEXT CLEANING ===
# Before: Ok
# After:  ok
#
# === TEXT CLEANING ===
# Before: Senang
# After:  senang
#
# === TEXT CLEANING ===
# Before: Aplikasinya sih masih bagus, tapi baru hari ini, 10 januari 2024, pesen gocar hampir 15 kali, goride 7 kali, ga ada yang nyantol, server sibuk, padahal cuaca cuma gerimis kecil, di pusat kota Purwokerto. Payah sekali ini. Ga siap kalau di butuhkan.
# After:  aplikasinya sih masih bagus tapi baru hari ini januari pesen gocar hampir kali goride kali ga ada yang nyantol server sibuk padahal cuaca cuma gerimis kecil di pusat kota purwokerto payah sekali ini ga siap kalau di butuhkan
#
# === TEXT CLEANING ===
# Before: gila, order goride nunggu l banget ga dspet driver juga, padahal di depan ada driver yang lagi nongkrong. malem2 balik kerja, capek, makasih gojek ga langganan aagi gue
# After:  gila order goride nunggu l banget ga dspet driver juga padahal di depan ada driver yang lagi nongkrong malem balik kerja capek makasih gojek ga langganan aagi gue
#
# === TEXT CLEANING ===
# Before: Baik
# After:  baik
#
# === TEXT CLEANING ===
# Before: Selalu dapat driver jauh2. Kalau pesen goride mau buru2 mau kerja bisa dipecat krn kelamaan! Apalagi kalo pesen Gosend. Bisa 15-20 menit jaraknya bisa 3-5 kilo. Ga kasihan sama drivernya apa?
# After:  selalu dapat driver jauh kalau pesen goride mau buru mau kerja bisa dipecat krn kelamaan apalagi kalo pesen gosend bisa menit jaraknya bisa kilo ga kasihan sama drivernya apa
#
# === TEXT CLEANING ===
# Before: The best apps for ride
# After:  the best apps for ride
#
# === TEXT CLEANING ===
# Before: Alhamdulillah kalo pas pake goride supirnya bagus2 dan sopan
# After:  alhamdulillah kalo pas pake goride supirnya bagus dan sopan
#
# === TEXT CLEANING ===
# Before: mantap
# After:  mantap
#
# === TEXT CLEANING ===
# Before: Kenapa saya isi gopay tidak bisa, pesen goride juga bisa tlg bantuannya terima kasih
# After:  kenapa saya isi gopay tidak bisa pesen goride juga bisa tlg bantuannya terima kasih
#
# === TEXT CLEANING ===
# Before: Sangat membantu dlm beraktifitas, semoga sering sering kasih diskon goridenya
# After:  sangat membantu dlm beraktifitas semoga sering sering kasih diskon goridenya
#
# === TEXT CLEANING ===
# Before: apa apaan ini gojek sama nunggu goride sampe satu jamm.... kacau ah terus aja ditampung keluhannya ehh ga ada perbaikan juga sekarang lebih parah nunggu hampir 15 menit padahal didepan saya ada drivernya dan ga diambil tolong jangan seperti ini saya juga punya keperluan lainnya 🙏
# After:  apa apaan ini gojek sama nunggu goride sampe satu jamm kacau ah terus aja ditampung keluhannya ehh ga ada perbaikan juga sekarang lebih parah nunggu hampir menit padahal didepan saya ada drivernya dan ga diambil tolong jangan seperti ini saya juga punya keperluan lainnya
#
# === TEXT CLEANING ===
# Before: Ramah terpercaya
# After:  ramah terpercaya
#
# === TEXT CLEANING ===
# Before: Boleh2 lah cuman kadang klo go ride lama bgt
# After:  boleh lah cuman kadang klo go ride lama bgt
#
# === TEXT CLEANING ===
# Before: Bagus
# After:  bagus
#
# === TEXT CLEANING ===
# Before: udah up ke gopay plus saya pikir bakal dapet voucher goride biar murah taunya gabisa dipakai gimana ini ?
# After:  udah up ke gopay plus saya pikir bakal dapet voucher goride biar murah taunya gabisa dipakai gimana ini
#
# === TEXT CLEANING ===
# Before: mantaf
# After:  mantaf
#
# === TEXT CLEANING ===
# Before: Kayaknya gak usah pake gocar/goride layanan hemat dech klo emng gak bisa digunakan,tiap x dipake bnyk bener alasan driver..🫣🥺🤔
# After:  kayaknya gak usah pake gocar goride layanan hemat dech klo emng gak bisa digunakan tiap x dipake bnyk bener alasan driver
#
# === TEXT CLEANING ===
# Before: Makasih gojek udah ada fitur pohon bisa menanam dengan seribu Rupiah fitur sangat berguna untuk berbagi oksigen
# After:  makasih gojek udah ada fitur pohon bisa menanam dengan seribu rupiah fitur sangat berguna untuk berbagi oksigen
#
# === TEXT CLEANING ===
# Before: Bagus baik
# After:  bagus baik
#
# === TEXT CLEANING ===
# Before: Sangat membantu
# After:  sangat membantu
#
# === TEXT CLEANING ===
# Before: Drivernya ramah
# After:  drivernya ramah
#
# === TEXT CLEANING ===
# Before: bagus pelayanan
# After:  bagus pelayanan
#
# === TEXT CLEANING ===
# Before: Gojek selalu memuaskan sy. Baik go ride maupun go car nya selalu the best.
# After:  gojek selalu memuaskan sy baik go ride maupun go car nya selalu the best
#
# === TEXT CLEANING ===
# Before: Pelanggan setia goride,gocar,gofood
# After:  pelanggan setia goride gocar gofood
#
# === TEXT CLEANING ===
# Before: bagus, tp sy pernah pesan goride malah driver nya salah ambil penumpang sdh sy chat ke driver ga di respon
# After:  bagus tp sy pernah pesan goride malah driver nya salah ambil penumpang sdh sy chat ke driver ga di respon
#
# === TEXT CLEANING ===
# Before: Maaf ini kenapa pasar polis goride bisa motong di akun customer saya??? Sebelumnya ga pernah kaya gini, harusnya pasar polis ga punya akses motong saldo akun customer... Baru kali ini ada potongan pasar polis goride di akun customer...
# After:  maaf ini kenapa pasar polis goride bisa motong di akun customer saya sebelumnya ga pernah kaya gini harusnya pasar polis ga punya akses motong saldo akun customer baru kali ini ada potongan pasar polis goride di akun customer
#
# === TEXT CLEANING ===
# Before: Aplikasi makin tolol...pesan goride yg muncul dan datang gocar
# After:  aplikasi makin tolol pesan goride yg muncul dan datang gocar
#
# === TEXT CLEANING ===
# Before: nunggu sampe sejam goride, tapi tulisannya sibuk terus. ini emg beneran pd sibuk gojek ny atau emg aplikasi nya lagi error???
# After:  nunggu sampe sejam goride tapi tulisannya sibuk terus ini emg beneran pd sibuk gojek ny atau emg aplikasi nya lagi error
#
# === TEXT CLEANING ===
# Before: Untuk saat ini saya hanya pakai gofood saja dan jarang menggunakan goride/Gocar karena masih trauma dengan cara mereka mengendarai kendaraan dan sempat membuat saya celaka. Masukan saja, lebih banyak promo Gofood dan Voucher Gratis ongkir/potongan ongkir seperti driver Oren.
# After:  untuk saat ini saya hanya pakai gofood saja dan jarang menggunakan goride gocar karena masih trauma dengan cara mereka mengendarai kendaraan dan sempat membuat saya celaka masukan saja lebih banyak promo gofood dan voucher gratis ongkir potongan ongkir seperti driver oren
#
# === TEXT CLEANING ===
# Before: Top markotop
# After:  top markotop
#
# === TEXT CLEANING ===
# Before: Selalu tepat waktu penjemputan,banyak promo Dan lebih hemat
# After:  selalu tepat waktu penjemputan banyak promo dan lebih hemat
#
# === TEXT CLEANING ===
# Before: Dapet driver goride nya lama padahal di kota depok mau berangkat kerja jadi telat ngga kaya aplikasi sebelah dapat drivernya cepat, sekalinya dapet jauh driver jemputnya
# After:  dapet driver goride nya lama padahal di kota depok mau berangkat kerja jadi telat ngga kaya aplikasi sebelah dapat drivernya cepat sekalinya dapet jauh driver jemputnya
#
# === TEXT CLEANING ===
# Before: Semakin lama semakin gk guna nih aplikasi.. Saya pesen goride.. di gambar banyak skali driver terdekat...eh nyantol nya di jepang saking jauhnya..mana skrg ongkir nya mahal banget..maaf untuk kali saya pindah ke apk sebelah gk ribet.......!!!!
# After:  semakin lama semakin gk guna nih aplikasi saya pesen goride di gambar banyak skali driver terdekat eh nyantol nya di jepang saking jauhnya mana skrg ongkir nya mahal banget maaf untuk kali saya pindah ke apk sebelah gk ribet
#
# === TEXT CLEANING ===
# Before: mengecewakan setiap mau order gocar pas lgi hujan para driver susah untuk menerima pesanan, apalagi pakai promo terutama yg buat goride, alasan bnyk orderan, lagi rame
# After:  mengecewakan setiap mau order gocar pas lgi hujan para driver susah untuk menerima pesanan apalagi pakai promo terutama yg buat goride alasan bnyk orderan lagi rame
#
# === TEXT CLEANING ===
# Before: Aplikasi bodoh, tidak ada yang mau ambil goride, driver bodoh
# After:  aplikasi bodoh tidak ada yang mau ambil goride driver bodoh
#
# === TEXT CLEANING ===
# Before: Gojek sekarang makin buruk ! Mencari Driver ny tidak dapat-dapat , Padahl saya tidak membatalkan pesanan dan saya menunggu 15-20 menit dan saya order lagi namun hasilnya sama saja.. tambah banyak bug saya ingin memesan makanan atau Goride
# After:  gojek sekarang makin buruk mencari driver ny tidak dapat dapat padahl saya tidak membatalkan pesanan dan saya menunggu menit dan saya order lagi namun hasilnya sama saja tambah banyak bug saya ingin memesan makanan atau goride
#
# === TEXT CLEANING ===
# Before: Mantap dah pokoknya mah
# After:  mantap dah pokoknya mah
#
# === TEXT CLEANING ===
# Before: Untuk goride dan gocar ,cukup lumayan voucernya ,tapi gofood nya saya jarang pake karna ada aplikasi lain jauh lebih murah
# After:  untuk goride dan gocar cukup lumayan voucernya tapi gofood nya saya jarang pake karna ada aplikasi lain jauh lebih murah
#
# === TEXT CLEANING ===
# Before: Mudah di gunakan
# After:  mudah di gunakan
#
# === TEXT CLEANING ===
# Before: nice
# After:  nice
#
# === TEXT CLEANING ===
# Before: Aplikasi tolol, kalau persen goride, di kasih driver yang jauh, sekeliling banyak, di ambilin dari Korea Utara, perkiraan 6 menit, ditunggu 30 menit gak sampai, update lokasi driver juga gak jelas,
# After:  aplikasi tolol kalau persen goride di kasih driver yang jauh sekeliling banyak di ambilin dari korea utara perkiraan menit ditunggu menit gak sampai update lokasi driver juga gak jelas
#
# === TEXT CLEANING ===
# Before: i love gojek sm, setiap hari berangkat pulang sekolah always make gojek, apalagi di gojek fitur goride comfort, cocok banget buat aku yang suka bawa barang banyak kesekolah suka bawa tas gede gitu deh, kaki nya dan pnttnya juga jadi ga pegel jaya terus deh yaa gojek
# After:  i love gojek sm setiap hari berangkat pulang sekolah always make gojek apalagi di gojek fitur goride comfort cocok banget buat aku yang suka bawa barang banyak kesekolah suka bawa tas gede gitu deh kaki nya dan pnttnya juga jadi ga pegel jaya terus deh yaa gojek
#
# === TEXT CLEANING ===
# Before: Kenapa saat saya ingin menggunakan Go-Ride dia berubah Go-car kan jadi mahal ongkosnya
# After:  kenapa saat saya ingin menggunakan go ride dia berubah go car kan jadi mahal ongkosnya
#
# === TEXT CLEANING ===
# Before: Good
# After:  good
#
# === TEXT CLEANING ===
# Before: apa apaan go transit skrng digabung sama go ridetransit, jadinya ga bisa edit stasiun kalo tujuannya berubah, padahal sblum update bisa, kalo diupdate makin nyusahin mending gausah di update. Tujuannya update kan untuk memudahkan bukan malah mempersulit.
# After:  apa apaan go transit skrng digabung sama go ridetransit jadinya ga bisa edit stasiun kalo tujuannya berubah padahal sblum update bisa kalo diupdate makin nyusahin mending gausah di update tujuannya update kan untuk memudahkan bukan malah mempersulit
#
# === TEXT CLEANING ===
# Before: Pelayanan nya lebih baik daripada aplikasi sebelah . Pilihannya juga banyak
# After:  pelayanan nya lebih baik daripada aplikasi sebelah pilihannya juga banyak
#
# === TEXT CLEANING ===
# Before: Mantap
# After:  mantap
#
# === TEXT CLEANING ===
# Before: Padahal pakai aplikasi ini udah lama.. tiba2 hari ini bingung, pas check goride harganya dari 40rb naik jadi 50rb.. eh iseng buka grab cuman bayar 33rb 😊
# After:  padahal pakai aplikasi ini udah lama tiba hari ini bingung pas check goride harganya dari rb naik jadi rb eh iseng buka grab cuman bayar rb
#
# === TEXT CLEANING ===
# Before: Susah dpt driver udah 4x pesen tetep gk dpt pindah dari menu go ride ke go car cmn hasilny nihil sama aja, parah sih
# After:  susah dpt driver udah x pesen tetep gk dpt pindah dari menu go ride ke go car cmn hasilny nihil sama aja parah sih
#
# === TEXT CLEANING ===
# Before: Saya suka pake jasa goride/gocar. Seneng aja denger curhatan mereka, cerita mereka, keluh kesah mereka. Cerita sedih, cerita bahagia semuanya saya rangkum jadi motivasi buat diri sendiri 👍👍
# After:  saya suka pake jasa goride gocar seneng aja denger curhatan mereka cerita mereka keluh kesah mereka cerita sedih cerita bahagia semuanya saya rangkum jadi motivasi buat diri sendiri
#
# === TEXT CLEANING ===
# Before: Ok
# After:  ok
#
# === TEXT CLEANING ===
# Before: Mau milih go transit tapi selalu dialihkan ke go ride
# After:  mau milih go transit tapi selalu dialihkan ke go ride
#
# === TEXT CLEANING ===
# Before: I got safety when I was ride Gojek
# After:  i got safety when i was ride gojek
#
# === TEXT CLEANING ===
# Before: Untuk goride lebih mudah dulu
# After:  untuk goride lebih mudah dulu
#
# === TEXT CLEANING ===
# Before: Kenapa aku masukin kode promo goride udah sukses tpi vocer promonya gada???? Aku udah cba update masin tetap sma, udah hpus download bbrapa kli tapi tetap sama, kenapa ya?? Apakah eror tpi cba punya temen mah gada masalah apa²
# After:  kenapa aku masukin kode promo goride udah sukses tpi vocer promonya gada aku udah cba update masin tetap sma udah hpus download bbrapa kli tapi tetap sama kenapa ya apakah eror tpi cba punya temen mah gada masalah apa
#
# === TEXT CLEANING ===
# Before: pesen goride posisi driver Deket ga mau pada ngambil, di kasihnya yang jaraknya jauh semuanya, sbagian di cancel sama drivernya.
# After:  pesen goride posisi driver deket ga mau pada ngambil di kasihnya yang jaraknya jauh semuanya sbagian di cancel sama drivernya
#
# === TEXT CLEANING ===
# Before: mohon pihak gojek memberikan saya pembelaan karena saya selalu pulang dengan goride tetapi tadi saya mendapat perlakuan yang sangat tidak menyenangkan karena saat saya membantalkan pesanan karena titik jemput tidak sesuai saya tetap didatangi driver tersebut dan driver tersebut marah²,bahkan sampai orang² melihat saya disitu saya sangat malu karena hal tersebut mohon bantuannya untuk menegur/mengingat kan driver tersebut
# After:  mohon pihak gojek memberikan saya pembelaan karena saya selalu pulang dengan goride tetapi tadi saya mendapat perlakuan yang sangat tidak menyenangkan karena saat saya membantalkan pesanan karena titik jemput tidak sesuai saya tetap didatangi driver tersebut dan driver tersebut marah bahkan sampai orang melihat saya disitu saya sangat malu karena hal tersebut mohon bantuannya untuk menegur mengingat kan driver tersebut
#
# === TEXT CLEANING ===
# Before: Layanan yg memudahkan masyarakat
# After:  layanan yg memudahkan masyarakat
#
# === TEXT CLEANING ===
# Before: Tolong untuk goride tidak perlu di pisah antara yang hemat sama yang comfort,karena percuma jika tidak ada perhatian dari pihak gojeknya,pengalaman saya pesan comfort tapi motor yang datang beda plat nomor beda jenisnya (masuk kategori hemat).Tolong lebih diperhatikan lagi khusus driver goride nya,karena keselamatan diatas segalanya.
# After:  tolong untuk goride tidak perlu di pisah antara yang hemat sama yang comfort karena percuma jika tidak ada perhatian dari pihak gojeknya pengalaman saya pesan comfort tapi motor yang datang beda plat nomor beda jenisnya masuk kategori hemat tolong lebih diperhatikan lagi khusus driver goride nya karena keselamatan diatas segalanya
#
# === TEXT CLEANING ===
# Before: Ok
# After:  ok
#
# === TEXT CLEANING ===
# Before: sangat membantu bagi saya dari goride..gocar..gofood
# After:  sangat membantu bagi saya dari goride gocar gofood
#
# === TEXT CLEANING ===
# Before: gofood nya mengecewakan sekali, udah nunggu sampe 2 jam, malah dibatalin dengan alasan gada driver, klw emg ga niat bisnis mending tutup aja aplikasinya, bukan hanya itu aja, pesan goride dll juga selalu drivernya gada, padahal jelas jelas banyak driver disekitar lokasi, makin hari makin ga banget ni aplikasi
# After:  gofood nya mengecewakan sekali udah nunggu sampe jam malah dibatalin dengan alasan gada driver klw emg ga niat bisnis mending tutup aja aplikasinya bukan hanya itu aja pesan goride dll juga selalu drivernya gada padahal jelas jelas banyak driver disekitar lokasi makin hari makin ga banget ni aplikasi
#
# === TEXT CLEANING ===
# Before: tidak pernah dapat voucher goride,jompor saya setiap hari pake goride PP 25rb gaperna dpt voucher goride
# After:  tidak pernah dapat voucher goride jompor saya setiap hari pake goride pp rb gaperna dpt voucher goride
#
# === TEXT CLEANING ===
# Before: Verygood
# After:  verygood
#
# === TEXT CLEANING ===
# Before: tiap transaksi di gojek,toped, blibli, alfagift kenapa selalu gopaylaternya ditulis diblokir? limit aman. tagihan blm japo. masa cuma bisa dipakai buat goride gocar doang?? gimana nih
# After:  tiap transaksi di gojek toped blibli alfagift kenapa selalu gopaylaternya ditulis diblokir limit aman tagihan blm japo masa cuma bisa dipakai buat goride gocar doang gimana nih
#
# === TEXT CLEANING ===
# Before: Sudah order goride lama nunggu dapat drivernya, sudah gitu susah di batalin jauh sama aplikasi tetangga
# After:  sudah order goride lama nunggu dapat drivernya sudah gitu susah di batalin jauh sama aplikasi tetangga
#
# === TEXT CLEANING ===
# Before: Mau bayar tagihan gopay later tp aplikasi gangguan melulu..mo order goride gocar juga sring gk ada driver tulisannya pdhl driver nya bnyak trlihat diaplikasi...gojek mkin buruk skrg aplikasinya kyknya uda gk tau diperbaiki dg cepet....
# After:  mau bayar tagihan gopay later tp aplikasi gangguan melulu mo order goride gocar juga sring gk ada driver tulisannya pdhl driver nya bnyak trlihat diaplikasi gojek mkin buruk skrg aplikasinya kyknya uda gk tau diperbaiki dg cepet
#
# === TEXT CLEANING ===
# Before: Udah sering pake Gojek mesen makan atau pun goride tetep aja sampai detik ini ga di buka2 Gopaylater atau Gopinjam nya, masa kalah sama yg baru daftar dan order cuma beberapa doang langsung bisa dapet limit gopaylater, Anehh banget lumayan kecewa si sama Aplikasi ini merasa ga Adil.
# After:  udah sering pake gojek mesen makan atau pun goride tetep aja sampai detik ini ga di buka gopaylater atau gopinjam nya masa kalah sama yg baru daftar dan order cuma beberapa doang langsung bisa dapet limit gopaylater anehh banget lumayan kecewa si sama aplikasi ini merasa ga adil
#
# === TEXT CLEANING ===
# Before: Saya pelanggan goride dan gosend. Ga ada masalah. Cuma saya kecewa sama go car di Jogja kok rata2 ga niat ya. Padahal kan yg milih acak dr aplikasi juga. Masa cuma karena jauh dikit minta dicancel.. padahal cm 1 km jemputnya.. jarak yg dianter pun jg ga jauh2 amat masih 2-3km. semoga pihak gojek bisa menyortir lagi driver gocar yang cuma iseng2 males2an. Wkwk kacau..
# After:  saya pelanggan goride dan gosend ga ada masalah cuma saya kecewa sama go car di jogja kok rata ga niat ya padahal kan yg milih acak dr aplikasi juga masa cuma karena jauh dikit minta dicancel padahal cm km jemputnya jarak yg dianter pun jg ga jauh amat masih km semoga pihak gojek bisa menyortir lagi driver gocar yang cuma iseng males an wkwk kacau
#
# === TEXT CLEANING ===
# Before: Tolong kalau kita sedang pesan goride/gocar cari driver yg lokasinya dekat dengan titik penjemputan. Sering bgt dapet driver yg jaraknya jauh, padahal driver yg mangkal di sekitar lokasi penjemputan banyak bangett. Tolong di perbaiki lgi. jangan buang² waktu kami hanya untuk nunggu driver yg datengnya lama karena jaraknya jauh!
# After:  tolong kalau kita sedang pesan goride gocar cari driver yg lokasinya dekat dengan titik penjemputan sering bgt dapet driver yg jaraknya jauh padahal driver yg mangkal di sekitar lokasi penjemputan banyak bangett tolong di perbaiki lgi jangan buang waktu kami hanya untuk nunggu driver yg datengnya lama karena jaraknya jauh
#
# === TEXT CLEANING ===
# Before: apa aja ada,mulai car ride dan food keren
# After:  apa aja ada mulai car ride dan food keren
#
# === TEXT CLEANING ===
# Before: GA SUKA SAMA GOJEK SKRG, KADANG PAKAI GO RIDE HEMAT GA DITERIMA SAMA DRIVER PADAHAL MERINGANKAN PENGELUARAN KLO LAGI TGL² TUA.. UDH GITU KLO PAGI SUSAHNYA MINTA AMPUN, SEKALINYA DAPET CUMA JARAK 6 MENIT DIA BILANG "KEJAUHAN SAYA MALES" PERNAH JUGA "SAYA LEBIH DEKAT KE LOKASI TUJUAN SITU, JADI KLO SAYA JEMPUT BULAK BALIK DONG" -_-
# After:  ga suka sama gojek skrg kadang pakai go ride hemat ga diterima sama driver padahal meringankan pengeluaran klo lagi tgl tua udh gitu klo pagi susahnya minta ampun sekalinya dapet cuma jarak menit dia bilang kejauhan saya males pernah juga saya lebih dekat ke lokasi tujuan situ jadi klo saya jemput bulak balik dong
#
# === TEXT CLEANING ===
# Before: Saya kecewa dengan driver goride,setiap hujan pasti tidak ada yang mengambil orderan,alasan tidak bawa jas hujan, padahal saya sudah chat kalo saya bawa jas hujan,buat apa ngojek kalo tidak sedia jas hujan untuk diri sendiri.
# After:  saya kecewa dengan driver goride setiap hujan pasti tidak ada yang mengambil orderan alasan tidak bawa jas hujan padahal saya sudah chat kalo saya bawa jas hujan buat apa ngojek kalo tidak sedia jas hujan untuk diri sendiri
#
# === TEXT CLEANING ===
# Before: Sekarang udah mahal goride dan gofood
# After:  sekarang udah mahal goride dan gofood
#
# === TEXT CLEANING ===
# Before: Gampang klo mau cari alamat.. enak
# After:  gampang klo mau cari alamat enak
#
# === TEXT CLEANING ===
# Before: Fitur go pay later & go pay pinjam ga bisa di non aktifkan. Lama² kaya aplikasi pinjol. Rawan penyalahgunaan. Ridernya seneng bgt batalin sendiri. Udah nunggu lama. Ga kaya sebelah.
# After:  fitur go pay later go pay pinjam ga bisa di non aktifkan lama kaya aplikasi pinjol rawan penyalahgunaan ridernya seneng bgt batalin sendiri udah nunggu lama ga kaya sebelah
#
# === TEXT CLEANING ===
# Before: 6 tahun mengunakan gojek,perlu di benahi,driver berbeda dengan aplikasi,apakah boleh orang yang bukan driver memakai akun driver gojek(JOKI).mengantarkan pesanan,takut makanan saya di apa-apin dengan orang yang bukan driver gojek (JOKI),mana lagi motor yang di pakai (JOKI)plat nya berbeda dengan aplikasi,pesan goride juga gitu sih,driver yang jemput orangnya berbeda dengan aplikasi.plat no motor nya juga berbeda,saya jadi was was,takut...tolong adakan vermuk berwaktu seperti grab...
# After:  tahun mengunakan gojek perlu di benahi driver berbeda dengan aplikasi apakah boleh orang yang bukan driver memakai akun driver gojek joki mengantarkan pesanan takut makanan saya di apa apin dengan orang yang bukan driver gojek joki mana lagi motor yang di pakai joki plat nya berbeda dengan aplikasi pesan goride juga gitu sih driver yang jemput orangnya berbeda dengan aplikasi plat no motor nya juga berbeda saya jadi was was takut tolong adakan vermuk berwaktu seperti grab
#
# === TEXT CLEANING ===
# Before: gimana ini waktu mau order goride, kendala kok bisa ada keterangan internetnya mati, padhal kuota banyak melimpahh, coba cek gojek di adek, bisa buat mesen, padahal punyaku biasane pakek juga baik2 saja, tolong segera diperbaiki !!
# After:  gimana ini waktu mau order goride kendala kok bisa ada keterangan internetnya mati padhal kuota banyak melimpahh coba cek gojek di adek bisa buat mesen padahal punyaku biasane pakek juga baik saja tolong segera diperbaiki
#
# === TEXT CLEANING ===
# Before: Woi harga goride nya kok nambah" dari hari ke hari,tempat nya sama aja kok,masa... Gara gara cuaca panas atau hujan jadi naik,kalo hujan ok lah(tapi ga ngotak juga kalo kali 2 njir) Oh...kualitas nya yang bikin nambah? perasaan sama aja deh,mau hemat atau comfort hoki"an aja,liat Maxim iya murah no diskon ga menarik tapi segitu aja terus...:)
# After:  woi harga goride nya kok nambah dari hari ke hari tempat nya sama aja kok masa gara gara cuaca panas atau hujan jadi naik kalo hujan ok lah tapi ga ngotak juga kalo kali njir oh kualitas nya yang bikin nambah perasaan sama aja deh mau hemat atau comfort hoki an aja liat maxim iya murah no diskon ga menarik tapi segitu aja terus
#
# === TEXT CLEANING ===
# Before: Thank you
# After:  thank you
#
# === TEXT CLEANING ===
# Before: Ok cepat dan tepat
# After:  ok cepat dan tepat
#
# === TEXT CLEANING ===
# Before: DC nya suka ngancam
# After:  dc nya suka ngancam
#
# === TEXT CLEANING ===
# Before: Jasa biaya gojek nya sudah mahal, di tambah lagi pesan go food atau go ride dll kena double order..sebagai custumer merasa di rugikan..rugi sudah bayar mahal , dan rugi waktu menunggu jadi lama..gojek makin gak jelas sekarang
# After:  jasa biaya gojek nya sudah mahal di tambah lagi pesan go food atau go ride dll kena double order sebagai custumer merasa di rugikan rugi sudah bayar mahal dan rugi waktu menunggu jadi lama gojek makin gak jelas sekarang
#
# === TEXT CLEANING ===
# Before: Terimakasih
# After:  terimakasih
#
# === TEXT CLEANING ===
# Before: Banyakin promonya khususnya goride and gofood
# After:  banyakin promonya khususnya goride and gofood
#
# === TEXT CLEANING ===
# Before: akun saya ke blokir tolong gimana solusinya, udh ngechat cs responnya sama selalu laporan ditutup. solusi dong!! keterangannya ke blokir dan tidak bisa menggunakan berbagai voucher termasuk goride&gofood. tolong gimana biar normal lagi
# After:  akun saya ke blokir tolong gimana solusinya udh ngechat cs responnya sama selalu laporan ditutup solusi dong keterangannya ke blokir dan tidak bisa menggunakan berbagai voucher termasuk goride gofood tolong gimana biar normal lagi
#
# === TEXT CLEANING ===
# Before: Bagus,minta tolong lebih banyak promo untuk gocar sama goride comfort supaya bisa menikmati perjalanan dengan hemat dan nyaman terima kasih
# After:  bagus minta tolong lebih banyak promo untuk gocar sama goride comfort supaya bisa menikmati perjalanan dengan hemat dan nyaman terima kasih
#
# === TEXT CLEANING ===
# Before: Gilaaaaaaaa saldo ilang gtu aja terus call center ga ngebantu bgt masa order goride gadapet² sampe 3kali dan saldonya ketarik 3²nya apa²in ini gojek !!!!!
# After:  gilaaaaaaaa saldo ilang gtu aja terus call center ga ngebantu bgt masa order goride gadapet sampe kali dan saldonya ketarik nya apa in ini gojek
#
# === TEXT CLEANING ===
# Before: Kemarin siang masih bisa pesan goride pake gopaylater tp pas malam tiba-tiba di gopaylater di blokir. Padahal tagihan belum jatuh tempo dan limit masih sangat sangat banyak. Sudah laporan tapi belum di tanggapi. Kecewa
# After:  kemarin siang masih bisa pesan goride pake gopaylater tp pas malam tiba tiba di gopaylater di blokir padahal tagihan belum jatuh tempo dan limit masih sangat sangat banyak sudah laporan tapi belum di tanggapi kecewa
#
# === TEXT CLEANING ===
# Before: Kenapa nggak bisa tukar voucher gorideaja??? sudah ditukar bilangnya berhasil tapi di cek di halaman voucher ngga ada sama sekali voucher nya... kosongg
# After:  kenapa nggak bisa tukar voucher gorideaja sudah ditukar bilangnya berhasil tapi di cek di halaman voucher ngga ada sama sekali voucher nya kosongg
#
# === TEXT CLEANING ===
# Before: Sangat membantu
# After:  sangat membantu
#
# === TEXT CLEANING ===
# Before: keren nih sekarang gojek, dapat driver nya cepat dan cepat sampai ga nunggu lama, dapat vocher diskon goride, gocar, gofood terus, tapi saya minta tolong dong vocher goride nya ada setiap hari jadi bisa membantu anak sekolah dengan promo yang murah dibawah 5ribu
# After:  keren nih sekarang gojek dapat driver nya cepat dan cepat sampai ga nunggu lama dapat vocher diskon goride gocar gofood terus tapi saya minta tolong dong vocher goride nya ada setiap hari jadi bisa membantu anak sekolah dengan promo yang murah dibawah ribu
#
# === TEXT CLEANING ===
# Before: gojek pasti ada jalan
# After:  gojek pasti ada jalan
#
# === TEXT CLEANING ===
# Before: kenapa map goride setiap dekat tol pasti di arahi ke lewat tol sehingga tarif tidak sesuai makasih
# After:  kenapa map goride setiap dekat tol pasti di arahi ke lewat tol sehingga tarif tidak sesuai makasih
#
# === TEXT CLEANING ===
# Before: Sy juga driver go ride min. Sangat disayangkan kalau orderan dibuat susah sekarang dan malah bensin 2x pengeluaran akhirnya saya akali beli cuman 5rb supaya ga rugi sejak system yg paling terdekat diterapkan. Sejak system goride yg sangat terdekat diterapkan otomatis pendapatan kita berkurang drastis, kita sebagai costumer gojek juga tidak bisa membantu orderan seperti biasanya bahkan belanja di tokopedia. Semoga system update terbaru pendapatan kita kembali konsisten diatas 200 lagi amin
# After:  sy juga driver go ride min sangat disayangkan kalau orderan dibuat susah sekarang dan malah bensin x pengeluaran akhirnya saya akali beli cuman rb supaya ga rugi sejak system yg paling terdekat diterapkan sejak system goride yg sangat terdekat diterapkan otomatis pendapatan kita berkurang drastis kita sebagai costumer gojek juga tidak bisa membantu orderan seperti biasanya bahkan belanja di tokopedia semoga system update terbaru pendapatan kita kembali konsisten diatas lagi amin
#
# === TEXT CLEANING ===
# Before: kami pelajar, turunkan tarif go ride!!!!!!!!! kami kaum missqueen
# After:  kami pelajar turunkan tarif go ride kami kaum missqueen
#
# === TEXT CLEANING ===
# Before: Good
# After:  good
#
# === TEXT CLEANING ===
# Before: Awal memakai aplikasi gojek puas, makin kesini keseringan kecewa, order makanan susah dpt driver nya harus menunggu hampir satu jam begitu pun untuk goride .. mohon diperhatikan dan ditindaklanjuti kedepannya..
# After:  awal memakai aplikasi gojek puas makin kesini keseringan kecewa order makanan susah dpt driver nya harus menunggu hampir satu jam begitu pun untuk goride mohon diperhatikan dan ditindaklanjuti kedepannya
#
# === TEXT CLEANING ===
# Before: Program sudah bagus, pertahankan & di tingkatkan lagi pelayanannya.. serta tolong di sejahterakan driver driver nya, berikan mereka penghidupan layak
# After:  program sudah bagus pertahankan di tingkatkan lagi pelayanannya serta tolong di sejahterakan driver driver nya berikan mereka penghidupan layak
#
# === TEXT CLEANING ===
# Before: Sangat membantu
# After:  sangat membantu
#
# === TEXT CLEANING ===
# Before: Go ride ,Ga Bisa melayani pas lagi hujan ,padahal gerimis doang 🙏 1 jam order ga ada yg nyangkut ,berharap sm gojek , nyampe kantor telat
# After:  go ride ga bisa melayani pas lagi hujan padahal gerimis doang jam order ga ada yg nyangkut berharap sm gojek nyampe kantor telat
#
# === TEXT CLEANING ===
# Before: mantep
# After:  mantep
#
# === TEXT CLEANING ===
# Before: Mudah"an semakin bnyak promonya, bukan hanya gofood tapi promo gocar, goride dll juga
# After:  mudah an semakin bnyak promonya bukan hanya gofood tapi promo gocar goride dll juga
#
# === TEXT CLEANING ===
# Before: Niatnya mau top up gopay ke driver dengan cara order go ride. pas driver datang, bisa top up dan saldo masuk. tapi dia kira saya mau pergi ke tempat yg saya tuju dan saya harus bayar ongkos trip tersebut. rugi dong!
# After:  niatnya mau top up gopay ke driver dengan cara order go ride pas driver datang bisa top up dan saldo masuk tapi dia kira saya mau pergi ke tempat yg saya tuju dan saya harus bayar ongkos trip tersebut rugi dong
#
# === TEXT CLEANING ===
# Before: Driver driver sekarang pada mls udh tau titik nya sesuai malah jauh banget, udah gitu mau nya di samperin, kan pesen ojol online agar kita praktis tapi ini gosend pun dan goride pun seperti ini emng banyak si voucher nya tapi emng gitu yaa maaf.
# After:  driver driver sekarang pada mls udh tau titik nya sesuai malah jauh banget udah gitu mau nya di samperin kan pesen ojol online agar kita praktis tapi ini gosend pun dan goride pun seperti ini emng banyak si voucher nya tapi emng gitu yaa maaf
#
# === TEXT CLEANING ===
# Before: Tampilan aplikasi Gojek semakin nyaman untuk dilihat, menarik. Penggunaan aplikasi Gojek hingga saat ini masih nyaman, aman, praktis dan suka order gofood/goride lewat aplikasi Gojek. Semoga bisa nambah terus promo buat gofood-nya hehe.
# After:  tampilan aplikasi gojek semakin nyaman untuk dilihat menarik penggunaan aplikasi gojek hingga saat ini masih nyaman aman praktis dan suka order gofood goride lewat aplikasi gojek semoga bisa nambah terus promo buat gofood nya hehe
#
# === TEXT CLEANING ===
# Before: Sediakan versi lite nya dong. buat goride & gocar doang... Ukuran aplikasinya jangan terlalu besarlah,...
# After:  sediakan versi lite nya dong buat goride gocar doang ukuran aplikasinya jangan terlalu besarlah
#
# === TEXT CLEANING ===
# Before: Untuk hari ini pelayanan gocar sangat buruk dicancel 2x padahal sudah dekat dari jalan rumah saya dan sekalinya dapat sopirnya ga dilayanin padahal pake gocar prioritas?? buruk, sgt buruk gocar. sy sgt kecewa, pdhl sy skrg pake goride & gofood jrg ada kendala spt ini. Bener2 ga akan mau pake gocar lg.
# After:  untuk hari ini pelayanan gocar sangat buruk dicancel x padahal sudah dekat dari jalan rumah saya dan sekalinya dapat sopirnya ga dilayanin padahal pake gocar prioritas buruk sgt buruk gocar sy sgt kecewa pdhl sy skrg pake goride gofood jrg ada kendala spt ini bener ga akan mau pake gocar lg
#
# === TEXT CLEANING ===
# Before: Gofood super mahal, ongkirnya biaya layanannya sgala macem, udh gitu ga ada promo potongan apapun. Pake gojek cuma buat kebutuhan gocar goride sama tiket kereta doang.
# After:  gofood super mahal ongkirnya biaya layanannya sgala macem udh gitu ga ada promo potongan apapun pake gojek cuma buat kebutuhan gocar goride sama tiket kereta doang
#
# === TEXT CLEANING ===
# Before: pokok nya top markotop deh 👍👍
# After:  pokok nya top markotop deh
#
# === TEXT CLEANING ===
# Before: Good
# After:  good
#
# === TEXT CLEANING ===
# Before: Pengalaman menyenangkan menggunakan Gojek
# After:  pengalaman menyenangkan menggunakan gojek
#
# === TEXT CLEANING ===
# Before: Sangat membantu sekali dalam perjalanan
# After:  sangat membantu sekali dalam perjalanan
#
# === TEXT CLEANING ===
# Before: saya langganan pake gojek kalau mau pigi bekerja naik goride.. jadi menurud saya drivenya ramah2 semoga ditingkatkan lagi..
# After:  saya langganan pake gojek kalau mau pigi bekerja naik goride jadi menurud saya drivenya ramah semoga ditingkatkan lagi
#
# === TEXT CLEANING ===
# Before: Driver:bik, sopan, rapi, ramah Kendaraan: Terawat baik. Dijalan: Patuh &taat peraturan lalu lintas. Layanan panggilan: Cepat, selalu beri salam, relatif yepay waktu. Untuk Gojek 1.Beri reward bagi: 1.Driver teladan. 2.Cistomersetia/ telafan.. Thn 23 - 24 pernah mengadakan indian voucer berhadiah mobil kapan pengumannya..! Sudah atau blm...disosialisasikan Terimakasih...🙏 Customer Gojek (go ride & go car)
# After:  driver bik sopan rapi ramah kendaraan terawat baik dijalan patuh taat peraturan lalu lintas layanan panggilan cepat selalu beri salam relatif yepay waktu untuk gojek beri reward bagi driver teladan cistomersetia telafan thn pernah mengadakan indian voucer berhadiah mobil kapan pengumannya sudah atau blm disosialisasikan terimakasih customer gojek go ride go car
#
# === TEXT CLEANING ===
# Before: Ketika promoan banyak driver yang gamau ambil orderan Gocar/Goride, sudah seringkali menunggu lama seperti ini tidak ada yang ambil, padahal coba pake grab langsung dapet.
# After:  ketika promoan banyak driver yang gamau ambil orderan gocar goride sudah seringkali menunggu lama seperti ini tidak ada yang ambil padahal coba pake grab langsung dapet
#
# === TEXT CLEANING ===
# Before: Bagus
# After:  bagus
#
# === TEXT CLEANING ===
# Before: Adanya orderan goride hemat , gofood hemat dsb bikin rugi driver secara keseluruhan. Tolong dong di hapus orderan "HEMAT" nya & pake tarif normal aja .
# After:  adanya orderan goride hemat gofood hemat dsb bikin rugi driver secara keseluruhan tolong dong di hapus orderan hemat nya pake tarif normal aja
#
# === TEXT CLEANING ===
# Before: Beragam aplikasi nya,mulai dari Goride,Gocar,Go food dsb. Semoga tambah terus innovasi nya di masa yang akan datang.
# After:  beragam aplikasi nya mulai dari goride gocar go food dsb semoga tambah terus innovasi nya di masa yang akan datang
#
# === TEXT CLEANING ===
# Before: Nice
# After:  nice
#
# === TEXT CLEANING ===
# Before: Kadang Kalo Hujan Gada Driver Go-ride Yang Mau Ambil Pesanan,Padahal hujan nya udah redah,Terpaksa Harus nunggu lama
# After:  kadang kalo hujan gada driver go ride yang mau ambil pesanan padahal hujan nya udah redah terpaksa harus nunggu lama
#
# === TEXT CLEANING ===
# Before: Mau order goride,gak bisa2, stuk di map.
# After:  mau order goride gak bisa stuk di map
#
# === TEXT CLEANING ===
# Before: Tidak pernah di kasi promo setiap order gofood atau goride atau gocar.
# After:  tidak pernah di kasi promo setiap order gofood atau goride atau gocar
#
# === TEXT CLEANING ===
# Before: Dari waktu yg ditentukan selalu telat,baik goride, gofood🥲
# After:  dari waktu yg ditentukan selalu telat baik goride gofood
#
# === TEXT CLEANING ===
# Before: Mana nih kota bandung tidak ada go ride atau gocar instan. Ngak kedepan banget menjengkelkan. Mau pesen aja gak keluar drivernya padahal saya lihat sebagian lalu lalang gak mau ambil dari hemat biasa sampe comvort
# After:  mana nih kota bandung tidak ada go ride atau gocar instan ngak kedepan banget menjengkelkan mau pesen aja gak keluar drivernya padahal saya lihat sebagian lalu lalang gak mau ambil dari hemat biasa sampe comvort
#
# === TEXT CLEANING ===
# Before: Gojek keren bisa pesen sekalian 2 goride satu waktu .... makasih gojek 😘😍🥰
# After:  gojek keren bisa pesen sekalian goride satu waktu makasih gojek
#
# === TEXT CLEANING ===
# Before: enak sih goride nya, TAPI kenapa cuman hujan rintik gerimis dikit doang driver nya ga mau ambil orderan gofood, masa ga punya jas ujan sih anjir....orng laper bgt udh nunggu hampir 2 jam sampe 2x mesen dan ngechat ke ig resto nya anjir bgt dah gojek ga jelas, restonya sampe ss ada yg pesen 3 orng ga dapat driver, tolong deh ini driver nya ujan dikit doang pada males, ga usah jadi gojek anjg!!
# After:  enak sih goride nya tapi kenapa cuman hujan rintik gerimis dikit doang driver nya ga mau ambil orderan gofood masa ga punya jas ujan sih anjir orng laper bgt udh nunggu hampir jam sampe x mesen dan ngechat ke ig resto nya anjir bgt dah gojek ga jelas restonya sampe ss ada yg pesen orng ga dapat driver tolong deh ini driver nya ujan dikit doang pada males ga usah jadi gojek anjg
#
# === TEXT CLEANING ===
# Before: Tolong hapus goride instan di stasiun Tangerang, sangat menyusahkan harus jalan kaki, apalagi di jam sibuk macet harus jalan kaki lagi
# After:  tolong hapus goride instan di stasiun tangerang sangat menyusahkan harus jalan kaki apalagi di jam sibuk macet harus jalan kaki lagi
#
# === TEXT CLEANING ===
# Before: Tolong radius driver di tambah setiap pesan goride di luar jangkauan.bedakan jg itu goride hemat dg goride reguler knp waktu tunggu nya sama.
# After:  tolong radius driver di tambah setiap pesan goride di luar jangkauan bedakan jg itu goride hemat dg goride reguler knp waktu tunggu nya sama
#
# === TEXT CLEANING ===
# Before: Okeh
# After:  okeh
#
# === TEXT CLEANING ===
# Before: Goride oke lah, gofoodnya sampah bgt bakal nyari driver kalo makanan uda jadi. 1 jam lebih nunggu endingnya cancle karena gadapat driver. Keburu laper yg ada php doang.
# After:  goride oke lah gofoodnya sampah bgt bakal nyari driver kalo makanan uda jadi jam lebih nunggu endingnya cancle karena gadapat driver keburu laper yg ada php doang
#
# === TEXT CLEANING ===
# Before: Mantap
# After:  mantap
#
# === TEXT CLEANING ===
# Before: Sangat bagus
# After:  sangat bagus
#
# === TEXT CLEANING ===
# Before: Cs gak ada yg online kalo ada kendala apa² susah. GOPAYLATER dikasih limit besar tapi tiap sebulan sekali bisa 2x pengecekan (pembekuan). Semakin tarif gofood dan goride gak masuk akal, lama² jadi gak worth it. Sorry to say tapi emg bikin muak.
# After:  cs gak ada yg online kalo ada kendala apa susah gopaylater dikasih limit besar tapi tiap sebulan sekali bisa x pengecekan pembekuan semakin tarif gofood dan goride gak masuk akal lama jadi gak worth it sorry to say tapi emg bikin muak
#
# === TEXT CLEANING ===
# Before: 👍👍👍👍👍👍
# After:
#
# === TEXT CLEANING ===
# Before: Goride hemat ko jadi di bawah min susah nyari jadinya. Mending di keatasin lagi biar gamapang langsung pesan
# After:  goride hemat ko jadi di bawah min susah nyari jadinya mending di keatasin lagi biar gamapang langsung pesan
#
# === TEXT CLEANING ===
# Before: Saya Pemakai : Go Box, Go Pulsa, Go Ride, Go Send, Go Car, Go Food, Dan Go Massage Aktif.. terimakasih Gojek Semua Bermanfaat.
# After:  saya pemakai go box go pulsa go ride go send go car go food dan go massage aktif terimakasih gojek semua bermanfaat
#
# === TEXT CLEANING ===
# Before: Banyak promo Dan diskon nya
# After:  banyak promo dan diskon nya
#
# === TEXT CLEANING ===
# Before: Aplikasi banyak bug nya akhir-akhir ini, saya order goride 1x tapi yg terpanggil 2 driver dengan tujuan yg sama dari akun saya, padahal saya hanya order 1x, sering kali hanya cek aplikasi, tapi tiba-tiba terorder sendiri goridenya terutama saat saldo gopay terisi
# After:  aplikasi banyak bug nya akhir akhir ini saya order goride x tapi yg terpanggil driver dengan tujuan yg sama dari akun saya padahal saya hanya order x sering kali hanya cek aplikasi tapi tiba tiba terorder sendiri goridenya terutama saat saldo gopay terisi
#
# === TEXT CLEANING ===
# Before: Mantul
# After:  mantul
#
# === TEXT CLEANING ===
# Before: Kalau ada yang mudah kenapa di persulit, kalau ada yang dekat kenapa dikasih yang jauh, walau kadang kadang pakai gojek, sekali nya butuh eh di kasih driver nya yang jauh, jadi nunggu lama deh, bukan hanya harga yg murah nya tapi cepat & tepat nya , terimakasih
# After:  kalau ada yang mudah kenapa di persulit kalau ada yang dekat kenapa dikasih yang jauh walau kadang kadang pakai gojek sekali nya butuh eh di kasih driver nya yang jauh jadi nunggu lama deh bukan hanya harga yg murah nya tapi cepat tepat nya terimakasih
#
# === TEXT CLEANING ===
# Before: Go ride instan sangat merugikan,kalo jarak nya dekat gak ada driver mau ambil
# After:  go ride instan sangat merugikan kalo jarak nya dekat gak ada driver mau ambil
#
# === TEXT CLEANING ===
# Before: gojek harus evaluasi mitranya lagi nih. nyari driver hujan² susah bgt. padahal ordernya gocar, bukan goride. tp susah bgt dapetnya. kalo ttg aplikasinya sih, oke oke aja lah.
# After:  gojek harus evaluasi mitranya lagi nih nyari driver hujan susah bgt padahal ordernya gocar bukan goride tp susah bgt dapetnya kalo ttg aplikasinya sih oke oke aja lah
#
# === TEXT CLEANING ===
# Before: Tolong di perbaikin goride hemat nya selalu hilang terus²an padahal sebelumnya ada terus pake goride hemat sangat membantu saya karena bukan sekali atau 2 kali saya pakai tapi selalu pulang kerja sangat menghemat ongkos saya jadi tolong perbaiki
# After:  tolong di perbaikin goride hemat nya selalu hilang terus an padahal sebelumnya ada terus pake goride hemat sangat membantu saya karena bukan sekali atau kali saya pakai tapi selalu pulang kerja sangat menghemat ongkos saya jadi tolong perbaiki
#
# === TEXT CLEANING ===
# Before: Kirain kalo langganan gojek plus itu potongannya beneran 8 ribu buat goride, ternyata cuman potongan 2 ribu anjirlah
# After:  kirain kalo langganan gojek plus itu potongannya beneran ribu buat goride ternyata cuman potongan ribu anjirlah
#
# === TEXT CLEANING ===
# Before: Sangat bermanfaat
# After:  sangat bermanfaat
#
# === TEXT CLEANING ===
# Before: good driver
# After:  good driver
#
# === TEXT CLEANING ===
# Before: Sangat membantu
# After:  sangat membantu
#
# === TEXT CLEANING ===
# Before: Ok buat goride nya
# After:  ok buat goride nya
#
# === TEXT CLEANING ===
# Before: Oke sip bgus
# After:  oke sip bgus
#
# === TEXT CLEANING ===
# Before: Pesan kan gojek buat orang lain, gk sengaja pembayaran pake GO-PAY, karena gak bisa di ganti metode pembayaran nya pake cash. Karena ini saya gk bisa dapet potongan di tempat makan krna saldo GO-PAY saya kurang kepotong goride dan terpaksa harus pake cash. Aplikasi macam apa ini???
# After:  pesan kan gojek buat orang lain gk sengaja pembayaran pake go pay karena gak bisa di ganti metode pembayaran nya pake cash karena ini saya gk bisa dapet potongan di tempat makan krna saldo go pay saya kurang kepotong goride dan terpaksa harus pake cash aplikasi macam apa ini
#
# === TEXT CLEANING ===
# ...
# After:  tambah berat pesan goride aja gak bisa klik alamat tujuan giliran udah bisa malah pas dapet drivernya aplikasi ngestuck delay harus close aplikasi terus masuk lagi biar normal
#
# === TEXT CLEANING ===
# Before: Parah hari ini mntang2 abis ujan saya pesan goride gocar smpe ke blue bird gak ada yg mau trima, pd sy byar tunai dan sdang buru2
# After:  parah hari ini mntang abis ujan saya pesan goride gocar smpe ke blue bird gak ada yg mau trima pd sy byar tunai dan sdang buru
#
# === TEXT CLEANING ===
# Before: Kalo jaraknya jauh, driver banyak alasan dan cancel sepihak. Saya punya bukti chat katanya cari orderan goride,juga saya bayar 32 ribu cuman masuk ke drivernya cuman 22 ribu
# After:  kalo jaraknya jauh driver banyak alasan dan cancel sepihak saya punya bukti chat katanya cari orderan goride juga saya bayar ribu cuman masuk ke drivernya cuman ribu
#
# === TEXT CLEANING ===
# Before: Tolong kalo ada driver diajarin pelayanan yg bener. Saya pesen Goride sama driver-nya didiemin doang, posisi driver juga diem doang, udah nunggu setengah jam lebih ujung2nya malah di-cancel sama dia, kalo misalnya gk bisa ambil orderan suruh ngomong ke pelanggan, saya sebagai pelanggan mau kok yg nge cancel orderannya biar rating driver gk minus, kalo gini kan saya yg rugi, nunggu lama hujan2an, ujung2nya malah di-cancel.
# After:  tolong kalo ada driver diajarin pelayanan yg bener saya pesen goride sama driver nya didiemin doang posisi driver juga diem doang udah nunggu setengah jam lebih ujung nya malah di cancel sama dia kalo misalnya gk bisa ambil orderan suruh ngomong ke pelanggan saya sebagai pelanggan mau kok yg nge cancel orderannya biar rating driver gk minus kalo gini kan saya yg rugi nunggu lama hujan an ujung nya malah di cancel
#
# === TEXT CLEANING ===
# Before: Setiap pesan GoRide selalu di batalkan di dpn customer krn motor kecil, giliran di pesan GoRide Comfort eh malah dtng motor kecil... gimana sih!!! Sudah 3 kali GoRide dtng
# After:  setiap pesan goride selalu di batalkan di dpn customer krn motor kecil giliran di pesan goride comfort eh malah dtng motor kecil gimana sih sudah kali goride dtng
#
# === TEXT CLEANING ===
# Before: Bangsattt....ongkos gofood mahal bgt, go ride melambung tinggi, kasihan drivernya diperas sampai mati
# After:  bangsattt ongkos gofood mahal bgt go ride melambung tinggi kasihan drivernya diperas sampai mati
#
# === TEXT CLEANING ===
# Before: Bagus.baik.
# After:  bagus baik
#
# === TEXT CLEANING ===
# Before: Pertahankan pelayanan kpd pelanggan & beri penghargaan yg sebesar-besarnya kpd para rider & driver. Kurangin potongan kpd mereka. Tanpa mereka, perusahaan ga ada apa2-nya
# After:  pertahankan pelayanan kpd pelanggan beri penghargaan yg sebesar besarnya kpd para rider driver kurangin potongan kpd mereka tanpa mereka perusahaan ga ada apa nya
#
# === TEXT CLEANING ===
# Before: plis promo nya yang jelas khusus buat goride, saya tiap hari pake goride knpa ga pernah dpt promo, sedangkan temen saya slalu dpt potongan 😓 sampe2 saya beli loh buat dpt potongan :' kek gaadil gt pls
# After:  plis promo nya yang jelas khusus buat goride saya tiap hari pake goride knpa ga pernah dpt promo sedangkan temen saya slalu dpt potongan sampe saya beli loh buat dpt potongan kek gaadil gt pls
#
# === TEXT CLEANING ===
# Before: Bagus aplikasi nya membantu banget
# After:  bagus aplikasi nya membantu banget
#
# === TEXT CLEANING ===
# Before: buat kesel aja, kalo misal pesen gocar/goride pagi pagi pasti ga ada driver nya, semisal ada pun lama nya minta ampun, pokoknya kecewa deh!!
# After:  buat kesel aja kalo misal pesen gocar goride pagi pagi pasti ga ada driver nya semisal ada pun lama nya minta ampun pokoknya kecewa deh
#
# === TEXT CLEANING ===
# Before: good apk
# After:  good apk
#
# === TEXT CLEANING ===
# Before: Hati2 kalau naik goride gojek ...topi tertinggal nyangkut d helm saja ti tilep sama drivernya ...sangat kecewa seminggu gak ada kejelasan atau sudah kerjasama ...coba kalau barang berharga apa gak bahaya kalau topi saja d curi begini
# After:  hati kalau naik goride gojek topi tertinggal nyangkut d helm saja ti tilep sama drivernya sangat kecewa seminggu gak ada kejelasan atau sudah kerjasama coba kalau barang berharga apa gak bahaya kalau topi saja d curi begini
#
# === TEXT CLEANING ===
# Before: mudah...lancar
# After:  mudah lancar
#
# === TEXT CLEANING ===
# Before: gmn si udh langganan vouch go plus mlh goride nya cuma diskon 2k nyeselllll
# After:  gmn si udh langganan vouch go plus mlh goride nya cuma diskon k nyeselllll
#
# === TEXT CLEANING ===
# Before: Mohon perbaiki drivernya..masak kalau hujan gak mau narik go ride nya...sampai hampir 1 jam pesan gak di peduliin,sekali dapet langsung di cancel sama driver Gak profesional banget Tempatku gak bisa mobil masuk makanya pesennya go ride
# After:  mohon perbaiki drivernya masak kalau hujan gak mau narik go ride nya sampai hampir jam pesan gak di peduliin sekali dapet langsung di cancel sama driver gak profesional banget tempatku gak bisa mobil masuk makanya pesennya go ride
#
# === TEXT CLEANING ===
# Before: Mantab
# After:  mantab
#
# === TEXT CLEANING ===
# Before: Saya suka pakai gojek.tapi di Sukatani utk goride kenapa tidak terjangkau yaa..
# After:  saya suka pakai gojek tapi di sukatani utk goride kenapa tidak terjangkau yaa
#
# === TEXT CLEANING ===
# Before: Mantap lah pokoknya
# After:  mantap lah pokoknya
#
# === TEXT CLEANING ===
# Before: Terimaksih jaya selalu
# After:  terimaksih jaya selalu
#
# === TEXT CLEANING ===
# Before: Nyaman
# After:  nyaman
#
# === TEXT CLEANING ===
# Before: Ada yang sekongkol antara sesama driver Go-Jek, saya order goride pas driver datang langsung nanya nama dan alamat tujuan (nama saya dan tujuan saya disebut dengan benar oleh driver tersebut) namun setelah sampai driver tersebut bilang kalo dia offline (tidak pakai aplikasi) saya cek diaplikasi driver yang saya order mengirim foto bahwa dia sedang menunggu dititik jemput, sedangkan saya sudah sampai ditujuan. Dan driver yang mengantar saya meminta tarif 2x lipat dari tarif diaplikasi
# After:  ada yang sekongkol antara sesama driver go jek saya order goride pas driver datang langsung nanya nama dan alamat tujuan nama saya dan tujuan saya disebut dengan benar oleh driver tersebut namun setelah sampai driver tersebut bilang kalo dia offline tidak pakai aplikasi saya cek diaplikasi driver yang saya order mengirim foto bahwa dia sedang menunggu dititik jemput sedangkan saya sudah sampai ditujuan dan driver yang mengantar saya meminta tarif x lipat dari tarif diaplikasi
#
# === TEXT CLEANING ===
# Before: Sangat bagus
# After:  sangat bagus
#
# === TEXT CLEANING ===
# Before: Pelayanannya ramah sopan.murah
# After:  pelayanannya ramah sopan murah
#
# === TEXT CLEANING ===
# Before: Aplikasi gojek sangat membantu
# After:  aplikasi gojek sangat membantu
#
# === TEXT CLEANING ===
# Before: order goride lama kali munculnya🥱
# After:  order goride lama kali munculnya
#
# === TEXT CLEANING ===
# Before: ok bgt
# After:  ok bgt
#
# === TEXT CLEANING ===
# Before: Go ride oke , gocar nya kurang
# After:  go ride oke gocar nya kurang
#
# === TEXT CLEANING ===
# Before: Go-Ride jembot, pada sombong drivernya, jarak cuma 6km , pada gmau , di tolak, di map deket ada banyak driver nolak semua, app sampah
# After:  go ride jembot pada sombong drivernya jarak cuma km pada gmau di tolak di map deket ada banyak driver nolak semua app sampah
#
# === TEXT CLEANING ===
# Before: Dapat driver nya selalu jauh, apalagi GoRide comfort nya aduhai jauhnya juara
# After:  dapat driver nya selalu jauh apalagi goride comfort nya aduhai jauhnya juara
#
# === TEXT CLEANING ===
# Before: Kalau ada bintang setengah, udah ngasih bintang setengah. Rutenya sinting, dibikin jauh muter-muter. Kemarin goride, sekarang go bluebird. Ngasih rute yang bener dong, buang-buang waktu sama duit konsumen aja!!!!
# After:  kalau ada bintang setengah udah ngasih bintang setengah rutenya sinting dibikin jauh muter muter kemarin goride sekarang go bluebird ngasih rute yang bener dong buang buang waktu sama duit konsumen aja
#
# === TEXT CLEANING ===
# Before: Njemput cepat, sopirannya enak tenang, sopirnya sopan, ramsh, rute nya tepat langsing sampe tepat tujuan gk nanya ini itu / sampe mana ini dlsb.
# After:  njemput cepat sopirannya enak tenang sopirnya sopan ramsh rute nya tepat langsing sampe tepat tujuan gk nanya ini itu sampe mana ini dlsb
#
# === TEXT CLEANING ===
# Before: top markotop
# After:  top markotop
#
# === TEXT CLEANING ===
# Before: Sangat membantu, semoga makin banyak voucher goride dan gofood
# After:  sangat membantu semoga makin banyak voucher goride dan gofood
#
# === TEXT CLEANING ===
# Before: Knp stiap mau mesen Goride or Gocar slalu milih peta manual? Padahal udh di simpen lokasi favorit Tpi ttp aja harus nyari manual Menyusahkan
# After:  knp stiap mau mesen goride or gocar slalu milih peta manual padahal udh di simpen lokasi favorit tpi ttp aja harus nyari manual menyusahkan
#
# === TEXT CLEANING ===
# Before: mrasa ga adil, tmn2 saya uda otomatis dpt voucher promo goride tp di saya gd sm skali ishhhh, uda dimasukin kode sgala macem ttp aj hargany nromal
# After:  mrasa ga adil tmn saya uda otomatis dpt voucher promo goride tp di saya gd sm skali ishhhh uda dimasukin kode sgala macem ttp aj hargany nromal
#
# === TEXT CLEANING ===
# Before: Goridenya udah bagus, tapi gofoodnya masih bermasalah besar di driver. Saya sudah menunggu 1jam, tidak dapat driver. Makanan sudah jadi, tapi driver g dapat... Kasian restonya juga kalau makananya sudah jadi...
# After:  goridenya udah bagus tapi gofoodnya masih bermasalah besar di driver saya sudah menunggu jam tidak dapat driver makanan sudah jadi tapi driver g dapat kasian restonya juga kalau makananya sudah jadi
#
# === TEXT CLEANING ===
# Before: Kenapa skrg susah ya pesen Gojek ( Goride / Gocar sama aja ) ?, saya buka 2 aplikasi pakai indrive malah cpt bgt, bukan ada peningkatan kok jadi malah kemunduran , sori ini udate review jujur ya, kalau nggak gojek bakal ketinggalan ma yg lain
# After:  kenapa skrg susah ya pesen gojek goride gocar sama aja saya buka aplikasi pakai indrive malah cpt bgt bukan ada peningkatan kok jadi malah kemunduran sori ini udate review jujur ya kalau nggak gojek bakal ketinggalan ma yg lain
#
# === TEXT CLEANING ===
# Before: Gojek gimana sih saya mau pesan goride kok gak bisa tulisannya harus pakai metode lain metode lain terus
# After:  gojek gimana sih saya mau pesan goride kok gak bisa tulisannya harus pakai metode lain metode lain terus
#
# === TEXT CLEANING ===
# Before: senang belanja di gomart kalo pas ada promo
# After:  senang belanja di gomart kalo pas ada promo
#
# === TEXT CLEANING ===
# Before: Semangaaat pagiiiii para pejuang keluarga Sedikit cerita tentang kekecewaan saya pakai GOJEK 1. Saya pernah pesan GoRide, tp lama banget sekitar 30mnt baru dapat driver, sekali dapat driver posisi nya jauh banget. Padahal saya lihat ada sekitr 4driver yg dekat dengan saya & saya juga sempat tanya kalau rekan" driver itu belum dpt orderan. Jadi karena terlalu lama saya nunggu, saya beralihlah ke GrabBike, tidak sampai 3menit sudah dapat driver & tidak sampai 10mnt driver sudah sampai.
# After:  semangaaat pagiiiii para pejuang keluarga sedikit cerita tentang kekecewaan saya pakai gojek saya pernah pesan goride tp lama banget sekitar mnt baru dapat driver sekali dapat driver posisi nya jauh banget padahal saya lihat ada sekitr driver yg dekat dengan saya saya juga sempat tanya kalau rekan driver itu belum dpt orderan jadi karena terlalu lama saya nunggu saya beralihlah ke grabbike tidak sampai menit sudah dapat driver tidak sampai mnt driver sudah sampai
#
# === TEXT CLEANING ===
# Before: Diskon terus
# After:  diskon terus
#
# === TEXT CLEANING ===
# Before: Woi yang bener lah, masa pake goride plus titik jemputnya jadi ngaco padahal sebelumnya ga pake plus biasa biasa aja
# After:  woi yang bener lah masa pake goride plus titik jemputnya jadi ngaco padahal sebelumnya ga pake plus biasa biasa aja
#
# === TEXT CLEANING ===
# Before: mantab
# After:  mantab
#
# === TEXT CLEANING ===
# Before: Ngga ada yang mau ngambil orderan go ride aku padahal aku pake diskon 5 ribu doang :(
# After:  ngga ada yang mau ngambil orderan go ride aku padahal aku pake diskon ribu doang
#
# === TEXT CLEANING ===
# Before: Berguna Bett sumpah
# After:  berguna bett sumpah
#
# === TEXT CLEANING ===
# Before: Hallo gojek , saya pengguna gojek dari tahun 2020 dan saya sangat senang sekali dengan app tersebut karena saya sering mendapatkan voucher goride untuk menjadi agak lebih murah dari biasanya jadi terimakasih gojek atas jasa jasa mu. Thanks 😘🥰
# After:  hallo gojek saya pengguna gojek dari tahun dan saya sangat senang sekali dengan app tersebut karena saya sering mendapatkan voucher goride untuk menjadi agak lebih murah dari biasanya jadi terimakasih gojek atas jasa jasa mu thanks
#
# === TEXT CLEANING ===
# Before: I love Gojek so much tapi kenapa sekarang klu kita dapat voucher koq cuma berlaku hanya 1 hari ? Dapat voucher Go Ride nya memang lumayan, paling sedikit dapat 4 voucher ( bisa lebih), & dapat voucher Go Car juga paling sedikit 4 voucher ( bisa lebih ). Tapi masak kita mau wira-wiri sebanyak itu dalam 1 hari kan nggak mungkin ? Kecuali klu kita punya asrama anak2 yg semua di pakaikan voucher tsb ? Tlg dunk bagian IT jangan mau klu di suruh bagian marketing buatin program yg absurd begini ?
# After:  i love gojek so much tapi kenapa sekarang klu kita dapat voucher koq cuma berlaku hanya hari dapat voucher go ride nya memang lumayan paling sedikit dapat voucher bisa lebih dapat voucher go car juga paling sedikit voucher bisa lebih tapi masak kita mau wira wiri sebanyak itu dalam hari kan nggak mungkin kecuali klu kita punya asrama anak yg semua di pakaikan voucher tsb tlg dunk bagian it jangan mau klu di suruh bagian marketing buatin program yg absurd begini
#
# === TEXT CLEANING ===
# Before: Gojek melakukan blunder dengan cara customer kalau mau pesan go-ride prioritas baru dapat driver yang dekat kalau tidak prioritas dapatnya driver jauh tapi kalau mau prioritas kena biaya tambahan lagi akhirnya customer pada pindah ke aplikasi lain.yang kocak lagi driver di suspen gara gara nglewatin order padahal disini orang kantor gojek yg salah kenapa penjemputan jauh..harusnya yg buat kebijakan ini juga di suspen karena membuat castamer susah dapet driver
# After:  gojek melakukan blunder dengan cara customer kalau mau pesan go ride prioritas baru dapat driver yang dekat kalau tidak prioritas dapatnya driver jauh tapi kalau mau prioritas kena biaya tambahan lagi akhirnya customer pada pindah ke aplikasi lain yang kocak lagi driver di suspen gara gara nglewatin order padahal disini orang kantor gojek yg salah kenapa penjemputan jauh harusnya yg buat kebijakan ini juga di suspen karena membuat castamer susah dapet driver
#
# === TEXT CLEANING ===
# Before: Pelayanannya buruk sekali. Terutama kalo pas hujan, tidak ada driver car yg mau ambil, karena entah bagaimana servernya gojek melempar pesanan pas hujan itu jauh2, sehingga rata2 driver minta di cancel, padahal pas banget baru dapat. Begitu terus. Kadang yg goride juga sama. BENAR2 BURUK SEKALI PELAYANAN GOJEK SEKARANG.
# After:  pelayanannya buruk sekali terutama kalo pas hujan tidak ada driver car yg mau ambil karena entah bagaimana servernya gojek melempar pesanan pas hujan itu jauh sehingga rata driver minta di cancel padahal pas banget baru dapat begitu terus kadang yg goride juga sama benar buruk sekali pelayanan gojek sekarang
#
# === TEXT CLEANING ===
# Before: sangat membantu di saat membutuhkan
# After:  sangat membantu di saat membutuhkan
#
# Hasil setelah cleaning:
#                                               ulasan  \
# 0  Matikan Fitur Order ganda pemesanan GoRide. Se...
# 1  Tolong ya..Pleeeeease...buat CUSTOMER yg Pesen...
# 2  Saya harap di update kedepanya saat pesan go f...
#
#                                          after_clean
# 0  matikan fitur order ganda pemesanan goride seh...
# 1  tolong ya pleeeeease buat customer yg pesen gi...
# 2  saya harap di update kedepanya saat pesan go f...

# %%
 #Langkah 2: Normalisasi Slang
print("\n=== Langkah 2: Slang Normalization ===")
def normalize_slang(text):
    """Normalisasi slang words"""
    before = text
    words = text.split()
    normalized = [slang_dict.get(word, word) for word in words]
    after = ' '.join(normalized)
    print_step("Slang Normalization", before, after)
    return after

df['after_slang'] = df['after_clean'].apply(normalize_slang)
print("\nHasil setelah normalisasi slang:")
df[['after_clean', 'after_slang']].head(3)
# Out:
# === Langkah 2: Slang Normalization ===
#
# === SLANG NORMALIZATION ===
# Before: matikan fitur order ganda pemesanan goride seharusnya kalau sudah order goride tidak bisa order goride lagi sekaligus harus dibatalkan dulu baru bisa pesan lagi
# After:  matikan fitur order ganda pemesanan goride seharusnya kalau sudah order goride tidak bisa order goride lagi sekaligus harus dibatalkan dulu baru bisa pesan lagi
#
# === SLANG NORMALIZATION ===
# Before: tolong ya pleeeeease buat customer yg pesen gibride tolong itu jempol jangan dikit cansel dikit cansel kalian beratus ratus kali cansel nggak ngaruh nggak ngefek kitw yg driver yg kena ampas nanti ama aplikator emang kalian bayar tarif nya super mahal tapi kita dibpitong gede super gede potongannya tolong kasihani kami ya driver ojol
# After:  tolong iya pleeeeease buat customer yang pesan gibride tolong itu jempol jangan dikit cansel dikit cansel kalian beratus ratus kali cansel tidak berpengaruh tidak ngefek kitw yang driver yang kena ampas nanti sama aplikator memang kalian bayar tarif nya super mahal tapi kita dibpitong gede super gede potongannya tolong kasihani kami iya driver ojol
#
# === SLANG NORMALIZATION ===
# Before: saya harap di update kedepanya saat pesan go food muncul notifikasi jangan go ride aja yang muncul
# After:  saya harap di update kedepanya saat pesan go food muncul notifikasi jangan go ride saja yang muncul
#
# === SLANG NORMALIZATION ===
# Before: buatku yg tinggal agak jauh dr kota ini aplikasi yg paling cpat utk kita dpat driver mau pesan goride ataupun pesan gofood nunggu gk pake lama kendaraan driver nya jg oke dan drivernya sopan sukses selalu gojek
# After:  buatku yang tinggal agak jauh dari kota ini aplikasi yang paling cpat untuk kita dpat driver mau pesan goride ataupun pesan gofood menunggu tidak pakai lama kendaraan driver nya juga oke dan drivernya sopan sukses selalu gojek
#
# === SLANG NORMALIZATION ===
# Before: layanan goride sangat membantu untuk aktifitas sehari di saat motor sedang perbaikan di bengkel masukan nya mgkin cuman kalo cuaca sedang hujan dlm situasi urgent butuh transport masih sering lama dpt driver nya
# After:  layanan goride sangat membantu untuk aktifitas sehari di saat motor sedang perbaikan di bengkel masukan nya mgkin Cuma kalau cuaca sedang hujan dalam situasi urgent butuh transport masih sering lama dapat driver nya
#
# === SLANG NORMALIZATION ===
# Before: ini gojek kenapa ya sekarang saya pakai akun baru biasanya suka ada voucher tapi voucher goride sekarang tidak ada tapi giliran saya beralih ke gocar ada voucher tapi pas giliran saya buka voucher ternyata tidak ada voucher apakah bug tolong di perbaiki lahi
# After:  ini gojek kenapa iya sekarang saya pakai akun baru biasanya suka ada voucher tapi voucher goride sekarang tidak ada tapi giliran saya beralih ke gocar ada voucher tapi pas giliran saya buka voucher ternyata tidak ada voucher apakah bug tolong di perbaiki lahi
#
# === SLANG NORMALIZATION ===
# Before: kalau terima rider seleksi dulu lah setiap naik gojek rider nya emosian mulu
# After:  kalau terima rider seleksi dulu lah setiap naik gojek rider nya emosian melulu
#
# === SLANG NORMALIZATION ===
# Before: gojek sekarang mahal meskipun pakai voucher perjalanan km biasanya dg harga pake voucher go ride aja pot rb sekarang jadi alhasil beralih ke ojol sebelah
# After:  gojek sekarang mahal meskipun pakai voucher perjalanan kamu biasanya dengan harga pakai voucher go ride saja pot rb sekarang jadi alhasil beralih ke ojol sebelah
#
# === SLANG NORMALIZATION ===
# Before: cepat dan murah
# After:  cepat dan murah
#
# === SLANG NORMALIZATION ===
# Before: keren dah murah
# After:  keren sudah murah
#
# === SLANG NORMALIZATION ===
# Before: drivernya banyak alesan bilang ga bawa helm trs ngapain ambil pesenan goride saya pas sy minta cancel aja dari dianya gamau dianya mo ambil helm dulu knapa ga mau cancel takut poinnya turun klo gitu ngapain ambil pesenan saya mana ngajak ribut lagi kurang ajar
# After:  drivernya banyak alesan bilang tidak bawa helm terus sedang apa ambil pesanan goride saya pas saya minta batal saja dari dianya tidak mau dianya mau ambil helm dulu knapa tidak mau batal takut poinnya turun kalau begitu sedang apa ambil pesanan saya mana ngajak ribut lagi kurang ajar
#
# === SLANG NORMALIZATION ===
# Before: rmh beda hp ee pesen go ride dng ttik dan tujuan sama knp nominal beda sya kena k pake hp ponakan k tunai jg blm gofood klu py sy mehongggg knp bs begitu rmh lho pdhl sy setia memakai gojeck utk order makanan
# After:  rumah beda hp ee pesan go ride dng ttik dan tujuan sama kenapa nominal beda sya kena ke pakai hp ponakan ke tunai juga belum gofood klu py saya mehongggg kenapa bisa begitu rumah lho padahal saya setia memakai gojeck untuk order makanan
#
# === SLANG NORMALIZATION ===
# Before: drivernya mengemudikan kendaraan dengan aman dan nyaman terimakasih
# After:  drivernya mengemudikan kendaraan dengan aman dan nyaman terimakasih
#
# === SLANG NORMALIZATION ===
# Before: ok
# After:  ok
#
# === SLANG NORMALIZATION ===
# Before: senang
# After:  senang
#
# === SLANG NORMALIZATION ===
# Before: aplikasinya sih masih bagus tapi baru hari ini januari pesen gocar hampir kali goride kali ga ada yang nyantol server sibuk padahal cuaca cuma gerimis kecil di pusat kota purwokerto payah sekali ini ga siap kalau di butuhkan
# After:  aplikasinya sih masih bagus tapi baru hari ini januari pesan gocar hampir kali goride kali tidak ada yang nyantol server sibuk padahal cuaca cuma gerimis kecil di pusat kota purwokerto susah sekali ini tidak siap kalau di butuhkan
#
# === SLANG NORMALIZATION ===
# Before: gila order goride nunggu l banget ga dspet driver juga padahal di depan ada driver yang lagi nongkrong malem balik kerja capek makasih gojek ga langganan aagi gue
# After:  gila order goride menunggu l banget tidak dspet driver juga padahal di depan ada driver yang lagi kumpul-kumpul malam balik kerja capek terima kasih gojek tidak langganan aagi saya
#
# === SLANG NORMALIZATION ===
# Before: baik
# After:  baik
#
# === SLANG NORMALIZATION ===
# Before: selalu dapat driver jauh kalau pesen goride mau buru mau kerja bisa dipecat krn kelamaan apalagi kalo pesen gosend bisa menit jaraknya bisa kilo ga kasihan sama drivernya apa
# After:  selalu dapat driver jauh kalau pesan goride mau buru mau kerja bisa dipecat karena kelamaan apalagi kalau pesan gosend bisa menit jaraknya bisa kilo tidak kasihan sama drivernya apa
#
# === SLANG NORMALIZATION ===
# Before: the best apps for ride
# After:  the best apps for ride
#
# === SLANG NORMALIZATION ===
# Before: alhamdulillah kalo pas pake goride supirnya bagus dan sopan
# After:  alhamdulillah kalau pas pakai goride supirnya bagus dan sopan
#
# === SLANG NORMALIZATION ===
# Before: mantap
# After:  mantap
#
# === SLANG NORMALIZATION ===
# Before: kenapa saya isi gopay tidak bisa pesen goride juga bisa tlg bantuannya terima kasih
# After:  kenapa saya isi gopay tidak bisa pesan goride juga bisa tlg bantuannya terima kasih
#
# === SLANG NORMALIZATION ===
# Before: sangat membantu dlm beraktifitas semoga sering sering kasih diskon goridenya
# After:  sangat membantu dalam beraktifitas semoga sering sering kasih diskon goridenya
#
# === SLANG NORMALIZATION ===
# Before: apa apaan ini gojek sama nunggu goride sampe satu jamm kacau ah terus aja ditampung keluhannya ehh ga ada perbaikan juga sekarang lebih parah nunggu hampir menit padahal didepan saya ada drivernya dan ga diambil tolong jangan seperti ini saya juga punya keperluan lainnya
# After:  apa apa ini gojek sama menunggu goride sampai satu jamm kacau ah terus saja ditampung keluhannya ehh tidak ada perbaikan juga sekarang lebih parah menunggu hampir menit padahal didepan saya ada drivernya dan tidak diambil tolong jangan seperti ini saya juga punya keperluan lainnya
#
# === SLANG NORMALIZATION ===
# Before: ramah terpercaya
# After:  ramah terpercaya
#
# === SLANG NORMALIZATION ===
# Before: boleh lah cuman kadang klo go ride lama bgt
# After:  boleh lah Cuma kadang kalau go ride lama banget
#
# === SLANG NORMALIZATION ===
# Before: bagus
# After:  bagus
#
# === SLANG NORMALIZATION ===
# Before: udah up ke gopay plus saya pikir bakal dapet voucher goride biar murah taunya gabisa dipakai gimana ini
# After:  sudah up ke gopay plus saya pikir bakal dapat voucher goride biar murah taunya tidak bisa dipakai bagaimana ini
#
# === SLANG NORMALIZATION ===
# Before: mantaf
# After:  mantaf
#
# === SLANG NORMALIZATION ===
# Before: kayaknya gak usah pake gocar goride layanan hemat dech klo emng gak bisa digunakan tiap x dipake bnyk bener alasan driver
# After:  kayaknya tidak perlu pakai gocar goride layanan hemat deh kalau memang tidak bisa digunakan tiap x dipake banyak benar alasan driver
#
# === SLANG NORMALIZATION ===
# Before: makasih gojek udah ada fitur pohon bisa menanam dengan seribu rupiah fitur sangat berguna untuk berbagi oksigen
# After:  terima kasih gojek sudah ada fitur pohon bisa menanam dengan seribu rupiah fitur sangat berguna untuk berbagi oksigen
#
# === SLANG NORMALIZATION ===
# Before: bagus baik
# After:  bagus baik
#
# === SLANG NORMALIZATION ===
# Before: sangat membantu
# After:  sangat membantu
#
# === SLANG NORMALIZATION ===
# Before: drivernya ramah
# After:  drivernya ramah
#
# === SLANG NORMALIZATION ===
# Before: bagus pelayanan
# After:  bagus layanan
#
# === SLANG NORMALIZATION ===
# Before: gojek selalu memuaskan sy baik go ride maupun go car nya selalu the best
# After:  gojek selalu puas saya baik go ride maupun go car nya selalu the best
#
# === SLANG NORMALIZATION ===
# Before: pelanggan setia goride gocar gofood
# After:  pelanggan setia goride gocar gofood
#
# === SLANG NORMALIZATION ===
# Before: bagus tp sy pernah pesan goride malah driver nya salah ambil penumpang sdh sy chat ke driver ga di respon
# After:  bagus tapi saya pernah pesan goride bahkan driver nya salah ambil penumpang sudah saya chat ke driver tidak di respon
#
# === SLANG NORMALIZATION ===
# Before: maaf ini kenapa pasar polis goride bisa motong di akun customer saya sebelumnya ga pernah kaya gini harusnya pasar polis ga punya akses motong saldo akun customer baru kali ini ada potongan pasar polis goride di akun customer
# After:  maaf ini kenapa pasar polis goride bisa motong di akun customer saya sebelumnya tidak pernah kaya begini harusnya pasar polis tidak punya akses motong saldo akun customer baru kali ini ada potongan pasar polis goride di akun customer
#
# === SLANG NORMALIZATION ===
# Before: aplikasi makin tolol pesan goride yg muncul dan datang gocar
# After:  aplikasi makin tolol pesan goride yang muncul dan datang gocar
#
# === SLANG NORMALIZATION ===
# Before: nunggu sampe sejam goride tapi tulisannya sibuk terus ini emg beneran pd sibuk gojek ny atau emg aplikasi nya lagi error
# After:  menunggu sampai sejam goride tapi tulisannya sibuk terus ini memang beneran pada sibuk gojek ny atau memang aplikasi nya lagi error
#
# === SLANG NORMALIZATION ===
# Before: untuk saat ini saya hanya pakai gofood saja dan jarang menggunakan goride gocar karena masih trauma dengan cara mereka mengendarai kendaraan dan sempat membuat saya celaka masukan saja lebih banyak promo gofood dan voucher gratis ongkir potongan ongkir seperti driver oren
# After:  untuk saat ini saya hanya pakai gofood saja dan jarang menggunakan goride gocar karena masih trauma dengan cara mereka mengendarai kendaraan dan sempat membuat saya celaka masukan saja lebih banyak promo gofood dan voucher gratis ongkos kirim potongan ongkos kirim seperti driver oren
#
# === SLANG NORMALIZATION ===
# Before: top markotop
# After:  top markotop
#
# === SLANG NORMALIZATION ===
# Before: selalu tepat waktu penjemputan banyak promo dan lebih hemat
# After:  selalu tepat waktu penjemputan banyak promo dan lebih hemat
#
# === SLANG NORMALIZATION ===
# Before: dapet driver goride nya lama padahal di kota depok mau berangkat kerja jadi telat ngga kaya aplikasi sebelah dapat drivernya cepat sekalinya dapet jauh driver jemputnya
# After:  dapat driver goride nya lama padahal di kota depok mau berangkat kerja jadi terlambat tidak kaya aplikasi sebelah dapat drivernya cepat sekalinya dapat jauh driver jemputnya
#
# === SLANG NORMALIZATION ===
# Before: semakin lama semakin gk guna nih aplikasi saya pesen goride di gambar banyak skali driver terdekat eh nyantol nya di jepang saking jauhnya mana skrg ongkir nya mahal banget maaf untuk kali saya pindah ke apk sebelah gk ribet
# After:  semakin lama semakin tidak guna ini aplikasi saya pesan goride di gambar banyak sekali driver terdekat eh nyantol nya di jepang saking jauhnya mana sekarang ongkos kirim nya mahal banget maaf untuk kali saya pindah ke apk sebelah tidak ribet
#
# === SLANG NORMALIZATION ===
# Before: mengecewakan setiap mau order gocar pas lgi hujan para driver susah untuk menerima pesanan apalagi pakai promo terutama yg buat goride alasan bnyk orderan lagi rame
# After:  mengecewakan setiap mau order gocar pas lagi hujan para driver susah untuk menerima pesanan apalagi pakai promo terutama yang buat goride alasan banyak orderan lagi ramai
#
# === SLANG NORMALIZATION ===
# Before: aplikasi bodoh tidak ada yang mau ambil goride driver bodoh
# After:  aplikasi bodoh tidak ada yang mau ambil goride driver bodoh
#
# === SLANG NORMALIZATION ===
# Before: gojek sekarang makin buruk mencari driver ny tidak dapat dapat padahl saya tidak membatalkan pesanan dan saya menunggu menit dan saya order lagi namun hasilnya sama saja tambah banyak bug saya ingin memesan makanan atau goride
# After:  gojek sekarang makin buruk mencari driver ny tidak dapat dapat padahl saya tidak membatalkan pesanan dan saya menunggu menit dan saya order lagi namun hasilnya sama saja tambah banyak bug saya ingin pesan makanan atau goride
#
# === SLANG NORMALIZATION ===
# Before: mantap dah pokoknya mah
# After:  mantap sudah pokoknya mah
#
# === SLANG NORMALIZATION ===
# Before: untuk goride dan gocar cukup lumayan voucernya tapi gofood nya saya jarang pake karna ada aplikasi lain jauh lebih murah
# After:  untuk goride dan gocar cukup lumayan voucernya tapi gofood nya saya jarang pakai karena ada aplikasi lain jauh lebih murah
#
# === SLANG NORMALIZATION ===
# Before: mudah di gunakan
# After:  mudah di gunakan
#
# === SLANG NORMALIZATION ===
# Before: nice
# After:  nice
#
# === SLANG NORMALIZATION ===
# Before: aplikasi tolol kalau persen goride di kasih driver yang jauh sekeliling banyak di ambilin dari korea utara perkiraan menit ditunggu menit gak sampai update lokasi driver juga gak jelas
# After:  aplikasi tolol kalau persen goride di kasih driver yang jauh sekeliling banyak di ambilkan dari korea utara perkiraan menit ditunggu menit tidak sampai update lokasi driver juga tidak jelas
#
# === SLANG NORMALIZATION ===
# Before: i love gojek sm setiap hari berangkat pulang sekolah always make gojek apalagi di gojek fitur goride comfort cocok banget buat aku yang suka bawa barang banyak kesekolah suka bawa tas gede gitu deh kaki nya dan pnttnya juga jadi ga pegel jaya terus deh yaa gojek
# After:  i love gojek sm setiap hari berangkat pulang sekolah always make gojek apalagi di gojek fitur goride comfort cocok banget buat aku yang suka bawa barang banyak kesekolah suka bawa tas gede begitu deh kaki nya dan pnttnya juga jadi tidak pegel jaya terus deh yaa gojek
#
# === SLANG NORMALIZATION ===
# Before: kenapa saat saya ingin menggunakan go ride dia berubah go car kan jadi mahal ongkosnya
# After:  kenapa saat saya ingin menggunakan go ride dia berubah go car kan jadi mahal ongkosnya
#
# === SLANG NORMALIZATION ===
# Before: good
# After:  good
#
# === SLANG NORMALIZATION ===
# Before: apa apaan go transit skrng digabung sama go ridetransit jadinya ga bisa edit stasiun kalo tujuannya berubah padahal sblum update bisa kalo diupdate makin nyusahin mending gausah di update tujuannya update kan untuk memudahkan bukan malah mempersulit
# After:  apa apa go transit sekarang digabung sama go ridetransit jadinya tidak bisa edit stasiun kalau tujuannya berubah padahal sblum update bisa kalau diupdate makin nyusahin lebih baik gausah di update tujuannya update kan untuk memudahkan bukan bahkan mempersulit
#
# === SLANG NORMALIZATION ===
# Before: pelayanan nya lebih baik daripada aplikasi sebelah pilihannya juga banyak
# After:  layanan nya lebih baik daripada aplikasi sebelah pilihannya juga banyak
#
# === SLANG NORMALIZATION ===
# Before: mantap
# After:  mantap
#
# === SLANG NORMALIZATION ===
# Before: padahal pakai aplikasi ini udah lama tiba hari ini bingung pas check goride harganya dari rb naik jadi rb eh iseng buka grab cuman bayar rb
# After:  padahal pakai aplikasi ini sudah lama tiba hari ini bingung pas check goride harganya dari rb naik jadi rb eh iseng buka grab Cuma bayar rb
#
# === SLANG NORMALIZATION ===
# Before: susah dpt driver udah x pesen tetep gk dpt pindah dari menu go ride ke go car cmn hasilny nihil sama aja parah sih
# After:  susah dapat driver sudah x pesan tetep tidak dapat pindah dari menu go ride ke go car cmn hasilny nihil sama saja parah sih
#
# === SLANG NORMALIZATION ===
# Before: saya suka pake jasa goride gocar seneng aja denger curhatan mereka cerita mereka keluh kesah mereka cerita sedih cerita bahagia semuanya saya rangkum jadi motivasi buat diri sendiri
# After:  saya suka pakai jasa goride gocar seneng saja denger curhatan mereka cerita mereka keluh kesah mereka cerita sedih cerita bahagia semuanya saya rangkum jadi motivasi buat diri sendiri
#
# === SLANG NORMALIZATION ===
# Before: ok
# After:  ok
#
# === SLANG NORMALIZATION ===
# Before: mau milih go transit tapi selalu dialihkan ke go ride
# After:  mau milih go transit tapi selalu dialihkan ke go ride
#
# === SLANG NORMALIZATION ===
# Before: i got safety when i was ride gojek
# After:  i got safety when i was ride gojek
#
# === SLANG NORMALIZATION ===
# Before: untuk goride lebih mudah dulu
# After:  untuk goride lebih mudah dulu
#
# === SLANG NORMALIZATION ===
# Before: kenapa aku masukin kode promo goride udah sukses tpi vocer promonya gada aku udah cba update masin tetap sma udah hpus download bbrapa kli tapi tetap sama kenapa ya apakah eror tpi cba punya temen mah gada masalah apa
# After:  kenapa aku masukkan kode promo goride sudah sukses tapi vocer promonya gada aku sudah cba update masin tetap sma sudah hpus download bbrapa kli tapi tetap sama kenapa iya apakah eror tapi cba punya teman mah gada masalah apa
#
# === SLANG NORMALIZATION ===
# Before: pesen goride posisi driver deket ga mau pada ngambil di kasihnya yang jaraknya jauh semuanya sbagian di cancel sama drivernya
# After:  pesan goride posisi driver dekat tidak mau pada mengambil di kasihnya yang jaraknya jauh semuanya sbagian di batal sama drivernya
#
# === SLANG NORMALIZATION ===
# Before: mohon pihak gojek memberikan saya pembelaan karena saya selalu pulang dengan goride tetapi tadi saya mendapat perlakuan yang sangat tidak menyenangkan karena saat saya membantalkan pesanan karena titik jemput tidak sesuai saya tetap didatangi driver tersebut dan driver tersebut marah bahkan sampai orang melihat saya disitu saya sangat malu karena hal tersebut mohon bantuannya untuk menegur mengingat kan driver tersebut
# After:  mohon pihak gojek memberikan saya pembelaan karena saya selalu pulang dengan goride tetapi tadi saya mendapat perlakuan yang sangat tidak menyenangkan karena saat saya membantalkan pesanan karena titik jemput tidak sesuai saya tetap didatangi driver tersebut dan driver tersebut marah bahkan sampai orang melihat saya disitu saya sangat malu karena hal tersebut mohon bantuannya untuk menegur mengingat kan driver tersebut
#
# === SLANG NORMALIZATION ===
# Before: layanan yg memudahkan masyarakat
# After:  layanan yang memudahkan masyarakat
#
# === SLANG NORMALIZATION ===
# Before: tolong untuk goride tidak perlu di pisah antara yang hemat sama yang comfort karena percuma jika tidak ada perhatian dari pihak gojeknya pengalaman saya pesan comfort tapi motor yang datang beda plat nomor beda jenisnya masuk kategori hemat tolong lebih diperhatikan lagi khusus driver goride nya karena keselamatan diatas segalanya
# After:  tolong untuk goride tidak perlu di pisah antara yang hemat sama yang comfort karena percuma jika tidak ada perhatian dari pihak gojeknya pengalaman saya pesan comfort tapi motor yang datang beda plat nomor beda jenisnya masuk kategori hemat tolong lebih diperhatikan lagi khusus driver goride nya karena keselamatan diatas segalanya
#
# === SLANG NORMALIZATION ===
# Before: ok
# After:  ok
#
# === SLANG NORMALIZATION ===
# Before: sangat membantu bagi saya dari goride gocar gofood
# After:  sangat membantu bagi saya dari goride gocar gofood
#
# === SLANG NORMALIZATION ===
# Before: gofood nya mengecewakan sekali udah nunggu sampe jam malah dibatalin dengan alasan gada driver klw emg ga niat bisnis mending tutup aja aplikasinya bukan hanya itu aja pesan goride dll juga selalu drivernya gada padahal jelas jelas banyak driver disekitar lokasi makin hari makin ga banget ni aplikasi
# After:  gofood nya mengecewakan sekali sudah menunggu sampai jam bahkan dibatalin dengan alasan gada driver kalau memang tidak niat bisnis lebih baik tutup saja aplikasinya bukan hanya itu saja pesan goride dan lain-lain juga selalu drivernya gada padahal jelas jelas banyak driver disekitar lokasi makin hari makin tidak banget ini aplikasi
#
# === SLANG NORMALIZATION ===
# Before: tidak pernah dapat voucher goride jompor saya setiap hari pake goride pp rb gaperna dpt voucher goride
# After:  tidak pernah dapat voucher goride jompor saya setiap hari pakai goride pulang pergi rb gaperna dapat voucher goride
#
# === SLANG NORMALIZATION ===
# Before: verygood
# After:  verygood
#
# === SLANG NORMALIZATION ===
# Before: tiap transaksi di gojek toped blibli alfagift kenapa selalu gopaylaternya ditulis diblokir limit aman tagihan blm japo masa cuma bisa dipakai buat goride gocar doang gimana nih
# After:  tiap transaksi di gojek toped blibli alfagift kenapa selalu gopaylaternya ditulis diblokir limit aman tagihan belum japo masa cuma bisa dipakai buat goride gocar saja bagaimana ini
#
# === SLANG NORMALIZATION ===
# Before: sudah order goride lama nunggu dapat drivernya sudah gitu susah di batalin jauh sama aplikasi tetangga
# After:  sudah order goride lama menunggu dapat drivernya sudah begitu susah di batalin jauh sama aplikasi tetangga
#
# === SLANG NORMALIZATION ===
# Before: mau bayar tagihan gopay later tp aplikasi gangguan melulu mo order goride gocar juga sring gk ada driver tulisannya pdhl driver nya bnyak trlihat diaplikasi gojek mkin buruk skrg aplikasinya kyknya uda gk tau diperbaiki dg cepet
# After:  mau bayar tagihan gopay later tapi aplikasi gangguan terus mau order goride gocar juga sring tidak ada driver tulisannya padahal driver nya bnyak trlihat diaplikasi gojek mkin buruk sekarang aplikasinya kyknya sudah tidak tahu diperbaiki dengan cepat
#
# === SLANG NORMALIZATION ===
# Before: udah sering pake gojek mesen makan atau pun goride tetep aja sampai detik ini ga di buka gopaylater atau gopinjam nya masa kalah sama yg baru daftar dan order cuma beberapa doang langsung bisa dapet limit gopaylater anehh banget lumayan kecewa si sama aplikasi ini merasa ga adil
# After:  sudah sering pakai gojek mesen makan atau pun goride tetep saja sampai detik ini tidak di buka gopaylater atau gopinjam nya masa kalah sama yang baru daftar dan order cuma beberapa saja langsung bisa dapat limit gopaylater anehh banget lumayan kecewa si sama aplikasi ini merasa tidak adil
#
# === SLANG NORMALIZATION ===
# Before: saya pelanggan goride dan gosend ga ada masalah cuma saya kecewa sama go car di jogja kok rata ga niat ya padahal kan yg milih acak dr aplikasi juga masa cuma karena jauh dikit minta dicancel padahal cm km jemputnya jarak yg dianter pun jg ga jauh amat masih km semoga pihak gojek bisa menyortir lagi driver gocar yang cuma iseng males an wkwk kacau
# After:  saya pelanggan goride dan gosend tidak ada masalah cuma saya kecewa sama go car di jogja kenapa rata tidak niat iya padahal kan yang milih acak dari aplikasi juga masa cuma karena jauh dikit minta dicancel padahal cm kamu jemputnya jarak yang dianter pun juga tidak jauh amat masih kamu semoga pihak gojek bisa menyortir lagi driver gocar yang cuma iseng males an tertawa kacau
#
# === SLANG NORMALIZATION ===
# Before: tolong kalau kita sedang pesan goride gocar cari driver yg lokasinya dekat dengan titik penjemputan sering bgt dapet driver yg jaraknya jauh padahal driver yg mangkal di sekitar lokasi penjemputan banyak bangett tolong di perbaiki lgi jangan buang waktu kami hanya untuk nunggu driver yg datengnya lama karena jaraknya jauh
# After:  tolong kalau kita sedang pesan goride gocar cari driver yang lokasinya dekat dengan titik penjemputan sering banget dapat driver yang jaraknya jauh padahal driver yang mangkal di sekitar lokasi penjemputan banyak bangett tolong di perbaiki lagi jangan buang waktu kami hanya untuk menunggu driver yang datengnya lama karena jaraknya jauh
#
# === SLANG NORMALIZATION ===
# Before: apa aja ada mulai car ride dan food keren
# After:  apa saja ada mulai car ride dan food keren
#
# === SLANG NORMALIZATION ===
# Before: ga suka sama gojek skrg kadang pakai go ride hemat ga diterima sama driver padahal meringankan pengeluaran klo lagi tgl tua udh gitu klo pagi susahnya minta ampun sekalinya dapet cuma jarak menit dia bilang kejauhan saya males pernah juga saya lebih dekat ke lokasi tujuan situ jadi klo saya jemput bulak balik dong
# After:  tidak suka sama gojek sekarang kadang pakai go ride hemat tidak diterima sama driver padahal meringankan pengeluaran kalau lagi tanggal tua sudah begitu kalau pagi susahnya minta ampun sekalinya dapat cuma jarak menit dia bilang kejauhan saya males pernah juga saya lebih dekat ke lokasi tujuan situ jadi kalau saya jemput bulak balik dong
#
# === SLANG NORMALIZATION ===
# Before: saya kecewa dengan driver goride setiap hujan pasti tidak ada yang mengambil orderan alasan tidak bawa jas hujan padahal saya sudah chat kalo saya bawa jas hujan buat apa ngojek kalo tidak sedia jas hujan untuk diri sendiri
# After:  saya kecewa dengan driver goride setiap hujan pasti tidak ada yang mengambil orderan alasan tidak bawa jas hujan padahal saya sudah chat kalau saya bawa jas hujan buat apa ngojek kalau tidak sedia jas hujan untuk diri sendiri
#
# === SLANG NORMALIZATION ===
# Before: sekarang udah mahal goride dan gofood
# After:  sekarang sudah mahal goride dan gofood
#
# === SLANG NORMALIZATION ===
# Before: gampang klo mau cari alamat enak
# After:  gampang kalau mau cari alamat enak
#
# === SLANG NORMALIZATION ===
# Before: fitur go pay later go pay pinjam ga bisa di non aktifkan lama kaya aplikasi pinjol rawan penyalahgunaan ridernya seneng bgt batalin sendiri udah nunggu lama ga kaya sebelah
# After:  fitur go pay later go pay pinjam tidak bisa di non aktifkan lama kaya aplikasi pinjol rawan penyalahgunaan ridernya seneng banget batalin sendiri sudah menunggu lama tidak kaya sebelah
#
# === SLANG NORMALIZATION ===
# Before: tahun mengunakan gojek perlu di benahi driver berbeda dengan aplikasi apakah boleh orang yang bukan driver memakai akun driver gojek joki mengantarkan pesanan takut makanan saya di apa apin dengan orang yang bukan driver gojek joki mana lagi motor yang di pakai joki plat nya berbeda dengan aplikasi pesan goride juga gitu sih driver yang jemput orangnya berbeda dengan aplikasi plat no motor nya juga berbeda saya jadi was was takut tolong adakan vermuk berwaktu seperti grab
# After:  tahun mengunakan gojek perlu di benahi driver berbeda dengan aplikasi apakah boleh orang yang bukan driver memakai akun driver gojek joki mengantarkan pesanan takut makanan saya di apa apin dengan orang yang bukan driver gojek joki mana lagi motor yang di pakai joki plat nya berbeda dengan aplikasi pesan goride juga begitu sih driver yang jemput orangnya berbeda dengan aplikasi plat nomor motor nya juga berbeda saya jadi was was takut tolong adakan vermuk berwaktu seperti grab
#
# === SLANG NORMALIZATION ===
# Before: gimana ini waktu mau order goride kendala kok bisa ada keterangan internetnya mati padhal kuota banyak melimpahh coba cek gojek di adek bisa buat mesen padahal punyaku biasane pakek juga baik saja tolong segera diperbaiki
# After:  bagaimana ini waktu mau order goride kendala kenapa bisa ada keterangan internetnya mati padhal kuota banyak melimpahh coba cek gojek di adek bisa buat mesen padahal punyaku biasane pakai juga baik saja tolong segera diperbaiki
#
# === SLANG NORMALIZATION ===
# Before: woi harga goride nya kok nambah dari hari ke hari tempat nya sama aja kok masa gara gara cuaca panas atau hujan jadi naik kalo hujan ok lah tapi ga ngotak juga kalo kali njir oh kualitas nya yang bikin nambah perasaan sama aja deh mau hemat atau comfort hoki an aja liat maxim iya murah no diskon ga menarik tapi segitu aja terus
# After:  woi harga goride nya kenapa nambah dari hari ke hari tempat nya sama saja kenapa masa gara gara cuaca panas atau hujan jadi naik kalau hujan ok lah tapi tidak ngotak juga kalau kali njir oh kualitas nya yang bikin nambah perasaan sama saja deh mau hemat atau comfort hoki an saja lihat maxim iya murah nomor diskon tidak menarik tapi segitu saja terus
#
# === SLANG NORMALIZATION ===
# Before: thank you
# After:  thank you
#
# === SLANG NORMALIZATION ===
# Before: ok cepat dan tepat
# After:  ok cepat dan tepat
#
# === SLANG NORMALIZATION ===
# Before: dc nya suka ngancam
# After:  dc nya suka ngancam
#
# === SLANG NORMALIZATION ===
# Before: jasa biaya gojek nya sudah mahal di tambah lagi pesan go food atau go ride dll kena double order sebagai custumer merasa di rugikan rugi sudah bayar mahal dan rugi waktu menunggu jadi lama gojek makin gak jelas sekarang
# After:  jasa biaya gojek nya sudah mahal di tambah lagi pesan go food atau go ride dan lain-lain kena double order sebagai custumer merasa di rugikan rugi sudah bayar mahal dan rugi waktu menunggu jadi lama gojek makin tidak jelas sekarang
#
# === SLANG NORMALIZATION ===
# Before: terimakasih
# After:  terimakasih
#
# === SLANG NORMALIZATION ===
# Before: banyakin promonya khususnya goride and gofood
# After:  banyakin promonya khususnya goride and gofood
#
# === SLANG NORMALIZATION ===
# Before: akun saya ke blokir tolong gimana solusinya udh ngechat cs responnya sama selalu laporan ditutup solusi dong keterangannya ke blokir dan tidak bisa menggunakan berbagai voucher termasuk goride gofood tolong gimana biar normal lagi
# After:  akun saya ke blokir tolong bagaimana solusinya sudah ngechat cs responnya sama selalu laporan ditutup solusi dong keterangannya ke blokir dan tidak bisa menggunakan berbagai voucher termasuk goride gofood tolong bagaimana biar normal lagi
#
# === SLANG NORMALIZATION ===
# Before: bagus minta tolong lebih banyak promo untuk gocar sama goride comfort supaya bisa menikmati perjalanan dengan hemat dan nyaman terima kasih
# After:  bagus minta tolong lebih banyak promo untuk gocar sama goride comfort supaya bisa menikmati perjalanan dengan hemat dan nyaman terima kasih
#
# === SLANG NORMALIZATION ===
# Before: gilaaaaaaaa saldo ilang gtu aja terus call center ga ngebantu bgt masa order goride gadapet sampe kali dan saldonya ketarik nya apa in ini gojek
# After:  gilaaaaaaaa saldo hilang gtu saja terus call center tidak ngebantu banget masa order goride gadapet sampai kali dan saldonya ketarik nya apa in ini gojek
#
# === SLANG NORMALIZATION ===
# Before: kemarin siang masih bisa pesan goride pake gopaylater tp pas malam tiba tiba di gopaylater di blokir padahal tagihan belum jatuh tempo dan limit masih sangat sangat banyak sudah laporan tapi belum di tanggapi kecewa
# After:  kemarin siang masih bisa pesan goride pakai gopaylater tapi pas malam tiba tiba di gopaylater di blokir padahal tagihan belum jatuh tempo dan limit masih sangat sangat banyak sudah laporan tapi belum di tanggapi kecewa
#
# === SLANG NORMALIZATION ===
# Before: kenapa nggak bisa tukar voucher gorideaja sudah ditukar bilangnya berhasil tapi di cek di halaman voucher ngga ada sama sekali voucher nya kosongg
# After:  kenapa tidak bisa tukar voucher gorideaja sudah ditukar bilangnya berhasil tapi di cek di halaman voucher tidak ada sama sekali voucher nya kosongg
#
# === SLANG NORMALIZATION ===
# Before: sangat membantu
# After:  sangat membantu
#
# === SLANG NORMALIZATION ===
# Before: keren nih sekarang gojek dapat driver nya cepat dan cepat sampai ga nunggu lama dapat vocher diskon goride gocar gofood terus tapi saya minta tolong dong vocher goride nya ada setiap hari jadi bisa membantu anak sekolah dengan promo yang murah dibawah ribu
# After:  keren ini sekarang gojek dapat driver nya cepat dan cepat sampai tidak menunggu lama dapat vocher diskon goride gocar gofood terus tapi saya minta tolong dong vocher goride nya ada setiap hari jadi bisa membantu anak sekolah dengan promo yang murah dibawah ribu
#
# === SLANG NORMALIZATION ===
# Before: gojek pasti ada jalan
# After:  gojek pasti ada jalan
#
# === SLANG NORMALIZATION ===
# Before: kenapa map goride setiap dekat tol pasti di arahi ke lewat tol sehingga tarif tidak sesuai makasih
# After:  kenapa map goride setiap dekat tol pasti di arahi ke lewat tol sehingga tarif tidak sesuai terima kasih
#
# === SLANG NORMALIZATION ===
# Before: sy juga driver go ride min sangat disayangkan kalau orderan dibuat susah sekarang dan malah bensin x pengeluaran akhirnya saya akali beli cuman rb supaya ga rugi sejak system yg paling terdekat diterapkan sejak system goride yg sangat terdekat diterapkan otomatis pendapatan kita berkurang drastis kita sebagai costumer gojek juga tidak bisa membantu orderan seperti biasanya bahkan belanja di tokopedia semoga system update terbaru pendapatan kita kembali konsisten diatas lagi amin
# After:  saya juga driver go ride min sangat disayangkan kalau orderan dibuat susah sekarang dan bahkan bensin x pengeluaran akhirnya saya akali beli Cuma rb supaya tidak rugi sejak system yang paling terdekat diterapkan sejak system goride yang sangat terdekat diterapkan otomatis pendapatan kita berkurang drastis kita sebagai costumer gojek juga tidak bisa membantu orderan seperti biasanya bahkan belanja di tokopedia semoga system update terbaru pendapatan kita kembali konsisten diatas lagi amin
#
# === SLANG NORMALIZATION ===
# Before: kami pelajar turunkan tarif go ride kami kaum missqueen
# After:  kami pelajar turunkan tarif go ride kami kaum missqueen
#
# === SLANG NORMALIZATION ===
# Before: good
# After:  good
#
# === SLANG NORMALIZATION ===
# Before: awal memakai aplikasi gojek puas makin kesini keseringan kecewa order makanan susah dpt driver nya harus menunggu hampir satu jam begitu pun untuk goride mohon diperhatikan dan ditindaklanjuti kedepannya
# After:  awal memakai aplikasi gojek puas makin kesini keseringan kecewa order makanan susah dapat driver nya harus menunggu hampir satu jam begitu pun untuk goride mohon diperhatikan dan ditindaklanjuti kedepannya
#
# === SLANG NORMALIZATION ===
# Before: program sudah bagus pertahankan di tingkatkan lagi pelayanannya serta tolong di sejahterakan driver driver nya berikan mereka penghidupan layak
# After:  program sudah bagus pertahankan di tingkatkan lagi layanan serta tolong di sejahterakan driver driver nya berikan mereka penghidupan layak
#
# === SLANG NORMALIZATION ===
# Before: sangat membantu
# After:  sangat membantu
#
# === SLANG NORMALIZATION ===
# Before: go ride ga bisa melayani pas lagi hujan padahal gerimis doang jam order ga ada yg nyangkut berharap sm gojek nyampe kantor telat
# After:  go ride tidak bisa melayani pas lagi hujan padahal gerimis saja jam order tidak ada yang nyangkut berharap sm gojek nyampe kantor terlambat
#
# === SLANG NORMALIZATION ===
# Before: mantep
# After:  mantap
#
# === SLANG NORMALIZATION ===
# Before: mudah an semakin bnyak promonya bukan hanya gofood tapi promo gocar goride dll juga
# After:  mudah an semakin bnyak promonya bukan hanya gofood tapi promo gocar goride dan lain-lain juga
#
# === SLANG NORMALIZATION ===
# Before: niatnya mau top up gopay ke driver dengan cara order go ride pas driver datang bisa top up dan saldo masuk tapi dia kira saya mau pergi ke tempat yg saya tuju dan saya harus bayar ongkos trip tersebut rugi dong
# After:  niatnya mau top up gopay ke driver dengan cara order go ride pas driver datang bisa top up dan saldo masuk tapi dia kira saya mau pergi ke tempat yang saya tuju dan saya harus bayar ongkos trip tersebut rugi dong
#
# === SLANG NORMALIZATION ===
# Before: driver driver sekarang pada mls udh tau titik nya sesuai malah jauh banget udah gitu mau nya di samperin kan pesen ojol online agar kita praktis tapi ini gosend pun dan goride pun seperti ini emng banyak si voucher nya tapi emng gitu yaa maaf
# After:  driver driver sekarang pada malas sudah tahu titik nya sesuai bahkan jauh banget sudah begitu mau nya di samperin kan pesan ojol online agar kita praktis tapi ini gosend pun dan goride pun seperti ini memang banyak si voucher nya tapi memang begitu yaa maaf
#
# === SLANG NORMALIZATION ===
# Before: tampilan aplikasi gojek semakin nyaman untuk dilihat menarik penggunaan aplikasi gojek hingga saat ini masih nyaman aman praktis dan suka order gofood goride lewat aplikasi gojek semoga bisa nambah terus promo buat gofood nya hehe
# After:  tampilan aplikasi gojek semakin nyaman untuk dilihat menarik penggunaan aplikasi gojek hingga saat ini masih nyaman aman praktis dan suka order gofood goride lewat aplikasi gojek semoga bisa nambah terus promo buat gofood nya he
#
# === SLANG NORMALIZATION ===
# Before: sediakan versi lite nya dong buat goride gocar doang ukuran aplikasinya jangan terlalu besarlah
# After:  sediakan versi lite nya dong buat goride gocar saja ukuran aplikasinya jangan terlalu besarlah
#
# === SLANG NORMALIZATION ===
# Before: untuk hari ini pelayanan gocar sangat buruk dicancel x padahal sudah dekat dari jalan rumah saya dan sekalinya dapat sopirnya ga dilayanin padahal pake gocar prioritas buruk sgt buruk gocar sy sgt kecewa pdhl sy skrg pake goride gofood jrg ada kendala spt ini bener ga akan mau pake gocar lg
# After:  untuk hari ini layanan gocar sangat buruk dicancel x padahal sudah dekat dari jalan rumah saya dan sekalinya dapat sopirnya tidak dilayanin padahal pakai gocar prioritas buruk sangat buruk gocar saya sangat kecewa padahal saya sekarang pakai goride gofood jrg ada kendala seperti ini benar tidak akan mau pakai gocar lagi
#
# === SLANG NORMALIZATION ===
# Before: gofood super mahal ongkirnya biaya layanannya sgala macem udh gitu ga ada promo potongan apapun pake gojek cuma buat kebutuhan gocar goride sama tiket kereta doang
# After:  gofood super mahal ongkirnya biaya layanannya sgala macam sudah begitu tidak ada promo potongan apapun pakai gojek cuma buat kebutuhan gocar goride sama tiket kereta saja
#
# === SLANG NORMALIZATION ===
# Before: pokok nya top markotop deh
# After:  pokok nya top markotop deh
#
# === SLANG NORMALIZATION ===
# Before: good
# After:  good
#
# === SLANG NORMALIZATION ===
# Before: pengalaman menyenangkan menggunakan gojek
# After:  pengalaman menyenangkan menggunakan gojek
#
# === SLANG NORMALIZATION ===
# Before: sangat membantu sekali dalam perjalanan
# After:  sangat membantu sekali dalam perjalanan
#
# === SLANG NORMALIZATION ===
# Before: saya langganan pake gojek kalau mau pigi bekerja naik goride jadi menurud saya drivenya ramah semoga ditingkatkan lagi
# After:  saya langganan pakai gojek kalau mau pigi bekerja naik goride jadi menurud saya drivenya ramah semoga ditingkatkan lagi
#
# === SLANG NORMALIZATION ===
# Before: driver bik sopan rapi ramah kendaraan terawat baik dijalan patuh taat peraturan lalu lintas layanan panggilan cepat selalu beri salam relatif yepay waktu untuk gojek beri reward bagi driver teladan cistomersetia telafan thn pernah mengadakan indian voucer berhadiah mobil kapan pengumannya sudah atau blm disosialisasikan terimakasih customer gojek go ride go car
# After:  driver bik sopan rapi ramah kendaraan terawat baik dijalan patuh taat peraturan lalu lintas layanan panggilan cepat selalu beri salam relatif yepay waktu untuk gojek beri reward bagi driver teladan cistomersetia telafan tahun pernah mengadakan indian voucer berhadiah mobil kapan pengumannya sudah atau belum disosialisasikan terimakasih customer gojek go ride go car
#
# === SLANG NORMALIZATION ===
# Before: ketika promoan banyak driver yang gamau ambil orderan gocar goride sudah seringkali menunggu lama seperti ini tidak ada yang ambil padahal coba pake grab langsung dapet
# After:  ketika promoan banyak driver yang tidak mau ambil orderan gocar goride sudah seringkali menunggu lama seperti ini tidak ada yang ambil padahal coba pakai grab langsung dapat
#
# === SLANG NORMALIZATION ===
# Before: bagus
# After:  bagus
#
# === SLANG NORMALIZATION ===
# Before: adanya orderan goride hemat gofood hemat dsb bikin rugi driver secara keseluruhan tolong dong di hapus orderan hemat nya pake tarif normal aja
# After:  adanya orderan goride hemat gofood hemat dan sebagainya bikin rugi driver secara keseluruhan tolong dong di hapus orderan hemat nya pakai tarif normal saja
#
# === SLANG NORMALIZATION ===
# Before: beragam aplikasi nya mulai dari goride gocar go food dsb semoga tambah terus innovasi nya di masa yang akan datang
# After:  beragam aplikasi nya mulai dari goride gocar go food dan sebagainya semoga tambah terus innovasi nya di masa yang akan datang
#
# === SLANG NORMALIZATION ===
# Before: nice
# After:  nice
#
# === SLANG NORMALIZATION ===
# Before: kadang kalo hujan gada driver go ride yang mau ambil pesanan padahal hujan nya udah redah terpaksa harus nunggu lama
# After:  kadang kalau hujan gada driver go ride yang mau ambil pesanan padahal hujan nya sudah redah terpaksa harus menunggu lama
#
# === SLANG NORMALIZATION ===
# Before: mau order goride gak bisa stuk di map
# After:  mau order goride tidak bisa stuk di map
#
# === SLANG NORMALIZATION ===
# Before: tidak pernah di kasi promo setiap order gofood atau goride atau gocar
# After:  tidak pernah di kasi promo setiap order gofood atau goride atau gocar
#
# === SLANG NORMALIZATION ===
# Before: dari waktu yg ditentukan selalu telat baik goride gofood
# After:  dari waktu yang ditentukan selalu terlambat baik goride gofood
#
# === SLANG NORMALIZATION ===
# Before: mana nih kota bandung tidak ada go ride atau gocar instan ngak kedepan banget menjengkelkan mau pesen aja gak keluar drivernya padahal saya lihat sebagian lalu lalang gak mau ambil dari hemat biasa sampe comvort
# After:  mana ini kota bandung tidak ada go ride atau gocar instan ngak kedepan banget menjengkelkan mau pesan saja tidak keluar drivernya padahal saya lihat sebagian lalu lalang tidak mau ambil dari hemat biasa sampai comvort
#
# === SLANG NORMALIZATION ===
# Before: gojek keren bisa pesen sekalian goride satu waktu makasih gojek
# After:  gojek keren bisa pesan sekalian goride satu waktu terima kasih gojek
#
# === SLANG NORMALIZATION ===
# Before: enak sih goride nya tapi kenapa cuman hujan rintik gerimis dikit doang driver nya ga mau ambil orderan gofood masa ga punya jas ujan sih anjir orng laper bgt udh nunggu hampir jam sampe x mesen dan ngechat ke ig resto nya anjir bgt dah gojek ga jelas restonya sampe ss ada yg pesen orng ga dapat driver tolong deh ini driver nya ujan dikit doang pada males ga usah jadi gojek anjg
# After:  enak sih goride nya tapi kenapa Cuma hujan rintik gerimis dikit saja driver nya tidak mau ambil orderan gofood masa tidak punya jas ujan sih anjing orng laper banget sudah menunggu hampir jam sampai x mesen dan ngechat ke ig resto nya anjing banget sudah gojek tidak jelas restonya sampai ss ada yang pesan orng tidak dapat driver tolong deh ini driver nya ujan dikit saja pada males tidak perlu jadi gojek anjg
#
# === SLANG NORMALIZATION ===
# Before: tolong hapus goride instan di stasiun tangerang sangat menyusahkan harus jalan kaki apalagi di jam sibuk macet harus jalan kaki lagi
# After:  tolong hapus goride instan di stasiun tangerang sangat menyusahkan harus jalan kaki apalagi di jam sibuk macet harus jalan kaki lagi
#
# === SLANG NORMALIZATION ===
# Before: tolong radius driver di tambah setiap pesan goride di luar jangkauan bedakan jg itu goride hemat dg goride reguler knp waktu tunggu nya sama
# After:  tolong radius driver di tambah setiap pesan goride di luar jangkauan bedakan juga itu goride hemat dengan goride reguler kenapa waktu tunggu nya sama
#
# === SLANG NORMALIZATION ===
# Before: okeh
# After:  okeh
#
# === SLANG NORMALIZATION ===
# Before: goride oke lah gofoodnya sampah bgt bakal nyari driver kalo makanan uda jadi jam lebih nunggu endingnya cancle karena gadapat driver keburu laper yg ada php doang
# After:  goride oke lah gofoodnya sampah banget bakal mencari driver kalau makanan sudah jadi jam lebih menunggu endingnya cancle karena gadapat driver terlanjur laper yang ada php saja
#
# === SLANG NORMALIZATION ===
# Before: mantap
# After:  mantap
#
# === SLANG NORMALIZATION ===
# Before: sangat bagus
# After:  sangat bagus
#
# === SLANG NORMALIZATION ===
# Before: cs gak ada yg online kalo ada kendala apa susah gopaylater dikasih limit besar tapi tiap sebulan sekali bisa x pengecekan pembekuan semakin tarif gofood dan goride gak masuk akal lama jadi gak worth it sorry to say tapi emg bikin muak
# After:  cs tidak ada yang online kalau ada kendala apa susah gopaylater dikasih limit besar tapi tiap sebulan sekali bisa x pengecekan pembekuan semakin tarif gofood dan goride tidak masuk akal lama jadi tidak worth it maaf to sayang tapi memang bikin muak
#
# === SLANG NORMALIZATION ===
# Before:
# After:
#
# === SLANG NORMALIZATION ===
# Before: goride hemat ko jadi di bawah min susah nyari jadinya mending di keatasin lagi biar gamapang langsung pesan
# After:  goride hemat ko jadi di bawah min susah mencari jadinya lebih baik di keatasin lagi biar gamapang langsung pesan
#
# === SLANG NORMALIZATION ===
# Before: saya pemakai go box go pulsa go ride go send go car go food dan go massage aktif terimakasih gojek semua bermanfaat
# After:  saya pemakai go box go pulsa go ride go send go car go food dan go massage aktif terimakasih gojek semua bermanfaat
#
# === SLANG NORMALIZATION ===
# Before: banyak promo dan diskon nya
# After:  banyak promo dan diskon nya
#
# === SLANG NORMALIZATION ===
# Before: aplikasi banyak bug nya akhir akhir ini saya order goride x tapi yg terpanggil driver dengan tujuan yg sama dari akun saya padahal saya hanya order x sering kali hanya cek aplikasi tapi tiba tiba terorder sendiri goridenya terutama saat saldo gopay terisi
# After:  aplikasi banyak bug nya akhir akhir ini saya order goride x tapi yang terpanggil driver dengan tujuan yang sama dari akun saya padahal saya hanya order x sering kali hanya cek aplikasi tapi tiba tiba terorder sendiri goridenya terutama saat saldo gopay terisi
#
# === SLANG NORMALIZATION ===
# Before: mantul
# After:  mantul
#
# === SLANG NORMALIZATION ===
# Before: kalau ada yang mudah kenapa di persulit kalau ada yang dekat kenapa dikasih yang jauh walau kadang kadang pakai gojek sekali nya butuh eh di kasih driver nya yang jauh jadi nunggu lama deh bukan hanya harga yg murah nya tapi cepat tepat nya terimakasih
# After:  kalau ada yang mudah kenapa di persulit kalau ada yang dekat kenapa dikasih yang jauh walau kadang kadang pakai gojek sekali nya butuh eh di kasih driver nya yang jauh jadi menunggu lama deh bukan hanya harga yang murah nya tapi cepat tepat nya terimakasih
#
# === SLANG NORMALIZATION ===
# Before: go ride instan sangat merugikan kalo jarak nya dekat gak ada driver mau ambil
# After:  go ride instan sangat merugikan kalau jarak nya dekat tidak ada driver mau ambil
#
# === SLANG NORMALIZATION ===
# Before: gojek harus evaluasi mitranya lagi nih nyari driver hujan susah bgt padahal ordernya gocar bukan goride tp susah bgt dapetnya kalo ttg aplikasinya sih oke oke aja lah
# After:  gojek harus evaluasi mitranya lagi ini mencari driver hujan susah banget padahal ordernya gocar bukan goride tapi susah banget dapetnya kalau tentang aplikasinya sih oke oke saja lah
#
# === SLANG NORMALIZATION ===
# Before: tolong di perbaikin goride hemat nya selalu hilang terus an padahal sebelumnya ada terus pake goride hemat sangat membantu saya karena bukan sekali atau kali saya pakai tapi selalu pulang kerja sangat menghemat ongkos saya jadi tolong perbaiki
# After:  tolong di perbaikin goride hemat nya selalu hilang terus an padahal sebelumnya ada terus pakai goride hemat sangat membantu saya karena bukan sekali atau kali saya pakai tapi selalu pulang kerja sangat menghemat ongkos saya jadi tolong perbaiki
#
# === SLANG NORMALIZATION ===
# Before: kirain kalo langganan gojek plus itu potongannya beneran ribu buat goride ternyata cuman potongan ribu anjirlah
# After:  kirain kalau langganan gojek plus itu potongannya beneran ribu buat goride ternyata Cuma potongan ribu anjirlah
#
# === SLANG NORMALIZATION ===
# Before: sangat bermanfaat
# ...
#
# === SLANG NORMALIZATION ===
# Before: parah hari ini mntang abis ujan saya pesan goride gocar smpe ke blue bird gak ada yg mau trima pd sy byar tunai dan sdang buru
# After:  parah hari ini mntang habis ujan saya pesan goride gocar smpe ke blue bird tidak ada yang mau terima kasih pada saya bayar tunai dan sdang buru
#
# === SLANG NORMALIZATION ===
# Before: kalo jaraknya jauh driver banyak alasan dan cancel sepihak saya punya bukti chat katanya cari orderan goride juga saya bayar ribu cuman masuk ke drivernya cuman ribu
# After:  kalau jaraknya jauh driver banyak alasan dan batal sepihak saya punya bukti chat katanya cari orderan goride juga saya bayar ribu Cuma masuk ke drivernya Cuma ribu
#
# === SLANG NORMALIZATION ===
# Before: tolong kalo ada driver diajarin pelayanan yg bener saya pesen goride sama driver nya didiemin doang posisi driver juga diem doang udah nunggu setengah jam lebih ujung nya malah di cancel sama dia kalo misalnya gk bisa ambil orderan suruh ngomong ke pelanggan saya sebagai pelanggan mau kok yg nge cancel orderannya biar rating driver gk minus kalo gini kan saya yg rugi nunggu lama hujan an ujung nya malah di cancel
# After:  tolong kalau ada driver diajarin layanan yang benar saya pesan goride sama driver nya didiemin saja posisi driver juga diem saja sudah menunggu setengah jam lebih ujung nya bahkan di batal sama dia kalau misalnya tidak bisa ambil orderan suruh bicara ke pelanggan saya sebagai pelanggan mau kenapa yang nge batal orderannya biar rating driver tidak minus kalau begini kan saya yang rugi menunggu lama hujan an ujung nya bahkan di batal
#
# === SLANG NORMALIZATION ===
# Before: setiap pesan goride selalu di batalkan di dpn customer krn motor kecil giliran di pesan goride comfort eh malah dtng motor kecil gimana sih sudah kali goride dtng
# After:  setiap pesan goride selalu di batalkan di dpn customer karena motor kecil giliran di pesan goride comfort eh bahkan dtng motor kecil bagaimana sih sudah kali goride dtng
#
# === SLANG NORMALIZATION ===
# Before: bangsattt ongkos gofood mahal bgt go ride melambung tinggi kasihan drivernya diperas sampai mati
# After:  bangsattt ongkos gofood mahal banget go ride melambung tinggi kasihan drivernya diperas sampai mati
#
# === SLANG NORMALIZATION ===
# Before: bagus baik
# After:  bagus baik
#
# === SLANG NORMALIZATION ===
# Before: pertahankan pelayanan kpd pelanggan beri penghargaan yg sebesar besarnya kpd para rider driver kurangin potongan kpd mereka tanpa mereka perusahaan ga ada apa nya
# After:  pertahankan layanan kepada pelanggan beri penghargaan yang sebesar besarnya kepada para rider driver kurangin potongan kepada mereka tanpa mereka perusahaan tidak ada apa nya
#
# === SLANG NORMALIZATION ===
# Before: plis promo nya yang jelas khusus buat goride saya tiap hari pake goride knpa ga pernah dpt promo sedangkan temen saya slalu dpt potongan sampe saya beli loh buat dpt potongan kek gaadil gt pls
# After:  plis promo nya yang jelas khusus buat goride saya tiap hari pakai goride kenapa tidak pernah dapat promo sedangkan teman saya slalu dapat potongan sampai saya beli loh buat dapat potongan seperti gaadil begitu pls
#
# === SLANG NORMALIZATION ===
# Before: bagus aplikasi nya membantu banget
# After:  bagus aplikasi nya membantu banget
#
# === SLANG NORMALIZATION ===
# Before: buat kesel aja kalo misal pesen gocar goride pagi pagi pasti ga ada driver nya semisal ada pun lama nya minta ampun pokoknya kecewa deh
# After:  buat kesel saja kalau misal pesan gocar goride pagi pagi pasti tidak ada driver nya semisal ada pun lama nya minta ampun pokoknya kecewa deh
#
# === SLANG NORMALIZATION ===
# Before: good apk
# After:  good apk
#
# === SLANG NORMALIZATION ===
# Before: hati kalau naik goride gojek topi tertinggal nyangkut d helm saja ti tilep sama drivernya sangat kecewa seminggu gak ada kejelasan atau sudah kerjasama coba kalau barang berharga apa gak bahaya kalau topi saja d curi begini
# After:  hati kalau naik goride gojek topi tertinggal nyangkut di helm saja ti tilep sama drivernya sangat kecewa seminggu tidak ada kejelasan atau sudah kerjasama coba kalau barang berharga apa tidak bahaya kalau topi saja di curi begini
#
# === SLANG NORMALIZATION ===
# Before: mudah lancar
# After:  mudah lancar
#
# === SLANG NORMALIZATION ===
# Before: gmn si udh langganan vouch go plus mlh goride nya cuma diskon k nyeselllll
# After:  bagaimana si sudah langganan vouch go plus mlh goride nya cuma diskon ke nyeselllll
#
# === SLANG NORMALIZATION ===
# Before: mohon perbaiki drivernya masak kalau hujan gak mau narik go ride nya sampai hampir jam pesan gak di peduliin sekali dapet langsung di cancel sama driver gak profesional banget tempatku gak bisa mobil masuk makanya pesennya go ride
# After:  mohon perbaiki drivernya masak kalau hujan tidak mau narik go ride nya sampai hampir jam pesan tidak di peduliin sekali dapat langsung di batal sama driver tidak profesional banget tempatku tidak bisa mobil masuk makanya pesennya go ride
#
# === SLANG NORMALIZATION ===
# Before: mantab
# After:  mantab
#
# === SLANG NORMALIZATION ===
# Before: saya suka pakai gojek tapi di sukatani utk goride kenapa tidak terjangkau yaa
# After:  saya suka pakai gojek tapi di sukatani untuk goride kenapa tidak terjangkau yaa
#
# === SLANG NORMALIZATION ===
# Before: mantap lah pokoknya
# After:  mantap lah pokoknya
#
# === SLANG NORMALIZATION ===
# Before: terimaksih jaya selalu
# After:  terimaksih jaya selalu
#
# === SLANG NORMALIZATION ===
# Before: nyaman
# After:  nyaman
#
# === SLANG NORMALIZATION ===
# Before: ada yang sekongkol antara sesama driver go jek saya order goride pas driver datang langsung nanya nama dan alamat tujuan nama saya dan tujuan saya disebut dengan benar oleh driver tersebut namun setelah sampai driver tersebut bilang kalo dia offline tidak pakai aplikasi saya cek diaplikasi driver yang saya order mengirim foto bahwa dia sedang menunggu dititik jemput sedangkan saya sudah sampai ditujuan dan driver yang mengantar saya meminta tarif x lipat dari tarif diaplikasi
# After:  ada yang sekongkol antara sesama driver go jek saya order goride pas driver datang langsung bertanya nama dan alamat tujuan nama saya dan tujuan saya disebut dengan benar oleh driver tersebut namun setelah sampai driver tersebut bilang kalau dia offline tidak pakai aplikasi saya cek diaplikasi driver yang saya order mengirim foto bahwa dia sedang menunggu dititik jemput sedangkan saya sudah sampai ditujuan dan driver yang mengantar saya meminta tarif x lipat dari tarif diaplikasi
#
# === SLANG NORMALIZATION ===
# Before: sangat bagus
# After:  sangat bagus
#
# === SLANG NORMALIZATION ===
# Before: pelayanannya ramah sopan murah
# After:  layanan ramah sopan murah
#
# === SLANG NORMALIZATION ===
# Before: aplikasi gojek sangat membantu
# After:  aplikasi gojek sangat membantu
#
# === SLANG NORMALIZATION ===
# Before: order goride lama kali munculnya
# After:  order goride lama kali munculnya
#
# === SLANG NORMALIZATION ===
# Before: ok bgt
# After:  ok banget
#
# === SLANG NORMALIZATION ===
# Before: go ride oke gocar nya kurang
# After:  go ride oke gocar nya kurang
#
# === SLANG NORMALIZATION ===
# Before: go ride jembot pada sombong drivernya jarak cuma km pada gmau di tolak di map deket ada banyak driver nolak semua app sampah
# After:  go ride jembot pada sombong drivernya jarak cuma kamu pada gmau di tolak di map dekat ada banyak driver nolak semua app sampah
#
# === SLANG NORMALIZATION ===
# Before: dapat driver nya selalu jauh apalagi goride comfort nya aduhai jauhnya juara
# After:  dapat driver nya selalu jauh apalagi goride comfort nya aduhai jauhnya juara
#
# === SLANG NORMALIZATION ===
# Before: kalau ada bintang setengah udah ngasih bintang setengah rutenya sinting dibikin jauh muter muter kemarin goride sekarang go bluebird ngasih rute yang bener dong buang buang waktu sama duit konsumen aja
# After:  kalau ada bintang setengah sudah memberikan bintang setengah rutenya sinting dibikin jauh muter muter kemarin goride sekarang go bluebird memberikan rute yang benar dong buang buang waktu sama uang konsumen saja
#
# === SLANG NORMALIZATION ===
# Before: njemput cepat sopirannya enak tenang sopirnya sopan ramsh rute nya tepat langsing sampe tepat tujuan gk nanya ini itu sampe mana ini dlsb
# After:  njemput cepat sopirannya enak tenang sopirnya sopan ramsh rute nya tepat langsing sampai tepat tujuan tidak bertanya ini itu sampai mana ini dlsb
#
# === SLANG NORMALIZATION ===
# Before: top markotop
# After:  top markotop
#
# === SLANG NORMALIZATION ===
# Before: sangat membantu semoga makin banyak voucher goride dan gofood
# After:  sangat membantu semoga makin banyak voucher goride dan gofood
#
# === SLANG NORMALIZATION ===
# Before: knp stiap mau mesen goride or gocar slalu milih peta manual padahal udh di simpen lokasi favorit tpi ttp aja harus nyari manual menyusahkan
# After:  kenapa setiap mau mesen goride or gocar slalu milih peta manual padahal sudah di simpen lokasi favorit tapi tetap saja harus mencari manual menyusahkan
#
# === SLANG NORMALIZATION ===
# Before: mrasa ga adil tmn saya uda otomatis dpt voucher promo goride tp di saya gd sm skali ishhhh uda dimasukin kode sgala macem ttp aj hargany nromal
# After:  mrasa tidak adil tmn saya sudah otomatis dapat voucher promo goride tapi di saya gd sm sekali ishhhh sudah dimasukin kode sgala macam tetap saja hargany nromal
#
# === SLANG NORMALIZATION ===
# Before: goridenya udah bagus tapi gofoodnya masih bermasalah besar di driver saya sudah menunggu jam tidak dapat driver makanan sudah jadi tapi driver g dapat kasian restonya juga kalau makananya sudah jadi
# After:  goridenya sudah bagus tapi gofoodnya masih bermasalah besar di driver saya sudah menunggu jam tidak dapat driver makanan sudah jadi tapi driver g dapat kasian restonya juga kalau makananya sudah jadi
#
# === SLANG NORMALIZATION ===
# Before: kenapa skrg susah ya pesen gojek goride gocar sama aja saya buka aplikasi pakai indrive malah cpt bgt bukan ada peningkatan kok jadi malah kemunduran sori ini udate review jujur ya kalau nggak gojek bakal ketinggalan ma yg lain
# After:  kenapa sekarang susah iya pesan gojek goride gocar sama saja saya buka aplikasi pakai indrive bahkan cpt banget bukan ada peningkatan kenapa jadi bahkan kemunduran sori ini udate review jujur iya kalau tidak gojek bakal ketinggalan ma yang lain
#
# === SLANG NORMALIZATION ===
# Before: gojek gimana sih saya mau pesan goride kok gak bisa tulisannya harus pakai metode lain metode lain terus
# After:  gojek bagaimana sih saya mau pesan goride kenapa tidak bisa tulisannya harus pakai metode lain metode lain terus
#
# === SLANG NORMALIZATION ===
# Before: senang belanja di gomart kalo pas ada promo
# After:  senang belanja di gomart kalau pas ada promo
#
# === SLANG NORMALIZATION ===
# Before: semangaaat pagiiiii para pejuang keluarga sedikit cerita tentang kekecewaan saya pakai gojek saya pernah pesan goride tp lama banget sekitar mnt baru dapat driver sekali dapat driver posisi nya jauh banget padahal saya lihat ada sekitr driver yg dekat dengan saya saya juga sempat tanya kalau rekan driver itu belum dpt orderan jadi karena terlalu lama saya nunggu saya beralihlah ke grabbike tidak sampai menit sudah dapat driver tidak sampai mnt driver sudah sampai
# After:  semangaaat pagiiiii para pejuang keluarga sedikit cerita tentang kekecewaan saya pakai gojek saya pernah pesan goride tapi lama banget sekitar minta baru dapat driver sekali dapat driver posisi nya jauh banget padahal saya lihat ada sekitr driver yang dekat dengan saya saya juga sempat tanya kalau rekan driver itu belum dapat orderan jadi karena terlalu lama saya menunggu saya beralihlah ke grabbike tidak sampai menit sudah dapat driver tidak sampai minta driver sudah sampai
#
# === SLANG NORMALIZATION ===
# Before: diskon terus
# After:  diskon terus
#
# === SLANG NORMALIZATION ===
# Before: woi yang bener lah masa pake goride plus titik jemputnya jadi ngaco padahal sebelumnya ga pake plus biasa biasa aja
# After:  woi yang benar lah masa pakai goride plus titik jemputnya jadi ngaco padahal sebelumnya tidak pakai plus biasa biasa saja
#
# === SLANG NORMALIZATION ===
# Before: mantab
# After:  mantab
#
# === SLANG NORMALIZATION ===
# Before: ngga ada yang mau ngambil orderan go ride aku padahal aku pake diskon ribu doang
# After:  tidak ada yang mau mengambil orderan go ride aku padahal aku pakai diskon ribu saja
#
# === SLANG NORMALIZATION ===
# Before: berguna bett sumpah
# After:  berguna bett sumpah
#
# === SLANG NORMALIZATION ===
# Before: hallo gojek saya pengguna gojek dari tahun dan saya sangat senang sekali dengan app tersebut karena saya sering mendapatkan voucher goride untuk menjadi agak lebih murah dari biasanya jadi terimakasih gojek atas jasa jasa mu thanks
# After:  hallo gojek saya pengguna gojek dari tahun dan saya sangat senang sekali dengan app tersebut karena saya sering mendapatkan voucher goride untuk menjadi agak lebih murah dari biasanya jadi terimakasih gojek atas jasa jasa mu terima kasih
#
# === SLANG NORMALIZATION ===
# Before: i love gojek so much tapi kenapa sekarang klu kita dapat voucher koq cuma berlaku hanya hari dapat voucher go ride nya memang lumayan paling sedikit dapat voucher bisa lebih dapat voucher go car juga paling sedikit voucher bisa lebih tapi masak kita mau wira wiri sebanyak itu dalam hari kan nggak mungkin kecuali klu kita punya asrama anak yg semua di pakaikan voucher tsb tlg dunk bagian it jangan mau klu di suruh bagian marketing buatin program yg absurd begini
# After:  i love gojek so much tapi kenapa sekarang klu kita dapat voucher kok cuma berlaku hanya hari dapat voucher go ride nya memang lumayan paling sedikit dapat voucher bisa lebih dapat voucher go car juga paling sedikit voucher bisa lebih tapi masak kita mau wira wiri sebanyak itu dalam hari kan tidak mungkin kecuali klu kita punya asrama anak yang semua di pakaikan voucher tersebut tlg dunk bagian it jangan mau klu di suruh bagian marketing buatin program yang absurd begini
#
# === SLANG NORMALIZATION ===
# Before: gojek melakukan blunder dengan cara customer kalau mau pesan go ride prioritas baru dapat driver yang dekat kalau tidak prioritas dapatnya driver jauh tapi kalau mau prioritas kena biaya tambahan lagi akhirnya customer pada pindah ke aplikasi lain yang kocak lagi driver di suspen gara gara nglewatin order padahal disini orang kantor gojek yg salah kenapa penjemputan jauh harusnya yg buat kebijakan ini juga di suspen karena membuat castamer susah dapet driver
# After:  gojek melakukan blunder dengan cara customer kalau mau pesan go ride prioritas baru dapat driver yang dekat kalau tidak prioritas dapatnya driver jauh tapi kalau mau prioritas kena biaya tambahan lagi akhirnya customer pada pindah ke aplikasi lain yang kocak lagi driver di suspen gara gara nglewatin order padahal disini orang kantor gojek yang salah kenapa penjemputan jauh harusnya yang buat kebijakan ini juga di suspen karena membuat castamer susah dapat driver
#
# === SLANG NORMALIZATION ===
# Before: pelayanannya buruk sekali terutama kalo pas hujan tidak ada driver car yg mau ambil karena entah bagaimana servernya gojek melempar pesanan pas hujan itu jauh sehingga rata driver minta di cancel padahal pas banget baru dapat begitu terus kadang yg goride juga sama benar buruk sekali pelayanan gojek sekarang
# After:  layanan buruk sekali terutama kalau pas hujan tidak ada driver car yang mau ambil karena entah bagaimana servernya gojek melempar pesanan pas hujan itu jauh sehingga rata driver minta di batal padahal pas banget baru dapat begitu terus kadang yang goride juga sama benar buruk sekali layanan gojek sekarang
#
# === SLANG NORMALIZATION ===
# Before: sangat membantu di saat membutuhkan
# After:  sangat membantu di saat membutuhkan
#
# Hasil setelah normalisasi slang:
#                                          after_clean  \
# 0  matikan fitur order ganda pemesanan goride seh...
# 1  tolong ya pleeeeease buat customer yg pesen gi...
# 2  saya harap di update kedepanya saat pesan go f...
#
#                                          after_slang
# 0  matikan fitur order ganda pemesanan goride seh...
# 1  tolong iya pleeeeease buat customer yang pesan...
# 2  saya harap di update kedepanya saat pesan go f...

# %%
# Langkah 3: Remove Repeated Characters
def remove_repeated(text):
    """Reduksi huruf berulang"""
    before = text
    after = re.sub(r'(\w)\1{2,}', r'\1\1', text)
    print_step("Remove Repeated Characters", before, after)
    return after

print("\n=== Langkah 3: Remove Repeated Characters ===")
df['after_repeated'] = df['after_slang'].apply(remove_repeated)
print("\nHasil setelah remove repeated characters:")
df[['after_slang', 'after_repeated']].head(3)
# Out:
# === Langkah 3: Remove Repeated Characters ===
#
# === REMOVE REPEATED CHARACTERS ===
# Before: matikan fitur order ganda pemesanan goride seharusnya kalau sudah order goride tidak bisa order goride lagi sekaligus harus dibatalkan dulu baru bisa pesan lagi
# After:  matikan fitur order ganda pemesanan goride seharusnya kalau sudah order goride tidak bisa order goride lagi sekaligus harus dibatalkan dulu baru bisa pesan lagi
#
# === REMOVE REPEATED CHARACTERS ===
# Before: tolong iya pleeeeease buat customer yang pesan gibride tolong itu jempol jangan dikit cansel dikit cansel kalian beratus ratus kali cansel tidak berpengaruh tidak ngefek kitw yang driver yang kena ampas nanti sama aplikator memang kalian bayar tarif nya super mahal tapi kita dibpitong gede super gede potongannya tolong kasihani kami iya driver ojol
# After:  tolong iya pleease buat customer yang pesan gibride tolong itu jempol jangan dikit cansel dikit cansel kalian beratus ratus kali cansel tidak berpengaruh tidak ngefek kitw yang driver yang kena ampas nanti sama aplikator memang kalian bayar tarif nya super mahal tapi kita dibpitong gede super gede potongannya tolong kasihani kami iya driver ojol
#
# === REMOVE REPEATED CHARACTERS ===
# Before: saya harap di update kedepanya saat pesan go food muncul notifikasi jangan go ride saja yang muncul
# After:  saya harap di update kedepanya saat pesan go food muncul notifikasi jangan go ride saja yang muncul
#
# === REMOVE REPEATED CHARACTERS ===
# Before: buatku yang tinggal agak jauh dari kota ini aplikasi yang paling cpat untuk kita dpat driver mau pesan goride ataupun pesan gofood menunggu tidak pakai lama kendaraan driver nya juga oke dan drivernya sopan sukses selalu gojek
# After:  buatku yang tinggal agak jauh dari kota ini aplikasi yang paling cpat untuk kita dpat driver mau pesan goride ataupun pesan gofood menunggu tidak pakai lama kendaraan driver nya juga oke dan drivernya sopan sukses selalu gojek
#
# === REMOVE REPEATED CHARACTERS ===
# Before: layanan goride sangat membantu untuk aktifitas sehari di saat motor sedang perbaikan di bengkel masukan nya mgkin Cuma kalau cuaca sedang hujan dalam situasi urgent butuh transport masih sering lama dapat driver nya
# After:  layanan goride sangat membantu untuk aktifitas sehari di saat motor sedang perbaikan di bengkel masukan nya mgkin Cuma kalau cuaca sedang hujan dalam situasi urgent butuh transport masih sering lama dapat driver nya
#
# === REMOVE REPEATED CHARACTERS ===
# Before: ini gojek kenapa iya sekarang saya pakai akun baru biasanya suka ada voucher tapi voucher goride sekarang tidak ada tapi giliran saya beralih ke gocar ada voucher tapi pas giliran saya buka voucher ternyata tidak ada voucher apakah bug tolong di perbaiki lahi
# After:  ini gojek kenapa iya sekarang saya pakai akun baru biasanya suka ada voucher tapi voucher goride sekarang tidak ada tapi giliran saya beralih ke gocar ada voucher tapi pas giliran saya buka voucher ternyata tidak ada voucher apakah bug tolong di perbaiki lahi
#
# === REMOVE REPEATED CHARACTERS ===
# Before: kalau terima rider seleksi dulu lah setiap naik gojek rider nya emosian melulu
# After:  kalau terima rider seleksi dulu lah setiap naik gojek rider nya emosian melulu
#
# === REMOVE REPEATED CHARACTERS ===
# Before: gojek sekarang mahal meskipun pakai voucher perjalanan kamu biasanya dengan harga pakai voucher go ride saja pot rb sekarang jadi alhasil beralih ke ojol sebelah
# After:  gojek sekarang mahal meskipun pakai voucher perjalanan kamu biasanya dengan harga pakai voucher go ride saja pot rb sekarang jadi alhasil beralih ke ojol sebelah
#
# === REMOVE REPEATED CHARACTERS ===
# Before: cepat dan murah
# After:  cepat dan murah
#
# === REMOVE REPEATED CHARACTERS ===
# Before: keren sudah murah
# After:  keren sudah murah
#
# === REMOVE REPEATED CHARACTERS ===
# Before: drivernya banyak alesan bilang tidak bawa helm terus sedang apa ambil pesanan goride saya pas saya minta batal saja dari dianya tidak mau dianya mau ambil helm dulu knapa tidak mau batal takut poinnya turun kalau begitu sedang apa ambil pesanan saya mana ngajak ribut lagi kurang ajar
# After:  drivernya banyak alesan bilang tidak bawa helm terus sedang apa ambil pesanan goride saya pas saya minta batal saja dari dianya tidak mau dianya mau ambil helm dulu knapa tidak mau batal takut poinnya turun kalau begitu sedang apa ambil pesanan saya mana ngajak ribut lagi kurang ajar
#
# === REMOVE REPEATED CHARACTERS ===
# Before: rumah beda hp ee pesan go ride dng ttik dan tujuan sama kenapa nominal beda sya kena ke pakai hp ponakan ke tunai juga belum gofood klu py saya mehongggg kenapa bisa begitu rumah lho padahal saya setia memakai gojeck untuk order makanan
# After:  rumah beda hp ee pesan go ride dng ttik dan tujuan sama kenapa nominal beda sya kena ke pakai hp ponakan ke tunai juga belum gofood klu py saya mehongg kenapa bisa begitu rumah lho padahal saya setia memakai gojeck untuk order makanan
#
# === REMOVE REPEATED CHARACTERS ===
# Before: drivernya mengemudikan kendaraan dengan aman dan nyaman terimakasih
# After:  drivernya mengemudikan kendaraan dengan aman dan nyaman terimakasih
#
# === REMOVE REPEATED CHARACTERS ===
# Before: ok
# After:  ok
#
# === REMOVE REPEATED CHARACTERS ===
# Before: senang
# After:  senang
#
# === REMOVE REPEATED CHARACTERS ===
# Before: aplikasinya sih masih bagus tapi baru hari ini januari pesan gocar hampir kali goride kali tidak ada yang nyantol server sibuk padahal cuaca cuma gerimis kecil di pusat kota purwokerto susah sekali ini tidak siap kalau di butuhkan
# After:  aplikasinya sih masih bagus tapi baru hari ini januari pesan gocar hampir kali goride kali tidak ada yang nyantol server sibuk padahal cuaca cuma gerimis kecil di pusat kota purwokerto susah sekali ini tidak siap kalau di butuhkan
#
# === REMOVE REPEATED CHARACTERS ===
# Before: gila order goride menunggu l banget tidak dspet driver juga padahal di depan ada driver yang lagi kumpul-kumpul malam balik kerja capek terima kasih gojek tidak langganan aagi saya
# After:  gila order goride menunggu l banget tidak dspet driver juga padahal di depan ada driver yang lagi kumpul-kumpul malam balik kerja capek terima kasih gojek tidak langganan aagi saya
#
# === REMOVE REPEATED CHARACTERS ===
# Before: baik
# After:  baik
#
# === REMOVE REPEATED CHARACTERS ===
# Before: selalu dapat driver jauh kalau pesan goride mau buru mau kerja bisa dipecat karena kelamaan apalagi kalau pesan gosend bisa menit jaraknya bisa kilo tidak kasihan sama drivernya apa
# After:  selalu dapat driver jauh kalau pesan goride mau buru mau kerja bisa dipecat karena kelamaan apalagi kalau pesan gosend bisa menit jaraknya bisa kilo tidak kasihan sama drivernya apa
#
# === REMOVE REPEATED CHARACTERS ===
# Before: the best apps for ride
# After:  the best apps for ride
#
# === REMOVE REPEATED CHARACTERS ===
# Before: alhamdulillah kalau pas pakai goride supirnya bagus dan sopan
# After:  alhamdulillah kalau pas pakai goride supirnya bagus dan sopan
#
# === REMOVE REPEATED CHARACTERS ===
# Before: mantap
# After:  mantap
#
# === REMOVE REPEATED CHARACTERS ===
# Before: kenapa saya isi gopay tidak bisa pesan goride juga bisa tlg bantuannya terima kasih
# After:  kenapa saya isi gopay tidak bisa pesan goride juga bisa tlg bantuannya terima kasih
#
# === REMOVE REPEATED CHARACTERS ===
# Before: sangat membantu dalam beraktifitas semoga sering sering kasih diskon goridenya
# After:  sangat membantu dalam beraktifitas semoga sering sering kasih diskon goridenya
#
# === REMOVE REPEATED CHARACTERS ===
# Before: apa apa ini gojek sama menunggu goride sampai satu jamm kacau ah terus saja ditampung keluhannya ehh tidak ada perbaikan juga sekarang lebih parah menunggu hampir menit padahal didepan saya ada drivernya dan tidak diambil tolong jangan seperti ini saya juga punya keperluan lainnya
# After:  apa apa ini gojek sama menunggu goride sampai satu jamm kacau ah terus saja ditampung keluhannya ehh tidak ada perbaikan juga sekarang lebih parah menunggu hampir menit padahal didepan saya ada drivernya dan tidak diambil tolong jangan seperti ini saya juga punya keperluan lainnya
#
# === REMOVE REPEATED CHARACTERS ===
# Before: ramah terpercaya
# After:  ramah terpercaya
#
# === REMOVE REPEATED CHARACTERS ===
# Before: boleh lah Cuma kadang kalau go ride lama banget
# After:  boleh lah Cuma kadang kalau go ride lama banget
#
# === REMOVE REPEATED CHARACTERS ===
# Before: bagus
# After:  bagus
#
# === REMOVE REPEATED CHARACTERS ===
# Before: sudah up ke gopay plus saya pikir bakal dapat voucher goride biar murah taunya tidak bisa dipakai bagaimana ini
# After:  sudah up ke gopay plus saya pikir bakal dapat voucher goride biar murah taunya tidak bisa dipakai bagaimana ini
#
# === REMOVE REPEATED CHARACTERS ===
# Before: mantaf
# After:  mantaf
#
# === REMOVE REPEATED CHARACTERS ===
# Before: kayaknya tidak perlu pakai gocar goride layanan hemat deh kalau memang tidak bisa digunakan tiap x dipake banyak benar alasan driver
# After:  kayaknya tidak perlu pakai gocar goride layanan hemat deh kalau memang tidak bisa digunakan tiap x dipake banyak benar alasan driver
#
# === REMOVE REPEATED CHARACTERS ===
# Before: terima kasih gojek sudah ada fitur pohon bisa menanam dengan seribu rupiah fitur sangat berguna untuk berbagi oksigen
# After:  terima kasih gojek sudah ada fitur pohon bisa menanam dengan seribu rupiah fitur sangat berguna untuk berbagi oksigen
#
# === REMOVE REPEATED CHARACTERS ===
# Before: bagus baik
# After:  bagus baik
#
# === REMOVE REPEATED CHARACTERS ===
# Before: sangat membantu
# After:  sangat membantu
#
# === REMOVE REPEATED CHARACTERS ===
# Before: drivernya ramah
# After:  drivernya ramah
#
# === REMOVE REPEATED CHARACTERS ===
# Before: bagus layanan
# After:  bagus layanan
#
# === REMOVE REPEATED CHARACTERS ===
# Before: gojek selalu puas saya baik go ride maupun go car nya selalu the best
# After:  gojek selalu puas saya baik go ride maupun go car nya selalu the best
#
# === REMOVE REPEATED CHARACTERS ===
# Before: pelanggan setia goride gocar gofood
# After:  pelanggan setia goride gocar gofood
#
# === REMOVE REPEATED CHARACTERS ===
# Before: bagus tapi saya pernah pesan goride bahkan driver nya salah ambil penumpang sudah saya chat ke driver tidak di respon
# After:  bagus tapi saya pernah pesan goride bahkan driver nya salah ambil penumpang sudah saya chat ke driver tidak di respon
#
# === REMOVE REPEATED CHARACTERS ===
# Before: maaf ini kenapa pasar polis goride bisa motong di akun customer saya sebelumnya tidak pernah kaya begini harusnya pasar polis tidak punya akses motong saldo akun customer baru kali ini ada potongan pasar polis goride di akun customer
# After:  maaf ini kenapa pasar polis goride bisa motong di akun customer saya sebelumnya tidak pernah kaya begini harusnya pasar polis tidak punya akses motong saldo akun customer baru kali ini ada potongan pasar polis goride di akun customer
#
# === REMOVE REPEATED CHARACTERS ===
# Before: aplikasi makin tolol pesan goride yang muncul dan datang gocar
# After:  aplikasi makin tolol pesan goride yang muncul dan datang gocar
#
# === REMOVE REPEATED CHARACTERS ===
# Before: menunggu sampai sejam goride tapi tulisannya sibuk terus ini memang beneran pada sibuk gojek ny atau memang aplikasi nya lagi error
# After:  menunggu sampai sejam goride tapi tulisannya sibuk terus ini memang beneran pada sibuk gojek ny atau memang aplikasi nya lagi error
#
# === REMOVE REPEATED CHARACTERS ===
# Before: untuk saat ini saya hanya pakai gofood saja dan jarang menggunakan goride gocar karena masih trauma dengan cara mereka mengendarai kendaraan dan sempat membuat saya celaka masukan saja lebih banyak promo gofood dan voucher gratis ongkos kirim potongan ongkos kirim seperti driver oren
# After:  untuk saat ini saya hanya pakai gofood saja dan jarang menggunakan goride gocar karena masih trauma dengan cara mereka mengendarai kendaraan dan sempat membuat saya celaka masukan saja lebih banyak promo gofood dan voucher gratis ongkos kirim potongan ongkos kirim seperti driver oren
#
# === REMOVE REPEATED CHARACTERS ===
# Before: top markotop
# After:  top markotop
#
# === REMOVE REPEATED CHARACTERS ===
# Before: selalu tepat waktu penjemputan banyak promo dan lebih hemat
# After:  selalu tepat waktu penjemputan banyak promo dan lebih hemat
#
# === REMOVE REPEATED CHARACTERS ===
# Before: dapat driver goride nya lama padahal di kota depok mau berangkat kerja jadi terlambat tidak kaya aplikasi sebelah dapat drivernya cepat sekalinya dapat jauh driver jemputnya
# After:  dapat driver goride nya lama padahal di kota depok mau berangkat kerja jadi terlambat tidak kaya aplikasi sebelah dapat drivernya cepat sekalinya dapat jauh driver jemputnya
#
# === REMOVE REPEATED CHARACTERS ===
# Before: semakin lama semakin tidak guna ini aplikasi saya pesan goride di gambar banyak sekali driver terdekat eh nyantol nya di jepang saking jauhnya mana sekarang ongkos kirim nya mahal banget maaf untuk kali saya pindah ke apk sebelah tidak ribet
# After:  semakin lama semakin tidak guna ini aplikasi saya pesan goride di gambar banyak sekali driver terdekat eh nyantol nya di jepang saking jauhnya mana sekarang ongkos kirim nya mahal banget maaf untuk kali saya pindah ke apk sebelah tidak ribet
#
# === REMOVE REPEATED CHARACTERS ===
# Before: mengecewakan setiap mau order gocar pas lagi hujan para driver susah untuk menerima pesanan apalagi pakai promo terutama yang buat goride alasan banyak orderan lagi ramai
# After:  mengecewakan setiap mau order gocar pas lagi hujan para driver susah untuk menerima pesanan apalagi pakai promo terutama yang buat goride alasan banyak orderan lagi ramai
#
# === REMOVE REPEATED CHARACTERS ===
# Before: aplikasi bodoh tidak ada yang mau ambil goride driver bodoh
# After:  aplikasi bodoh tidak ada yang mau ambil goride driver bodoh
#
# === REMOVE REPEATED CHARACTERS ===
# Before: gojek sekarang makin buruk mencari driver ny tidak dapat dapat padahl saya tidak membatalkan pesanan dan saya menunggu menit dan saya order lagi namun hasilnya sama saja tambah banyak bug saya ingin pesan makanan atau goride
# After:  gojek sekarang makin buruk mencari driver ny tidak dapat dapat padahl saya tidak membatalkan pesanan dan saya menunggu menit dan saya order lagi namun hasilnya sama saja tambah banyak bug saya ingin pesan makanan atau goride
#
# === REMOVE REPEATED CHARACTERS ===
# Before: mantap sudah pokoknya mah
# After:  mantap sudah pokoknya mah
#
# === REMOVE REPEATED CHARACTERS ===
# Before: untuk goride dan gocar cukup lumayan voucernya tapi gofood nya saya jarang pakai karena ada aplikasi lain jauh lebih murah
# After:  untuk goride dan gocar cukup lumayan voucernya tapi gofood nya saya jarang pakai karena ada aplikasi lain jauh lebih murah
#
# === REMOVE REPEATED CHARACTERS ===
# Before: mudah di gunakan
# After:  mudah di gunakan
#
# === REMOVE REPEATED CHARACTERS ===
# Before: nice
# After:  nice
#
# === REMOVE REPEATED CHARACTERS ===
# Before: aplikasi tolol kalau persen goride di kasih driver yang jauh sekeliling banyak di ambilkan dari korea utara perkiraan menit ditunggu menit tidak sampai update lokasi driver juga tidak jelas
# After:  aplikasi tolol kalau persen goride di kasih driver yang jauh sekeliling banyak di ambilkan dari korea utara perkiraan menit ditunggu menit tidak sampai update lokasi driver juga tidak jelas
#
# === REMOVE REPEATED CHARACTERS ===
# Before: i love gojek sm setiap hari berangkat pulang sekolah always make gojek apalagi di gojek fitur goride comfort cocok banget buat aku yang suka bawa barang banyak kesekolah suka bawa tas gede begitu deh kaki nya dan pnttnya juga jadi tidak pegel jaya terus deh yaa gojek
# After:  i love gojek sm setiap hari berangkat pulang sekolah always make gojek apalagi di gojek fitur goride comfort cocok banget buat aku yang suka bawa barang banyak kesekolah suka bawa tas gede begitu deh kaki nya dan pnttnya juga jadi tidak pegel jaya terus deh yaa gojek
#
# === REMOVE REPEATED CHARACTERS ===
# Before: kenapa saat saya ingin menggunakan go ride dia berubah go car kan jadi mahal ongkosnya
# After:  kenapa saat saya ingin menggunakan go ride dia berubah go car kan jadi mahal ongkosnya
#
# === REMOVE REPEATED CHARACTERS ===
# Before: good
# After:  good
#
# === REMOVE REPEATED CHARACTERS ===
# Before: apa apa go transit sekarang digabung sama go ridetransit jadinya tidak bisa edit stasiun kalau tujuannya berubah padahal sblum update bisa kalau diupdate makin nyusahin lebih baik gausah di update tujuannya update kan untuk memudahkan bukan bahkan mempersulit
# After:  apa apa go transit sekarang digabung sama go ridetransit jadinya tidak bisa edit stasiun kalau tujuannya berubah padahal sblum update bisa kalau diupdate makin nyusahin lebih baik gausah di update tujuannya update kan untuk memudahkan bukan bahkan mempersulit
#
# === REMOVE REPEATED CHARACTERS ===
# Before: layanan nya lebih baik daripada aplikasi sebelah pilihannya juga banyak
# After:  layanan nya lebih baik daripada aplikasi sebelah pilihannya juga banyak
#
# === REMOVE REPEATED CHARACTERS ===
# Before: mantap
# After:  mantap
#
# === REMOVE REPEATED CHARACTERS ===
# Before: padahal pakai aplikasi ini sudah lama tiba hari ini bingung pas check goride harganya dari rb naik jadi rb eh iseng buka grab Cuma bayar rb
# After:  padahal pakai aplikasi ini sudah lama tiba hari ini bingung pas check goride harganya dari rb naik jadi rb eh iseng buka grab Cuma bayar rb
#
# === REMOVE REPEATED CHARACTERS ===
# Before: susah dapat driver sudah x pesan tetep tidak dapat pindah dari menu go ride ke go car cmn hasilny nihil sama saja parah sih
# After:  susah dapat driver sudah x pesan tetep tidak dapat pindah dari menu go ride ke go car cmn hasilny nihil sama saja parah sih
#
# === REMOVE REPEATED CHARACTERS ===
# Before: saya suka pakai jasa goride gocar seneng saja denger curhatan mereka cerita mereka keluh kesah mereka cerita sedih cerita bahagia semuanya saya rangkum jadi motivasi buat diri sendiri
# After:  saya suka pakai jasa goride gocar seneng saja denger curhatan mereka cerita mereka keluh kesah mereka cerita sedih cerita bahagia semuanya saya rangkum jadi motivasi buat diri sendiri
#
# === REMOVE REPEATED CHARACTERS ===
# Before: ok
# After:  ok
#
# === REMOVE REPEATED CHARACTERS ===
# Before: mau milih go transit tapi selalu dialihkan ke go ride
# After:  mau milih go transit tapi selalu dialihkan ke go ride
#
# === REMOVE REPEATED CHARACTERS ===
# Before: i got safety when i was ride gojek
# After:  i got safety when i was ride gojek
#
# === REMOVE REPEATED CHARACTERS ===
# Before: untuk goride lebih mudah dulu
# After:  untuk goride lebih mudah dulu
#
# === REMOVE REPEATED CHARACTERS ===
# Before: kenapa aku masukkan kode promo goride sudah sukses tapi vocer promonya gada aku sudah cba update masin tetap sma sudah hpus download bbrapa kli tapi tetap sama kenapa iya apakah eror tapi cba punya teman mah gada masalah apa
# After:  kenapa aku masukkan kode promo goride sudah sukses tapi vocer promonya gada aku sudah cba update masin tetap sma sudah hpus download bbrapa kli tapi tetap sama kenapa iya apakah eror tapi cba punya teman mah gada masalah apa
#
# === REMOVE REPEATED CHARACTERS ===
# Before: pesan goride posisi driver dekat tidak mau pada mengambil di kasihnya yang jaraknya jauh semuanya sbagian di batal sama drivernya
# After:  pesan goride posisi driver dekat tidak mau pada mengambil di kasihnya yang jaraknya jauh semuanya sbagian di batal sama drivernya
#
# === REMOVE REPEATED CHARACTERS ===
# Before: mohon pihak gojek memberikan saya pembelaan karena saya selalu pulang dengan goride tetapi tadi saya mendapat perlakuan yang sangat tidak menyenangkan karena saat saya membantalkan pesanan karena titik jemput tidak sesuai saya tetap didatangi driver tersebut dan driver tersebut marah bahkan sampai orang melihat saya disitu saya sangat malu karena hal tersebut mohon bantuannya untuk menegur mengingat kan driver tersebut
# After:  mohon pihak gojek memberikan saya pembelaan karena saya selalu pulang dengan goride tetapi tadi saya mendapat perlakuan yang sangat tidak menyenangkan karena saat saya membantalkan pesanan karena titik jemput tidak sesuai saya tetap didatangi driver tersebut dan driver tersebut marah bahkan sampai orang melihat saya disitu saya sangat malu karena hal tersebut mohon bantuannya untuk menegur mengingat kan driver tersebut
#
# === REMOVE REPEATED CHARACTERS ===
# Before: layanan yang memudahkan masyarakat
# After:  layanan yang memudahkan masyarakat
#
# === REMOVE REPEATED CHARACTERS ===
# Before: tolong untuk goride tidak perlu di pisah antara yang hemat sama yang comfort karena percuma jika tidak ada perhatian dari pihak gojeknya pengalaman saya pesan comfort tapi motor yang datang beda plat nomor beda jenisnya masuk kategori hemat tolong lebih diperhatikan lagi khusus driver goride nya karena keselamatan diatas segalanya
# After:  tolong untuk goride tidak perlu di pisah antara yang hemat sama yang comfort karena percuma jika tidak ada perhatian dari pihak gojeknya pengalaman saya pesan comfort tapi motor yang datang beda plat nomor beda jenisnya masuk kategori hemat tolong lebih diperhatikan lagi khusus driver goride nya karena keselamatan diatas segalanya
#
# === REMOVE REPEATED CHARACTERS ===
# Before: ok
# After:  ok
#
# === REMOVE REPEATED CHARACTERS ===
# Before: sangat membantu bagi saya dari goride gocar gofood
# After:  sangat membantu bagi saya dari goride gocar gofood
#
# === REMOVE REPEATED CHARACTERS ===
# Before: gofood nya mengecewakan sekali sudah menunggu sampai jam bahkan dibatalin dengan alasan gada driver kalau memang tidak niat bisnis lebih baik tutup saja aplikasinya bukan hanya itu saja pesan goride dan lain-lain juga selalu drivernya gada padahal jelas jelas banyak driver disekitar lokasi makin hari makin tidak banget ini aplikasi
# After:  gofood nya mengecewakan sekali sudah menunggu sampai jam bahkan dibatalin dengan alasan gada driver kalau memang tidak niat bisnis lebih baik tutup saja aplikasinya bukan hanya itu saja pesan goride dan lain-lain juga selalu drivernya gada padahal jelas jelas banyak driver disekitar lokasi makin hari makin tidak banget ini aplikasi
#
# === REMOVE REPEATED CHARACTERS ===
# Before: tidak pernah dapat voucher goride jompor saya setiap hari pakai goride pulang pergi rb gaperna dapat voucher goride
# After:  tidak pernah dapat voucher goride jompor saya setiap hari pakai goride pulang pergi rb gaperna dapat voucher goride
#
# === REMOVE REPEATED CHARACTERS ===
# Before: verygood
# After:  verygood
#
# === REMOVE REPEATED CHARACTERS ===
# Before: tiap transaksi di gojek toped blibli alfagift kenapa selalu gopaylaternya ditulis diblokir limit aman tagihan belum japo masa cuma bisa dipakai buat goride gocar saja bagaimana ini
# After:  tiap transaksi di gojek toped blibli alfagift kenapa selalu gopaylaternya ditulis diblokir limit aman tagihan belum japo masa cuma bisa dipakai buat goride gocar saja bagaimana ini
#
# === REMOVE REPEATED CHARACTERS ===
# Before: sudah order goride lama menunggu dapat drivernya sudah begitu susah di batalin jauh sama aplikasi tetangga
# After:  sudah order goride lama menunggu dapat drivernya sudah begitu susah di batalin jauh sama aplikasi tetangga
#
# === REMOVE REPEATED CHARACTERS ===
# Before: mau bayar tagihan gopay later tapi aplikasi gangguan terus mau order goride gocar juga sring tidak ada driver tulisannya padahal driver nya bnyak trlihat diaplikasi gojek mkin buruk sekarang aplikasinya kyknya sudah tidak tahu diperbaiki dengan cepat
# After:  mau bayar tagihan gopay later tapi aplikasi gangguan terus mau order goride gocar juga sring tidak ada driver tulisannya padahal driver nya bnyak trlihat diaplikasi gojek mkin buruk sekarang aplikasinya kyknya sudah tidak tahu diperbaiki dengan cepat
#
# === REMOVE REPEATED CHARACTERS ===
# Before: sudah sering pakai gojek mesen makan atau pun goride tetep saja sampai detik ini tidak di buka gopaylater atau gopinjam nya masa kalah sama yang baru daftar dan order cuma beberapa saja langsung bisa dapat limit gopaylater anehh banget lumayan kecewa si sama aplikasi ini merasa tidak adil
# After:  sudah sering pakai gojek mesen makan atau pun goride tetep saja sampai detik ini tidak di buka gopaylater atau gopinjam nya masa kalah sama yang baru daftar dan order cuma beberapa saja langsung bisa dapat limit gopaylater anehh banget lumayan kecewa si sama aplikasi ini merasa tidak adil
#
# === REMOVE REPEATED CHARACTERS ===
# Before: saya pelanggan goride dan gosend tidak ada masalah cuma saya kecewa sama go car di jogja kenapa rata tidak niat iya padahal kan yang milih acak dari aplikasi juga masa cuma karena jauh dikit minta dicancel padahal cm kamu jemputnya jarak yang dianter pun juga tidak jauh amat masih kamu semoga pihak gojek bisa menyortir lagi driver gocar yang cuma iseng males an tertawa kacau
# After:  saya pelanggan goride dan gosend tidak ada masalah cuma saya kecewa sama go car di jogja kenapa rata tidak niat iya padahal kan yang milih acak dari aplikasi juga masa cuma karena jauh dikit minta dicancel padahal cm kamu jemputnya jarak yang dianter pun juga tidak jauh amat masih kamu semoga pihak gojek bisa menyortir lagi driver gocar yang cuma iseng males an tertawa kacau
#
# === REMOVE REPEATED CHARACTERS ===
# Before: tolong kalau kita sedang pesan goride gocar cari driver yang lokasinya dekat dengan titik penjemputan sering banget dapat driver yang jaraknya jauh padahal driver yang mangkal di sekitar lokasi penjemputan banyak bangett tolong di perbaiki lagi jangan buang waktu kami hanya untuk menunggu driver yang datengnya lama karena jaraknya jauh
# After:  tolong kalau kita sedang pesan goride gocar cari driver yang lokasinya dekat dengan titik penjemputan sering banget dapat driver yang jaraknya jauh padahal driver yang mangkal di sekitar lokasi penjemputan banyak bangett tolong di perbaiki lagi jangan buang waktu kami hanya untuk menunggu driver yang datengnya lama karena jaraknya jauh
#
# === REMOVE REPEATED CHARACTERS ===
# Before: apa saja ada mulai car ride dan food keren
# After:  apa saja ada mulai car ride dan food keren
#
# === REMOVE REPEATED CHARACTERS ===
# Before: tidak suka sama gojek sekarang kadang pakai go ride hemat tidak diterima sama driver padahal meringankan pengeluaran kalau lagi tanggal tua sudah begitu kalau pagi susahnya minta ampun sekalinya dapat cuma jarak menit dia bilang kejauhan saya males pernah juga saya lebih dekat ke lokasi tujuan situ jadi kalau saya jemput bulak balik dong
# After:  tidak suka sama gojek sekarang kadang pakai go ride hemat tidak diterima sama driver padahal meringankan pengeluaran kalau lagi tanggal tua sudah begitu kalau pagi susahnya minta ampun sekalinya dapat cuma jarak menit dia bilang kejauhan saya males pernah juga saya lebih dekat ke lokasi tujuan situ jadi kalau saya jemput bulak balik dong
#
# === REMOVE REPEATED CHARACTERS ===
# Before: saya kecewa dengan driver goride setiap hujan pasti tidak ada yang mengambil orderan alasan tidak bawa jas hujan padahal saya sudah chat kalau saya bawa jas hujan buat apa ngojek kalau tidak sedia jas hujan untuk diri sendiri
# After:  saya kecewa dengan driver goride setiap hujan pasti tidak ada yang mengambil orderan alasan tidak bawa jas hujan padahal saya sudah chat kalau saya bawa jas hujan buat apa ngojek kalau tidak sedia jas hujan untuk diri sendiri
#
# === REMOVE REPEATED CHARACTERS ===
# Before: sekarang sudah mahal goride dan gofood
# After:  sekarang sudah mahal goride dan gofood
#
# === REMOVE REPEATED CHARACTERS ===
# Before: gampang kalau mau cari alamat enak
# After:  gampang kalau mau cari alamat enak
#
# === REMOVE REPEATED CHARACTERS ===
# Before: fitur go pay later go pay pinjam tidak bisa di non aktifkan lama kaya aplikasi pinjol rawan penyalahgunaan ridernya seneng banget batalin sendiri sudah menunggu lama tidak kaya sebelah
# After:  fitur go pay later go pay pinjam tidak bisa di non aktifkan lama kaya aplikasi pinjol rawan penyalahgunaan ridernya seneng banget batalin sendiri sudah menunggu lama tidak kaya sebelah
#
# === REMOVE REPEATED CHARACTERS ===
# Before: tahun mengunakan gojek perlu di benahi driver berbeda dengan aplikasi apakah boleh orang yang bukan driver memakai akun driver gojek joki mengantarkan pesanan takut makanan saya di apa apin dengan orang yang bukan driver gojek joki mana lagi motor yang di pakai joki plat nya berbeda dengan aplikasi pesan goride juga begitu sih driver yang jemput orangnya berbeda dengan aplikasi plat nomor motor nya juga berbeda saya jadi was was takut tolong adakan vermuk berwaktu seperti grab
# After:  tahun mengunakan gojek perlu di benahi driver berbeda dengan aplikasi apakah boleh orang yang bukan driver memakai akun driver gojek joki mengantarkan pesanan takut makanan saya di apa apin dengan orang yang bukan driver gojek joki mana lagi motor yang di pakai joki plat nya berbeda dengan aplikasi pesan goride juga begitu sih driver yang jemput orangnya berbeda dengan aplikasi plat nomor motor nya juga berbeda saya jadi was was takut tolong adakan vermuk berwaktu seperti grab
#
# === REMOVE REPEATED CHARACTERS ===
# Before: bagaimana ini waktu mau order goride kendala kenapa bisa ada keterangan internetnya mati padhal kuota banyak melimpahh coba cek gojek di adek bisa buat mesen padahal punyaku biasane pakai juga baik saja tolong segera diperbaiki
# After:  bagaimana ini waktu mau order goride kendala kenapa bisa ada keterangan internetnya mati padhal kuota banyak melimpahh coba cek gojek di adek bisa buat mesen padahal punyaku biasane pakai juga baik saja tolong segera diperbaiki
#
# === REMOVE REPEATED CHARACTERS ===
# Before: woi harga goride nya kenapa nambah dari hari ke hari tempat nya sama saja kenapa masa gara gara cuaca panas atau hujan jadi naik kalau hujan ok lah tapi tidak ngotak juga kalau kali njir oh kualitas nya yang bikin nambah perasaan sama saja deh mau hemat atau comfort hoki an saja lihat maxim iya murah nomor diskon tidak menarik tapi segitu saja terus
# After:  woi harga goride nya kenapa nambah dari hari ke hari tempat nya sama saja kenapa masa gara gara cuaca panas atau hujan jadi naik kalau hujan ok lah tapi tidak ngotak juga kalau kali njir oh kualitas nya yang bikin nambah perasaan sama saja deh mau hemat atau comfort hoki an saja lihat maxim iya murah nomor diskon tidak menarik tapi segitu saja terus
#
# === REMOVE REPEATED CHARACTERS ===
# Before: thank you
# After:  thank you
#
# === REMOVE REPEATED CHARACTERS ===
# Before: ok cepat dan tepat
# After:  ok cepat dan tepat
#
# === REMOVE REPEATED CHARACTERS ===
# Before: dc nya suka ngancam
# After:  dc nya suka ngancam
#
# === REMOVE REPEATED CHARACTERS ===
# Before: jasa biaya gojek nya sudah mahal di tambah lagi pesan go food atau go ride dan lain-lain kena double order sebagai custumer merasa di rugikan rugi sudah bayar mahal dan rugi waktu menunggu jadi lama gojek makin tidak jelas sekarang
# After:  jasa biaya gojek nya sudah mahal di tambah lagi pesan go food atau go ride dan lain-lain kena double order sebagai custumer merasa di rugikan rugi sudah bayar mahal dan rugi waktu menunggu jadi lama gojek makin tidak jelas sekarang
#
# === REMOVE REPEATED CHARACTERS ===
# Before: terimakasih
# After:  terimakasih
#
# === REMOVE REPEATED CHARACTERS ===
# Before: banyakin promonya khususnya goride and gofood
# After:  banyakin promonya khususnya goride and gofood
#
# === REMOVE REPEATED CHARACTERS ===
# Before: akun saya ke blokir tolong bagaimana solusinya sudah ngechat cs responnya sama selalu laporan ditutup solusi dong keterangannya ke blokir dan tidak bisa menggunakan berbagai voucher termasuk goride gofood tolong bagaimana biar normal lagi
# After:  akun saya ke blokir tolong bagaimana solusinya sudah ngechat cs responnya sama selalu laporan ditutup solusi dong keterangannya ke blokir dan tidak bisa menggunakan berbagai voucher termasuk goride gofood tolong bagaimana biar normal lagi
#
# === REMOVE REPEATED CHARACTERS ===
# Before: bagus minta tolong lebih banyak promo untuk gocar sama goride comfort supaya bisa menikmati perjalanan dengan hemat dan nyaman terima kasih
# After:  bagus minta tolong lebih banyak promo untuk gocar sama goride comfort supaya bisa menikmati perjalanan dengan hemat dan nyaman terima kasih
#
# === REMOVE REPEATED CHARACTERS ===
# Before: gilaaaaaaaa saldo hilang gtu saja terus call center tidak ngebantu banget masa order goride gadapet sampai kali dan saldonya ketarik nya apa in ini gojek
# After:  gilaa saldo hilang gtu saja terus call center tidak ngebantu banget masa order goride gadapet sampai kali dan saldonya ketarik nya apa in ini gojek
#
# === REMOVE REPEATED CHARACTERS ===
# Before: kemarin siang masih bisa pesan goride pakai gopaylater tapi pas malam tiba tiba di gopaylater di blokir padahal tagihan belum jatuh tempo dan limit masih sangat sangat banyak sudah laporan tapi belum di tanggapi kecewa
# After:  kemarin siang masih bisa pesan goride pakai gopaylater tapi pas malam tiba tiba di gopaylater di blokir padahal tagihan belum jatuh tempo dan limit masih sangat sangat banyak sudah laporan tapi belum di tanggapi kecewa
#
# === REMOVE REPEATED CHARACTERS ===
# Before: kenapa tidak bisa tukar voucher gorideaja sudah ditukar bilangnya berhasil tapi di cek di halaman voucher tidak ada sama sekali voucher nya kosongg
# After:  kenapa tidak bisa tukar voucher gorideaja sudah ditukar bilangnya berhasil tapi di cek di halaman voucher tidak ada sama sekali voucher nya kosongg
#
# === REMOVE REPEATED CHARACTERS ===
# Before: sangat membantu
# After:  sangat membantu
#
# === REMOVE REPEATED CHARACTERS ===
# Before: keren ini sekarang gojek dapat driver nya cepat dan cepat sampai tidak menunggu lama dapat vocher diskon goride gocar gofood terus tapi saya minta tolong dong vocher goride nya ada setiap hari jadi bisa membantu anak sekolah dengan promo yang murah dibawah ribu
# After:  keren ini sekarang gojek dapat driver nya cepat dan cepat sampai tidak menunggu lama dapat vocher diskon goride gocar gofood terus tapi saya minta tolong dong vocher goride nya ada setiap hari jadi bisa membantu anak sekolah dengan promo yang murah dibawah ribu
#
# === REMOVE REPEATED CHARACTERS ===
# Before: gojek pasti ada jalan
# After:  gojek pasti ada jalan
#
# === REMOVE REPEATED CHARACTERS ===
# Before: kenapa map goride setiap dekat tol pasti di arahi ke lewat tol sehingga tarif tidak sesuai terima kasih
# After:  kenapa map goride setiap dekat tol pasti di arahi ke lewat tol sehingga tarif tidak sesuai terima kasih
#
# === REMOVE REPEATED CHARACTERS ===
# Before: saya juga driver go ride min sangat disayangkan kalau orderan dibuat susah sekarang dan bahkan bensin x pengeluaran akhirnya saya akali beli Cuma rb supaya tidak rugi sejak system yang paling terdekat diterapkan sejak system goride yang sangat terdekat diterapkan otomatis pendapatan kita berkurang drastis kita sebagai costumer gojek juga tidak bisa membantu orderan seperti biasanya bahkan belanja di tokopedia semoga system update terbaru pendapatan kita kembali konsisten diatas lagi amin
# After:  saya juga driver go ride min sangat disayangkan kalau orderan dibuat susah sekarang dan bahkan bensin x pengeluaran akhirnya saya akali beli Cuma rb supaya tidak rugi sejak system yang paling terdekat diterapkan sejak system goride yang sangat terdekat diterapkan otomatis pendapatan kita berkurang drastis kita sebagai costumer gojek juga tidak bisa membantu orderan seperti biasanya bahkan belanja di tokopedia semoga system update terbaru pendapatan kita kembali konsisten diatas lagi amin
#
# === REMOVE REPEATED CHARACTERS ===
# Before: kami pelajar turunkan tarif go ride kami kaum missqueen
# After:  kami pelajar turunkan tarif go ride kami kaum missqueen
#
# === REMOVE REPEATED CHARACTERS ===
# Before: good
# After:  good
#
# === REMOVE REPEATED CHARACTERS ===
# Before: awal memakai aplikasi gojek puas makin kesini keseringan kecewa order makanan susah dapat driver nya harus menunggu hampir satu jam begitu pun untuk goride mohon diperhatikan dan ditindaklanjuti kedepannya
# After:  awal memakai aplikasi gojek puas makin kesini keseringan kecewa order makanan susah dapat driver nya harus menunggu hampir satu jam begitu pun untuk goride mohon diperhatikan dan ditindaklanjuti kedepannya
#
# === REMOVE REPEATED CHARACTERS ===
# Before: program sudah bagus pertahankan di tingkatkan lagi layanan serta tolong di sejahterakan driver driver nya berikan mereka penghidupan layak
# After:  program sudah bagus pertahankan di tingkatkan lagi layanan serta tolong di sejahterakan driver driver nya berikan mereka penghidupan layak
#
# === REMOVE REPEATED CHARACTERS ===
# Before: sangat membantu
# After:  sangat membantu
#
# === REMOVE REPEATED CHARACTERS ===
# Before: go ride tidak bisa melayani pas lagi hujan padahal gerimis saja jam order tidak ada yang nyangkut berharap sm gojek nyampe kantor terlambat
# After:  go ride tidak bisa melayani pas lagi hujan padahal gerimis saja jam order tidak ada yang nyangkut berharap sm gojek nyampe kantor terlambat
#
# === REMOVE REPEATED CHARACTERS ===
# Before: mantap
# After:  mantap
#
# === REMOVE REPEATED CHARACTERS ===
# Before: mudah an semakin bnyak promonya bukan hanya gofood tapi promo gocar goride dan lain-lain juga
# After:  mudah an semakin bnyak promonya bukan hanya gofood tapi promo gocar goride dan lain-lain juga
#
# === REMOVE REPEATED CHARACTERS ===
# Before: niatnya mau top up gopay ke driver dengan cara order go ride pas driver datang bisa top up dan saldo masuk tapi dia kira saya mau pergi ke tempat yang saya tuju dan saya harus bayar ongkos trip tersebut rugi dong
# After:  niatnya mau top up gopay ke driver dengan cara order go ride pas driver datang bisa top up dan saldo masuk tapi dia kira saya mau pergi ke tempat yang saya tuju dan saya harus bayar ongkos trip tersebut rugi dong
#
# === REMOVE REPEATED CHARACTERS ===
# Before: driver driver sekarang pada malas sudah tahu titik nya sesuai bahkan jauh banget sudah begitu mau nya di samperin kan pesan ojol online agar kita praktis tapi ini gosend pun dan goride pun seperti ini memang banyak si voucher nya tapi memang begitu yaa maaf
# After:  driver driver sekarang pada malas sudah tahu titik nya sesuai bahkan jauh banget sudah begitu mau nya di samperin kan pesan ojol online agar kita praktis tapi ini gosend pun dan goride pun seperti ini memang banyak si voucher nya tapi memang begitu yaa maaf
#
# === REMOVE REPEATED CHARACTERS ===
# Before: tampilan aplikasi gojek semakin nyaman untuk dilihat menarik penggunaan aplikasi gojek hingga saat ini masih nyaman aman praktis dan suka order gofood goride lewat aplikasi gojek semoga bisa nambah terus promo buat gofood nya he
# After:  tampilan aplikasi gojek semakin nyaman untuk dilihat menarik penggunaan aplikasi gojek hingga saat ini masih nyaman aman praktis dan suka order gofood goride lewat aplikasi gojek semoga bisa nambah terus promo buat gofood nya he
#
# === REMOVE REPEATED CHARACTERS ===
# Before: sediakan versi lite nya dong buat goride gocar saja ukuran aplikasinya jangan terlalu besarlah
# After:  sediakan versi lite nya dong buat goride gocar saja ukuran aplikasinya jangan terlalu besarlah
#
# === REMOVE REPEATED CHARACTERS ===
# Before: untuk hari ini layanan gocar sangat buruk dicancel x padahal sudah dekat dari jalan rumah saya dan sekalinya dapat sopirnya tidak dilayanin padahal pakai gocar prioritas buruk sangat buruk gocar saya sangat kecewa padahal saya sekarang pakai goride gofood jrg ada kendala seperti ini benar tidak akan mau pakai gocar lagi
# After:  untuk hari ini layanan gocar sangat buruk dicancel x padahal sudah dekat dari jalan rumah saya dan sekalinya dapat sopirnya tidak dilayanin padahal pakai gocar prioritas buruk sangat buruk gocar saya sangat kecewa padahal saya sekarang pakai goride gofood jrg ada kendala seperti ini benar tidak akan mau pakai gocar lagi
#
# === REMOVE REPEATED CHARACTERS ===
# Before: gofood super mahal ongkirnya biaya layanannya sgala macam sudah begitu tidak ada promo potongan apapun pakai gojek cuma buat kebutuhan gocar goride sama tiket kereta saja
# After:  gofood super mahal ongkirnya biaya layanannya sgala macam sudah begitu tidak ada promo potongan apapun pakai gojek cuma buat kebutuhan gocar goride sama tiket kereta saja
#
# === REMOVE REPEATED CHARACTERS ===
# Before: pokok nya top markotop deh
# After:  pokok nya top markotop deh
#
# === REMOVE REPEATED CHARACTERS ===
# Before: good
# After:  good
#
# === REMOVE REPEATED CHARACTERS ===
# Before: pengalaman menyenangkan menggunakan gojek
# After:  pengalaman menyenangkan menggunakan gojek
#
# === REMOVE REPEATED CHARACTERS ===
# Before: sangat membantu sekali dalam perjalanan
# After:  sangat membantu sekali dalam perjalanan
#
# === REMOVE REPEATED CHARACTERS ===
# Before: saya langganan pakai gojek kalau mau pigi bekerja naik goride jadi menurud saya drivenya ramah semoga ditingkatkan lagi
# After:  saya langganan pakai gojek kalau mau pigi bekerja naik goride jadi menurud saya drivenya ramah semoga ditingkatkan lagi
#
# === REMOVE REPEATED CHARACTERS ===
# Before: driver bik sopan rapi ramah kendaraan terawat baik dijalan patuh taat peraturan lalu lintas layanan panggilan cepat selalu beri salam relatif yepay waktu untuk gojek beri reward bagi driver teladan cistomersetia telafan tahun pernah mengadakan indian voucer berhadiah mobil kapan pengumannya sudah atau belum disosialisasikan terimakasih customer gojek go ride go car
# After:  driver bik sopan rapi ramah kendaraan terawat baik dijalan patuh taat peraturan lalu lintas layanan panggilan cepat selalu beri salam relatif yepay waktu untuk gojek beri reward bagi driver teladan cistomersetia telafan tahun pernah mengadakan indian voucer berhadiah mobil kapan pengumannya sudah atau belum disosialisasikan terimakasih customer gojek go ride go car
#
# === REMOVE REPEATED CHARACTERS ===
# Before: ketika promoan banyak driver yang tidak mau ambil orderan gocar goride sudah seringkali menunggu lama seperti ini tidak ada yang ambil padahal coba pakai grab langsung dapat
# After:  ketika promoan banyak driver yang tidak mau ambil orderan gocar goride sudah seringkali menunggu lama seperti ini tidak ada yang ambil padahal coba pakai grab langsung dapat
#
# === REMOVE REPEATED CHARACTERS ===
# Before: bagus
# After:  bagus
#
# === REMOVE REPEATED CHARACTERS ===
# Before: adanya orderan goride hemat gofood hemat dan sebagainya bikin rugi driver secara keseluruhan tolong dong di hapus orderan hemat nya pakai tarif normal saja
# After:  adanya orderan goride hemat gofood hemat dan sebagainya bikin rugi driver secara keseluruhan tolong dong di hapus orderan hemat nya pakai tarif normal saja
#
# === REMOVE REPEATED CHARACTERS ===
# Before: beragam aplikasi nya mulai dari goride gocar go food dan sebagainya semoga tambah terus innovasi nya di masa yang akan datang
# After:  beragam aplikasi nya mulai dari goride gocar go food dan sebagainya semoga tambah terus innovasi nya di masa yang akan datang
#
# === REMOVE REPEATED CHARACTERS ===
# Before: nice
# After:  nice
#
# === REMOVE REPEATED CHARACTERS ===
# Before: kadang kalau hujan gada driver go ride yang mau ambil pesanan padahal hujan nya sudah redah terpaksa harus menunggu lama
# After:  kadang kalau hujan gada driver go ride yang mau ambil pesanan padahal hujan nya sudah redah terpaksa harus menunggu lama
#
# === REMOVE REPEATED CHARACTERS ===
# Before: mau order goride tidak bisa stuk di map
# After:  mau order goride tidak bisa stuk di map
#
# === REMOVE REPEATED CHARACTERS ===
# Before: tidak pernah di kasi promo setiap order gofood atau goride atau gocar
# After:  tidak pernah di kasi promo setiap order gofood atau goride atau gocar
#
# === REMOVE REPEATED CHARACTERS ===
# Before: dari waktu yang ditentukan selalu terlambat baik goride gofood
# After:  dari waktu yang ditentukan selalu terlambat baik goride gofood
#
# === REMOVE REPEATED CHARACTERS ===
# Before: mana ini kota bandung tidak ada go ride atau gocar instan ngak kedepan banget menjengkelkan mau pesan saja tidak keluar drivernya padahal saya lihat sebagian lalu lalang tidak mau ambil dari hemat biasa sampai comvort
# After:  mana ini kota bandung tidak ada go ride atau gocar instan ngak kedepan banget menjengkelkan mau pesan saja tidak keluar drivernya padahal saya lihat sebagian lalu lalang tidak mau ambil dari hemat biasa sampai comvort
#
# === REMOVE REPEATED CHARACTERS ===
# Before: gojek keren bisa pesan sekalian goride satu waktu terima kasih gojek
# After:  gojek keren bisa pesan sekalian goride satu waktu terima kasih gojek
#
# === REMOVE REPEATED CHARACTERS ===
# Before: enak sih goride nya tapi kenapa Cuma hujan rintik gerimis dikit saja driver nya tidak mau ambil orderan gofood masa tidak punya jas ujan sih anjing orng laper banget sudah menunggu hampir jam sampai x mesen dan ngechat ke ig resto nya anjing banget sudah gojek tidak jelas restonya sampai ss ada yang pesan orng tidak dapat driver tolong deh ini driver nya ujan dikit saja pada males tidak perlu jadi gojek anjg
# After:  enak sih goride nya tapi kenapa Cuma hujan rintik gerimis dikit saja driver nya tidak mau ambil orderan gofood masa tidak punya jas ujan sih anjing orng laper banget sudah menunggu hampir jam sampai x mesen dan ngechat ke ig resto nya anjing banget sudah gojek tidak jelas restonya sampai ss ada yang pesan orng tidak dapat driver tolong deh ini driver nya ujan dikit saja pada males tidak perlu jadi gojek anjg
#
# === REMOVE REPEATED CHARACTERS ===
# Before: tolong hapus goride instan di stasiun tangerang sangat menyusahkan harus jalan kaki apalagi di jam sibuk macet harus jalan kaki lagi
# After:  tolong hapus goride instan di stasiun tangerang sangat menyusahkan harus jalan kaki apalagi di jam sibuk macet harus jalan kaki lagi
#
# === REMOVE REPEATED CHARACTERS ===
# Before: tolong radius driver di tambah setiap pesan goride di luar jangkauan bedakan juga itu goride hemat dengan goride reguler kenapa waktu tunggu nya sama
# After:  tolong radius driver di tambah setiap pesan goride di luar jangkauan bedakan juga itu goride hemat dengan goride reguler kenapa waktu tunggu nya sama
#
# === REMOVE REPEATED CHARACTERS ===
# Before: okeh
# After:  okeh
#
# === REMOVE REPEATED CHARACTERS ===
# Before: goride oke lah gofoodnya sampah banget bakal mencari driver kalau makanan sudah jadi jam lebih menunggu endingnya cancle karena gadapat driver terlanjur laper yang ada php saja
# After:  goride oke lah gofoodnya sampah banget bakal mencari driver kalau makanan sudah jadi jam lebih menunggu endingnya cancle karena gadapat driver terlanjur laper yang ada php saja
#
# === REMOVE REPEATED CHARACTERS ===
# Before: mantap
# After:  mantap
#
# === REMOVE REPEATED CHARACTERS ===
# Before: sangat bagus
# After:  sangat bagus
#
# === REMOVE REPEATED CHARACTERS ===
# Before: cs tidak ada yang online kalau ada kendala apa susah gopaylater dikasih limit besar tapi tiap sebulan sekali bisa x pengecekan pembekuan semakin tarif gofood dan goride tidak masuk akal lama jadi tidak worth it maaf to sayang tapi memang bikin muak
# After:  cs tidak ada yang online kalau ada kendala apa susah gopaylater dikasih limit besar tapi tiap sebulan sekali bisa x pengecekan pembekuan semakin tarif gofood dan goride tidak masuk akal lama jadi tidak worth it maaf to sayang tapi memang bikin muak
#
# === REMOVE REPEATED CHARACTERS ===
# Before:
# After:
#
# === REMOVE REPEATED CHARACTERS ===
# Before: goride hemat ko jadi di bawah min susah mencari jadinya lebih baik di keatasin lagi biar gamapang langsung pesan
# After:  goride hemat ko jadi di bawah min susah mencari jadinya lebih baik di keatasin lagi biar gamapang langsung pesan
#
# === REMOVE REPEATED CHARACTERS ===
# Before: saya pemakai go box go pulsa go ride go send go car go food dan go massage aktif terimakasih gojek semua bermanfaat
# After:  saya pemakai go box go pulsa go ride go send go car go food dan go massage aktif terimakasih gojek semua bermanfaat
#
# === REMOVE REPEATED CHARACTERS ===
# Before: banyak promo dan diskon nya
# After:  banyak promo dan diskon nya
#
# === REMOVE REPEATED CHARACTERS ===
# Before: aplikasi banyak bug nya akhir akhir ini saya order goride x tapi yang terpanggil driver dengan tujuan yang sama dari akun saya padahal saya hanya order x sering kali hanya cek aplikasi tapi tiba tiba terorder sendiri goridenya terutama saat saldo gopay terisi
# After:  aplikasi banyak bug nya akhir akhir ini saya order goride x tapi yang terpanggil driver dengan tujuan yang sama dari akun saya padahal saya hanya order x sering kali hanya cek aplikasi tapi tiba tiba terorder sendiri goridenya terutama saat saldo gopay terisi
#
# === REMOVE REPEATED CHARACTERS ===
# Before: mantul
# After:  mantul
#
# === REMOVE REPEATED CHARACTERS ===
# ...
# After:  kalau jaraknya jauh driver banyak alasan dan batal sepihak saya punya bukti chat katanya cari orderan goride juga saya bayar ribu Cuma masuk ke drivernya Cuma ribu
#
# === REMOVE REPEATED CHARACTERS ===
# Before: tolong kalau ada driver diajarin layanan yang benar saya pesan goride sama driver nya didiemin saja posisi driver juga diem saja sudah menunggu setengah jam lebih ujung nya bahkan di batal sama dia kalau misalnya tidak bisa ambil orderan suruh bicara ke pelanggan saya sebagai pelanggan mau kenapa yang nge batal orderannya biar rating driver tidak minus kalau begini kan saya yang rugi menunggu lama hujan an ujung nya bahkan di batal
# After:  tolong kalau ada driver diajarin layanan yang benar saya pesan goride sama driver nya didiemin saja posisi driver juga diem saja sudah menunggu setengah jam lebih ujung nya bahkan di batal sama dia kalau misalnya tidak bisa ambil orderan suruh bicara ke pelanggan saya sebagai pelanggan mau kenapa yang nge batal orderannya biar rating driver tidak minus kalau begini kan saya yang rugi menunggu lama hujan an ujung nya bahkan di batal
#
# === REMOVE REPEATED CHARACTERS ===
# Before: setiap pesan goride selalu di batalkan di dpn customer karena motor kecil giliran di pesan goride comfort eh bahkan dtng motor kecil bagaimana sih sudah kali goride dtng
# After:  setiap pesan goride selalu di batalkan di dpn customer karena motor kecil giliran di pesan goride comfort eh bahkan dtng motor kecil bagaimana sih sudah kali goride dtng
#
# === REMOVE REPEATED CHARACTERS ===
# Before: bangsattt ongkos gofood mahal banget go ride melambung tinggi kasihan drivernya diperas sampai mati
# After:  bangsatt ongkos gofood mahal banget go ride melambung tinggi kasihan drivernya diperas sampai mati
#
# === REMOVE REPEATED CHARACTERS ===
# Before: bagus baik
# After:  bagus baik
#
# === REMOVE REPEATED CHARACTERS ===
# Before: pertahankan layanan kepada pelanggan beri penghargaan yang sebesar besarnya kepada para rider driver kurangin potongan kepada mereka tanpa mereka perusahaan tidak ada apa nya
# After:  pertahankan layanan kepada pelanggan beri penghargaan yang sebesar besarnya kepada para rider driver kurangin potongan kepada mereka tanpa mereka perusahaan tidak ada apa nya
#
# === REMOVE REPEATED CHARACTERS ===
# Before: plis promo nya yang jelas khusus buat goride saya tiap hari pakai goride kenapa tidak pernah dapat promo sedangkan teman saya slalu dapat potongan sampai saya beli loh buat dapat potongan seperti gaadil begitu pls
# After:  plis promo nya yang jelas khusus buat goride saya tiap hari pakai goride kenapa tidak pernah dapat promo sedangkan teman saya slalu dapat potongan sampai saya beli loh buat dapat potongan seperti gaadil begitu pls
#
# === REMOVE REPEATED CHARACTERS ===
# Before: bagus aplikasi nya membantu banget
# After:  bagus aplikasi nya membantu banget
#
# === REMOVE REPEATED CHARACTERS ===
# Before: buat kesel saja kalau misal pesan gocar goride pagi pagi pasti tidak ada driver nya semisal ada pun lama nya minta ampun pokoknya kecewa deh
# After:  buat kesel saja kalau misal pesan gocar goride pagi pagi pasti tidak ada driver nya semisal ada pun lama nya minta ampun pokoknya kecewa deh
#
# === REMOVE REPEATED CHARACTERS ===
# Before: good apk
# After:  good apk
#
# === REMOVE REPEATED CHARACTERS ===
# Before: hati kalau naik goride gojek topi tertinggal nyangkut di helm saja ti tilep sama drivernya sangat kecewa seminggu tidak ada kejelasan atau sudah kerjasama coba kalau barang berharga apa tidak bahaya kalau topi saja di curi begini
# After:  hati kalau naik goride gojek topi tertinggal nyangkut di helm saja ti tilep sama drivernya sangat kecewa seminggu tidak ada kejelasan atau sudah kerjasama coba kalau barang berharga apa tidak bahaya kalau topi saja di curi begini
#
# === REMOVE REPEATED CHARACTERS ===
# Before: mudah lancar
# After:  mudah lancar
#
# === REMOVE REPEATED CHARACTERS ===
# Before: bagaimana si sudah langganan vouch go plus mlh goride nya cuma diskon ke nyeselllll
# After:  bagaimana si sudah langganan vouch go plus mlh goride nya cuma diskon ke nyesell
#
# === REMOVE REPEATED CHARACTERS ===
# Before: mohon perbaiki drivernya masak kalau hujan tidak mau narik go ride nya sampai hampir jam pesan tidak di peduliin sekali dapat langsung di batal sama driver tidak profesional banget tempatku tidak bisa mobil masuk makanya pesennya go ride
# After:  mohon perbaiki drivernya masak kalau hujan tidak mau narik go ride nya sampai hampir jam pesan tidak di peduliin sekali dapat langsung di batal sama driver tidak profesional banget tempatku tidak bisa mobil masuk makanya pesennya go ride
#
# === REMOVE REPEATED CHARACTERS ===
# Before: mantab
# After:  mantab
#
# === REMOVE REPEATED CHARACTERS ===
# Before: saya suka pakai gojek tapi di sukatani untuk goride kenapa tidak terjangkau yaa
# After:  saya suka pakai gojek tapi di sukatani untuk goride kenapa tidak terjangkau yaa
#
# === REMOVE REPEATED CHARACTERS ===
# Before: mantap lah pokoknya
# After:  mantap lah pokoknya
#
# === REMOVE REPEATED CHARACTERS ===
# Before: terimaksih jaya selalu
# After:  terimaksih jaya selalu
#
# === REMOVE REPEATED CHARACTERS ===
# Before: nyaman
# After:  nyaman
#
# === REMOVE REPEATED CHARACTERS ===
# Before: ada yang sekongkol antara sesama driver go jek saya order goride pas driver datang langsung bertanya nama dan alamat tujuan nama saya dan tujuan saya disebut dengan benar oleh driver tersebut namun setelah sampai driver tersebut bilang kalau dia offline tidak pakai aplikasi saya cek diaplikasi driver yang saya order mengirim foto bahwa dia sedang menunggu dititik jemput sedangkan saya sudah sampai ditujuan dan driver yang mengantar saya meminta tarif x lipat dari tarif diaplikasi
# After:  ada yang sekongkol antara sesama driver go jek saya order goride pas driver datang langsung bertanya nama dan alamat tujuan nama saya dan tujuan saya disebut dengan benar oleh driver tersebut namun setelah sampai driver tersebut bilang kalau dia offline tidak pakai aplikasi saya cek diaplikasi driver yang saya order mengirim foto bahwa dia sedang menunggu dititik jemput sedangkan saya sudah sampai ditujuan dan driver yang mengantar saya meminta tarif x lipat dari tarif diaplikasi
#
# === REMOVE REPEATED CHARACTERS ===
# Before: sangat bagus
# After:  sangat bagus
#
# === REMOVE REPEATED CHARACTERS ===
# Before: layanan ramah sopan murah
# After:  layanan ramah sopan murah
#
# === REMOVE REPEATED CHARACTERS ===
# Before: aplikasi gojek sangat membantu
# After:  aplikasi gojek sangat membantu
#
# === REMOVE REPEATED CHARACTERS ===
# Before: order goride lama kali munculnya
# After:  order goride lama kali munculnya
#
# === REMOVE REPEATED CHARACTERS ===
# Before: ok banget
# After:  ok banget
#
# === REMOVE REPEATED CHARACTERS ===
# Before: go ride oke gocar nya kurang
# After:  go ride oke gocar nya kurang
#
# === REMOVE REPEATED CHARACTERS ===
# Before: go ride jembot pada sombong drivernya jarak cuma kamu pada gmau di tolak di map dekat ada banyak driver nolak semua app sampah
# After:  go ride jembot pada sombong drivernya jarak cuma kamu pada gmau di tolak di map dekat ada banyak driver nolak semua app sampah
#
# === REMOVE REPEATED CHARACTERS ===
# Before: dapat driver nya selalu jauh apalagi goride comfort nya aduhai jauhnya juara
# After:  dapat driver nya selalu jauh apalagi goride comfort nya aduhai jauhnya juara
#
# === REMOVE REPEATED CHARACTERS ===
# Before: kalau ada bintang setengah sudah memberikan bintang setengah rutenya sinting dibikin jauh muter muter kemarin goride sekarang go bluebird memberikan rute yang benar dong buang buang waktu sama uang konsumen saja
# After:  kalau ada bintang setengah sudah memberikan bintang setengah rutenya sinting dibikin jauh muter muter kemarin goride sekarang go bluebird memberikan rute yang benar dong buang buang waktu sama uang konsumen saja
#
# === REMOVE REPEATED CHARACTERS ===
# Before: njemput cepat sopirannya enak tenang sopirnya sopan ramsh rute nya tepat langsing sampai tepat tujuan tidak bertanya ini itu sampai mana ini dlsb
# After:  njemput cepat sopirannya enak tenang sopirnya sopan ramsh rute nya tepat langsing sampai tepat tujuan tidak bertanya ini itu sampai mana ini dlsb
#
# === REMOVE REPEATED CHARACTERS ===
# Before: top markotop
# After:  top markotop
#
# === REMOVE REPEATED CHARACTERS ===
# Before: sangat membantu semoga makin banyak voucher goride dan gofood
# After:  sangat membantu semoga makin banyak voucher goride dan gofood
#
# === REMOVE REPEATED CHARACTERS ===
# Before: kenapa setiap mau mesen goride or gocar slalu milih peta manual padahal sudah di simpen lokasi favorit tapi tetap saja harus mencari manual menyusahkan
# After:  kenapa setiap mau mesen goride or gocar slalu milih peta manual padahal sudah di simpen lokasi favorit tapi tetap saja harus mencari manual menyusahkan
#
# === REMOVE REPEATED CHARACTERS ===
# Before: mrasa tidak adil tmn saya sudah otomatis dapat voucher promo goride tapi di saya gd sm sekali ishhhh sudah dimasukin kode sgala macam tetap saja hargany nromal
# After:  mrasa tidak adil tmn saya sudah otomatis dapat voucher promo goride tapi di saya gd sm sekali ishh sudah dimasukin kode sgala macam tetap saja hargany nromal
#
# === REMOVE REPEATED CHARACTERS ===
# Before: goridenya sudah bagus tapi gofoodnya masih bermasalah besar di driver saya sudah menunggu jam tidak dapat driver makanan sudah jadi tapi driver g dapat kasian restonya juga kalau makananya sudah jadi
# After:  goridenya sudah bagus tapi gofoodnya masih bermasalah besar di driver saya sudah menunggu jam tidak dapat driver makanan sudah jadi tapi driver g dapat kasian restonya juga kalau makananya sudah jadi
#
# === REMOVE REPEATED CHARACTERS ===
# Before: kenapa sekarang susah iya pesan gojek goride gocar sama saja saya buka aplikasi pakai indrive bahkan cpt banget bukan ada peningkatan kenapa jadi bahkan kemunduran sori ini udate review jujur iya kalau tidak gojek bakal ketinggalan ma yang lain
# After:  kenapa sekarang susah iya pesan gojek goride gocar sama saja saya buka aplikasi pakai indrive bahkan cpt banget bukan ada peningkatan kenapa jadi bahkan kemunduran sori ini udate review jujur iya kalau tidak gojek bakal ketinggalan ma yang lain
#
# === REMOVE REPEATED CHARACTERS ===
# Before: gojek bagaimana sih saya mau pesan goride kenapa tidak bisa tulisannya harus pakai metode lain metode lain terus
# After:  gojek bagaimana sih saya mau pesan goride kenapa tidak bisa tulisannya harus pakai metode lain metode lain terus
#
# === REMOVE REPEATED CHARACTERS ===
# Before: senang belanja di gomart kalau pas ada promo
# After:  senang belanja di gomart kalau pas ada promo
#
# === REMOVE REPEATED CHARACTERS ===
# Before: semangaaat pagiiiii para pejuang keluarga sedikit cerita tentang kekecewaan saya pakai gojek saya pernah pesan goride tapi lama banget sekitar minta baru dapat driver sekali dapat driver posisi nya jauh banget padahal saya lihat ada sekitr driver yang dekat dengan saya saya juga sempat tanya kalau rekan driver itu belum dapat orderan jadi karena terlalu lama saya menunggu saya beralihlah ke grabbike tidak sampai menit sudah dapat driver tidak sampai minta driver sudah sampai
# After:  semangaat pagii para pejuang keluarga sedikit cerita tentang kekecewaan saya pakai gojek saya pernah pesan goride tapi lama banget sekitar minta baru dapat driver sekali dapat driver posisi nya jauh banget padahal saya lihat ada sekitr driver yang dekat dengan saya saya juga sempat tanya kalau rekan driver itu belum dapat orderan jadi karena terlalu lama saya menunggu saya beralihlah ke grabbike tidak sampai menit sudah dapat driver tidak sampai minta driver sudah sampai
#
# === REMOVE REPEATED CHARACTERS ===
# Before: diskon terus
# After:  diskon terus
#
# === REMOVE REPEATED CHARACTERS ===
# Before: woi yang benar lah masa pakai goride plus titik jemputnya jadi ngaco padahal sebelumnya tidak pakai plus biasa biasa saja
# After:  woi yang benar lah masa pakai goride plus titik jemputnya jadi ngaco padahal sebelumnya tidak pakai plus biasa biasa saja
#
# === REMOVE REPEATED CHARACTERS ===
# Before: mantab
# After:  mantab
#
# === REMOVE REPEATED CHARACTERS ===
# Before: tidak ada yang mau mengambil orderan go ride aku padahal aku pakai diskon ribu saja
# After:  tidak ada yang mau mengambil orderan go ride aku padahal aku pakai diskon ribu saja
#
# === REMOVE REPEATED CHARACTERS ===
# Before: berguna bett sumpah
# After:  berguna bett sumpah
#
# === REMOVE REPEATED CHARACTERS ===
# Before: hallo gojek saya pengguna gojek dari tahun dan saya sangat senang sekali dengan app tersebut karena saya sering mendapatkan voucher goride untuk menjadi agak lebih murah dari biasanya jadi terimakasih gojek atas jasa jasa mu terima kasih
# After:  hallo gojek saya pengguna gojek dari tahun dan saya sangat senang sekali dengan app tersebut karena saya sering mendapatkan voucher goride untuk menjadi agak lebih murah dari biasanya jadi terimakasih gojek atas jasa jasa mu terima kasih
#
# === REMOVE REPEATED CHARACTERS ===
# Before: i love gojek so much tapi kenapa sekarang klu kita dapat voucher kok cuma berlaku hanya hari dapat voucher go ride nya memang lumayan paling sedikit dapat voucher bisa lebih dapat voucher go car juga paling sedikit voucher bisa lebih tapi masak kita mau wira wiri sebanyak itu dalam hari kan tidak mungkin kecuali klu kita punya asrama anak yang semua di pakaikan voucher tersebut tlg dunk bagian it jangan mau klu di suruh bagian marketing buatin program yang absurd begini
# After:  i love gojek so much tapi kenapa sekarang klu kita dapat voucher kok cuma berlaku hanya hari dapat voucher go ride nya memang lumayan paling sedikit dapat voucher bisa lebih dapat voucher go car juga paling sedikit voucher bisa lebih tapi masak kita mau wira wiri sebanyak itu dalam hari kan tidak mungkin kecuali klu kita punya asrama anak yang semua di pakaikan voucher tersebut tlg dunk bagian it jangan mau klu di suruh bagian marketing buatin program yang absurd begini
#
# === REMOVE REPEATED CHARACTERS ===
# Before: gojek melakukan blunder dengan cara customer kalau mau pesan go ride prioritas baru dapat driver yang dekat kalau tidak prioritas dapatnya driver jauh tapi kalau mau prioritas kena biaya tambahan lagi akhirnya customer pada pindah ke aplikasi lain yang kocak lagi driver di suspen gara gara nglewatin order padahal disini orang kantor gojek yang salah kenapa penjemputan jauh harusnya yang buat kebijakan ini juga di suspen karena membuat castamer susah dapat driver
# After:  gojek melakukan blunder dengan cara customer kalau mau pesan go ride prioritas baru dapat driver yang dekat kalau tidak prioritas dapatnya driver jauh tapi kalau mau prioritas kena biaya tambahan lagi akhirnya customer pada pindah ke aplikasi lain yang kocak lagi driver di suspen gara gara nglewatin order padahal disini orang kantor gojek yang salah kenapa penjemputan jauh harusnya yang buat kebijakan ini juga di suspen karena membuat castamer susah dapat driver
#
# === REMOVE REPEATED CHARACTERS ===
# Before: layanan buruk sekali terutama kalau pas hujan tidak ada driver car yang mau ambil karena entah bagaimana servernya gojek melempar pesanan pas hujan itu jauh sehingga rata driver minta di batal padahal pas banget baru dapat begitu terus kadang yang goride juga sama benar buruk sekali layanan gojek sekarang
# After:  layanan buruk sekali terutama kalau pas hujan tidak ada driver car yang mau ambil karena entah bagaimana servernya gojek melempar pesanan pas hujan itu jauh sehingga rata driver minta di batal padahal pas banget baru dapat begitu terus kadang yang goride juga sama benar buruk sekali layanan gojek sekarang
#
# === REMOVE REPEATED CHARACTERS ===
# Before: sangat membantu di saat membutuhkan
# After:  sangat membantu di saat membutuhkan
#
# Hasil setelah remove repeated characters:
#                                          after_slang  \
# 0  matikan fitur order ganda pemesanan goride seh...
# 1  tolong iya pleeeeease buat customer yang pesan...
# 2  saya harap di update kedepanya saat pesan go f...
#
#                                       after_repeated
# 0  matikan fitur order ganda pemesanan goride seh...
# 1  tolong iya pleease buat customer yang pesan gi...
# 2  saya harap di update kedepanya saat pesan go f...

# %%
# Langkah 4: Tokenisasi
print("\n=== Langkah 4: Tokenization ===")
def tokenize_text(text):
    """Tokenisasi teks"""
    before = text
    after = text.split()
    print_step("Tokenization", before, after)
    return after

df['after_tokenize'] = df['after_repeated'].apply(tokenize_text)
print("\nHasil setelah tokenization:")
df[['after_repeated', 'after_tokenize']].head(3)
# Out:
# === Langkah 4: Tokenization ===
#
# === TOKENIZATION ===
# Before: matikan fitur order ganda pemesanan goride seharusnya kalau sudah order goride tidak bisa order goride lagi sekaligus harus dibatalkan dulu baru bisa pesan lagi
# After:  ['matikan', 'fitur', 'order', 'ganda', 'pemesanan', 'goride', 'seharusnya', 'kalau', 'sudah', 'order', 'goride', 'tidak', 'bisa', 'order', 'goride', 'lagi', 'sekaligus', 'harus', 'dibatalkan', 'dulu', 'baru', 'bisa', 'pesan', 'lagi']
#
# === TOKENIZATION ===
# Before: tolong iya pleease buat customer yang pesan gibride tolong itu jempol jangan dikit cansel dikit cansel kalian beratus ratus kali cansel tidak berpengaruh tidak ngefek kitw yang driver yang kena ampas nanti sama aplikator memang kalian bayar tarif nya super mahal tapi kita dibpitong gede super gede potongannya tolong kasihani kami iya driver ojol
# After:  ['tolong', 'iya', 'pleease', 'buat', 'customer', 'yang', 'pesan', 'gibride', 'tolong', 'itu', 'jempol', 'jangan', 'dikit', 'cansel', 'dikit', 'cansel', 'kalian', 'beratus', 'ratus', 'kali', 'cansel', 'tidak', 'berpengaruh', 'tidak', 'ngefek', 'kitw', 'yang', 'driver', 'yang', 'kena', 'ampas', 'nanti', 'sama', 'aplikator', 'memang', 'kalian', 'bayar', 'tarif', 'nya', 'super', 'mahal', 'tapi', 'kita', 'dibpitong', 'gede', 'super', 'gede', 'potongannya', 'tolong', 'kasihani', 'kami', 'iya', 'driver', 'ojol']
#
# === TOKENIZATION ===
# Before: saya harap di update kedepanya saat pesan go food muncul notifikasi jangan go ride saja yang muncul
# After:  ['saya', 'harap', 'di', 'update', 'kedepanya', 'saat', 'pesan', 'go', 'food', 'muncul', 'notifikasi', 'jangan', 'go', 'ride', 'saja', 'yang', 'muncul']
#
# === TOKENIZATION ===
# Before: buatku yang tinggal agak jauh dari kota ini aplikasi yang paling cpat untuk kita dpat driver mau pesan goride ataupun pesan gofood menunggu tidak pakai lama kendaraan driver nya juga oke dan drivernya sopan sukses selalu gojek
# After:  ['buatku', 'yang', 'tinggal', 'agak', 'jauh', 'dari', 'kota', 'ini', 'aplikasi', 'yang', 'paling', 'cpat', 'untuk', 'kita', 'dpat', 'driver', 'mau', 'pesan', 'goride', 'ataupun', 'pesan', 'gofood', 'menunggu', 'tidak', 'pakai', 'lama', 'kendaraan', 'driver', 'nya', 'juga', 'oke', 'dan', 'drivernya', 'sopan', 'sukses', 'selalu', 'gojek']
#
# === TOKENIZATION ===
# Before: layanan goride sangat membantu untuk aktifitas sehari di saat motor sedang perbaikan di bengkel masukan nya mgkin Cuma kalau cuaca sedang hujan dalam situasi urgent butuh transport masih sering lama dapat driver nya
# After:  ['layanan', 'goride', 'sangat', 'membantu', 'untuk', 'aktifitas', 'sehari', 'di', 'saat', 'motor', 'sedang', 'perbaikan', 'di', 'bengkel', 'masukan', 'nya', 'mgkin', 'Cuma', 'kalau', 'cuaca', 'sedang', 'hujan', 'dalam', 'situasi', 'urgent', 'butuh', 'transport', 'masih', 'sering', 'lama', 'dapat', 'driver', 'nya']
#
# === TOKENIZATION ===
# Before: ini gojek kenapa iya sekarang saya pakai akun baru biasanya suka ada voucher tapi voucher goride sekarang tidak ada tapi giliran saya beralih ke gocar ada voucher tapi pas giliran saya buka voucher ternyata tidak ada voucher apakah bug tolong di perbaiki lahi
# After:  ['ini', 'gojek', 'kenapa', 'iya', 'sekarang', 'saya', 'pakai', 'akun', 'baru', 'biasanya', 'suka', 'ada', 'voucher', 'tapi', 'voucher', 'goride', 'sekarang', 'tidak', 'ada', 'tapi', 'giliran', 'saya', 'beralih', 'ke', 'gocar', 'ada', 'voucher', 'tapi', 'pas', 'giliran', 'saya', 'buka', 'voucher', 'ternyata', 'tidak', 'ada', 'voucher', 'apakah', 'bug', 'tolong', 'di', 'perbaiki', 'lahi']
#
# === TOKENIZATION ===
# Before: kalau terima rider seleksi dulu lah setiap naik gojek rider nya emosian melulu
# After:  ['kalau', 'terima', 'rider', 'seleksi', 'dulu', 'lah', 'setiap', 'naik', 'gojek', 'rider', 'nya', 'emosian', 'melulu']
#
# === TOKENIZATION ===
# Before: gojek sekarang mahal meskipun pakai voucher perjalanan kamu biasanya dengan harga pakai voucher go ride saja pot rb sekarang jadi alhasil beralih ke ojol sebelah
# After:  ['gojek', 'sekarang', 'mahal', 'meskipun', 'pakai', 'voucher', 'perjalanan', 'kamu', 'biasanya', 'dengan', 'harga', 'pakai', 'voucher', 'go', 'ride', 'saja', 'pot', 'rb', 'sekarang', 'jadi', 'alhasil', 'beralih', 'ke', 'ojol', 'sebelah']
#
# === TOKENIZATION ===
# Before: cepat dan murah
# After:  ['cepat', 'dan', 'murah']
#
# === TOKENIZATION ===
# Before: keren sudah murah
# After:  ['keren', 'sudah', 'murah']
#
# === TOKENIZATION ===
# Before: drivernya banyak alesan bilang tidak bawa helm terus sedang apa ambil pesanan goride saya pas saya minta batal saja dari dianya tidak mau dianya mau ambil helm dulu knapa tidak mau batal takut poinnya turun kalau begitu sedang apa ambil pesanan saya mana ngajak ribut lagi kurang ajar
# After:  ['drivernya', 'banyak', 'alesan', 'bilang', 'tidak', 'bawa', 'helm', 'terus', 'sedang', 'apa', 'ambil', 'pesanan', 'goride', 'saya', 'pas', 'saya', 'minta', 'batal', 'saja', 'dari', 'dianya', 'tidak', 'mau', 'dianya', 'mau', 'ambil', 'helm', 'dulu', 'knapa', 'tidak', 'mau', 'batal', 'takut', 'poinnya', 'turun', 'kalau', 'begitu', 'sedang', 'apa', 'ambil', 'pesanan', 'saya', 'mana', 'ngajak', 'ribut', 'lagi', 'kurang', 'ajar']
#
# === TOKENIZATION ===
# Before: rumah beda hp ee pesan go ride dng ttik dan tujuan sama kenapa nominal beda sya kena ke pakai hp ponakan ke tunai juga belum gofood klu py saya mehongg kenapa bisa begitu rumah lho padahal saya setia memakai gojeck untuk order makanan
# After:  ['rumah', 'beda', 'hp', 'ee', 'pesan', 'go', 'ride', 'dng', 'ttik', 'dan', 'tujuan', 'sama', 'kenapa', 'nominal', 'beda', 'sya', 'kena', 'ke', 'pakai', 'hp', 'ponakan', 'ke', 'tunai', 'juga', 'belum', 'gofood', 'klu', 'py', 'saya', 'mehongg', 'kenapa', 'bisa', 'begitu', 'rumah', 'lho', 'padahal', 'saya', 'setia', 'memakai', 'gojeck', 'untuk', 'order', 'makanan']
#
# === TOKENIZATION ===
# Before: drivernya mengemudikan kendaraan dengan aman dan nyaman terimakasih
# After:  ['drivernya', 'mengemudikan', 'kendaraan', 'dengan', 'aman', 'dan', 'nyaman', 'terimakasih']
#
# === TOKENIZATION ===
# Before: ok
# After:  ['ok']
#
# === TOKENIZATION ===
# Before: senang
# After:  ['senang']
#
# === TOKENIZATION ===
# Before: aplikasinya sih masih bagus tapi baru hari ini januari pesan gocar hampir kali goride kali tidak ada yang nyantol server sibuk padahal cuaca cuma gerimis kecil di pusat kota purwokerto susah sekali ini tidak siap kalau di butuhkan
# After:  ['aplikasinya', 'sih', 'masih', 'bagus', 'tapi', 'baru', 'hari', 'ini', 'januari', 'pesan', 'gocar', 'hampir', 'kali', 'goride', 'kali', 'tidak', 'ada', 'yang', 'nyantol', 'server', 'sibuk', 'padahal', 'cuaca', 'cuma', 'gerimis', 'kecil', 'di', 'pusat', 'kota', 'purwokerto', 'susah', 'sekali', 'ini', 'tidak', 'siap', 'kalau', 'di', 'butuhkan']
#
# === TOKENIZATION ===
# Before: gila order goride menunggu l banget tidak dspet driver juga padahal di depan ada driver yang lagi kumpul-kumpul malam balik kerja capek terima kasih gojek tidak langganan aagi saya
# After:  ['gila', 'order', 'goride', 'menunggu', 'l', 'banget', 'tidak', 'dspet', 'driver', 'juga', 'padahal', 'di', 'depan', 'ada', 'driver', 'yang', 'lagi', 'kumpul-kumpul', 'malam', 'balik', 'kerja', 'capek', 'terima', 'kasih', 'gojek', 'tidak', 'langganan', 'aagi', 'saya']
#
# === TOKENIZATION ===
# Before: baik
# After:  ['baik']
#
# === TOKENIZATION ===
# Before: selalu dapat driver jauh kalau pesan goride mau buru mau kerja bisa dipecat karena kelamaan apalagi kalau pesan gosend bisa menit jaraknya bisa kilo tidak kasihan sama drivernya apa
# After:  ['selalu', 'dapat', 'driver', 'jauh', 'kalau', 'pesan', 'goride', 'mau', 'buru', 'mau', 'kerja', 'bisa', 'dipecat', 'karena', 'kelamaan', 'apalagi', 'kalau', 'pesan', 'gosend', 'bisa', 'menit', 'jaraknya', 'bisa', 'kilo', 'tidak', 'kasihan', 'sama', 'drivernya', 'apa']
#
# === TOKENIZATION ===
# Before: the best apps for ride
# After:  ['the', 'best', 'apps', 'for', 'ride']
#
# === TOKENIZATION ===
# Before: alhamdulillah kalau pas pakai goride supirnya bagus dan sopan
# After:  ['alhamdulillah', 'kalau', 'pas', 'pakai', 'goride', 'supirnya', 'bagus', 'dan', 'sopan']
#
# === TOKENIZATION ===
# Before: mantap
# After:  ['mantap']
#
# === TOKENIZATION ===
# Before: kenapa saya isi gopay tidak bisa pesan goride juga bisa tlg bantuannya terima kasih
# After:  ['kenapa', 'saya', 'isi', 'gopay', 'tidak', 'bisa', 'pesan', 'goride', 'juga', 'bisa', 'tlg', 'bantuannya', 'terima', 'kasih']
#
# === TOKENIZATION ===
# Before: sangat membantu dalam beraktifitas semoga sering sering kasih diskon goridenya
# After:  ['sangat', 'membantu', 'dalam', 'beraktifitas', 'semoga', 'sering', 'sering', 'kasih', 'diskon', 'goridenya']
#
# === TOKENIZATION ===
# Before: apa apa ini gojek sama menunggu goride sampai satu jamm kacau ah terus saja ditampung keluhannya ehh tidak ada perbaikan juga sekarang lebih parah menunggu hampir menit padahal didepan saya ada drivernya dan tidak diambil tolong jangan seperti ini saya juga punya keperluan lainnya
# After:  ['apa', 'apa', 'ini', 'gojek', 'sama', 'menunggu', 'goride', 'sampai', 'satu', 'jamm', 'kacau', 'ah', 'terus', 'saja', 'ditampung', 'keluhannya', 'ehh', 'tidak', 'ada', 'perbaikan', 'juga', 'sekarang', 'lebih', 'parah', 'menunggu', 'hampir', 'menit', 'padahal', 'didepan', 'saya', 'ada', 'drivernya', 'dan', 'tidak', 'diambil', 'tolong', 'jangan', 'seperti', 'ini', 'saya', 'juga', 'punya', 'keperluan', 'lainnya']
#
# === TOKENIZATION ===
# Before: ramah terpercaya
# After:  ['ramah', 'terpercaya']
#
# === TOKENIZATION ===
# Before: boleh lah Cuma kadang kalau go ride lama banget
# After:  ['boleh', 'lah', 'Cuma', 'kadang', 'kalau', 'go', 'ride', 'lama', 'banget']
#
# === TOKENIZATION ===
# Before: bagus
# After:  ['bagus']
#
# === TOKENIZATION ===
# Before: sudah up ke gopay plus saya pikir bakal dapat voucher goride biar murah taunya tidak bisa dipakai bagaimana ini
# After:  ['sudah', 'up', 'ke', 'gopay', 'plus', 'saya', 'pikir', 'bakal', 'dapat', 'voucher', 'goride', 'biar', 'murah', 'taunya', 'tidak', 'bisa', 'dipakai', 'bagaimana', 'ini']
#
# === TOKENIZATION ===
# Before: mantaf
# After:  ['mantaf']
#
# === TOKENIZATION ===
# Before: kayaknya tidak perlu pakai gocar goride layanan hemat deh kalau memang tidak bisa digunakan tiap x dipake banyak benar alasan driver
# After:  ['kayaknya', 'tidak', 'perlu', 'pakai', 'gocar', 'goride', 'layanan', 'hemat', 'deh', 'kalau', 'memang', 'tidak', 'bisa', 'digunakan', 'tiap', 'x', 'dipake', 'banyak', 'benar', 'alasan', 'driver']
#
# === TOKENIZATION ===
# Before: terima kasih gojek sudah ada fitur pohon bisa menanam dengan seribu rupiah fitur sangat berguna untuk berbagi oksigen
# After:  ['terima', 'kasih', 'gojek', 'sudah', 'ada', 'fitur', 'pohon', 'bisa', 'menanam', 'dengan', 'seribu', 'rupiah', 'fitur', 'sangat', 'berguna', 'untuk', 'berbagi', 'oksigen']
#
# === TOKENIZATION ===
# Before: bagus baik
# After:  ['bagus', 'baik']
#
# === TOKENIZATION ===
# Before: sangat membantu
# After:  ['sangat', 'membantu']
#
# === TOKENIZATION ===
# Before: drivernya ramah
# After:  ['drivernya', 'ramah']
#
# === TOKENIZATION ===
# Before: bagus layanan
# After:  ['bagus', 'layanan']
#
# === TOKENIZATION ===
# Before: gojek selalu puas saya baik go ride maupun go car nya selalu the best
# After:  ['gojek', 'selalu', 'puas', 'saya', 'baik', 'go', 'ride', 'maupun', 'go', 'car', 'nya', 'selalu', 'the', 'best']
#
# === TOKENIZATION ===
# Before: pelanggan setia goride gocar gofood
# After:  ['pelanggan', 'setia', 'goride', 'gocar', 'gofood']
#
# === TOKENIZATION ===
# Before: bagus tapi saya pernah pesan goride bahkan driver nya salah ambil penumpang sudah saya chat ke driver tidak di respon
# After:  ['bagus', 'tapi', 'saya', 'pernah', 'pesan', 'goride', 'bahkan', 'driver', 'nya', 'salah', 'ambil', 'penumpang', 'sudah', 'saya', 'chat', 'ke', 'driver', 'tidak', 'di', 'respon']
#
# === TOKENIZATION ===
# Before: maaf ini kenapa pasar polis goride bisa motong di akun customer saya sebelumnya tidak pernah kaya begini harusnya pasar polis tidak punya akses motong saldo akun customer baru kali ini ada potongan pasar polis goride di akun customer
# After:  ['maaf', 'ini', 'kenapa', 'pasar', 'polis', 'goride', 'bisa', 'motong', 'di', 'akun', 'customer', 'saya', 'sebelumnya', 'tidak', 'pernah', 'kaya', 'begini', 'harusnya', 'pasar', 'polis', 'tidak', 'punya', 'akses', 'motong', 'saldo', 'akun', 'customer', 'baru', 'kali', 'ini', 'ada', 'potongan', 'pasar', 'polis', 'goride', 'di', 'akun', 'customer']
#
# === TOKENIZATION ===
# Before: aplikasi makin tolol pesan goride yang muncul dan datang gocar
# After:  ['aplikasi', 'makin', 'tolol', 'pesan', 'goride', 'yang', 'muncul', 'dan', 'datang', 'gocar']
#
# === TOKENIZATION ===
# Before: menunggu sampai sejam goride tapi tulisannya sibuk terus ini memang beneran pada sibuk gojek ny atau memang aplikasi nya lagi error
# After:  ['menunggu', 'sampai', 'sejam', 'goride', 'tapi', 'tulisannya', 'sibuk', 'terus', 'ini', 'memang', 'beneran', 'pada', 'sibuk', 'gojek', 'ny', 'atau', 'memang', 'aplikasi', 'nya', 'lagi', 'error']
#
# === TOKENIZATION ===
# Before: untuk saat ini saya hanya pakai gofood saja dan jarang menggunakan goride gocar karena masih trauma dengan cara mereka mengendarai kendaraan dan sempat membuat saya celaka masukan saja lebih banyak promo gofood dan voucher gratis ongkos kirim potongan ongkos kirim seperti driver oren
# After:  ['untuk', 'saat', 'ini', 'saya', 'hanya', 'pakai', 'gofood', 'saja', 'dan', 'jarang', 'menggunakan', 'goride', 'gocar', 'karena', 'masih', 'trauma', 'dengan', 'cara', 'mereka', 'mengendarai', 'kendaraan', 'dan', 'sempat', 'membuat', 'saya', 'celaka', 'masukan', 'saja', 'lebih', 'banyak', 'promo', 'gofood', 'dan', 'voucher', 'gratis', 'ongkos', 'kirim', 'potongan', 'ongkos', 'kirim', 'seperti', 'driver', 'oren']
#
# === TOKENIZATION ===
# Before: top markotop
# After:  ['top', 'markotop']
#
# === TOKENIZATION ===
# Before: selalu tepat waktu penjemputan banyak promo dan lebih hemat
# After:  ['selalu', 'tepat', 'waktu', 'penjemputan', 'banyak', 'promo', 'dan', 'lebih', 'hemat']
#
# === TOKENIZATION ===
# Before: dapat driver goride nya lama padahal di kota depok mau berangkat kerja jadi terlambat tidak kaya aplikasi sebelah dapat drivernya cepat sekalinya dapat jauh driver jemputnya
# After:  ['dapat', 'driver', 'goride', 'nya', 'lama', 'padahal', 'di', 'kota', 'depok', 'mau', 'berangkat', 'kerja', 'jadi', 'terlambat', 'tidak', 'kaya', 'aplikasi', 'sebelah', 'dapat', 'drivernya', 'cepat', 'sekalinya', 'dapat', 'jauh', 'driver', 'jemputnya']
#
# === TOKENIZATION ===
# Before: semakin lama semakin tidak guna ini aplikasi saya pesan goride di gambar banyak sekali driver terdekat eh nyantol nya di jepang saking jauhnya mana sekarang ongkos kirim nya mahal banget maaf untuk kali saya pindah ke apk sebelah tidak ribet
# After:  ['semakin', 'lama', 'semakin', 'tidak', 'guna', 'ini', 'aplikasi', 'saya', 'pesan', 'goride', 'di', 'gambar', 'banyak', 'sekali', 'driver', 'terdekat', 'eh', 'nyantol', 'nya', 'di', 'jepang', 'saking', 'jauhnya', 'mana', 'sekarang', 'ongkos', 'kirim', 'nya', 'mahal', 'banget', 'maaf', 'untuk', 'kali', 'saya', 'pindah', 'ke', 'apk', 'sebelah', 'tidak', 'ribet']
#
# === TOKENIZATION ===
# Before: mengecewakan setiap mau order gocar pas lagi hujan para driver susah untuk menerima pesanan apalagi pakai promo terutama yang buat goride alasan banyak orderan lagi ramai
# After:  ['mengecewakan', 'setiap', 'mau', 'order', 'gocar', 'pas', 'lagi', 'hujan', 'para', 'driver', 'susah', 'untuk', 'menerima', 'pesanan', 'apalagi', 'pakai', 'promo', 'terutama', 'yang', 'buat', 'goride', 'alasan', 'banyak', 'orderan', 'lagi', 'ramai']
#
# === TOKENIZATION ===
# Before: aplikasi bodoh tidak ada yang mau ambil goride driver bodoh
# After:  ['aplikasi', 'bodoh', 'tidak', 'ada', 'yang', 'mau', 'ambil', 'goride', 'driver', 'bodoh']
#
# === TOKENIZATION ===
# Before: gojek sekarang makin buruk mencari driver ny tidak dapat dapat padahl saya tidak membatalkan pesanan dan saya menunggu menit dan saya order lagi namun hasilnya sama saja tambah banyak bug saya ingin pesan makanan atau goride
# After:  ['gojek', 'sekarang', 'makin', 'buruk', 'mencari', 'driver', 'ny', 'tidak', 'dapat', 'dapat', 'padahl', 'saya', 'tidak', 'membatalkan', 'pesanan', 'dan', 'saya', 'menunggu', 'menit', 'dan', 'saya', 'order', 'lagi', 'namun', 'hasilnya', 'sama', 'saja', 'tambah', 'banyak', 'bug', 'saya', 'ingin', 'pesan', 'makanan', 'atau', 'goride']
#
# === TOKENIZATION ===
# Before: mantap sudah pokoknya mah
# After:  ['mantap', 'sudah', 'pokoknya', 'mah']
#
# === TOKENIZATION ===
# Before: untuk goride dan gocar cukup lumayan voucernya tapi gofood nya saya jarang pakai karena ada aplikasi lain jauh lebih murah
# After:  ['untuk', 'goride', 'dan', 'gocar', 'cukup', 'lumayan', 'voucernya', 'tapi', 'gofood', 'nya', 'saya', 'jarang', 'pakai', 'karena', 'ada', 'aplikasi', 'lain', 'jauh', 'lebih', 'murah']
#
# === TOKENIZATION ===
# Before: mudah di gunakan
# After:  ['mudah', 'di', 'gunakan']
#
# === TOKENIZATION ===
# Before: nice
# After:  ['nice']
#
# === TOKENIZATION ===
# Before: aplikasi tolol kalau persen goride di kasih driver yang jauh sekeliling banyak di ambilkan dari korea utara perkiraan menit ditunggu menit tidak sampai update lokasi driver juga tidak jelas
# After:  ['aplikasi', 'tolol', 'kalau', 'persen', 'goride', 'di', 'kasih', 'driver', 'yang', 'jauh', 'sekeliling', 'banyak', 'di', 'ambilkan', 'dari', 'korea', 'utara', 'perkiraan', 'menit', 'ditunggu', 'menit', 'tidak', 'sampai', 'update', 'lokasi', 'driver', 'juga', 'tidak', 'jelas']
#
# === TOKENIZATION ===
# Before: i love gojek sm setiap hari berangkat pulang sekolah always make gojek apalagi di gojek fitur goride comfort cocok banget buat aku yang suka bawa barang banyak kesekolah suka bawa tas gede begitu deh kaki nya dan pnttnya juga jadi tidak pegel jaya terus deh yaa gojek
# After:  ['i', 'love', 'gojek', 'sm', 'setiap', 'hari', 'berangkat', 'pulang', 'sekolah', 'always', 'make', 'gojek', 'apalagi', 'di', 'gojek', 'fitur', 'goride', 'comfort', 'cocok', 'banget', 'buat', 'aku', 'yang', 'suka', 'bawa', 'barang', 'banyak', 'kesekolah', 'suka', 'bawa', 'tas', 'gede', 'begitu', 'deh', 'kaki', 'nya', 'dan', 'pnttnya', 'juga', 'jadi', 'tidak', 'pegel', 'jaya', 'terus', 'deh', 'yaa', 'gojek']
#
# === TOKENIZATION ===
# Before: kenapa saat saya ingin menggunakan go ride dia berubah go car kan jadi mahal ongkosnya
# After:  ['kenapa', 'saat', 'saya', 'ingin', 'menggunakan', 'go', 'ride', 'dia', 'berubah', 'go', 'car', 'kan', 'jadi', 'mahal', 'ongkosnya']
#
# === TOKENIZATION ===
# Before: good
# After:  ['good']
#
# === TOKENIZATION ===
# Before: apa apa go transit sekarang digabung sama go ridetransit jadinya tidak bisa edit stasiun kalau tujuannya berubah padahal sblum update bisa kalau diupdate makin nyusahin lebih baik gausah di update tujuannya update kan untuk memudahkan bukan bahkan mempersulit
# After:  ['apa', 'apa', 'go', 'transit', 'sekarang', 'digabung', 'sama', 'go', 'ridetransit', 'jadinya', 'tidak', 'bisa', 'edit', 'stasiun', 'kalau', 'tujuannya', 'berubah', 'padahal', 'sblum', 'update', 'bisa', 'kalau', 'diupdate', 'makin', 'nyusahin', 'lebih', 'baik', 'gausah', 'di', 'update', 'tujuannya', 'update', 'kan', 'untuk', 'memudahkan', 'bukan', 'bahkan', 'mempersulit']
#
# === TOKENIZATION ===
# Before: layanan nya lebih baik daripada aplikasi sebelah pilihannya juga banyak
# After:  ['layanan', 'nya', 'lebih', 'baik', 'daripada', 'aplikasi', 'sebelah', 'pilihannya', 'juga', 'banyak']
#
# === TOKENIZATION ===
# Before: mantap
# After:  ['mantap']
#
# === TOKENIZATION ===
# Before: padahal pakai aplikasi ini sudah lama tiba hari ini bingung pas check goride harganya dari rb naik jadi rb eh iseng buka grab Cuma bayar rb
# After:  ['padahal', 'pakai', 'aplikasi', 'ini', 'sudah', 'lama', 'tiba', 'hari', 'ini', 'bingung', 'pas', 'check', 'goride', 'harganya', 'dari', 'rb', 'naik', 'jadi', 'rb', 'eh', 'iseng', 'buka', 'grab', 'Cuma', 'bayar', 'rb']
#
# === TOKENIZATION ===
# Before: susah dapat driver sudah x pesan tetep tidak dapat pindah dari menu go ride ke go car cmn hasilny nihil sama saja parah sih
# After:  ['susah', 'dapat', 'driver', 'sudah', 'x', 'pesan', 'tetep', 'tidak', 'dapat', 'pindah', 'dari', 'menu', 'go', 'ride', 'ke', 'go', 'car', 'cmn', 'hasilny', 'nihil', 'sama', 'saja', 'parah', 'sih']
#
# === TOKENIZATION ===
# Before: saya suka pakai jasa goride gocar seneng saja denger curhatan mereka cerita mereka keluh kesah mereka cerita sedih cerita bahagia semuanya saya rangkum jadi motivasi buat diri sendiri
# After:  ['saya', 'suka', 'pakai', 'jasa', 'goride', 'gocar', 'seneng', 'saja', 'denger', 'curhatan', 'mereka', 'cerita', 'mereka', 'keluh', 'kesah', 'mereka', 'cerita', 'sedih', 'cerita', 'bahagia', 'semuanya', 'saya', 'rangkum', 'jadi', 'motivasi', 'buat', 'diri', 'sendiri']
#
# === TOKENIZATION ===
# Before: ok
# After:  ['ok']
#
# === TOKENIZATION ===
# Before: mau milih go transit tapi selalu dialihkan ke go ride
# After:  ['mau', 'milih', 'go', 'transit', 'tapi', 'selalu', 'dialihkan', 'ke', 'go', 'ride']
#
# === TOKENIZATION ===
# Before: i got safety when i was ride gojek
# After:  ['i', 'got', 'safety', 'when', 'i', 'was', 'ride', 'gojek']
#
# === TOKENIZATION ===
# Before: untuk goride lebih mudah dulu
# After:  ['untuk', 'goride', 'lebih', 'mudah', 'dulu']
#
# === TOKENIZATION ===
# Before: kenapa aku masukkan kode promo goride sudah sukses tapi vocer promonya gada aku sudah cba update masin tetap sma sudah hpus download bbrapa kli tapi tetap sama kenapa iya apakah eror tapi cba punya teman mah gada masalah apa
# After:  ['kenapa', 'aku', 'masukkan', 'kode', 'promo', 'goride', 'sudah', 'sukses', 'tapi', 'vocer', 'promonya', 'gada', 'aku', 'sudah', 'cba', 'update', 'masin', 'tetap', 'sma', 'sudah', 'hpus', 'download', 'bbrapa', 'kli', 'tapi', 'tetap', 'sama', 'kenapa', 'iya', 'apakah', 'eror', 'tapi', 'cba', 'punya', 'teman', 'mah', 'gada', 'masalah', 'apa']
#
# === TOKENIZATION ===
# Before: pesan goride posisi driver dekat tidak mau pada mengambil di kasihnya yang jaraknya jauh semuanya sbagian di batal sama drivernya
# After:  ['pesan', 'goride', 'posisi', 'driver', 'dekat', 'tidak', 'mau', 'pada', 'mengambil', 'di', 'kasihnya', 'yang', 'jaraknya', 'jauh', 'semuanya', 'sbagian', 'di', 'batal', 'sama', 'drivernya']
#
# === TOKENIZATION ===
# Before: mohon pihak gojek memberikan saya pembelaan karena saya selalu pulang dengan goride tetapi tadi saya mendapat perlakuan yang sangat tidak menyenangkan karena saat saya membantalkan pesanan karena titik jemput tidak sesuai saya tetap didatangi driver tersebut dan driver tersebut marah bahkan sampai orang melihat saya disitu saya sangat malu karena hal tersebut mohon bantuannya untuk menegur mengingat kan driver tersebut
# After:  ['mohon', 'pihak', 'gojek', 'memberikan', 'saya', 'pembelaan', 'karena', 'saya', 'selalu', 'pulang', 'dengan', 'goride', 'tetapi', 'tadi', 'saya', 'mendapat', 'perlakuan', 'yang', 'sangat', 'tidak', 'menyenangkan', 'karena', 'saat', 'saya', 'membantalkan', 'pesanan', 'karena', 'titik', 'jemput', 'tidak', 'sesuai', 'saya', 'tetap', 'didatangi', 'driver', 'tersebut', 'dan', 'driver', 'tersebut', 'marah', 'bahkan', 'sampai', 'orang', 'melihat', 'saya', 'disitu', 'saya', 'sangat', 'malu', 'karena', 'hal', 'tersebut', 'mohon', 'bantuannya', 'untuk', 'menegur', 'mengingat', 'kan', 'driver', 'tersebut']
#
# === TOKENIZATION ===
# Before: layanan yang memudahkan masyarakat
# After:  ['layanan', 'yang', 'memudahkan', 'masyarakat']
#
# === TOKENIZATION ===
# Before: tolong untuk goride tidak perlu di pisah antara yang hemat sama yang comfort karena percuma jika tidak ada perhatian dari pihak gojeknya pengalaman saya pesan comfort tapi motor yang datang beda plat nomor beda jenisnya masuk kategori hemat tolong lebih diperhatikan lagi khusus driver goride nya karena keselamatan diatas segalanya
# After:  ['tolong', 'untuk', 'goride', 'tidak', 'perlu', 'di', 'pisah', 'antara', 'yang', 'hemat', 'sama', 'yang', 'comfort', 'karena', 'percuma', 'jika', 'tidak', 'ada', 'perhatian', 'dari', 'pihak', 'gojeknya', 'pengalaman', 'saya', 'pesan', 'comfort', 'tapi', 'motor', 'yang', 'datang', 'beda', 'plat', 'nomor', 'beda', 'jenisnya', 'masuk', 'kategori', 'hemat', 'tolong', 'lebih', 'diperhatikan', 'lagi', 'khusus', 'driver', 'goride', 'nya', 'karena', 'keselamatan', 'diatas', 'segalanya']
#
# === TOKENIZATION ===
# Before: ok
# After:  ['ok']
#
# === TOKENIZATION ===
# Before: sangat membantu bagi saya dari goride gocar gofood
# After:  ['sangat', 'membantu', 'bagi', 'saya', 'dari', 'goride', 'gocar', 'gofood']
#
# === TOKENIZATION ===
# Before: gofood nya mengecewakan sekali sudah menunggu sampai jam bahkan dibatalin dengan alasan gada driver kalau memang tidak niat bisnis lebih baik tutup saja aplikasinya bukan hanya itu saja pesan goride dan lain-lain juga selalu drivernya gada padahal jelas jelas banyak driver disekitar lokasi makin hari makin tidak banget ini aplikasi
# After:  ['gofood', 'nya', 'mengecewakan', 'sekali', 'sudah', 'menunggu', 'sampai', 'jam', 'bahkan', 'dibatalin', 'dengan', 'alasan', 'gada', 'driver', 'kalau', 'memang', 'tidak', 'niat', 'bisnis', 'lebih', 'baik', 'tutup', 'saja', 'aplikasinya', 'bukan', 'hanya', 'itu', 'saja', 'pesan', 'goride', 'dan', 'lain-lain', 'juga', 'selalu', 'drivernya', 'gada', 'padahal', 'jelas', 'jelas', 'banyak', 'driver', 'disekitar', 'lokasi', 'makin', 'hari', 'makin', 'tidak', 'banget', 'ini', 'aplikasi']
#
# === TOKENIZATION ===
# Before: tidak pernah dapat voucher goride jompor saya setiap hari pakai goride pulang pergi rb gaperna dapat voucher goride
# After:  ['tidak', 'pernah', 'dapat', 'voucher', 'goride', 'jompor', 'saya', 'setiap', 'hari', 'pakai', 'goride', 'pulang', 'pergi', 'rb', 'gaperna', 'dapat', 'voucher', 'goride']
#
# === TOKENIZATION ===
# Before: verygood
# After:  ['verygood']
#
# === TOKENIZATION ===
# Before: tiap transaksi di gojek toped blibli alfagift kenapa selalu gopaylaternya ditulis diblokir limit aman tagihan belum japo masa cuma bisa dipakai buat goride gocar saja bagaimana ini
# After:  ['tiap', 'transaksi', 'di', 'gojek', 'toped', 'blibli', 'alfagift', 'kenapa', 'selalu', 'gopaylaternya', 'ditulis', 'diblokir', 'limit', 'aman', 'tagihan', 'belum', 'japo', 'masa', 'cuma', 'bisa', 'dipakai', 'buat', 'goride', 'gocar', 'saja', 'bagaimana', 'ini']
#
# === TOKENIZATION ===
# Before: sudah order goride lama menunggu dapat drivernya sudah begitu susah di batalin jauh sama aplikasi tetangga
# After:  ['sudah', 'order', 'goride', 'lama', 'menunggu', 'dapat', 'drivernya', 'sudah', 'begitu', 'susah', 'di', 'batalin', 'jauh', 'sama', 'aplikasi', 'tetangga']
#
# === TOKENIZATION ===
# Before: mau bayar tagihan gopay later tapi aplikasi gangguan terus mau order goride gocar juga sring tidak ada driver tulisannya padahal driver nya bnyak trlihat diaplikasi gojek mkin buruk sekarang aplikasinya kyknya sudah tidak tahu diperbaiki dengan cepat
# After:  ['mau', 'bayar', 'tagihan', 'gopay', 'later', 'tapi', 'aplikasi', 'gangguan', 'terus', 'mau', 'order', 'goride', 'gocar', 'juga', 'sring', 'tidak', 'ada', 'driver', 'tulisannya', 'padahal', 'driver', 'nya', 'bnyak', 'trlihat', 'diaplikasi', 'gojek', 'mkin', 'buruk', 'sekarang', 'aplikasinya', 'kyknya', 'sudah', 'tidak', 'tahu', 'diperbaiki', 'dengan', 'cepat']
#
# === TOKENIZATION ===
# Before: sudah sering pakai gojek mesen makan atau pun goride tetep saja sampai detik ini tidak di buka gopaylater atau gopinjam nya masa kalah sama yang baru daftar dan order cuma beberapa saja langsung bisa dapat limit gopaylater anehh banget lumayan kecewa si sama aplikasi ini merasa tidak adil
# After:  ['sudah', 'sering', 'pakai', 'gojek', 'mesen', 'makan', 'atau', 'pun', 'goride', 'tetep', 'saja', 'sampai', 'detik', 'ini', 'tidak', 'di', 'buka', 'gopaylater', 'atau', 'gopinjam', 'nya', 'masa', 'kalah', 'sama', 'yang', 'baru', 'daftar', 'dan', 'order', 'cuma', 'beberapa', 'saja', 'langsung', 'bisa', 'dapat', 'limit', 'gopaylater', 'anehh', 'banget', 'lumayan', 'kecewa', 'si', 'sama', 'aplikasi', 'ini', 'merasa', 'tidak', 'adil']
#
# === TOKENIZATION ===
# Before: saya pelanggan goride dan gosend tidak ada masalah cuma saya kecewa sama go car di jogja kenapa rata tidak niat iya padahal kan yang milih acak dari aplikasi juga masa cuma karena jauh dikit minta dicancel padahal cm kamu jemputnya jarak yang dianter pun juga tidak jauh amat masih kamu semoga pihak gojek bisa menyortir lagi driver gocar yang cuma iseng males an tertawa kacau
# After:  ['saya', 'pelanggan', 'goride', 'dan', 'gosend', 'tidak', 'ada', 'masalah', 'cuma', 'saya', 'kecewa', 'sama', 'go', 'car', 'di', 'jogja', 'kenapa', 'rata', 'tidak', 'niat', 'iya', 'padahal', 'kan', 'yang', 'milih', 'acak', 'dari', 'aplikasi', 'juga', 'masa', 'cuma', 'karena', 'jauh', 'dikit', 'minta', 'dicancel', 'padahal', 'cm', 'kamu', 'jemputnya', 'jarak', 'yang', 'dianter', 'pun', 'juga', 'tidak', 'jauh', 'amat', 'masih', 'kamu', 'semoga', 'pihak', 'gojek', 'bisa', 'menyortir', 'lagi', 'driver', 'gocar', 'yang', 'cuma', 'iseng', 'males', 'an', 'tertawa', 'kacau']
#
# === TOKENIZATION ===
# Before: tolong kalau kita sedang pesan goride gocar cari driver yang lokasinya dekat dengan titik penjemputan sering banget dapat driver yang jaraknya jauh padahal driver yang mangkal di sekitar lokasi penjemputan banyak bangett tolong di perbaiki lagi jangan buang waktu kami hanya untuk menunggu driver yang datengnya lama karena jaraknya jauh
# After:  ['tolong', 'kalau', 'kita', 'sedang', 'pesan', 'goride', 'gocar', 'cari', 'driver', 'yang', 'lokasinya', 'dekat', 'dengan', 'titik', 'penjemputan', 'sering', 'banget', 'dapat', 'driver', 'yang', 'jaraknya', 'jauh', 'padahal', 'driver', 'yang', 'mangkal', 'di', 'sekitar', 'lokasi', 'penjemputan', 'banyak', 'bangett', 'tolong', 'di', 'perbaiki', 'lagi', 'jangan', 'buang', 'waktu', 'kami', 'hanya', 'untuk', 'menunggu', 'driver', 'yang', 'datengnya', 'lama', 'karena', 'jaraknya', 'jauh']
#
# === TOKENIZATION ===
# Before: apa saja ada mulai car ride dan food keren
# After:  ['apa', 'saja', 'ada', 'mulai', 'car', 'ride', 'dan', 'food', 'keren']
#
# === TOKENIZATION ===
# Before: tidak suka sama gojek sekarang kadang pakai go ride hemat tidak diterima sama driver padahal meringankan pengeluaran kalau lagi tanggal tua sudah begitu kalau pagi susahnya minta ampun sekalinya dapat cuma jarak menit dia bilang kejauhan saya males pernah juga saya lebih dekat ke lokasi tujuan situ jadi kalau saya jemput bulak balik dong
# After:  ['tidak', 'suka', 'sama', 'gojek', 'sekarang', 'kadang', 'pakai', 'go', 'ride', 'hemat', 'tidak', 'diterima', 'sama', 'driver', 'padahal', 'meringankan', 'pengeluaran', 'kalau', 'lagi', 'tanggal', 'tua', 'sudah', 'begitu', 'kalau', 'pagi', 'susahnya', 'minta', 'ampun', 'sekalinya', 'dapat', 'cuma', 'jarak', 'menit', 'dia', 'bilang', 'kejauhan', 'saya', 'males', 'pernah', 'juga', 'saya', 'lebih', 'dekat', 'ke', 'lokasi', 'tujuan', 'situ', 'jadi', 'kalau', 'saya', 'jemput', 'bulak', 'balik', 'dong']
#
# === TOKENIZATION ===
# Before: saya kecewa dengan driver goride setiap hujan pasti tidak ada yang mengambil orderan alasan tidak bawa jas hujan padahal saya sudah chat kalau saya bawa jas hujan buat apa ngojek kalau tidak sedia jas hujan untuk diri sendiri
# After:  ['saya', 'kecewa', 'dengan', 'driver', 'goride', 'setiap', 'hujan', 'pasti', 'tidak', 'ada', 'yang', 'mengambil', 'orderan', 'alasan', 'tidak', 'bawa', 'jas', 'hujan', 'padahal', 'saya', 'sudah', 'chat', 'kalau', 'saya', 'bawa', 'jas', 'hujan', 'buat', 'apa', 'ngojek', 'kalau', 'tidak', 'sedia', 'jas', 'hujan', 'untuk', 'diri', 'sendiri']
#
# === TOKENIZATION ===
# Before: sekarang sudah mahal goride dan gofood
# After:  ['sekarang', 'sudah', 'mahal', 'goride', 'dan', 'gofood']
#
# === TOKENIZATION ===
# Before: gampang kalau mau cari alamat enak
# After:  ['gampang', 'kalau', 'mau', 'cari', 'alamat', 'enak']
#
# === TOKENIZATION ===
# Before: fitur go pay later go pay pinjam tidak bisa di non aktifkan lama kaya aplikasi pinjol rawan penyalahgunaan ridernya seneng banget batalin sendiri sudah menunggu lama tidak kaya sebelah
# After:  ['fitur', 'go', 'pay', 'later', 'go', 'pay', 'pinjam', 'tidak', 'bisa', 'di', 'non', 'aktifkan', 'lama', 'kaya', 'aplikasi', 'pinjol', 'rawan', 'penyalahgunaan', 'ridernya', 'seneng', 'banget', 'batalin', 'sendiri', 'sudah', 'menunggu', 'lama', 'tidak', 'kaya', 'sebelah']
#
# === TOKENIZATION ===
# Before: tahun mengunakan gojek perlu di benahi driver berbeda dengan aplikasi apakah boleh orang yang bukan driver memakai akun driver gojek joki mengantarkan pesanan takut makanan saya di apa apin dengan orang yang bukan driver gojek joki mana lagi motor yang di pakai joki plat nya berbeda dengan aplikasi pesan goride juga begitu sih driver yang jemput orangnya berbeda dengan aplikasi plat nomor motor nya juga berbeda saya jadi was was takut tolong adakan vermuk berwaktu seperti grab
# After:  ['tahun', 'mengunakan', 'gojek', 'perlu', 'di', 'benahi', 'driver', 'berbeda', 'dengan', 'aplikasi', 'apakah', 'boleh', 'orang', 'yang', 'bukan', 'driver', 'memakai', 'akun', 'driver', 'gojek', 'joki', 'mengantarkan', 'pesanan', 'takut', 'makanan', 'saya', 'di', 'apa', 'apin', 'dengan', 'orang', 'yang', 'bukan', 'driver', 'gojek', 'joki', 'mana', 'lagi', 'motor', 'yang', 'di', 'pakai', 'joki', 'plat', 'nya', 'berbeda', 'dengan', 'aplikasi', 'pesan', 'goride', 'juga', 'begitu', 'sih', 'driver', 'yang', 'jemput', 'orangnya', 'berbeda', 'dengan', 'aplikasi', 'plat', 'nomor', 'motor', 'nya', 'juga', 'berbeda', 'saya', 'jadi', 'was', 'was', 'takut', 'tolong', 'adakan', 'vermuk', 'berwaktu', 'seperti', 'grab']
#
# === TOKENIZATION ===
# Before: bagaimana ini waktu mau order goride kendala kenapa bisa ada keterangan internetnya mati padhal kuota banyak melimpahh coba cek gojek di adek bisa buat mesen padahal punyaku biasane pakai juga baik saja tolong segera diperbaiki
# After:  ['bagaimana', 'ini', 'waktu', 'mau', 'order', 'goride', 'kendala', 'kenapa', 'bisa', 'ada', 'keterangan', 'internetnya', 'mati', 'padhal', 'kuota', 'banyak', 'melimpahh', 'coba', 'cek', 'gojek', 'di', 'adek', 'bisa', 'buat', 'mesen', 'padahal', 'punyaku', 'biasane', 'pakai', 'juga', 'baik', 'saja', 'tolong', 'segera', 'diperbaiki']
#
# === TOKENIZATION ===
# Before: woi harga goride nya kenapa nambah dari hari ke hari tempat nya sama saja kenapa masa gara gara cuaca panas atau hujan jadi naik kalau hujan ok lah tapi tidak ngotak juga kalau kali njir oh kualitas nya yang bikin nambah perasaan sama saja deh mau hemat atau comfort hoki an saja lihat maxim iya murah nomor diskon tidak menarik tapi segitu saja terus
# After:  ['woi', 'harga', 'goride', 'nya', 'kenapa', 'nambah', 'dari', 'hari', 'ke', 'hari', 'tempat', 'nya', 'sama', 'saja', 'kenapa', 'masa', 'gara', 'gara', 'cuaca', 'panas', 'atau', 'hujan', 'jadi', 'naik', 'kalau', 'hujan', 'ok', 'lah', 'tapi', 'tidak', 'ngotak', 'juga', 'kalau', 'kali', 'njir', 'oh', 'kualitas', 'nya', 'yang', 'bikin', 'nambah', 'perasaan', 'sama', 'saja', 'deh', 'mau', 'hemat', 'atau', 'comfort', 'hoki', 'an', 'saja', 'lihat', 'maxim', 'iya', 'murah', 'nomor', 'diskon', 'tidak', 'menarik', 'tapi', 'segitu', 'saja', 'terus']
#
# === TOKENIZATION ===
# Before: thank you
# After:  ['thank', 'you']
#
# === TOKENIZATION ===
# Before: ok cepat dan tepat
# After:  ['ok', 'cepat', 'dan', 'tepat']
#
# === TOKENIZATION ===
# Before: dc nya suka ngancam
# After:  ['dc', 'nya', 'suka', 'ngancam']
#
# === TOKENIZATION ===
# Before: jasa biaya gojek nya sudah mahal di tambah lagi pesan go food atau go ride dan lain-lain kena double order sebagai custumer merasa di rugikan rugi sudah bayar mahal dan rugi waktu menunggu jadi lama gojek makin tidak jelas sekarang
# After:  ['jasa', 'biaya', 'gojek', 'nya', 'sudah', 'mahal', 'di', 'tambah', 'lagi', 'pesan', 'go', 'food', 'atau', 'go', 'ride', 'dan', 'lain-lain', 'kena', 'double', 'order', 'sebagai', 'custumer', 'merasa', 'di', 'rugikan', 'rugi', 'sudah', 'bayar', 'mahal', 'dan', 'rugi', 'waktu', 'menunggu', 'jadi', 'lama', 'gojek', 'makin', 'tidak', 'jelas', 'sekarang']
#
# === TOKENIZATION ===
# Before: terimakasih
# After:  ['terimakasih']
#
# === TOKENIZATION ===
# Before: banyakin promonya khususnya goride and gofood
# After:  ['banyakin', 'promonya', 'khususnya', 'goride', 'and', 'gofood']
#
# === TOKENIZATION ===
# Before: akun saya ke blokir tolong bagaimana solusinya sudah ngechat cs responnya sama selalu laporan ditutup solusi dong keterangannya ke blokir dan tidak bisa menggunakan berbagai voucher termasuk goride gofood tolong bagaimana biar normal lagi
# After:  ['akun', 'saya', 'ke', 'blokir', 'tolong', 'bagaimana', 'solusinya', 'sudah', 'ngechat', 'cs', 'responnya', 'sama', 'selalu', 'laporan', 'ditutup', 'solusi', 'dong', 'keterangannya', 'ke', 'blokir', 'dan', 'tidak', 'bisa', 'menggunakan', 'berbagai', 'voucher', 'termasuk', 'goride', 'gofood', 'tolong', 'bagaimana', 'biar', 'normal', 'lagi']
#
# === TOKENIZATION ===
# Before: bagus minta tolong lebih banyak promo untuk gocar sama goride comfort supaya bisa menikmati perjalanan dengan hemat dan nyaman terima kasih
# After:  ['bagus', 'minta', 'tolong', 'lebih', 'banyak', 'promo', 'untuk', 'gocar', 'sama', 'goride', 'comfort', 'supaya', 'bisa', 'menikmati', 'perjalanan', 'dengan', 'hemat', 'dan', 'nyaman', 'terima', 'kasih']
#
# === TOKENIZATION ===
# Before: gilaa saldo hilang gtu saja terus call center tidak ngebantu banget masa order goride gadapet sampai kali dan saldonya ketarik nya apa in ini gojek
# After:  ['gilaa', 'saldo', 'hilang', 'gtu', 'saja', 'terus', 'call', 'center', 'tidak', 'ngebantu', 'banget', 'masa', 'order', 'goride', 'gadapet', 'sampai', 'kali', 'dan', 'saldonya', 'ketarik', 'nya', 'apa', 'in', 'ini', 'gojek']
#
# === TOKENIZATION ===
# Before: kemarin siang masih bisa pesan goride pakai gopaylater tapi pas malam tiba tiba di gopaylater di blokir padahal tagihan belum jatuh tempo dan limit masih sangat sangat banyak sudah laporan tapi belum di tanggapi kecewa
# After:  ['kemarin', 'siang', 'masih', 'bisa', 'pesan', 'goride', 'pakai', 'gopaylater', 'tapi', 'pas', 'malam', 'tiba', 'tiba', 'di', 'gopaylater', 'di', 'blokir', 'padahal', 'tagihan', 'belum', 'jatuh', 'tempo', 'dan', 'limit', 'masih', 'sangat', 'sangat', 'banyak', 'sudah', 'laporan', 'tapi', 'belum', 'di', 'tanggapi', 'kecewa']
#
# === TOKENIZATION ===
# Before: kenapa tidak bisa tukar voucher gorideaja sudah ditukar bilangnya berhasil tapi di cek di halaman voucher tidak ada sama sekali voucher nya kosongg
# After:  ['kenapa', 'tidak', 'bisa', 'tukar', 'voucher', 'gorideaja', 'sudah', 'ditukar', 'bilangnya', 'berhasil', 'tapi', 'di', 'cek', 'di', 'halaman', 'voucher', 'tidak', 'ada', 'sama', 'sekali', 'voucher', 'nya', 'kosongg']
#
# === TOKENIZATION ===
# Before: sangat membantu
# After:  ['sangat', 'membantu']
#
# === TOKENIZATION ===
# Before: keren ini sekarang gojek dapat driver nya cepat dan cepat sampai tidak menunggu lama dapat vocher diskon goride gocar gofood terus tapi saya minta tolong dong vocher goride nya ada setiap hari jadi bisa membantu anak sekolah dengan promo yang murah dibawah ribu
# After:  ['keren', 'ini', 'sekarang', 'gojek', 'dapat', 'driver', 'nya', 'cepat', 'dan', 'cepat', 'sampai', 'tidak', 'menunggu', 'lama', 'dapat', 'vocher', 'diskon', 'goride', 'gocar', 'gofood', 'terus', 'tapi', 'saya', 'minta', 'tolong', 'dong', 'vocher', 'goride', 'nya', 'ada', 'setiap', 'hari', 'jadi', 'bisa', 'membantu', 'anak', 'sekolah', 'dengan', 'promo', 'yang', 'murah', 'dibawah', 'ribu']
#
# === TOKENIZATION ===
# Before: gojek pasti ada jalan
# After:  ['gojek', 'pasti', 'ada', 'jalan']
#
# === TOKENIZATION ===
# Before: kenapa map goride setiap dekat tol pasti di arahi ke lewat tol sehingga tarif tidak sesuai terima kasih
# After:  ['kenapa', 'map', 'goride', 'setiap', 'dekat', 'tol', 'pasti', 'di', 'arahi', 'ke', 'lewat', 'tol', 'sehingga', 'tarif', 'tidak', 'sesuai', 'terima', 'kasih']
#
# === TOKENIZATION ===
# Before: saya juga driver go ride min sangat disayangkan kalau orderan dibuat susah sekarang dan bahkan bensin x pengeluaran akhirnya saya akali beli Cuma rb supaya tidak rugi sejak system yang paling terdekat diterapkan sejak system goride yang sangat terdekat diterapkan otomatis pendapatan kita berkurang drastis kita sebagai costumer gojek juga tidak bisa membantu orderan seperti biasanya bahkan belanja di tokopedia semoga system update terbaru pendapatan kita kembali konsisten diatas lagi amin
# After:  ['saya', 'juga', 'driver', 'go', 'ride', 'min', 'sangat', 'disayangkan', 'kalau', 'orderan', 'dibuat', 'susah', 'sekarang', 'dan', 'bahkan', 'bensin', 'x', 'pengeluaran', 'akhirnya', 'saya', 'akali', 'beli', 'Cuma', 'rb', 'supaya', 'tidak', 'rugi', 'sejak', 'system', 'yang', 'paling', 'terdekat', 'diterapkan', 'sejak', 'system', 'goride', 'yang', 'sangat', 'terdekat', 'diterapkan', 'otomatis', 'pendapatan', 'kita', 'berkurang', 'drastis', 'kita', 'sebagai', 'costumer', 'gojek', 'juga', 'tidak', 'bisa', 'membantu', 'orderan', 'seperti', 'biasanya', 'bahkan', 'belanja', 'di', 'tokopedia', 'semoga', 'system', 'update', 'terbaru', 'pendapatan', 'kita', 'kembali', 'konsisten', 'diatas', 'lagi', 'amin']
#
# === TOKENIZATION ===
# Before: kami pelajar turunkan tarif go ride kami kaum missqueen
# After:  ['kami', 'pelajar', 'turunkan', 'tarif', 'go', 'ride', 'kami', 'kaum', 'missqueen']
#
# === TOKENIZATION ===
# Before: good
# After:  ['good']
#
# === TOKENIZATION ===
# Before: awal memakai aplikasi gojek puas makin kesini keseringan kecewa order makanan susah dapat driver nya harus menunggu hampir satu jam begitu pun untuk goride mohon diperhatikan dan ditindaklanjuti kedepannya
# After:  ['awal', 'memakai', 'aplikasi', 'gojek', 'puas', 'makin', 'kesini', 'keseringan', 'kecewa', 'order', 'makanan', 'susah', 'dapat', 'driver', 'nya', 'harus', 'menunggu', 'hampir', 'satu', 'jam', 'begitu', 'pun', 'untuk', 'goride', 'mohon', 'diperhatikan', 'dan', 'ditindaklanjuti', 'kedepannya']
#
# === TOKENIZATION ===
# Before: program sudah bagus pertahankan di tingkatkan lagi layanan serta tolong di sejahterakan driver driver nya berikan mereka penghidupan layak
# After:  ['program', 'sudah', 'bagus', 'pertahankan', 'di', 'tingkatkan', 'lagi', 'layanan', 'serta', 'tolong', 'di', 'sejahterakan', 'driver', 'driver', 'nya', 'berikan', 'mereka', 'penghidupan', 'layak']
#
# === TOKENIZATION ===
# Before: sangat membantu
# After:  ['sangat', 'membantu']
#
# === TOKENIZATION ===
# Before: go ride tidak bisa melayani pas lagi hujan padahal gerimis saja jam order tidak ada yang nyangkut berharap sm gojek nyampe kantor terlambat
# After:  ['go', 'ride', 'tidak', 'bisa', 'melayani', 'pas', 'lagi', 'hujan', 'padahal', 'gerimis', 'saja', 'jam', 'order', 'tidak', 'ada', 'yang', 'nyangkut', 'berharap', 'sm', 'gojek', 'nyampe', 'kantor', 'terlambat']
#
# === TOKENIZATION ===
# Before: mantap
# After:  ['mantap']
#
# === TOKENIZATION ===
# Before: mudah an semakin bnyak promonya bukan hanya gofood tapi promo gocar goride dan lain-lain juga
# After:  ['mudah', 'an', 'semakin', 'bnyak', 'promonya', 'bukan', 'hanya', 'gofood', 'tapi', 'promo', 'gocar', 'goride', 'dan', 'lain-lain', 'juga']
#
# === TOKENIZATION ===
# Before: niatnya mau top up gopay ke driver dengan cara order go ride pas driver datang bisa top up dan saldo masuk tapi dia kira saya mau pergi ke tempat yang saya tuju dan saya harus bayar ongkos trip tersebut rugi dong
# After:  ['niatnya', 'mau', 'top', 'up', 'gopay', 'ke', 'driver', 'dengan', 'cara', 'order', 'go', 'ride', 'pas', 'driver', 'datang', 'bisa', 'top', 'up', 'dan', 'saldo', 'masuk', 'tapi', 'dia', 'kira', 'saya', 'mau', 'pergi', 'ke', 'tempat', 'yang', 'saya', 'tuju', 'dan', 'saya', 'harus', 'bayar', 'ongkos', 'trip', 'tersebut', 'rugi', 'dong']
#
# === TOKENIZATION ===
# Before: driver driver sekarang pada malas sudah tahu titik nya sesuai bahkan jauh banget sudah begitu mau nya di samperin kan pesan ojol online agar kita praktis tapi ini gosend pun dan goride pun seperti ini memang banyak si voucher nya tapi memang begitu yaa maaf
# After:  ['driver', 'driver', 'sekarang', 'pada', 'malas', 'sudah', 'tahu', 'titik', 'nya', 'sesuai', 'bahkan', 'jauh', 'banget', 'sudah', 'begitu', 'mau', 'nya', 'di', 'samperin', 'kan', 'pesan', 'ojol', 'online', 'agar', 'kita', 'praktis', 'tapi', 'ini', 'gosend', 'pun', 'dan', 'goride', 'pun', 'seperti', 'ini', 'memang', 'banyak', 'si', 'voucher', 'nya', 'tapi', 'memang', 'begitu', 'yaa', 'maaf']
#
# === TOKENIZATION ===
# Before: tampilan aplikasi gojek semakin nyaman untuk dilihat menarik penggunaan aplikasi gojek hingga saat ini masih nyaman aman praktis dan suka order gofood goride lewat aplikasi gojek semoga bisa nambah terus promo buat gofood nya he
# After:  ['tampilan', 'aplikasi', 'gojek', 'semakin', 'nyaman', 'untuk', 'dilihat', 'menarik', 'penggunaan', 'aplikasi', 'gojek', 'hingga', 'saat', 'ini', 'masih', 'nyaman', 'aman', 'praktis', 'dan', 'suka', 'order', 'gofood', 'goride', 'lewat', 'aplikasi', 'gojek', 'semoga', 'bisa', 'nambah', 'terus', 'promo', 'buat', 'gofood', 'nya', 'he']
#
# === TOKENIZATION ===
# Before: sediakan versi lite nya dong buat goride gocar saja ukuran aplikasinya jangan terlalu besarlah
# After:  ['sediakan', 'versi', 'lite', 'nya', 'dong', 'buat', 'goride', 'gocar', 'saja', 'ukuran', 'aplikasinya', 'jangan', 'terlalu', 'besarlah']
#
# === TOKENIZATION ===
# Before: untuk hari ini layanan gocar sangat buruk dicancel x padahal sudah dekat dari jalan rumah saya dan sekalinya dapat sopirnya tidak dilayanin padahal pakai gocar prioritas buruk sangat buruk gocar saya sangat kecewa padahal saya sekarang pakai goride gofood jrg ada kendala seperti ini benar tidak akan mau pakai gocar lagi
# After:  ['untuk', 'hari', 'ini', 'layanan', 'gocar', 'sangat', 'buruk', 'dicancel', 'x', 'padahal', 'sudah', 'dekat', 'dari', 'jalan', 'rumah', 'saya', 'dan', 'sekalinya', 'dapat', 'sopirnya', 'tidak', 'dilayanin', 'padahal', 'pakai', 'gocar', 'prioritas', 'buruk', 'sangat', 'buruk', 'gocar', 'saya', 'sangat', 'kecewa', 'padahal', 'saya', 'sekarang', 'pakai', 'goride', 'gofood', 'jrg', 'ada', 'kendala', 'seperti', 'ini', 'benar', 'tidak', 'akan', 'mau', 'pakai', 'gocar', 'lagi']
#
# === TOKENIZATION ===
# Before: gofood super mahal ongkirnya biaya layanannya sgala macam sudah begitu tidak ada promo potongan apapun pakai gojek cuma buat kebutuhan gocar goride sama tiket kereta saja
# After:  ['gofood', 'super', 'mahal', 'ongkirnya', 'biaya', 'layanannya', 'sgala', 'macam', 'sudah', 'begitu', 'tidak', 'ada', 'promo', 'potongan', 'apapun', 'pakai', 'gojek', 'cuma', 'buat', 'kebutuhan', 'gocar', 'goride', 'sama', 'tiket', 'kereta', 'saja']
#
# === TOKENIZATION ===
# Before: pokok nya top markotop deh
# After:  ['pokok', 'nya', 'top', 'markotop', 'deh']
#
# === TOKENIZATION ===
# Before: good
# After:  ['good']
#
# === TOKENIZATION ===
# Before: pengalaman menyenangkan menggunakan gojek
# After:  ['pengalaman', 'menyenangkan', 'menggunakan', 'gojek']
#
# === TOKENIZATION ===
# Before: sangat membantu sekali dalam perjalanan
# After:  ['sangat', 'membantu', 'sekali', 'dalam', 'perjalanan']
#
# === TOKENIZATION ===
# Before: saya langganan pakai gojek kalau mau pigi bekerja naik goride jadi menurud saya drivenya ramah semoga ditingkatkan lagi
# After:  ['saya', 'langganan', 'pakai', 'gojek', 'kalau', 'mau', 'pigi', 'bekerja', 'naik', 'goride', 'jadi', 'menurud', 'saya', 'drivenya', 'ramah', 'semoga', 'ditingkatkan', 'lagi']
#
# === TOKENIZATION ===
# Before: driver bik sopan rapi ramah kendaraan terawat baik dijalan patuh taat peraturan lalu lintas layanan panggilan cepat selalu beri salam relatif yepay waktu untuk gojek beri reward bagi driver teladan cistomersetia telafan tahun pernah mengadakan indian voucer berhadiah mobil kapan pengumannya sudah atau belum disosialisasikan terimakasih customer gojek go ride go car
# After:  ['driver', 'bik', 'sopan', 'rapi', 'ramah', 'kendaraan', 'terawat', 'baik', 'dijalan', 'patuh', 'taat', 'peraturan', 'lalu', 'lintas', 'layanan', 'panggilan', 'cepat', 'selalu', 'beri', 'salam', 'relatif', 'yepay', 'waktu', 'untuk', 'gojek', 'beri', 'reward', 'bagi', 'driver', 'teladan', 'cistomersetia', 'telafan', 'tahun', 'pernah', 'mengadakan', 'indian', 'voucer', 'berhadiah', 'mobil', 'kapan', 'pengumannya', 'sudah', 'atau', 'belum', 'disosialisasikan', 'terimakasih', 'customer', 'gojek', 'go', 'ride', 'go', 'car']
#
# === TOKENIZATION ===
# Before: ketika promoan banyak driver yang tidak mau ambil orderan gocar goride sudah seringkali menunggu lama seperti ini tidak ada yang ambil padahal coba pakai grab langsung dapat
# ...
#
# === TOKENIZATION ===
# Before: plis promo nya yang jelas khusus buat goride saya tiap hari pakai goride kenapa tidak pernah dapat promo sedangkan teman saya slalu dapat potongan sampai saya beli loh buat dapat potongan seperti gaadil begitu pls
# After:  ['plis', 'promo', 'nya', 'yang', 'jelas', 'khusus', 'buat', 'goride', 'saya', 'tiap', 'hari', 'pakai', 'goride', 'kenapa', 'tidak', 'pernah', 'dapat', 'promo', 'sedangkan', 'teman', 'saya', 'slalu', 'dapat', 'potongan', 'sampai', 'saya', 'beli', 'loh', 'buat', 'dapat', 'potongan', 'seperti', 'gaadil', 'begitu', 'pls']
#
# === TOKENIZATION ===
# Before: bagus aplikasi nya membantu banget
# After:  ['bagus', 'aplikasi', 'nya', 'membantu', 'banget']
#
# === TOKENIZATION ===
# Before: buat kesel saja kalau misal pesan gocar goride pagi pagi pasti tidak ada driver nya semisal ada pun lama nya minta ampun pokoknya kecewa deh
# After:  ['buat', 'kesel', 'saja', 'kalau', 'misal', 'pesan', 'gocar', 'goride', 'pagi', 'pagi', 'pasti', 'tidak', 'ada', 'driver', 'nya', 'semisal', 'ada', 'pun', 'lama', 'nya', 'minta', 'ampun', 'pokoknya', 'kecewa', 'deh']
#
# === TOKENIZATION ===
# Before: good apk
# After:  ['good', 'apk']
#
# === TOKENIZATION ===
# Before: hati kalau naik goride gojek topi tertinggal nyangkut di helm saja ti tilep sama drivernya sangat kecewa seminggu tidak ada kejelasan atau sudah kerjasama coba kalau barang berharga apa tidak bahaya kalau topi saja di curi begini
# After:  ['hati', 'kalau', 'naik', 'goride', 'gojek', 'topi', 'tertinggal', 'nyangkut', 'di', 'helm', 'saja', 'ti', 'tilep', 'sama', 'drivernya', 'sangat', 'kecewa', 'seminggu', 'tidak', 'ada', 'kejelasan', 'atau', 'sudah', 'kerjasama', 'coba', 'kalau', 'barang', 'berharga', 'apa', 'tidak', 'bahaya', 'kalau', 'topi', 'saja', 'di', 'curi', 'begini']
#
# === TOKENIZATION ===
# Before: mudah lancar
# After:  ['mudah', 'lancar']
#
# === TOKENIZATION ===
# Before: bagaimana si sudah langganan vouch go plus mlh goride nya cuma diskon ke nyesell
# After:  ['bagaimana', 'si', 'sudah', 'langganan', 'vouch', 'go', 'plus', 'mlh', 'goride', 'nya', 'cuma', 'diskon', 'ke', 'nyesell']
#
# === TOKENIZATION ===
# Before: mohon perbaiki drivernya masak kalau hujan tidak mau narik go ride nya sampai hampir jam pesan tidak di peduliin sekali dapat langsung di batal sama driver tidak profesional banget tempatku tidak bisa mobil masuk makanya pesennya go ride
# After:  ['mohon', 'perbaiki', 'drivernya', 'masak', 'kalau', 'hujan', 'tidak', 'mau', 'narik', 'go', 'ride', 'nya', 'sampai', 'hampir', 'jam', 'pesan', 'tidak', 'di', 'peduliin', 'sekali', 'dapat', 'langsung', 'di', 'batal', 'sama', 'driver', 'tidak', 'profesional', 'banget', 'tempatku', 'tidak', 'bisa', 'mobil', 'masuk', 'makanya', 'pesennya', 'go', 'ride']
#
# === TOKENIZATION ===
# Before: mantab
# After:  ['mantab']
#
# === TOKENIZATION ===
# Before: saya suka pakai gojek tapi di sukatani untuk goride kenapa tidak terjangkau yaa
# After:  ['saya', 'suka', 'pakai', 'gojek', 'tapi', 'di', 'sukatani', 'untuk', 'goride', 'kenapa', 'tidak', 'terjangkau', 'yaa']
#
# === TOKENIZATION ===
# Before: mantap lah pokoknya
# After:  ['mantap', 'lah', 'pokoknya']
#
# === TOKENIZATION ===
# Before: terimaksih jaya selalu
# After:  ['terimaksih', 'jaya', 'selalu']
#
# === TOKENIZATION ===
# Before: nyaman
# After:  ['nyaman']
#
# === TOKENIZATION ===
# Before: ada yang sekongkol antara sesama driver go jek saya order goride pas driver datang langsung bertanya nama dan alamat tujuan nama saya dan tujuan saya disebut dengan benar oleh driver tersebut namun setelah sampai driver tersebut bilang kalau dia offline tidak pakai aplikasi saya cek diaplikasi driver yang saya order mengirim foto bahwa dia sedang menunggu dititik jemput sedangkan saya sudah sampai ditujuan dan driver yang mengantar saya meminta tarif x lipat dari tarif diaplikasi
# After:  ['ada', 'yang', 'sekongkol', 'antara', 'sesama', 'driver', 'go', 'jek', 'saya', 'order', 'goride', 'pas', 'driver', 'datang', 'langsung', 'bertanya', 'nama', 'dan', 'alamat', 'tujuan', 'nama', 'saya', 'dan', 'tujuan', 'saya', 'disebut', 'dengan', 'benar', 'oleh', 'driver', 'tersebut', 'namun', 'setelah', 'sampai', 'driver', 'tersebut', 'bilang', 'kalau', 'dia', 'offline', 'tidak', 'pakai', 'aplikasi', 'saya', 'cek', 'diaplikasi', 'driver', 'yang', 'saya', 'order', 'mengirim', 'foto', 'bahwa', 'dia', 'sedang', 'menunggu', 'dititik', 'jemput', 'sedangkan', 'saya', 'sudah', 'sampai', 'ditujuan', 'dan', 'driver', 'yang', 'mengantar', 'saya', 'meminta', 'tarif', 'x', 'lipat', 'dari', 'tarif', 'diaplikasi']
#
# === TOKENIZATION ===
# Before: sangat bagus
# After:  ['sangat', 'bagus']
#
# === TOKENIZATION ===
# Before: layanan ramah sopan murah
# After:  ['layanan', 'ramah', 'sopan', 'murah']
#
# === TOKENIZATION ===
# Before: aplikasi gojek sangat membantu
# After:  ['aplikasi', 'gojek', 'sangat', 'membantu']
#
# === TOKENIZATION ===
# Before: order goride lama kali munculnya
# After:  ['order', 'goride', 'lama', 'kali', 'munculnya']
#
# === TOKENIZATION ===
# Before: ok banget
# After:  ['ok', 'banget']
#
# === TOKENIZATION ===
# Before: go ride oke gocar nya kurang
# After:  ['go', 'ride', 'oke', 'gocar', 'nya', 'kurang']
#
# === TOKENIZATION ===
# Before: go ride jembot pada sombong drivernya jarak cuma kamu pada gmau di tolak di map dekat ada banyak driver nolak semua app sampah
# After:  ['go', 'ride', 'jembot', 'pada', 'sombong', 'drivernya', 'jarak', 'cuma', 'kamu', 'pada', 'gmau', 'di', 'tolak', 'di', 'map', 'dekat', 'ada', 'banyak', 'driver', 'nolak', 'semua', 'app', 'sampah']
#
# === TOKENIZATION ===
# Before: dapat driver nya selalu jauh apalagi goride comfort nya aduhai jauhnya juara
# After:  ['dapat', 'driver', 'nya', 'selalu', 'jauh', 'apalagi', 'goride', 'comfort', 'nya', 'aduhai', 'jauhnya', 'juara']
#
# === TOKENIZATION ===
# Before: kalau ada bintang setengah sudah memberikan bintang setengah rutenya sinting dibikin jauh muter muter kemarin goride sekarang go bluebird memberikan rute yang benar dong buang buang waktu sama uang konsumen saja
# After:  ['kalau', 'ada', 'bintang', 'setengah', 'sudah', 'memberikan', 'bintang', 'setengah', 'rutenya', 'sinting', 'dibikin', 'jauh', 'muter', 'muter', 'kemarin', 'goride', 'sekarang', 'go', 'bluebird', 'memberikan', 'rute', 'yang', 'benar', 'dong', 'buang', 'buang', 'waktu', 'sama', 'uang', 'konsumen', 'saja']
#
# === TOKENIZATION ===
# Before: njemput cepat sopirannya enak tenang sopirnya sopan ramsh rute nya tepat langsing sampai tepat tujuan tidak bertanya ini itu sampai mana ini dlsb
# After:  ['njemput', 'cepat', 'sopirannya', 'enak', 'tenang', 'sopirnya', 'sopan', 'ramsh', 'rute', 'nya', 'tepat', 'langsing', 'sampai', 'tepat', 'tujuan', 'tidak', 'bertanya', 'ini', 'itu', 'sampai', 'mana', 'ini', 'dlsb']
#
# === TOKENIZATION ===
# Before: top markotop
# After:  ['top', 'markotop']
#
# === TOKENIZATION ===
# Before: sangat membantu semoga makin banyak voucher goride dan gofood
# After:  ['sangat', 'membantu', 'semoga', 'makin', 'banyak', 'voucher', 'goride', 'dan', 'gofood']
#
# === TOKENIZATION ===
# Before: kenapa setiap mau mesen goride or gocar slalu milih peta manual padahal sudah di simpen lokasi favorit tapi tetap saja harus mencari manual menyusahkan
# After:  ['kenapa', 'setiap', 'mau', 'mesen', 'goride', 'or', 'gocar', 'slalu', 'milih', 'peta', 'manual', 'padahal', 'sudah', 'di', 'simpen', 'lokasi', 'favorit', 'tapi', 'tetap', 'saja', 'harus', 'mencari', 'manual', 'menyusahkan']
#
# === TOKENIZATION ===
# Before: mrasa tidak adil tmn saya sudah otomatis dapat voucher promo goride tapi di saya gd sm sekali ishh sudah dimasukin kode sgala macam tetap saja hargany nromal
# After:  ['mrasa', 'tidak', 'adil', 'tmn', 'saya', 'sudah', 'otomatis', 'dapat', 'voucher', 'promo', 'goride', 'tapi', 'di', 'saya', 'gd', 'sm', 'sekali', 'ishh', 'sudah', 'dimasukin', 'kode', 'sgala', 'macam', 'tetap', 'saja', 'hargany', 'nromal']
#
# === TOKENIZATION ===
# Before: goridenya sudah bagus tapi gofoodnya masih bermasalah besar di driver saya sudah menunggu jam tidak dapat driver makanan sudah jadi tapi driver g dapat kasian restonya juga kalau makananya sudah jadi
# After:  ['goridenya', 'sudah', 'bagus', 'tapi', 'gofoodnya', 'masih', 'bermasalah', 'besar', 'di', 'driver', 'saya', 'sudah', 'menunggu', 'jam', 'tidak', 'dapat', 'driver', 'makanan', 'sudah', 'jadi', 'tapi', 'driver', 'g', 'dapat', 'kasian', 'restonya', 'juga', 'kalau', 'makananya', 'sudah', 'jadi']
#
# === TOKENIZATION ===
# Before: kenapa sekarang susah iya pesan gojek goride gocar sama saja saya buka aplikasi pakai indrive bahkan cpt banget bukan ada peningkatan kenapa jadi bahkan kemunduran sori ini udate review jujur iya kalau tidak gojek bakal ketinggalan ma yang lain
# After:  ['kenapa', 'sekarang', 'susah', 'iya', 'pesan', 'gojek', 'goride', 'gocar', 'sama', 'saja', 'saya', 'buka', 'aplikasi', 'pakai', 'indrive', 'bahkan', 'cpt', 'banget', 'bukan', 'ada', 'peningkatan', 'kenapa', 'jadi', 'bahkan', 'kemunduran', 'sori', 'ini', 'udate', 'review', 'jujur', 'iya', 'kalau', 'tidak', 'gojek', 'bakal', 'ketinggalan', 'ma', 'yang', 'lain']
#
# === TOKENIZATION ===
# Before: gojek bagaimana sih saya mau pesan goride kenapa tidak bisa tulisannya harus pakai metode lain metode lain terus
# After:  ['gojek', 'bagaimana', 'sih', 'saya', 'mau', 'pesan', 'goride', 'kenapa', 'tidak', 'bisa', 'tulisannya', 'harus', 'pakai', 'metode', 'lain', 'metode', 'lain', 'terus']
#
# === TOKENIZATION ===
# Before: senang belanja di gomart kalau pas ada promo
# After:  ['senang', 'belanja', 'di', 'gomart', 'kalau', 'pas', 'ada', 'promo']
#
# === TOKENIZATION ===
# Before: semangaat pagii para pejuang keluarga sedikit cerita tentang kekecewaan saya pakai gojek saya pernah pesan goride tapi lama banget sekitar minta baru dapat driver sekali dapat driver posisi nya jauh banget padahal saya lihat ada sekitr driver yang dekat dengan saya saya juga sempat tanya kalau rekan driver itu belum dapat orderan jadi karena terlalu lama saya menunggu saya beralihlah ke grabbike tidak sampai menit sudah dapat driver tidak sampai minta driver sudah sampai
# After:  ['semangaat', 'pagii', 'para', 'pejuang', 'keluarga', 'sedikit', 'cerita', 'tentang', 'kekecewaan', 'saya', 'pakai', 'gojek', 'saya', 'pernah', 'pesan', 'goride', 'tapi', 'lama', 'banget', 'sekitar', 'minta', 'baru', 'dapat', 'driver', 'sekali', 'dapat', 'driver', 'posisi', 'nya', 'jauh', 'banget', 'padahal', 'saya', 'lihat', 'ada', 'sekitr', 'driver', 'yang', 'dekat', 'dengan', 'saya', 'saya', 'juga', 'sempat', 'tanya', 'kalau', 'rekan', 'driver', 'itu', 'belum', 'dapat', 'orderan', 'jadi', 'karena', 'terlalu', 'lama', 'saya', 'menunggu', 'saya', 'beralihlah', 'ke', 'grabbike', 'tidak', 'sampai', 'menit', 'sudah', 'dapat', 'driver', 'tidak', 'sampai', 'minta', 'driver', 'sudah', 'sampai']
#
# === TOKENIZATION ===
# Before: diskon terus
# After:  ['diskon', 'terus']
#
# === TOKENIZATION ===
# Before: woi yang benar lah masa pakai goride plus titik jemputnya jadi ngaco padahal sebelumnya tidak pakai plus biasa biasa saja
# After:  ['woi', 'yang', 'benar', 'lah', 'masa', 'pakai', 'goride', 'plus', 'titik', 'jemputnya', 'jadi', 'ngaco', 'padahal', 'sebelumnya', 'tidak', 'pakai', 'plus', 'biasa', 'biasa', 'saja']
#
# === TOKENIZATION ===
# Before: mantab
# After:  ['mantab']
#
# === TOKENIZATION ===
# Before: tidak ada yang mau mengambil orderan go ride aku padahal aku pakai diskon ribu saja
# After:  ['tidak', 'ada', 'yang', 'mau', 'mengambil', 'orderan', 'go', 'ride', 'aku', 'padahal', 'aku', 'pakai', 'diskon', 'ribu', 'saja']
#
# === TOKENIZATION ===
# Before: berguna bett sumpah
# After:  ['berguna', 'bett', 'sumpah']
#
# === TOKENIZATION ===
# Before: hallo gojek saya pengguna gojek dari tahun dan saya sangat senang sekali dengan app tersebut karena saya sering mendapatkan voucher goride untuk menjadi agak lebih murah dari biasanya jadi terimakasih gojek atas jasa jasa mu terima kasih
# After:  ['hallo', 'gojek', 'saya', 'pengguna', 'gojek', 'dari', 'tahun', 'dan', 'saya', 'sangat', 'senang', 'sekali', 'dengan', 'app', 'tersebut', 'karena', 'saya', 'sering', 'mendapatkan', 'voucher', 'goride', 'untuk', 'menjadi', 'agak', 'lebih', 'murah', 'dari', 'biasanya', 'jadi', 'terimakasih', 'gojek', 'atas', 'jasa', 'jasa', 'mu', 'terima', 'kasih']
#
# === TOKENIZATION ===
# Before: i love gojek so much tapi kenapa sekarang klu kita dapat voucher kok cuma berlaku hanya hari dapat voucher go ride nya memang lumayan paling sedikit dapat voucher bisa lebih dapat voucher go car juga paling sedikit voucher bisa lebih tapi masak kita mau wira wiri sebanyak itu dalam hari kan tidak mungkin kecuali klu kita punya asrama anak yang semua di pakaikan voucher tersebut tlg dunk bagian it jangan mau klu di suruh bagian marketing buatin program yang absurd begini
# After:  ['i', 'love', 'gojek', 'so', 'much', 'tapi', 'kenapa', 'sekarang', 'klu', 'kita', 'dapat', 'voucher', 'kok', 'cuma', 'berlaku', 'hanya', 'hari', 'dapat', 'voucher', 'go', 'ride', 'nya', 'memang', 'lumayan', 'paling', 'sedikit', 'dapat', 'voucher', 'bisa', 'lebih', 'dapat', 'voucher', 'go', 'car', 'juga', 'paling', 'sedikit', 'voucher', 'bisa', 'lebih', 'tapi', 'masak', 'kita', 'mau', 'wira', 'wiri', 'sebanyak', 'itu', 'dalam', 'hari', 'kan', 'tidak', 'mungkin', 'kecuali', 'klu', 'kita', 'punya', 'asrama', 'anak', 'yang', 'semua', 'di', 'pakaikan', 'voucher', 'tersebut', 'tlg', 'dunk', 'bagian', 'it', 'jangan', 'mau', 'klu', 'di', 'suruh', 'bagian', 'marketing', 'buatin', 'program', 'yang', 'absurd', 'begini']
#
# === TOKENIZATION ===
# Before: gojek melakukan blunder dengan cara customer kalau mau pesan go ride prioritas baru dapat driver yang dekat kalau tidak prioritas dapatnya driver jauh tapi kalau mau prioritas kena biaya tambahan lagi akhirnya customer pada pindah ke aplikasi lain yang kocak lagi driver di suspen gara gara nglewatin order padahal disini orang kantor gojek yang salah kenapa penjemputan jauh harusnya yang buat kebijakan ini juga di suspen karena membuat castamer susah dapat driver
# After:  ['gojek', 'melakukan', 'blunder', 'dengan', 'cara', 'customer', 'kalau', 'mau', 'pesan', 'go', 'ride', 'prioritas', 'baru', 'dapat', 'driver', 'yang', 'dekat', 'kalau', 'tidak', 'prioritas', 'dapatnya', 'driver', 'jauh', 'tapi', 'kalau', 'mau', 'prioritas', 'kena', 'biaya', 'tambahan', 'lagi', 'akhirnya', 'customer', 'pada', 'pindah', 'ke', 'aplikasi', 'lain', 'yang', 'kocak', 'lagi', 'driver', 'di', 'suspen', 'gara', 'gara', 'nglewatin', 'order', 'padahal', 'disini', 'orang', 'kantor', 'gojek', 'yang', 'salah', 'kenapa', 'penjemputan', 'jauh', 'harusnya', 'yang', 'buat', 'kebijakan', 'ini', 'juga', 'di', 'suspen', 'karena', 'membuat', 'castamer', 'susah', 'dapat', 'driver']
#
# === TOKENIZATION ===
# Before: layanan buruk sekali terutama kalau pas hujan tidak ada driver car yang mau ambil karena entah bagaimana servernya gojek melempar pesanan pas hujan itu jauh sehingga rata driver minta di batal padahal pas banget baru dapat begitu terus kadang yang goride juga sama benar buruk sekali layanan gojek sekarang
# After:  ['layanan', 'buruk', 'sekali', 'terutama', 'kalau', 'pas', 'hujan', 'tidak', 'ada', 'driver', 'car', 'yang', 'mau', 'ambil', 'karena', 'entah', 'bagaimana', 'servernya', 'gojek', 'melempar', 'pesanan', 'pas', 'hujan', 'itu', 'jauh', 'sehingga', 'rata', 'driver', 'minta', 'di', 'batal', 'padahal', 'pas', 'banget', 'baru', 'dapat', 'begitu', 'terus', 'kadang', 'yang', 'goride', 'juga', 'sama', 'benar', 'buruk', 'sekali', 'layanan', 'gojek', 'sekarang']
#
# === TOKENIZATION ===
# Before: sangat membantu di saat membutuhkan
# After:  ['sangat', 'membantu', 'di', 'saat', 'membutuhkan']
#
# Hasil setelah tokenization:
#                                       after_repeated  \
# 0  matikan fitur order ganda pemesanan goride seh...
# 1  tolong iya pleease buat customer yang pesan gi...
# 2  saya harap di update kedepanya saat pesan go f...
#
#                                       after_tokenize
# 0  [matikan, fitur, order, ganda, pemesanan, gori...
# 1  [tolong, iya, pleease, buat, customer, yang, p...
# 2  [saya, harap, di, update, kedepanya, saat, pes...

# %%
# Langkah 5: Stopword Removal
print("\n=== Langkah 5: Stopword Removal ===")
def remove_stopwords(tokens):
    """Menghapus stopword"""
    if isinstance(tokens, str):  # Handle case if input is string
        tokens = tokens.split()
    before = tokens.copy()
    after = [word for word in tokens if word not in stopword_custom]
    print_step("Stopword Removal", before, after)
    return after

df['after_stopwords'] = df['after_tokenize'].apply(remove_stopwords)
print("\nHasil setelah stopword removal:")
df[['after_tokenize', 'after_stopwords']].head(3)
# Out:
# === Langkah 5: Stopword Removal ===
#
# === STOPWORD REMOVAL ===
# Before: ['matikan', 'fitur', 'order', 'ganda', 'pemesanan', 'goride', 'seharusnya', 'kalau', 'sudah', 'order', 'goride', 'tidak', 'bisa', 'order', 'goride', 'lagi', 'sekaligus', 'harus', 'dibatalkan', 'dulu', 'baru', 'bisa', 'pesan', 'lagi']
# After:  ['matikan', 'fitur', 'order', 'ganda', 'pemesanan', 'goride', 'order', 'goride', 'order', 'goride', 'dibatalkan', 'pesan']
#
# === STOPWORD REMOVAL ===
# Before: ['tolong', 'iya', 'pleease', 'buat', 'customer', 'yang', 'pesan', 'gibride', 'tolong', 'itu', 'jempol', 'jangan', 'dikit', 'cansel', 'dikit', 'cansel', 'kalian', 'beratus', 'ratus', 'kali', 'cansel', 'tidak', 'berpengaruh', 'tidak', 'ngefek', 'kitw', 'yang', 'driver', 'yang', 'kena', 'ampas', 'nanti', 'sama', 'aplikator', 'memang', 'kalian', 'bayar', 'tarif', 'nya', 'super', 'mahal', 'tapi', 'kita', 'dibpitong', 'gede', 'super', 'gede', 'potongannya', 'tolong', 'kasihani', 'kami', 'iya', 'driver', 'ojol']
# After:  ['tolong', 'iya', 'pleease', 'customer', 'pesan', 'gibride', 'tolong', 'jempol', 'dikit', 'cansel', 'dikit', 'cansel', 'beratus', 'ratus', 'kali', 'cansel', 'berpengaruh', 'ngefek', 'kitw', 'driver', 'kena', 'ampas', 'aplikator', 'bayar', 'tarif', 'nya', 'super', 'mahal', 'dibpitong', 'gede', 'super', 'gede', 'potongannya', 'tolong', 'kasihani', 'iya', 'driver', 'ojol']
#
# === STOPWORD REMOVAL ===
# Before: ['saya', 'harap', 'di', 'update', 'kedepanya', 'saat', 'pesan', 'go', 'food', 'muncul', 'notifikasi', 'jangan', 'go', 'ride', 'saja', 'yang', 'muncul']
# After:  ['harap', 'update', 'kedepanya', 'pesan', 'go', 'food', 'muncul', 'notifikasi', 'go', 'ride', 'muncul']
#
# === STOPWORD REMOVAL ===
# Before: ['buatku', 'yang', 'tinggal', 'agak', 'jauh', 'dari', 'kota', 'ini', 'aplikasi', 'yang', 'paling', 'cpat', 'untuk', 'kita', 'dpat', 'driver', 'mau', 'pesan', 'goride', 'ataupun', 'pesan', 'gofood', 'menunggu', 'tidak', 'pakai', 'lama', 'kendaraan', 'driver', 'nya', 'juga', 'oke', 'dan', 'drivernya', 'sopan', 'sukses', 'selalu', 'gojek']
# After:  ['buatku', 'tinggal', 'kota', 'aplikasi', 'cpat', 'dpat', 'driver', 'pesan', 'goride', 'pesan', 'gofood', 'menunggu', 'pakai', 'kendaraan', 'driver', 'nya', 'oke', 'drivernya', 'sopan', 'sukses', 'gojek']
#
# === STOPWORD REMOVAL ===
# Before: ['layanan', 'goride', 'sangat', 'membantu', 'untuk', 'aktifitas', 'sehari', 'di', 'saat', 'motor', 'sedang', 'perbaikan', 'di', 'bengkel', 'masukan', 'nya', 'mgkin', 'Cuma', 'kalau', 'cuaca', 'sedang', 'hujan', 'dalam', 'situasi', 'urgent', 'butuh', 'transport', 'masih', 'sering', 'lama', 'dapat', 'driver', 'nya']
# After:  ['layanan', 'goride', 'membantu', 'aktifitas', 'sehari', 'motor', 'perbaikan', 'bengkel', 'masukan', 'nya', 'mgkin', 'Cuma', 'cuaca', 'hujan', 'situasi', 'urgent', 'butuh', 'transport', 'driver', 'nya']
#
# === STOPWORD REMOVAL ===
# Before: ['ini', 'gojek', 'kenapa', 'iya', 'sekarang', 'saya', 'pakai', 'akun', 'baru', 'biasanya', 'suka', 'ada', 'voucher', 'tapi', 'voucher', 'goride', 'sekarang', 'tidak', 'ada', 'tapi', 'giliran', 'saya', 'beralih', 'ke', 'gocar', 'ada', 'voucher', 'tapi', 'pas', 'giliran', 'saya', 'buka', 'voucher', 'ternyata', 'tidak', 'ada', 'voucher', 'apakah', 'bug', 'tolong', 'di', 'perbaiki', 'lahi']
# After:  ['gojek', 'iya', 'pakai', 'akun', 'suka', 'voucher', 'voucher', 'goride', 'giliran', 'beralih', 'gocar', 'voucher', 'pas', 'giliran', 'buka', 'voucher', 'voucher', 'bug', 'tolong', 'perbaiki', 'lahi']
#
# === STOPWORD REMOVAL ===
# Before: ['kalau', 'terima', 'rider', 'seleksi', 'dulu', 'lah', 'setiap', 'naik', 'gojek', 'rider', 'nya', 'emosian', 'melulu']
# After:  ['terima', 'rider', 'seleksi', 'gojek', 'rider', 'nya', 'emosian', 'melulu']
#
# === STOPWORD REMOVAL ===
# Before: ['gojek', 'sekarang', 'mahal', 'meskipun', 'pakai', 'voucher', 'perjalanan', 'kamu', 'biasanya', 'dengan', 'harga', 'pakai', 'voucher', 'go', 'ride', 'saja', 'pot', 'rb', 'sekarang', 'jadi', 'alhasil', 'beralih', 'ke', 'ojol', 'sebelah']
# After:  ['gojek', 'mahal', 'pakai', 'voucher', 'perjalanan', 'harga', 'pakai', 'voucher', 'go', 'ride', 'pot', 'rb', 'alhasil', 'beralih', 'ojol', 'sebelah']
#
# === STOPWORD REMOVAL ===
# Before: ['cepat', 'dan', 'murah']
# After:  ['cepat', 'murah']
#
# === STOPWORD REMOVAL ===
# Before: ['keren', 'sudah', 'murah']
# After:  ['keren', 'murah']
#
# === STOPWORD REMOVAL ===
# Before: ['drivernya', 'banyak', 'alesan', 'bilang', 'tidak', 'bawa', 'helm', 'terus', 'sedang', 'apa', 'ambil', 'pesanan', 'goride', 'saya', 'pas', 'saya', 'minta', 'batal', 'saja', 'dari', 'dianya', 'tidak', 'mau', 'dianya', 'mau', 'ambil', 'helm', 'dulu', 'knapa', 'tidak', 'mau', 'batal', 'takut', 'poinnya', 'turun', 'kalau', 'begitu', 'sedang', 'apa', 'ambil', 'pesanan', 'saya', 'mana', 'ngajak', 'ribut', 'lagi', 'kurang', 'ajar']
# After:  ['drivernya', 'alesan', 'bilang', 'bawa', 'helm', 'ambil', 'pesanan', 'goride', 'pas', 'batal', 'dianya', 'dianya', 'ambil', 'helm', 'knapa', 'batal', 'takut', 'poinnya', 'turun', 'ambil', 'pesanan', 'ngajak', 'ribut', 'ajar']
#
# === STOPWORD REMOVAL ===
# Before: ['rumah', 'beda', 'hp', 'ee', 'pesan', 'go', 'ride', 'dng', 'ttik', 'dan', 'tujuan', 'sama', 'kenapa', 'nominal', 'beda', 'sya', 'kena', 'ke', 'pakai', 'hp', 'ponakan', 'ke', 'tunai', 'juga', 'belum', 'gofood', 'klu', 'py', 'saya', 'mehongg', 'kenapa', 'bisa', 'begitu', 'rumah', 'lho', 'padahal', 'saya', 'setia', 'memakai', 'gojeck', 'untuk', 'order', 'makanan']
# After:  ['rumah', 'beda', 'hp', 'ee', 'pesan', 'go', 'ride', 'dng', 'ttik', 'tujuan', 'nominal', 'beda', 'sya', 'kena', 'pakai', 'hp', 'ponakan', 'tunai', 'gofood', 'klu', 'py', 'mehongg', 'rumah', 'lho', 'setia', 'memakai', 'gojeck', 'order', 'makanan']
#
# === STOPWORD REMOVAL ===
# Before: ['drivernya', 'mengemudikan', 'kendaraan', 'dengan', 'aman', 'dan', 'nyaman', 'terimakasih']
# After:  ['drivernya', 'mengemudikan', 'kendaraan', 'aman', 'nyaman', 'terimakasih']
#
# === STOPWORD REMOVAL ===
# Before: ['ok']
# After:  ['ok']
#
# === STOPWORD REMOVAL ===
# Before: ['senang']
# After:  ['senang']
#
# === STOPWORD REMOVAL ===
# Before: ['aplikasinya', 'sih', 'masih', 'bagus', 'tapi', 'baru', 'hari', 'ini', 'januari', 'pesan', 'gocar', 'hampir', 'kali', 'goride', 'kali', 'tidak', 'ada', 'yang', 'nyantol', 'server', 'sibuk', 'padahal', 'cuaca', 'cuma', 'gerimis', 'kecil', 'di', 'pusat', 'kota', 'purwokerto', 'susah', 'sekali', 'ini', 'tidak', 'siap', 'kalau', 'di', 'butuhkan']
# After:  ['aplikasinya', 'sih', 'bagus', 'januari', 'pesan', 'gocar', 'kali', 'goride', 'kali', 'nyantol', 'server', 'sibuk', 'cuaca', 'gerimis', 'pusat', 'kota', 'purwokerto', 'susah', 'butuhkan']
#
# === STOPWORD REMOVAL ===
# Before: ['gila', 'order', 'goride', 'menunggu', 'l', 'banget', 'tidak', 'dspet', 'driver', 'juga', 'padahal', 'di', 'depan', 'ada', 'driver', 'yang', 'lagi', 'kumpul-kumpul', 'malam', 'balik', 'kerja', 'capek', 'terima', 'kasih', 'gojek', 'tidak', 'langganan', 'aagi', 'saya']
# After:  ['gila', 'order', 'goride', 'menunggu', 'l', 'banget', 'dspet', 'driver', 'driver', 'kumpul-kumpul', 'malam', 'kerja', 'capek', 'terima', 'kasih', 'gojek', 'langganan', 'aagi']
#
# === STOPWORD REMOVAL ===
# Before: ['baik']
# After:  []
#
# === STOPWORD REMOVAL ===
# Before: ['selalu', 'dapat', 'driver', 'jauh', 'kalau', 'pesan', 'goride', 'mau', 'buru', 'mau', 'kerja', 'bisa', 'dipecat', 'karena', 'kelamaan', 'apalagi', 'kalau', 'pesan', 'gosend', 'bisa', 'menit', 'jaraknya', 'bisa', 'kilo', 'tidak', 'kasihan', 'sama', 'drivernya', 'apa']
# After:  ['driver', 'pesan', 'goride', 'buru', 'kerja', 'dipecat', 'pesan', 'gosend', 'menit', 'jaraknya', 'kilo', 'kasihan', 'drivernya']
#
# === STOPWORD REMOVAL ===
# Before: ['the', 'best', 'apps', 'for', 'ride']
# After:  ['the', 'best', 'apps', 'for', 'ride']
#
# === STOPWORD REMOVAL ===
# Before: ['alhamdulillah', 'kalau', 'pas', 'pakai', 'goride', 'supirnya', 'bagus', 'dan', 'sopan']
# After:  ['alhamdulillah', 'pas', 'pakai', 'goride', 'supirnya', 'bagus', 'sopan']
#
# === STOPWORD REMOVAL ===
# Before: ['mantap']
# After:  ['mantap']
#
# === STOPWORD REMOVAL ===
# Before: ['kenapa', 'saya', 'isi', 'gopay', 'tidak', 'bisa', 'pesan', 'goride', 'juga', 'bisa', 'tlg', 'bantuannya', 'terima', 'kasih']
# After:  ['isi', 'gopay', 'pesan', 'goride', 'tlg', 'bantuannya', 'terima', 'kasih']
#
# === STOPWORD REMOVAL ===
# Before: ['sangat', 'membantu', 'dalam', 'beraktifitas', 'semoga', 'sering', 'sering', 'kasih', 'diskon', 'goridenya']
# After:  ['membantu', 'beraktifitas', 'semoga', 'kasih', 'diskon', 'goridenya']
#
# === STOPWORD REMOVAL ===
# Before: ['apa', 'apa', 'ini', 'gojek', 'sama', 'menunggu', 'goride', 'sampai', 'satu', 'jamm', 'kacau', 'ah', 'terus', 'saja', 'ditampung', 'keluhannya', 'ehh', 'tidak', 'ada', 'perbaikan', 'juga', 'sekarang', 'lebih', 'parah', 'menunggu', 'hampir', 'menit', 'padahal', 'didepan', 'saya', 'ada', 'drivernya', 'dan', 'tidak', 'diambil', 'tolong', 'jangan', 'seperti', 'ini', 'saya', 'juga', 'punya', 'keperluan', 'lainnya']
# After:  ['gojek', 'menunggu', 'goride', 'jamm', 'kacau', 'ah', 'ditampung', 'keluhannya', 'ehh', 'perbaikan', 'parah', 'menunggu', 'menit', 'didepan', 'drivernya', 'diambil', 'tolong', 'keperluan']
#
# === STOPWORD REMOVAL ===
# Before: ['ramah', 'terpercaya']
# After:  ['ramah', 'terpercaya']
#
# === STOPWORD REMOVAL ===
# Before: ['boleh', 'lah', 'Cuma', 'kadang', 'kalau', 'go', 'ride', 'lama', 'banget']
# After:  ['Cuma', 'kadang', 'go', 'ride', 'banget']
#
# === STOPWORD REMOVAL ===
# Before: ['bagus']
# After:  ['bagus']
#
# === STOPWORD REMOVAL ===
# Before: ['sudah', 'up', 'ke', 'gopay', 'plus', 'saya', 'pikir', 'bakal', 'dapat', 'voucher', 'goride', 'biar', 'murah', 'taunya', 'tidak', 'bisa', 'dipakai', 'bagaimana', 'ini']
# After:  ['up', 'gopay', 'plus', 'pikir', 'voucher', 'goride', 'biar', 'murah', 'taunya', 'dipakai']
#
# === STOPWORD REMOVAL ===
# Before: ['mantaf']
# After:  ['mantaf']
#
# === STOPWORD REMOVAL ===
# Before: ['kayaknya', 'tidak', 'perlu', 'pakai', 'gocar', 'goride', 'layanan', 'hemat', 'deh', 'kalau', 'memang', 'tidak', 'bisa', 'digunakan', 'tiap', 'x', 'dipake', 'banyak', 'benar', 'alasan', 'driver']
# After:  ['kayaknya', 'pakai', 'gocar', 'goride', 'layanan', 'hemat', 'deh', 'x', 'dipake', 'alasan', 'driver']
#
# === STOPWORD REMOVAL ===
# Before: ['terima', 'kasih', 'gojek', 'sudah', 'ada', 'fitur', 'pohon', 'bisa', 'menanam', 'dengan', 'seribu', 'rupiah', 'fitur', 'sangat', 'berguna', 'untuk', 'berbagi', 'oksigen']
# After:  ['terima', 'kasih', 'gojek', 'fitur', 'pohon', 'menanam', 'seribu', 'rupiah', 'fitur', 'berguna', 'berbagi', 'oksigen']
#
# === STOPWORD REMOVAL ===
# Before: ['bagus', 'baik']
# After:  ['bagus']
#
# === STOPWORD REMOVAL ===
# Before: ['sangat', 'membantu']
# After:  ['membantu']
#
# === STOPWORD REMOVAL ===
# Before: ['drivernya', 'ramah']
# After:  ['drivernya', 'ramah']
#
# === STOPWORD REMOVAL ===
# Before: ['bagus', 'layanan']
# After:  ['bagus', 'layanan']
#
# === STOPWORD REMOVAL ===
# Before: ['gojek', 'selalu', 'puas', 'saya', 'baik', 'go', 'ride', 'maupun', 'go', 'car', 'nya', 'selalu', 'the', 'best']
# After:  ['gojek', 'puas', 'go', 'ride', 'go', 'car', 'nya', 'the', 'best']
#
# === STOPWORD REMOVAL ===
# Before: ['pelanggan', 'setia', 'goride', 'gocar', 'gofood']
# After:  ['pelanggan', 'setia', 'goride', 'gocar', 'gofood']
#
# === STOPWORD REMOVAL ===
# Before: ['bagus', 'tapi', 'saya', 'pernah', 'pesan', 'goride', 'bahkan', 'driver', 'nya', 'salah', 'ambil', 'penumpang', 'sudah', 'saya', 'chat', 'ke', 'driver', 'tidak', 'di', 'respon']
# After:  ['bagus', 'pesan', 'goride', 'driver', 'nya', 'salah', 'ambil', 'penumpang', 'chat', 'driver', 'respon']
#
# === STOPWORD REMOVAL ===
# Before: ['maaf', 'ini', 'kenapa', 'pasar', 'polis', 'goride', 'bisa', 'motong', 'di', 'akun', 'customer', 'saya', 'sebelumnya', 'tidak', 'pernah', 'kaya', 'begini', 'harusnya', 'pasar', 'polis', 'tidak', 'punya', 'akses', 'motong', 'saldo', 'akun', 'customer', 'baru', 'kali', 'ini', 'ada', 'potongan', 'pasar', 'polis', 'goride', 'di', 'akun', 'customer']
# After:  ['maaf', 'pasar', 'polis', 'goride', 'motong', 'akun', 'customer', 'kaya', 'pasar', 'polis', 'akses', 'motong', 'saldo', 'akun', 'customer', 'kali', 'potongan', 'pasar', 'polis', 'goride', 'akun', 'customer']
#
# === STOPWORD REMOVAL ===
# Before: ['aplikasi', 'makin', 'tolol', 'pesan', 'goride', 'yang', 'muncul', 'dan', 'datang', 'gocar']
# After:  ['aplikasi', 'tolol', 'pesan', 'goride', 'muncul', 'gocar']
#
# === STOPWORD REMOVAL ===
# Before: ['menunggu', 'sampai', 'sejam', 'goride', 'tapi', 'tulisannya', 'sibuk', 'terus', 'ini', 'memang', 'beneran', 'pada', 'sibuk', 'gojek', 'ny', 'atau', 'memang', 'aplikasi', 'nya', 'lagi', 'error']
# After:  ['menunggu', 'sejam', 'goride', 'tulisannya', 'sibuk', 'beneran', 'sibuk', 'gojek', 'ny', 'aplikasi', 'nya', 'error']
#
# === STOPWORD REMOVAL ===
# Before: ['untuk', 'saat', 'ini', 'saya', 'hanya', 'pakai', 'gofood', 'saja', 'dan', 'jarang', 'menggunakan', 'goride', 'gocar', 'karena', 'masih', 'trauma', 'dengan', 'cara', 'mereka', 'mengendarai', 'kendaraan', 'dan', 'sempat', 'membuat', 'saya', 'celaka', 'masukan', 'saja', 'lebih', 'banyak', 'promo', 'gofood', 'dan', 'voucher', 'gratis', 'ongkos', 'kirim', 'potongan', 'ongkos', 'kirim', 'seperti', 'driver', 'oren']
# After:  ['pakai', 'gofood', 'jarang', 'goride', 'gocar', 'trauma', 'mengendarai', 'kendaraan', 'celaka', 'masukan', 'promo', 'gofood', 'voucher', 'gratis', 'ongkos', 'kirim', 'potongan', 'ongkos', 'kirim', 'driver', 'oren']
#
# === STOPWORD REMOVAL ===
# Before: ['top', 'markotop']
# After:  ['top', 'markotop']
#
# === STOPWORD REMOVAL ===
# Before: ['selalu', 'tepat', 'waktu', 'penjemputan', 'banyak', 'promo', 'dan', 'lebih', 'hemat']
# After:  ['penjemputan', 'promo', 'hemat']
#
# === STOPWORD REMOVAL ===
# Before: ['dapat', 'driver', 'goride', 'nya', 'lama', 'padahal', 'di', 'kota', 'depok', 'mau', 'berangkat', 'kerja', 'jadi', 'terlambat', 'tidak', 'kaya', 'aplikasi', 'sebelah', 'dapat', 'drivernya', 'cepat', 'sekalinya', 'dapat', 'jauh', 'driver', 'jemputnya']
# After:  ['driver', 'goride', 'nya', 'kota', 'depok', 'berangkat', 'kerja', 'terlambat', 'kaya', 'aplikasi', 'sebelah', 'drivernya', 'cepat', 'sekalinya', 'driver', 'jemputnya']
#
# === STOPWORD REMOVAL ===
# Before: ['semakin', 'lama', 'semakin', 'tidak', 'guna', 'ini', 'aplikasi', 'saya', 'pesan', 'goride', 'di', 'gambar', 'banyak', 'sekali', 'driver', 'terdekat', 'eh', 'nyantol', 'nya', 'di', 'jepang', 'saking', 'jauhnya', 'mana', 'sekarang', 'ongkos', 'kirim', 'nya', 'mahal', 'banget', 'maaf', 'untuk', 'kali', 'saya', 'pindah', 'ke', 'apk', 'sebelah', 'tidak', 'ribet']
# After:  ['aplikasi', 'pesan', 'goride', 'gambar', 'driver', 'terdekat', 'eh', 'nyantol', 'nya', 'jepang', 'saking', 'jauhnya', 'ongkos', 'kirim', 'nya', 'mahal', 'banget', 'maaf', 'kali', 'pindah', 'apk', 'sebelah', 'ribet']
#
# === STOPWORD REMOVAL ===
# Before: ['mengecewakan', 'setiap', 'mau', 'order', 'gocar', 'pas', 'lagi', 'hujan', 'para', 'driver', 'susah', 'untuk', 'menerima', 'pesanan', 'apalagi', 'pakai', 'promo', 'terutama', 'yang', 'buat', 'goride', 'alasan', 'banyak', 'orderan', 'lagi', 'ramai']
# After:  ['mengecewakan', 'order', 'gocar', 'pas', 'hujan', 'driver', 'susah', 'menerima', 'pesanan', 'pakai', 'promo', 'goride', 'alasan', 'orderan', 'ramai']
#
# === STOPWORD REMOVAL ===
# Before: ['aplikasi', 'bodoh', 'tidak', 'ada', 'yang', 'mau', 'ambil', 'goride', 'driver', 'bodoh']
# After:  ['aplikasi', 'bodoh', 'ambil', 'goride', 'driver', 'bodoh']
#
# === STOPWORD REMOVAL ===
# Before: ['gojek', 'sekarang', 'makin', 'buruk', 'mencari', 'driver', 'ny', 'tidak', 'dapat', 'dapat', 'padahl', 'saya', 'tidak', 'membatalkan', 'pesanan', 'dan', 'saya', 'menunggu', 'menit', 'dan', 'saya', 'order', 'lagi', 'namun', 'hasilnya', 'sama', 'saja', 'tambah', 'banyak', 'bug', 'saya', 'ingin', 'pesan', 'makanan', 'atau', 'goride']
# After:  ['gojek', 'buruk', 'mencari', 'driver', 'ny', 'padahl', 'membatalkan', 'pesanan', 'menunggu', 'menit', 'order', 'hasilnya', 'bug', 'pesan', 'makanan', 'goride']
#
# === STOPWORD REMOVAL ===
# Before: ['mantap', 'sudah', 'pokoknya', 'mah']
# After:  ['mantap', 'pokoknya', 'mah']
#
# === STOPWORD REMOVAL ===
# Before: ['untuk', 'goride', 'dan', 'gocar', 'cukup', 'lumayan', 'voucernya', 'tapi', 'gofood', 'nya', 'saya', 'jarang', 'pakai', 'karena', 'ada', 'aplikasi', 'lain', 'jauh', 'lebih', 'murah']
# After:  ['goride', 'gocar', 'lumayan', 'voucernya', 'gofood', 'nya', 'jarang', 'pakai', 'aplikasi', 'murah']
#
# === STOPWORD REMOVAL ===
# Before: ['mudah', 'di', 'gunakan']
# After:  ['mudah']
#
# === STOPWORD REMOVAL ===
# Before: ['nice']
# After:  ['nice']
#
# === STOPWORD REMOVAL ===
# Before: ['aplikasi', 'tolol', 'kalau', 'persen', 'goride', 'di', 'kasih', 'driver', 'yang', 'jauh', 'sekeliling', 'banyak', 'di', 'ambilkan', 'dari', 'korea', 'utara', 'perkiraan', 'menit', 'ditunggu', 'menit', 'tidak', 'sampai', 'update', 'lokasi', 'driver', 'juga', 'tidak', 'jelas']
# After:  ['aplikasi', 'tolol', 'persen', 'goride', 'kasih', 'driver', 'sekeliling', 'ambilkan', 'korea', 'utara', 'perkiraan', 'menit', 'ditunggu', 'menit', 'update', 'lokasi', 'driver']
#
# === STOPWORD REMOVAL ===
# Before: ['i', 'love', 'gojek', 'sm', 'setiap', 'hari', 'berangkat', 'pulang', 'sekolah', 'always', 'make', 'gojek', 'apalagi', 'di', 'gojek', 'fitur', 'goride', 'comfort', 'cocok', 'banget', 'buat', 'aku', 'yang', 'suka', 'bawa', 'barang', 'banyak', 'kesekolah', 'suka', 'bawa', 'tas', 'gede', 'begitu', 'deh', 'kaki', 'nya', 'dan', 'pnttnya', 'juga', 'jadi', 'tidak', 'pegel', 'jaya', 'terus', 'deh', 'yaa', 'gojek']
# After:  ['i', 'love', 'gojek', 'sm', 'berangkat', 'pulang', 'sekolah', 'always', 'make', 'gojek', 'gojek', 'fitur', 'goride', 'comfort', 'cocok', 'banget', 'suka', 'bawa', 'barang', 'kesekolah', 'suka', 'bawa', 'tas', 'gede', 'deh', 'kaki', 'nya', 'pnttnya', 'pegel', 'jaya', 'deh', 'yaa', 'gojek']
#
# === STOPWORD REMOVAL ===
# Before: ['kenapa', 'saat', 'saya', 'ingin', 'menggunakan', 'go', 'ride', 'dia', 'berubah', 'go', 'car', 'kan', 'jadi', 'mahal', 'ongkosnya']
# After:  ['go', 'ride', 'berubah', 'go', 'car', 'mahal', 'ongkosnya']
#
# === STOPWORD REMOVAL ===
# Before: ['good']
# After:  ['good']
#
# === STOPWORD REMOVAL ===
# Before: ['apa', 'apa', 'go', 'transit', 'sekarang', 'digabung', 'sama', 'go', 'ridetransit', 'jadinya', 'tidak', 'bisa', 'edit', 'stasiun', 'kalau', 'tujuannya', 'berubah', 'padahal', 'sblum', 'update', 'bisa', 'kalau', 'diupdate', 'makin', 'nyusahin', 'lebih', 'baik', 'gausah', 'di', 'update', 'tujuannya', 'update', 'kan', 'untuk', 'memudahkan', 'bukan', 'bahkan', 'mempersulit']
# After:  ['go', 'transit', 'digabung', 'go', 'ridetransit', 'edit', 'stasiun', 'tujuannya', 'berubah', 'sblum', 'update', 'diupdate', 'nyusahin', 'gausah', 'update', 'tujuannya', 'update', 'memudahkan', 'mempersulit']
#
# === STOPWORD REMOVAL ===
# Before: ['layanan', 'nya', 'lebih', 'baik', 'daripada', 'aplikasi', 'sebelah', 'pilihannya', 'juga', 'banyak']
# After:  ['layanan', 'nya', 'aplikasi', 'sebelah', 'pilihannya']
#
# === STOPWORD REMOVAL ===
# Before: ['mantap']
# After:  ['mantap']
#
# === STOPWORD REMOVAL ===
# Before: ['padahal', 'pakai', 'aplikasi', 'ini', 'sudah', 'lama', 'tiba', 'hari', 'ini', 'bingung', 'pas', 'check', 'goride', 'harganya', 'dari', 'rb', 'naik', 'jadi', 'rb', 'eh', 'iseng', 'buka', 'grab', 'Cuma', 'bayar', 'rb']
# After:  ['pakai', 'aplikasi', 'bingung', 'pas', 'check', 'goride', 'harganya', 'rb', 'rb', 'eh', 'iseng', 'buka', 'grab', 'Cuma', 'bayar', 'rb']
#
# === STOPWORD REMOVAL ===
# Before: ['susah', 'dapat', 'driver', 'sudah', 'x', 'pesan', 'tetep', 'tidak', 'dapat', 'pindah', 'dari', 'menu', 'go', 'ride', 'ke', 'go', 'car', 'cmn', 'hasilny', 'nihil', 'sama', 'saja', 'parah', 'sih']
# After:  ['susah', 'driver', 'x', 'pesan', 'tetep', 'pindah', 'menu', 'go', 'ride', 'go', 'car', 'cmn', 'hasilny', 'nihil', 'parah', 'sih']
#
# === STOPWORD REMOVAL ===
# Before: ['saya', 'suka', 'pakai', 'jasa', 'goride', 'gocar', 'seneng', 'saja', 'denger', 'curhatan', 'mereka', 'cerita', 'mereka', 'keluh', 'kesah', 'mereka', 'cerita', 'sedih', 'cerita', 'bahagia', 'semuanya', 'saya', 'rangkum', 'jadi', 'motivasi', 'buat', 'diri', 'sendiri']
# After:  ['suka', 'pakai', 'jasa', 'goride', 'gocar', 'seneng', 'denger', 'curhatan', 'cerita', 'keluh', 'kesah', 'cerita', 'sedih', 'cerita', 'bahagia', 'rangkum', 'motivasi']
#
# === STOPWORD REMOVAL ===
# Before: ['ok']
# After:  ['ok']
#
# === STOPWORD REMOVAL ===
# Before: ['mau', 'milih', 'go', 'transit', 'tapi', 'selalu', 'dialihkan', 'ke', 'go', 'ride']
# After:  ['milih', 'go', 'transit', 'dialihkan', 'go', 'ride']
#
# === STOPWORD REMOVAL ===
# Before: ['i', 'got', 'safety', 'when', 'i', 'was', 'ride', 'gojek']
# After:  ['i', 'got', 'safety', 'when', 'i', 'was', 'ride', 'gojek']
#
# === STOPWORD REMOVAL ===
# Before: ['untuk', 'goride', 'lebih', 'mudah', 'dulu']
# After:  ['goride', 'mudah']
#
# === STOPWORD REMOVAL ===
# Before: ['kenapa', 'aku', 'masukkan', 'kode', 'promo', 'goride', 'sudah', 'sukses', 'tapi', 'vocer', 'promonya', 'gada', 'aku', 'sudah', 'cba', 'update', 'masin', 'tetap', 'sma', 'sudah', 'hpus', 'download', 'bbrapa', 'kli', 'tapi', 'tetap', 'sama', 'kenapa', 'iya', 'apakah', 'eror', 'tapi', 'cba', 'punya', 'teman', 'mah', 'gada', 'masalah', 'apa']
# After:  ['masukkan', 'kode', 'promo', 'goride', 'sukses', 'vocer', 'promonya', 'gada', 'cba', 'update', 'masin', 'sma', 'hpus', 'download', 'bbrapa', 'kli', 'iya', 'eror', 'cba', 'teman', 'mah', 'gada']
#
# === STOPWORD REMOVAL ===
# Before: ['pesan', 'goride', 'posisi', 'driver', 'dekat', 'tidak', 'mau', 'pada', 'mengambil', 'di', 'kasihnya', 'yang', 'jaraknya', 'jauh', 'semuanya', 'sbagian', 'di', 'batal', 'sama', 'drivernya']
# After:  ['pesan', 'goride', 'posisi', 'driver', 'mengambil', 'kasihnya', 'jaraknya', 'sbagian', 'batal', 'drivernya']
#
# === STOPWORD REMOVAL ===
# Before: ['mohon', 'pihak', 'gojek', 'memberikan', 'saya', 'pembelaan', 'karena', 'saya', 'selalu', 'pulang', 'dengan', 'goride', 'tetapi', 'tadi', 'saya', 'mendapat', 'perlakuan', 'yang', 'sangat', 'tidak', 'menyenangkan', 'karena', 'saat', 'saya', 'membantalkan', 'pesanan', 'karena', 'titik', 'jemput', 'tidak', 'sesuai', 'saya', 'tetap', 'didatangi', 'driver', 'tersebut', 'dan', 'driver', 'tersebut', 'marah', 'bahkan', 'sampai', 'orang', 'melihat', 'saya', 'disitu', 'saya', 'sangat', 'malu', 'karena', 'hal', 'tersebut', 'mohon', 'bantuannya', 'untuk', 'menegur', 'mengingat', 'kan', 'driver', 'tersebut']
# After:  ['mohon', 'gojek', 'pembelaan', 'pulang', 'goride', 'perlakuan', 'menyenangkan', 'membantalkan', 'pesanan', 'titik', 'jemput', 'sesuai', 'didatangi', 'driver', 'driver', 'marah', 'orang', 'disitu', 'malu', 'mohon', 'bantuannya', 'menegur', 'driver']
#
# === STOPWORD REMOVAL ===
# Before: ['layanan', 'yang', 'memudahkan', 'masyarakat']
# After:  ['layanan', 'memudahkan', 'masyarakat']
#
# === STOPWORD REMOVAL ===
# Before: ['tolong', 'untuk', 'goride', 'tidak', 'perlu', 'di', 'pisah', 'antara', 'yang', 'hemat', 'sama', 'yang', 'comfort', 'karena', 'percuma', 'jika', 'tidak', 'ada', 'perhatian', 'dari', 'pihak', 'gojeknya', 'pengalaman', 'saya', 'pesan', 'comfort', 'tapi', 'motor', 'yang', 'datang', 'beda', 'plat', 'nomor', 'beda', 'jenisnya', 'masuk', 'kategori', 'hemat', 'tolong', 'lebih', 'diperhatikan', 'lagi', 'khusus', 'driver', 'goride', 'nya', 'karena', 'keselamatan', 'diatas', 'segalanya']
# After:  ['tolong', 'goride', 'pisah', 'hemat', 'comfort', 'perhatian', 'gojeknya', 'pengalaman', 'pesan', 'comfort', 'motor', 'beda', 'plat', 'nomor', 'beda', 'jenisnya', 'masuk', 'kategori', 'hemat', 'tolong', 'diperhatikan', 'khusus', 'driver', 'goride', 'nya', 'keselamatan', 'diatas']
#
# === STOPWORD REMOVAL ===
# Before: ['ok']
# After:  ['ok']
#
# === STOPWORD REMOVAL ===
# Before: ['sangat', 'membantu', 'bagi', 'saya', 'dari', 'goride', 'gocar', 'gofood']
# After:  ['membantu', 'goride', 'gocar', 'gofood']
#
# === STOPWORD REMOVAL ===
# Before: ['gofood', 'nya', 'mengecewakan', 'sekali', 'sudah', 'menunggu', 'sampai', 'jam', 'bahkan', 'dibatalin', 'dengan', 'alasan', 'gada', 'driver', 'kalau', 'memang', 'tidak', 'niat', 'bisnis', 'lebih', 'baik', 'tutup', 'saja', 'aplikasinya', 'bukan', 'hanya', 'itu', 'saja', 'pesan', 'goride', 'dan', 'lain-lain', 'juga', 'selalu', 'drivernya', 'gada', 'padahal', 'jelas', 'jelas', 'banyak', 'driver', 'disekitar', 'lokasi', 'makin', 'hari', 'makin', 'tidak', 'banget', 'ini', 'aplikasi']
# After:  ['gofood', 'nya', 'mengecewakan', 'menunggu', 'jam', 'dibatalin', 'alasan', 'gada', 'driver', 'niat', 'bisnis', 'tutup', 'aplikasinya', 'pesan', 'goride', 'lain-lain', 'drivernya', 'gada', 'driver', 'disekitar', 'lokasi', 'banget', 'aplikasi']
#
# === STOPWORD REMOVAL ===
# Before: ['tidak', 'pernah', 'dapat', 'voucher', 'goride', 'jompor', 'saya', 'setiap', 'hari', 'pakai', 'goride', 'pulang', 'pergi', 'rb', 'gaperna', 'dapat', 'voucher', 'goride']
# After:  ['voucher', 'goride', 'jompor', 'pakai', 'goride', 'pulang', 'pergi', 'rb', 'gaperna', 'voucher', 'goride']
#
# === STOPWORD REMOVAL ===
# Before: ['verygood']
# After:  ['verygood']
#
# === STOPWORD REMOVAL ===
# Before: ['tiap', 'transaksi', 'di', 'gojek', 'toped', 'blibli', 'alfagift', 'kenapa', 'selalu', 'gopaylaternya', 'ditulis', 'diblokir', 'limit', 'aman', 'tagihan', 'belum', 'japo', 'masa', 'cuma', 'bisa', 'dipakai', 'buat', 'goride', 'gocar', 'saja', 'bagaimana', 'ini']
# After:  ['transaksi', 'gojek', 'toped', 'blibli', 'alfagift', 'gopaylaternya', 'ditulis', 'diblokir', 'limit', 'aman', 'tagihan', 'japo', 'dipakai', 'goride', 'gocar']
#
# === STOPWORD REMOVAL ===
# Before: ['sudah', 'order', 'goride', 'lama', 'menunggu', 'dapat', 'drivernya', 'sudah', 'begitu', 'susah', 'di', 'batalin', 'jauh', 'sama', 'aplikasi', 'tetangga']
# After:  ['order', 'goride', 'menunggu', 'drivernya', 'susah', 'batalin', 'aplikasi', 'tetangga']
#
# === STOPWORD REMOVAL ===
# Before: ['mau', 'bayar', 'tagihan', 'gopay', 'later', 'tapi', 'aplikasi', 'gangguan', 'terus', 'mau', 'order', 'goride', 'gocar', 'juga', 'sring', 'tidak', 'ada', 'driver', 'tulisannya', 'padahal', 'driver', 'nya', 'bnyak', 'trlihat', 'diaplikasi', 'gojek', 'mkin', 'buruk', 'sekarang', 'aplikasinya', 'kyknya', 'sudah', 'tidak', 'tahu', 'diperbaiki', 'dengan', 'cepat']
# After:  ['bayar', 'tagihan', 'gopay', 'later', 'aplikasi', 'gangguan', 'order', 'goride', 'gocar', 'sring', 'driver', 'tulisannya', 'driver', 'nya', 'bnyak', 'trlihat', 'diaplikasi', 'gojek', 'mkin', 'buruk', 'aplikasinya', 'kyknya', 'diperbaiki', 'cepat']
#
# === STOPWORD REMOVAL ===
# Before: ['sudah', 'sering', 'pakai', 'gojek', 'mesen', 'makan', 'atau', 'pun', 'goride', 'tetep', 'saja', 'sampai', 'detik', 'ini', 'tidak', 'di', 'buka', 'gopaylater', 'atau', 'gopinjam', 'nya', 'masa', 'kalah', 'sama', 'yang', 'baru', 'daftar', 'dan', 'order', 'cuma', 'beberapa', 'saja', 'langsung', 'bisa', 'dapat', 'limit', 'gopaylater', 'anehh', 'banget', 'lumayan', 'kecewa', 'si', 'sama', 'aplikasi', 'ini', 'merasa', 'tidak', 'adil']
# After:  ['pakai', 'gojek', 'mesen', 'makan', 'goride', 'tetep', 'detik', 'buka', 'gopaylater', 'gopinjam', 'nya', 'kalah', 'daftar', 'order', 'langsung', 'limit', 'gopaylater', 'anehh', 'banget', 'lumayan', 'kecewa', 'si', 'aplikasi', 'adil']
#
# === STOPWORD REMOVAL ===
# Before: ['saya', 'pelanggan', 'goride', 'dan', 'gosend', 'tidak', 'ada', 'masalah', 'cuma', 'saya', 'kecewa', 'sama', 'go', 'car', 'di', 'jogja', 'kenapa', 'rata', 'tidak', 'niat', 'iya', 'padahal', 'kan', 'yang', 'milih', 'acak', 'dari', 'aplikasi', 'juga', 'masa', 'cuma', 'karena', 'jauh', 'dikit', 'minta', 'dicancel', 'padahal', 'cm', 'kamu', 'jemputnya', 'jarak', 'yang', 'dianter', 'pun', 'juga', 'tidak', 'jauh', 'amat', 'masih', 'kamu', 'semoga', 'pihak', 'gojek', 'bisa', 'menyortir', 'lagi', 'driver', 'gocar', 'yang', 'cuma', 'iseng', 'males', 'an', 'tertawa', 'kacau']
# After:  ['pelanggan', 'goride', 'gosend', 'kecewa', 'go', 'car', 'jogja', 'niat', 'iya', 'milih', 'acak', 'aplikasi', 'dikit', 'dicancel', 'cm', 'jemputnya', 'jarak', 'dianter', 'semoga', 'gojek', 'menyortir', 'driver', 'gocar', 'iseng', 'males', 'an', 'tertawa', 'kacau']
#
# === STOPWORD REMOVAL ===
# Before: ['tolong', 'kalau', 'kita', 'sedang', 'pesan', 'goride', 'gocar', 'cari', 'driver', 'yang', 'lokasinya', 'dekat', 'dengan', 'titik', 'penjemputan', 'sering', 'banget', 'dapat', 'driver', 'yang', 'jaraknya', 'jauh', 'padahal', 'driver', 'yang', 'mangkal', 'di', 'sekitar', 'lokasi', 'penjemputan', 'banyak', 'bangett', 'tolong', 'di', 'perbaiki', 'lagi', 'jangan', 'buang', 'waktu', 'kami', 'hanya', 'untuk', 'menunggu', 'driver', 'yang', 'datengnya', 'lama', 'karena', 'jaraknya', 'jauh']
# After:  ['tolong', 'pesan', 'goride', 'gocar', 'cari', 'driver', 'lokasinya', 'titik', 'penjemputan', 'banget', 'driver', 'jaraknya', 'driver', 'mangkal', 'lokasi', 'penjemputan', 'bangett', 'tolong', 'perbaiki', 'buang', 'menunggu', 'driver', 'datengnya', 'jaraknya']
#
# === STOPWORD REMOVAL ===
# Before: ['apa', 'saja', 'ada', 'mulai', 'car', 'ride', 'dan', 'food', 'keren']
# After:  ['car', 'ride', 'food', 'keren']
#
# === STOPWORD REMOVAL ===
# Before: ['tidak', 'suka', 'sama', 'gojek', 'sekarang', 'kadang', 'pakai', 'go', 'ride', 'hemat', 'tidak', 'diterima', 'sama', 'driver', 'padahal', 'meringankan', 'pengeluaran', 'kalau', 'lagi', 'tanggal', 'tua', 'sudah', 'begitu', 'kalau', 'pagi', 'susahnya', 'minta', 'ampun', 'sekalinya', 'dapat', 'cuma', 'jarak', 'menit', 'dia', 'bilang', 'kejauhan', 'saya', 'males', 'pernah', 'juga', 'saya', 'lebih', 'dekat', 'ke', 'lokasi', 'tujuan', 'situ', 'jadi', 'kalau', 'saya', 'jemput', 'bulak', 'balik', 'dong']
# After:  ['suka', 'gojek', 'kadang', 'pakai', 'go', 'ride', 'hemat', 'diterima', 'driver', 'meringankan', 'pengeluaran', 'tanggal', 'tua', 'pagi', 'susahnya', 'ampun', 'sekalinya', 'jarak', 'menit', 'bilang', 'kejauhan', 'males', 'lokasi', 'tujuan', 'situ', 'jemput', 'bulak']
#
# === STOPWORD REMOVAL ===
# Before: ['saya', 'kecewa', 'dengan', 'driver', 'goride', 'setiap', 'hujan', 'pasti', 'tidak', 'ada', 'yang', 'mengambil', 'orderan', 'alasan', 'tidak', 'bawa', 'jas', 'hujan', 'padahal', 'saya', 'sudah', 'chat', 'kalau', 'saya', 'bawa', 'jas', 'hujan', 'buat', 'apa', 'ngojek', 'kalau', 'tidak', 'sedia', 'jas', 'hujan', 'untuk', 'diri', 'sendiri']
# After:  ['kecewa', 'driver', 'goride', 'hujan', 'mengambil', 'orderan', 'alasan', 'bawa', 'jas', 'hujan', 'chat', 'bawa', 'jas', 'hujan', 'ngojek', 'sedia', 'jas', 'hujan']
#
# === STOPWORD REMOVAL ===
# Before: ['sekarang', 'sudah', 'mahal', 'goride', 'dan', 'gofood']
# After:  ['mahal', 'goride', 'gofood']
#
# === STOPWORD REMOVAL ===
# Before: ['gampang', 'kalau', 'mau', 'cari', 'alamat', 'enak']
# After:  ['gampang', 'cari', 'alamat', 'enak']
#
# === STOPWORD REMOVAL ===
# Before: ['fitur', 'go', 'pay', 'later', 'go', 'pay', 'pinjam', 'tidak', 'bisa', 'di', 'non', 'aktifkan', 'lama', 'kaya', 'aplikasi', 'pinjol', 'rawan', 'penyalahgunaan', 'ridernya', 'seneng', 'banget', 'batalin', 'sendiri', 'sudah', 'menunggu', 'lama', 'tidak', 'kaya', 'sebelah']
# After:  ['fitur', 'go', 'pay', 'later', 'go', 'pay', 'pinjam', 'non', 'aktifkan', 'kaya', 'aplikasi', 'pinjol', 'rawan', 'penyalahgunaan', 'ridernya', 'seneng', 'banget', 'batalin', 'menunggu', 'kaya', 'sebelah']
#
# === STOPWORD REMOVAL ===
# Before: ['tahun', 'mengunakan', 'gojek', 'perlu', 'di', 'benahi', 'driver', 'berbeda', 'dengan', 'aplikasi', 'apakah', 'boleh', 'orang', 'yang', 'bukan', 'driver', 'memakai', 'akun', 'driver', 'gojek', 'joki', 'mengantarkan', 'pesanan', 'takut', 'makanan', 'saya', 'di', 'apa', 'apin', 'dengan', 'orang', 'yang', 'bukan', 'driver', 'gojek', 'joki', 'mana', 'lagi', 'motor', 'yang', 'di', 'pakai', 'joki', 'plat', 'nya', 'berbeda', 'dengan', 'aplikasi', 'pesan', 'goride', 'juga', 'begitu', 'sih', 'driver', 'yang', 'jemput', 'orangnya', 'berbeda', 'dengan', 'aplikasi', 'plat', 'nomor', 'motor', 'nya', 'juga', 'berbeda', 'saya', 'jadi', 'was', 'was', 'takut', 'tolong', 'adakan', 'vermuk', 'berwaktu', 'seperti', 'grab']
# After:  ['mengunakan', 'gojek', 'benahi', 'driver', 'berbeda', 'aplikasi', 'orang', 'driver', 'memakai', 'akun', 'driver', 'gojek', 'joki', 'mengantarkan', 'pesanan', 'takut', 'makanan', 'apin', 'orang', 'driver', 'gojek', 'joki', 'motor', 'pakai', 'joki', 'plat', 'nya', 'berbeda', 'aplikasi', 'pesan', 'goride', 'sih', 'driver', 'jemput', 'orangnya', 'berbeda', 'aplikasi', 'plat', 'nomor', 'motor', 'nya', 'berbeda', 'was', 'was', 'takut', 'tolong', 'adakan', 'vermuk', 'berwaktu', 'grab']
#
# === STOPWORD REMOVAL ===
# Before: ['bagaimana', 'ini', 'waktu', 'mau', 'order', 'goride', 'kendala', 'kenapa', 'bisa', 'ada', 'keterangan', 'internetnya', 'mati', 'padhal', 'kuota', 'banyak', 'melimpahh', 'coba', 'cek', 'gojek', 'di', 'adek', 'bisa', 'buat', 'mesen', 'padahal', 'punyaku', 'biasane', 'pakai', 'juga', 'baik', 'saja', 'tolong', 'segera', 'diperbaiki']
# After:  ['order', 'goride', 'kendala', 'keterangan', 'internetnya', 'mati', 'padhal', 'kuota', 'melimpahh', 'coba', 'cek', 'gojek', 'adek', 'mesen', 'punyaku', 'biasane', 'pakai', 'tolong', 'diperbaiki']
#
# === STOPWORD REMOVAL ===
# Before: ['woi', 'harga', 'goride', 'nya', 'kenapa', 'nambah', 'dari', 'hari', 'ke', 'hari', 'tempat', 'nya', 'sama', 'saja', 'kenapa', 'masa', 'gara', 'gara', 'cuaca', 'panas', 'atau', 'hujan', 'jadi', 'naik', 'kalau', 'hujan', 'ok', 'lah', 'tapi', 'tidak', 'ngotak', 'juga', 'kalau', 'kali', 'njir', 'oh', 'kualitas', 'nya', 'yang', 'bikin', 'nambah', 'perasaan', 'sama', 'saja', 'deh', 'mau', 'hemat', 'atau', 'comfort', 'hoki', 'an', 'saja', 'lihat', 'maxim', 'iya', 'murah', 'nomor', 'diskon', 'tidak', 'menarik', 'tapi', 'segitu', 'saja', 'terus']
# After:  ['woi', 'harga', 'goride', 'nya', 'nambah', 'nya', 'gara', 'gara', 'cuaca', 'panas', 'hujan', 'hujan', 'ok', 'ngotak', 'kali', 'njir', 'oh', 'kualitas', 'nya', 'bikin', 'nambah', 'perasaan', 'deh', 'hemat', 'comfort', 'hoki', 'an', 'lihat', 'maxim', 'iya', 'murah', 'nomor', 'diskon', 'menarik', 'segitu']
#
# === STOPWORD REMOVAL ===
# Before: ['thank', 'you']
# After:  ['thank', 'you']
#
# === STOPWORD REMOVAL ===
# Before: ['ok', 'cepat', 'dan', 'tepat']
# After:  ['ok', 'cepat']
#
# === STOPWORD REMOVAL ===
# Before: ['dc', 'nya', 'suka', 'ngancam']
# After:  ['dc', 'nya', 'suka', 'ngancam']
#
# === STOPWORD REMOVAL ===
# Before: ['jasa', 'biaya', 'gojek', 'nya', 'sudah', 'mahal', 'di', 'tambah', 'lagi', 'pesan', 'go', 'food', 'atau', 'go', 'ride', 'dan', 'lain-lain', 'kena', 'double', 'order', 'sebagai', 'custumer', 'merasa', 'di', 'rugikan', 'rugi', 'sudah', 'bayar', 'mahal', 'dan', 'rugi', 'waktu', 'menunggu', 'jadi', 'lama', 'gojek', 'makin', 'tidak', 'jelas', 'sekarang']
# After:  ['jasa', 'biaya', 'gojek', 'nya', 'mahal', 'pesan', 'go', 'food', 'go', 'ride', 'lain-lain', 'kena', 'double', 'order', 'custumer', 'rugikan', 'rugi', 'bayar', 'mahal', 'rugi', 'menunggu', 'gojek']
#
# === STOPWORD REMOVAL ===
# Before: ['terimakasih']
# After:  ['terimakasih']
#
# === STOPWORD REMOVAL ===
# Before: ['banyakin', 'promonya', 'khususnya', 'goride', 'and', 'gofood']
# After:  ['banyakin', 'promonya', 'goride', 'and', 'gofood']
#
# === STOPWORD REMOVAL ===
# Before: ['akun', 'saya', 'ke', 'blokir', 'tolong', 'bagaimana', 'solusinya', 'sudah', 'ngechat', 'cs', 'responnya', 'sama', 'selalu', 'laporan', 'ditutup', 'solusi', 'dong', 'keterangannya', 'ke', 'blokir', 'dan', 'tidak', 'bisa', 'menggunakan', 'berbagai', 'voucher', 'termasuk', 'goride', 'gofood', 'tolong', 'bagaimana', 'biar', 'normal', 'lagi']
# After:  ['akun', 'blokir', 'tolong', 'solusinya', 'ngechat', 'cs', 'responnya', 'laporan', 'ditutup', 'solusi', 'keterangannya', 'blokir', 'voucher', 'goride', 'gofood', 'tolong', 'biar', 'normal']
#
# === STOPWORD REMOVAL ===
# Before: ['bagus', 'minta', 'tolong', 'lebih', 'banyak', 'promo', 'untuk', 'gocar', 'sama', 'goride', 'comfort', 'supaya', 'bisa', 'menikmati', 'perjalanan', 'dengan', 'hemat', 'dan', 'nyaman', 'terima', 'kasih']
# After:  ['bagus', 'tolong', 'promo', 'gocar', 'goride', 'comfort', 'menikmati', 'perjalanan', 'hemat', 'nyaman', 'terima', 'kasih']
#
# === STOPWORD REMOVAL ===
# Before: ['gilaa', 'saldo', 'hilang', 'gtu', 'saja', 'terus', 'call', 'center', 'tidak', 'ngebantu', 'banget', 'masa', 'order', 'goride', 'gadapet', 'sampai', 'kali', 'dan', 'saldonya', 'ketarik', 'nya', 'apa', 'in', 'ini', 'gojek']
# After:  ['gilaa', 'saldo', 'hilang', 'gtu', 'call', 'center', 'ngebantu', 'banget', 'order', 'goride', 'gadapet', 'kali', 'saldonya', 'ketarik', 'nya', 'in', 'gojek']
#
# === STOPWORD REMOVAL ===
# Before: ['kemarin', 'siang', 'masih', 'bisa', 'pesan', 'goride', 'pakai', 'gopaylater', 'tapi', 'pas', 'malam', 'tiba', 'tiba', 'di', 'gopaylater', 'di', 'blokir', 'padahal', 'tagihan', 'belum', 'jatuh', 'tempo', 'dan', 'limit', 'masih', 'sangat', 'sangat', 'banyak', 'sudah', 'laporan', 'tapi', 'belum', 'di', 'tanggapi', 'kecewa']
# After:  ['kemarin', 'siang', 'pesan', 'goride', 'pakai', 'gopaylater', 'pas', 'malam', 'gopaylater', 'blokir', 'tagihan', 'jatuh', 'tempo', 'limit', 'laporan', 'tanggapi', 'kecewa']
#
# === STOPWORD REMOVAL ===
# Before: ['kenapa', 'tidak', 'bisa', 'tukar', 'voucher', 'gorideaja', 'sudah', 'ditukar', 'bilangnya', 'berhasil', 'tapi', 'di', 'cek', 'di', 'halaman', 'voucher', 'tidak', 'ada', 'sama', 'sekali', 'voucher', 'nya', 'kosongg']
# After:  ['tukar', 'voucher', 'gorideaja', 'ditukar', 'bilangnya', 'berhasil', 'cek', 'halaman', 'voucher', 'voucher', 'nya', 'kosongg']
#
# === STOPWORD REMOVAL ===
# Before: ['sangat', 'membantu']
# After:  ['membantu']
#
# === STOPWORD REMOVAL ===
# Before: ['keren', 'ini', 'sekarang', 'gojek', 'dapat', 'driver', 'nya', 'cepat', 'dan', 'cepat', 'sampai', 'tidak', 'menunggu', 'lama', 'dapat', 'vocher', 'diskon', 'goride', 'gocar', 'gofood', 'terus', 'tapi', 'saya', 'minta', 'tolong', 'dong', 'vocher', 'goride', 'nya', 'ada', 'setiap', 'hari', 'jadi', 'bisa', 'membantu', 'anak', 'sekolah', 'dengan', 'promo', 'yang', 'murah', 'dibawah', 'ribu']
# After:  ['keren', 'gojek', 'driver', 'nya', 'cepat', 'cepat', 'menunggu', 'vocher', 'diskon', 'goride', 'gocar', 'gofood', 'tolong', 'vocher', 'goride', 'nya', 'membantu', 'anak', 'sekolah', 'promo', 'murah', 'dibawah', 'ribu']
#
# === STOPWORD REMOVAL ===
# Before: ['gojek', 'pasti', 'ada', 'jalan']
# After:  ['gojek', 'jalan']
#
# === STOPWORD REMOVAL ===
# Before: ['kenapa', 'map', 'goride', 'setiap', 'dekat', 'tol', 'pasti', 'di', 'arahi', 'ke', 'lewat', 'tol', 'sehingga', 'tarif', 'tidak', 'sesuai', 'terima', 'kasih']
# After:  ['map', 'goride', 'tol', 'arahi', 'tol', 'tarif', 'sesuai', 'terima', 'kasih']
#
# === STOPWORD REMOVAL ===
# Before: ['saya', 'juga', 'driver', 'go', 'ride', 'min', 'sangat', 'disayangkan', 'kalau', 'orderan', 'dibuat', 'susah', 'sekarang', 'dan', 'bahkan', 'bensin', 'x', 'pengeluaran', 'akhirnya', 'saya', 'akali', 'beli', 'Cuma', 'rb', 'supaya', 'tidak', 'rugi', 'sejak', 'system', 'yang', 'paling', 'terdekat', 'diterapkan', 'sejak', 'system', 'goride', 'yang', 'sangat', 'terdekat', 'diterapkan', 'otomatis', 'pendapatan', 'kita', 'berkurang', 'drastis', 'kita', 'sebagai', 'costumer', 'gojek', 'juga', 'tidak', 'bisa', 'membantu', 'orderan', 'seperti', 'biasanya', 'bahkan', 'belanja', 'di', 'tokopedia', 'semoga', 'system', 'update', 'terbaru', 'pendapatan', 'kita', 'kembali', 'konsisten', 'diatas', 'lagi', 'amin']
# After:  ['driver', 'go', 'ride', 'min', 'disayangkan', 'orderan', 'susah', 'bensin', 'x', 'pengeluaran', 'akali', 'beli', 'Cuma', 'rb', 'rugi', 'system', 'terdekat', 'diterapkan', 'system', 'goride', 'terdekat', 'diterapkan', 'otomatis', 'pendapatan', 'berkurang', 'drastis', 'costumer', 'gojek', 'membantu', 'orderan', 'belanja', 'tokopedia', 'semoga', 'system', 'update', 'terbaru', 'pendapatan', 'konsisten', 'diatas', 'amin']
#
# === STOPWORD REMOVAL ===
# Before: ['kami', 'pelajar', 'turunkan', 'tarif', 'go', 'ride', 'kami', 'kaum', 'missqueen']
# After:  ['pelajar', 'turunkan', 'tarif', 'go', 'ride', 'kaum', 'missqueen']
#
# === STOPWORD REMOVAL ===
# Before: ['good']
# After:  ['good']
#
# === STOPWORD REMOVAL ===
# Before: ['awal', 'memakai', 'aplikasi', 'gojek', 'puas', 'makin', 'kesini', 'keseringan', 'kecewa', 'order', 'makanan', 'susah', 'dapat', 'driver', 'nya', 'harus', 'menunggu', 'hampir', 'satu', 'jam', 'begitu', 'pun', 'untuk', 'goride', 'mohon', 'diperhatikan', 'dan', 'ditindaklanjuti', 'kedepannya']
# After:  ['memakai', 'aplikasi', 'gojek', 'puas', 'kesini', 'keseringan', 'kecewa', 'order', 'makanan', 'susah', 'driver', 'nya', 'menunggu', 'jam', 'goride', 'mohon', 'diperhatikan', 'ditindaklanjuti', 'kedepannya']
#
# === STOPWORD REMOVAL ===
# Before: ['program', 'sudah', 'bagus', 'pertahankan', 'di', 'tingkatkan', 'lagi', 'layanan', 'serta', 'tolong', 'di', 'sejahterakan', 'driver', 'driver', 'nya', 'berikan', 'mereka', 'penghidupan', 'layak']
# After:  ['program', 'bagus', 'pertahankan', 'tingkatkan', 'layanan', 'tolong', 'sejahterakan', 'driver', 'driver', 'nya', 'penghidupan', 'layak']
#
# === STOPWORD REMOVAL ===
# Before: ['sangat', 'membantu']
# After:  ['membantu']
#
# === STOPWORD REMOVAL ===
# Before: ['go', 'ride', 'tidak', 'bisa', 'melayani', 'pas', 'lagi', 'hujan', 'padahal', 'gerimis', 'saja', 'jam', 'order', 'tidak', 'ada', 'yang', 'nyangkut', 'berharap', 'sm', 'gojek', 'nyampe', 'kantor', 'terlambat']
# After:  ['go', 'ride', 'melayani', 'pas', 'hujan', 'gerimis', 'jam', 'order', 'nyangkut', 'berharap', 'sm', 'gojek', 'nyampe', 'kantor', 'terlambat']
#
# === STOPWORD REMOVAL ===
# Before: ['mantap']
# After:  ['mantap']
#
# === STOPWORD REMOVAL ===
# Before: ['mudah', 'an', 'semakin', 'bnyak', 'promonya', 'bukan', 'hanya', 'gofood', 'tapi', 'promo', 'gocar', 'goride', 'dan', 'lain-lain', 'juga']
# After:  ['mudah', 'an', 'bnyak', 'promonya', 'gofood', 'promo', 'gocar', 'goride', 'lain-lain']
#
# === STOPWORD REMOVAL ===
# Before: ['niatnya', 'mau', 'top', 'up', 'gopay', 'ke', 'driver', 'dengan', 'cara', 'order', 'go', 'ride', 'pas', 'driver', 'datang', 'bisa', 'top', 'up', 'dan', 'saldo', 'masuk', 'tapi', 'dia', 'kira', 'saya', 'mau', 'pergi', 'ke', 'tempat', 'yang', 'saya', 'tuju', 'dan', 'saya', 'harus', 'bayar', 'ongkos', 'trip', 'tersebut', 'rugi', 'dong']
# After:  ['niatnya', 'top', 'up', 'gopay', 'driver', 'order', 'go', 'ride', 'pas', 'driver', 'top', 'up', 'saldo', 'masuk', 'pergi', 'tuju', 'bayar', 'ongkos', 'trip', 'rugi']
#
# === STOPWORD REMOVAL ===
# Before: ['driver', 'driver', 'sekarang', 'pada', 'malas', 'sudah', 'tahu', 'titik', 'nya', 'sesuai', 'bahkan', 'jauh', 'banget', 'sudah', 'begitu', 'mau', 'nya', 'di', 'samperin', 'kan', 'pesan', 'ojol', 'online', 'agar', 'kita', 'praktis', 'tapi', 'ini', 'gosend', 'pun', 'dan', 'goride', 'pun', 'seperti', 'ini', 'memang', 'banyak', 'si', 'voucher', 'nya', 'tapi', 'memang', 'begitu', 'yaa', 'maaf']
# After:  ['driver', 'driver', 'malas', 'titik', 'nya', 'sesuai', 'banget', 'nya', 'samperin', 'pesan', 'ojol', 'online', 'praktis', 'gosend', 'goride', 'si', 'voucher', 'nya', 'yaa', 'maaf']
#
# === STOPWORD REMOVAL ===
# Before: ['tampilan', 'aplikasi', 'gojek', 'semakin', 'nyaman', 'untuk', 'dilihat', 'menarik', 'penggunaan', 'aplikasi', 'gojek', 'hingga', 'saat', 'ini', 'masih', 'nyaman', 'aman', 'praktis', 'dan', 'suka', 'order', 'gofood', 'goride', 'lewat', 'aplikasi', 'gojek', 'semoga', 'bisa', 'nambah', 'terus', 'promo', 'buat', 'gofood', 'nya', 'he']
# After:  ['tampilan', 'aplikasi', 'gojek', 'nyaman', 'menarik', 'penggunaan', 'aplikasi', 'gojek', 'nyaman', 'aman', 'praktis', 'suka', 'order', 'gofood', 'goride', 'aplikasi', 'gojek', 'semoga', 'nambah', 'promo', 'gofood', 'nya', 'he']
#
# === STOPWORD REMOVAL ===
# Before: ['sediakan', 'versi', 'lite', 'nya', 'dong', 'buat', 'goride', 'gocar', 'saja', 'ukuran', 'aplikasinya', 'jangan', 'terlalu', 'besarlah']
# After:  ['sediakan', 'versi', 'lite', 'nya', 'goride', 'gocar', 'ukuran', 'aplikasinya', 'besarlah']
#
# === STOPWORD REMOVAL ===
# Before: ['untuk', 'hari', 'ini', 'layanan', 'gocar', 'sangat', 'buruk', 'dicancel', 'x', 'padahal', 'sudah', 'dekat', 'dari', 'jalan', 'rumah', 'saya', 'dan', 'sekalinya', 'dapat', 'sopirnya', 'tidak', 'dilayanin', 'padahal', 'pakai', 'gocar', 'prioritas', 'buruk', 'sangat', 'buruk', 'gocar', 'saya', 'sangat', 'kecewa', 'padahal', 'saya', 'sekarang', 'pakai', 'goride', 'gofood', 'jrg', 'ada', 'kendala', 'seperti', 'ini', 'benar', 'tidak', 'akan', 'mau', 'pakai', 'gocar', 'lagi']
# After:  ['layanan', 'gocar', 'buruk', 'dicancel', 'x', 'jalan', 'rumah', 'sekalinya', 'sopirnya', 'dilayanin', 'pakai', 'gocar', 'prioritas', 'buruk', 'buruk', 'gocar', 'kecewa', 'pakai', 'goride', 'gofood', 'jrg', 'kendala', 'pakai', 'gocar']
#
# === STOPWORD REMOVAL ===
# Before: ['gofood', 'super', 'mahal', 'ongkirnya', 'biaya', 'layanannya', 'sgala', 'macam', 'sudah', 'begitu', 'tidak', 'ada', 'promo', 'potongan', 'apapun', 'pakai', 'gojek', 'cuma', 'buat', 'kebutuhan', 'gocar', 'goride', 'sama', 'tiket', 'kereta', 'saja']
# After:  ['gofood', 'super', 'mahal', 'ongkirnya', 'biaya', 'layanannya', 'sgala', 'promo', 'potongan', 'apapun', 'pakai', 'gojek', 'kebutuhan', 'gocar', 'goride', 'tiket', 'kereta']
#
# === STOPWORD REMOVAL ===
# Before: ['pokok', 'nya', 'top', 'markotop', 'deh']
# After:  ['pokok', 'nya', 'top', 'markotop', 'deh']
#
# === STOPWORD REMOVAL ===
# Before: ['good']
# After:  ['good']
#
# === STOPWORD REMOVAL ===
# Before: ['pengalaman', 'menyenangkan', 'menggunakan', 'gojek']
# After:  ['pengalaman', 'menyenangkan', 'gojek']
#
# === STOPWORD REMOVAL ===
# Before: ['sangat', 'membantu', 'sekali', 'dalam', 'perjalanan']
# After:  ['membantu', 'perjalanan']
#
# === STOPWORD REMOVAL ===
# Before: ['saya', 'langganan', 'pakai', 'gojek', 'kalau', 'mau', 'pigi', 'bekerja', 'naik', 'goride', 'jadi', 'menurud', 'saya', 'drivenya', 'ramah', 'semoga', 'ditingkatkan', 'lagi']
# After:  ['langganan', 'pakai', 'gojek', 'pigi', 'goride', 'menurud', 'drivenya', 'ramah', 'semoga', 'ditingkatkan']
#
# === STOPWORD REMOVAL ===
# Before: ['driver', 'bik', 'sopan', 'rapi', 'ramah', 'kendaraan', 'terawat', 'baik', 'dijalan', 'patuh', 'taat', 'peraturan', 'lalu', 'lintas', 'layanan', 'panggilan', 'cepat', 'selalu', 'beri', 'salam', 'relatif', 'yepay', 'waktu', 'untuk', 'gojek', 'beri', 'reward', 'bagi', 'driver', 'teladan', 'cistomersetia', 'telafan', 'tahun', 'pernah', 'mengadakan', 'indian', 'voucer', 'berhadiah', 'mobil', 'kapan', 'pengumannya', 'sudah', 'atau', 'belum', 'disosialisasikan', 'terimakasih', 'customer', 'gojek', 'go', 'ride', 'go', 'car']
# After:  ['driver', 'bik', 'sopan', 'rapi', 'ramah', 'kendaraan', 'terawat', 'dijalan', 'patuh', 'taat', 'peraturan', 'lintas', 'layanan', 'panggilan', 'cepat', 'salam', 'relatif', 'yepay', 'gojek', 'reward', 'driver', 'teladan', 'cistomersetia', 'telafan', 'mengadakan', 'indian', 'voucer', 'berhadiah', 'mobil', 'pengumannya', 'disosialisasikan', 'terimakasih', 'customer', 'gojek', 'go', 'ride', 'go', 'car']
#
# === STOPWORD REMOVAL ===
# Before: ['ketika', 'promoan', 'banyak', 'driver', 'yang', 'tidak', 'mau', 'ambil', 'orderan', 'gocar', 'goride', 'sudah', 'seringkali', 'menunggu', 'lama', 'seperti', 'ini', 'tidak', 'ada', 'yang', 'ambil', 'padahal', 'coba', 'pakai', 'grab', 'langsung', 'dapat']
# After:  ['promoan', 'driver', 'ambil', 'orderan', 'gocar', 'goride', 'seringkali', 'menunggu', 'ambil', 'coba', 'pakai', 'grab', 'langsung']
#
# === STOPWORD REMOVAL ===
# Before: ['bagus']
# After:  ['bagus']
#
# === STOPWORD REMOVAL ===
# Before: ['adanya', 'orderan', 'goride', 'hemat', 'gofood', 'hemat', 'dan', 'sebagainya', 'bikin', 'rugi', 'driver', 'secara', 'keseluruhan', 'tolong', 'dong', 'di', 'hapus', 'orderan', 'hemat', 'nya', 'pakai', 'tarif', 'normal', 'saja']
# After:  ['orderan', 'goride', 'hemat', 'gofood', 'hemat', 'bikin', 'rugi', 'driver', 'tolong', 'hapus', 'orderan', 'hemat', 'nya', 'pakai', 'tarif', 'normal']
#
# === STOPWORD REMOVAL ===
# Before: ['beragam', 'aplikasi', 'nya', 'mulai', 'dari', 'goride', 'gocar', 'go', 'food', 'dan', 'sebagainya', 'semoga', 'tambah', 'terus', 'innovasi', 'nya', 'di', 'masa', 'yang', 'akan', 'datang']
# After:  ['beragam', 'aplikasi', 'nya', 'goride', 'gocar', 'go', 'food', 'semoga', 'innovasi', 'nya']
#
# === STOPWORD REMOVAL ===
# Before: ['nice']
# After:  ['nice']
#
# === STOPWORD REMOVAL ===
# Before: ['kadang', 'kalau', 'hujan', 'gada', 'driver', 'go', 'ride', 'yang', 'mau', 'ambil', 'pesanan', 'padahal', 'hujan', 'nya', 'sudah', 'redah', 'terpaksa', 'harus', 'menunggu', 'lama']
# After:  ['kadang', 'hujan', 'gada', 'driver', 'go', 'ride', 'ambil', 'pesanan', 'hujan', 'nya', 'redah', 'terpaksa', 'menunggu']
#
# === STOPWORD REMOVAL ===
# Before: ['mau', 'order', 'goride', 'tidak', 'bisa', 'stuk', 'di', 'map']
# After:  ['order', 'goride', 'stuk', 'map']
#
# === STOPWORD REMOVAL ===
# ...
# After:  ['pesan', 'goride', 'batalkan', 'dpn', 'customer', 'motor', 'giliran', 'pesan', 'goride', 'comfort', 'eh', 'dtng', 'motor', 'sih', 'kali', 'goride', 'dtng']
#
# === STOPWORD REMOVAL ===
# Before: ['bangsatt', 'ongkos', 'gofood', 'mahal', 'banget', 'go', 'ride', 'melambung', 'tinggi', 'kasihan', 'drivernya', 'diperas', 'sampai', 'mati']
# After:  ['bangsatt', 'ongkos', 'gofood', 'mahal', 'banget', 'go', 'ride', 'melambung', 'kasihan', 'drivernya', 'diperas', 'mati']
#
# === STOPWORD REMOVAL ===
# Before: ['bagus', 'baik']
# After:  ['bagus']
#
# === STOPWORD REMOVAL ===
# Before: ['pertahankan', 'layanan', 'kepada', 'pelanggan', 'beri', 'penghargaan', 'yang', 'sebesar', 'besarnya', 'kepada', 'para', 'rider', 'driver', 'kurangin', 'potongan', 'kepada', 'mereka', 'tanpa', 'mereka', 'perusahaan', 'tidak', 'ada', 'apa', 'nya']
# After:  ['pertahankan', 'layanan', 'pelanggan', 'penghargaan', 'besarnya', 'rider', 'driver', 'kurangin', 'potongan', 'perusahaan', 'nya']
#
# === STOPWORD REMOVAL ===
# Before: ['plis', 'promo', 'nya', 'yang', 'jelas', 'khusus', 'buat', 'goride', 'saya', 'tiap', 'hari', 'pakai', 'goride', 'kenapa', 'tidak', 'pernah', 'dapat', 'promo', 'sedangkan', 'teman', 'saya', 'slalu', 'dapat', 'potongan', 'sampai', 'saya', 'beli', 'loh', 'buat', 'dapat', 'potongan', 'seperti', 'gaadil', 'begitu', 'pls']
# After:  ['plis', 'promo', 'nya', 'khusus', 'goride', 'pakai', 'goride', 'promo', 'teman', 'slalu', 'potongan', 'beli', 'loh', 'potongan', 'gaadil', 'pls']
#
# === STOPWORD REMOVAL ===
# Before: ['bagus', 'aplikasi', 'nya', 'membantu', 'banget']
# After:  ['bagus', 'aplikasi', 'nya', 'membantu', 'banget']
#
# === STOPWORD REMOVAL ===
# Before: ['buat', 'kesel', 'saja', 'kalau', 'misal', 'pesan', 'gocar', 'goride', 'pagi', 'pagi', 'pasti', 'tidak', 'ada', 'driver', 'nya', 'semisal', 'ada', 'pun', 'lama', 'nya', 'minta', 'ampun', 'pokoknya', 'kecewa', 'deh']
# After:  ['kesel', 'pesan', 'gocar', 'goride', 'pagi', 'pagi', 'driver', 'nya', 'nya', 'ampun', 'pokoknya', 'kecewa', 'deh']
#
# === STOPWORD REMOVAL ===
# Before: ['good', 'apk']
# After:  ['good', 'apk']
#
# === STOPWORD REMOVAL ===
# Before: ['hati', 'kalau', 'naik', 'goride', 'gojek', 'topi', 'tertinggal', 'nyangkut', 'di', 'helm', 'saja', 'ti', 'tilep', 'sama', 'drivernya', 'sangat', 'kecewa', 'seminggu', 'tidak', 'ada', 'kejelasan', 'atau', 'sudah', 'kerjasama', 'coba', 'kalau', 'barang', 'berharga', 'apa', 'tidak', 'bahaya', 'kalau', 'topi', 'saja', 'di', 'curi', 'begini']
# After:  ['hati', 'goride', 'gojek', 'topi', 'tertinggal', 'nyangkut', 'helm', 'ti', 'tilep', 'drivernya', 'kecewa', 'seminggu', 'kejelasan', 'kerjasama', 'coba', 'barang', 'berharga', 'bahaya', 'topi', 'curi']
#
# === STOPWORD REMOVAL ===
# Before: ['mudah', 'lancar']
# After:  ['mudah', 'lancar']
#
# === STOPWORD REMOVAL ===
# Before: ['bagaimana', 'si', 'sudah', 'langganan', 'vouch', 'go', 'plus', 'mlh', 'goride', 'nya', 'cuma', 'diskon', 'ke', 'nyesell']
# After:  ['si', 'langganan', 'vouch', 'go', 'plus', 'mlh', 'goride', 'nya', 'diskon', 'nyesell']
#
# === STOPWORD REMOVAL ===
# Before: ['mohon', 'perbaiki', 'drivernya', 'masak', 'kalau', 'hujan', 'tidak', 'mau', 'narik', 'go', 'ride', 'nya', 'sampai', 'hampir', 'jam', 'pesan', 'tidak', 'di', 'peduliin', 'sekali', 'dapat', 'langsung', 'di', 'batal', 'sama', 'driver', 'tidak', 'profesional', 'banget', 'tempatku', 'tidak', 'bisa', 'mobil', 'masuk', 'makanya', 'pesennya', 'go', 'ride']
# After:  ['mohon', 'perbaiki', 'drivernya', 'masak', 'hujan', 'narik', 'go', 'ride', 'nya', 'jam', 'pesan', 'peduliin', 'langsung', 'batal', 'driver', 'profesional', 'banget', 'tempatku', 'mobil', 'masuk', 'pesennya', 'go', 'ride']
#
# === STOPWORD REMOVAL ===
# Before: ['mantab']
# After:  ['mantab']
#
# === STOPWORD REMOVAL ===
# Before: ['saya', 'suka', 'pakai', 'gojek', 'tapi', 'di', 'sukatani', 'untuk', 'goride', 'kenapa', 'tidak', 'terjangkau', 'yaa']
# After:  ['suka', 'pakai', 'gojek', 'sukatani', 'goride', 'terjangkau', 'yaa']
#
# === STOPWORD REMOVAL ===
# Before: ['mantap', 'lah', 'pokoknya']
# After:  ['mantap', 'pokoknya']
#
# === STOPWORD REMOVAL ===
# Before: ['terimaksih', 'jaya', 'selalu']
# After:  ['terimaksih', 'jaya']
#
# === STOPWORD REMOVAL ===
# Before: ['nyaman']
# After:  ['nyaman']
#
# === STOPWORD REMOVAL ===
# Before: ['ada', 'yang', 'sekongkol', 'antara', 'sesama', 'driver', 'go', 'jek', 'saya', 'order', 'goride', 'pas', 'driver', 'datang', 'langsung', 'bertanya', 'nama', 'dan', 'alamat', 'tujuan', 'nama', 'saya', 'dan', 'tujuan', 'saya', 'disebut', 'dengan', 'benar', 'oleh', 'driver', 'tersebut', 'namun', 'setelah', 'sampai', 'driver', 'tersebut', 'bilang', 'kalau', 'dia', 'offline', 'tidak', 'pakai', 'aplikasi', 'saya', 'cek', 'diaplikasi', 'driver', 'yang', 'saya', 'order', 'mengirim', 'foto', 'bahwa', 'dia', 'sedang', 'menunggu', 'dititik', 'jemput', 'sedangkan', 'saya', 'sudah', 'sampai', 'ditujuan', 'dan', 'driver', 'yang', 'mengantar', 'saya', 'meminta', 'tarif', 'x', 'lipat', 'dari', 'tarif', 'diaplikasi']
# After:  ['sekongkol', 'driver', 'go', 'jek', 'order', 'goride', 'pas', 'driver', 'langsung', 'nama', 'alamat', 'tujuan', 'nama', 'tujuan', 'driver', 'driver', 'bilang', 'offline', 'pakai', 'aplikasi', 'cek', 'diaplikasi', 'driver', 'order', 'mengirim', 'foto', 'menunggu', 'dititik', 'jemput', 'ditujuan', 'driver', 'mengantar', 'tarif', 'x', 'lipat', 'tarif', 'diaplikasi']
#
# === STOPWORD REMOVAL ===
# Before: ['sangat', 'bagus']
# After:  ['bagus']
#
# === STOPWORD REMOVAL ===
# Before: ['layanan', 'ramah', 'sopan', 'murah']
# After:  ['layanan', 'ramah', 'sopan', 'murah']
#
# === STOPWORD REMOVAL ===
# Before: ['aplikasi', 'gojek', 'sangat', 'membantu']
# After:  ['aplikasi', 'gojek', 'membantu']
#
# === STOPWORD REMOVAL ===
# Before: ['order', 'goride', 'lama', 'kali', 'munculnya']
# After:  ['order', 'goride', 'kali', 'munculnya']
#
# === STOPWORD REMOVAL ===
# Before: ['ok', 'banget']
# After:  ['ok', 'banget']
#
# === STOPWORD REMOVAL ===
# Before: ['go', 'ride', 'oke', 'gocar', 'nya', 'kurang']
# After:  ['go', 'ride', 'oke', 'gocar', 'nya']
#
# === STOPWORD REMOVAL ===
# Before: ['go', 'ride', 'jembot', 'pada', 'sombong', 'drivernya', 'jarak', 'cuma', 'kamu', 'pada', 'gmau', 'di', 'tolak', 'di', 'map', 'dekat', 'ada', 'banyak', 'driver', 'nolak', 'semua', 'app', 'sampah']
# After:  ['go', 'ride', 'jembot', 'sombong', 'drivernya', 'jarak', 'gmau', 'tolak', 'map', 'driver', 'nolak', 'app', 'sampah']
#
# === STOPWORD REMOVAL ===
# Before: ['dapat', 'driver', 'nya', 'selalu', 'jauh', 'apalagi', 'goride', 'comfort', 'nya', 'aduhai', 'jauhnya', 'juara']
# After:  ['driver', 'nya', 'goride', 'comfort', 'nya', 'aduhai', 'jauhnya', 'juara']
#
# === STOPWORD REMOVAL ===
# Before: ['kalau', 'ada', 'bintang', 'setengah', 'sudah', 'memberikan', 'bintang', 'setengah', 'rutenya', 'sinting', 'dibikin', 'jauh', 'muter', 'muter', 'kemarin', 'goride', 'sekarang', 'go', 'bluebird', 'memberikan', 'rute', 'yang', 'benar', 'dong', 'buang', 'buang', 'waktu', 'sama', 'uang', 'konsumen', 'saja']
# After:  ['bintang', 'bintang', 'rutenya', 'sinting', 'dibikin', 'muter', 'muter', 'kemarin', 'goride', 'go', 'bluebird', 'rute', 'buang', 'buang', 'uang', 'konsumen']
#
# === STOPWORD REMOVAL ===
# Before: ['njemput', 'cepat', 'sopirannya', 'enak', 'tenang', 'sopirnya', 'sopan', 'ramsh', 'rute', 'nya', 'tepat', 'langsing', 'sampai', 'tepat', 'tujuan', 'tidak', 'bertanya', 'ini', 'itu', 'sampai', 'mana', 'ini', 'dlsb']
# After:  ['njemput', 'cepat', 'sopirannya', 'enak', 'tenang', 'sopirnya', 'sopan', 'ramsh', 'rute', 'nya', 'langsing', 'tujuan', 'dlsb']
#
# === STOPWORD REMOVAL ===
# Before: ['top', 'markotop']
# After:  ['top', 'markotop']
#
# === STOPWORD REMOVAL ===
# Before: ['sangat', 'membantu', 'semoga', 'makin', 'banyak', 'voucher', 'goride', 'dan', 'gofood']
# After:  ['membantu', 'semoga', 'voucher', 'goride', 'gofood']
#
# === STOPWORD REMOVAL ===
# Before: ['kenapa', 'setiap', 'mau', 'mesen', 'goride', 'or', 'gocar', 'slalu', 'milih', 'peta', 'manual', 'padahal', 'sudah', 'di', 'simpen', 'lokasi', 'favorit', 'tapi', 'tetap', 'saja', 'harus', 'mencari', 'manual', 'menyusahkan']
# After:  ['mesen', 'goride', 'or', 'gocar', 'slalu', 'milih', 'peta', 'manual', 'simpen', 'lokasi', 'favorit', 'mencari', 'manual', 'menyusahkan']
#
# === STOPWORD REMOVAL ===
# Before: ['mrasa', 'tidak', 'adil', 'tmn', 'saya', 'sudah', 'otomatis', 'dapat', 'voucher', 'promo', 'goride', 'tapi', 'di', 'saya', 'gd', 'sm', 'sekali', 'ishh', 'sudah', 'dimasukin', 'kode', 'sgala', 'macam', 'tetap', 'saja', 'hargany', 'nromal']
# After:  ['mrasa', 'adil', 'tmn', 'otomatis', 'voucher', 'promo', 'goride', 'gd', 'sm', 'ishh', 'dimasukin', 'kode', 'sgala', 'hargany', 'nromal']
#
# === STOPWORD REMOVAL ===
# Before: ['goridenya', 'sudah', 'bagus', 'tapi', 'gofoodnya', 'masih', 'bermasalah', 'besar', 'di', 'driver', 'saya', 'sudah', 'menunggu', 'jam', 'tidak', 'dapat', 'driver', 'makanan', 'sudah', 'jadi', 'tapi', 'driver', 'g', 'dapat', 'kasian', 'restonya', 'juga', 'kalau', 'makananya', 'sudah', 'jadi']
# After:  ['goridenya', 'bagus', 'gofoodnya', 'bermasalah', 'driver', 'menunggu', 'jam', 'driver', 'makanan', 'driver', 'g', 'kasian', 'restonya', 'makananya']
#
# === STOPWORD REMOVAL ===
# Before: ['kenapa', 'sekarang', 'susah', 'iya', 'pesan', 'gojek', 'goride', 'gocar', 'sama', 'saja', 'saya', 'buka', 'aplikasi', 'pakai', 'indrive', 'bahkan', 'cpt', 'banget', 'bukan', 'ada', 'peningkatan', 'kenapa', 'jadi', 'bahkan', 'kemunduran', 'sori', 'ini', 'udate', 'review', 'jujur', 'iya', 'kalau', 'tidak', 'gojek', 'bakal', 'ketinggalan', 'ma', 'yang', 'lain']
# After:  ['susah', 'iya', 'pesan', 'gojek', 'goride', 'gocar', 'buka', 'aplikasi', 'pakai', 'indrive', 'cpt', 'banget', 'peningkatan', 'kemunduran', 'sori', 'udate', 'review', 'jujur', 'iya', 'gojek', 'ketinggalan', 'ma']
#
# === STOPWORD REMOVAL ===
# Before: ['gojek', 'bagaimana', 'sih', 'saya', 'mau', 'pesan', 'goride', 'kenapa', 'tidak', 'bisa', 'tulisannya', 'harus', 'pakai', 'metode', 'lain', 'metode', 'lain', 'terus']
# After:  ['gojek', 'sih', 'pesan', 'goride', 'tulisannya', 'pakai', 'metode', 'metode']
#
# === STOPWORD REMOVAL ===
# Before: ['senang', 'belanja', 'di', 'gomart', 'kalau', 'pas', 'ada', 'promo']
# After:  ['senang', 'belanja', 'gomart', 'pas', 'promo']
#
# === STOPWORD REMOVAL ===
# Before: ['semangaat', 'pagii', 'para', 'pejuang', 'keluarga', 'sedikit', 'cerita', 'tentang', 'kekecewaan', 'saya', 'pakai', 'gojek', 'saya', 'pernah', 'pesan', 'goride', 'tapi', 'lama', 'banget', 'sekitar', 'minta', 'baru', 'dapat', 'driver', 'sekali', 'dapat', 'driver', 'posisi', 'nya', 'jauh', 'banget', 'padahal', 'saya', 'lihat', 'ada', 'sekitr', 'driver', 'yang', 'dekat', 'dengan', 'saya', 'saya', 'juga', 'sempat', 'tanya', 'kalau', 'rekan', 'driver', 'itu', 'belum', 'dapat', 'orderan', 'jadi', 'karena', 'terlalu', 'lama', 'saya', 'menunggu', 'saya', 'beralihlah', 'ke', 'grabbike', 'tidak', 'sampai', 'menit', 'sudah', 'dapat', 'driver', 'tidak', 'sampai', 'minta', 'driver', 'sudah', 'sampai']
# After:  ['semangaat', 'pagii', 'pejuang', 'keluarga', 'cerita', 'kekecewaan', 'pakai', 'gojek', 'pesan', 'goride', 'banget', 'driver', 'driver', 'posisi', 'nya', 'banget', 'lihat', 'sekitr', 'driver', 'rekan', 'driver', 'orderan', 'menunggu', 'beralihlah', 'grabbike', 'menit', 'driver', 'driver']
#
# === STOPWORD REMOVAL ===
# Before: ['diskon', 'terus']
# After:  ['diskon']
#
# === STOPWORD REMOVAL ===
# Before: ['woi', 'yang', 'benar', 'lah', 'masa', 'pakai', 'goride', 'plus', 'titik', 'jemputnya', 'jadi', 'ngaco', 'padahal', 'sebelumnya', 'tidak', 'pakai', 'plus', 'biasa', 'biasa', 'saja']
# After:  ['woi', 'pakai', 'goride', 'plus', 'titik', 'jemputnya', 'ngaco', 'pakai', 'plus']
#
# === STOPWORD REMOVAL ===
# Before: ['mantab']
# After:  ['mantab']
#
# === STOPWORD REMOVAL ===
# Before: ['tidak', 'ada', 'yang', 'mau', 'mengambil', 'orderan', 'go', 'ride', 'aku', 'padahal', 'aku', 'pakai', 'diskon', 'ribu', 'saja']
# After:  ['mengambil', 'orderan', 'go', 'ride', 'pakai', 'diskon', 'ribu']
#
# === STOPWORD REMOVAL ===
# Before: ['berguna', 'bett', 'sumpah']
# After:  ['berguna', 'bett', 'sumpah']
#
# === STOPWORD REMOVAL ===
# Before: ['hallo', 'gojek', 'saya', 'pengguna', 'gojek', 'dari', 'tahun', 'dan', 'saya', 'sangat', 'senang', 'sekali', 'dengan', 'app', 'tersebut', 'karena', 'saya', 'sering', 'mendapatkan', 'voucher', 'goride', 'untuk', 'menjadi', 'agak', 'lebih', 'murah', 'dari', 'biasanya', 'jadi', 'terimakasih', 'gojek', 'atas', 'jasa', 'jasa', 'mu', 'terima', 'kasih']
# After:  ['hallo', 'gojek', 'pengguna', 'gojek', 'senang', 'app', 'voucher', 'goride', 'murah', 'terimakasih', 'gojek', 'jasa', 'jasa', 'mu', 'terima', 'kasih']
#
# === STOPWORD REMOVAL ===
# Before: ['i', 'love', 'gojek', 'so', 'much', 'tapi', 'kenapa', 'sekarang', 'klu', 'kita', 'dapat', 'voucher', 'kok', 'cuma', 'berlaku', 'hanya', 'hari', 'dapat', 'voucher', 'go', 'ride', 'nya', 'memang', 'lumayan', 'paling', 'sedikit', 'dapat', 'voucher', 'bisa', 'lebih', 'dapat', 'voucher', 'go', 'car', 'juga', 'paling', 'sedikit', 'voucher', 'bisa', 'lebih', 'tapi', 'masak', 'kita', 'mau', 'wira', 'wiri', 'sebanyak', 'itu', 'dalam', 'hari', 'kan', 'tidak', 'mungkin', 'kecuali', 'klu', 'kita', 'punya', 'asrama', 'anak', 'yang', 'semua', 'di', 'pakaikan', 'voucher', 'tersebut', 'tlg', 'dunk', 'bagian', 'it', 'jangan', 'mau', 'klu', 'di', 'suruh', 'bagian', 'marketing', 'buatin', 'program', 'yang', 'absurd', 'begini']
# After:  ['i', 'love', 'gojek', 'so', 'much', 'klu', 'voucher', 'berlaku', 'voucher', 'go', 'ride', 'nya', 'lumayan', 'voucher', 'voucher', 'go', 'car', 'voucher', 'masak', 'wira', 'wiri', 'kecuali', 'klu', 'asrama', 'anak', 'pakaikan', 'voucher', 'tlg', 'dunk', 'it', 'klu', 'suruh', 'marketing', 'buatin', 'program', 'absurd']
#
# === STOPWORD REMOVAL ===
# Before: ['gojek', 'melakukan', 'blunder', 'dengan', 'cara', 'customer', 'kalau', 'mau', 'pesan', 'go', 'ride', 'prioritas', 'baru', 'dapat', 'driver', 'yang', 'dekat', 'kalau', 'tidak', 'prioritas', 'dapatnya', 'driver', 'jauh', 'tapi', 'kalau', 'mau', 'prioritas', 'kena', 'biaya', 'tambahan', 'lagi', 'akhirnya', 'customer', 'pada', 'pindah', 'ke', 'aplikasi', 'lain', 'yang', 'kocak', 'lagi', 'driver', 'di', 'suspen', 'gara', 'gara', 'nglewatin', 'order', 'padahal', 'disini', 'orang', 'kantor', 'gojek', 'yang', 'salah', 'kenapa', 'penjemputan', 'jauh', 'harusnya', 'yang', 'buat', 'kebijakan', 'ini', 'juga', 'di', 'suspen', 'karena', 'membuat', 'castamer', 'susah', 'dapat', 'driver']
# After:  ['gojek', 'blunder', 'customer', 'pesan', 'go', 'ride', 'prioritas', 'driver', 'prioritas', 'dapatnya', 'driver', 'prioritas', 'kena', 'biaya', 'tambahan', 'customer', 'pindah', 'aplikasi', 'kocak', 'driver', 'suspen', 'gara', 'gara', 'nglewatin', 'order', 'orang', 'kantor', 'gojek', 'salah', 'penjemputan', 'kebijakan', 'suspen', 'castamer', 'susah', 'driver']
#
# === STOPWORD REMOVAL ===
# Before: ['layanan', 'buruk', 'sekali', 'terutama', 'kalau', 'pas', 'hujan', 'tidak', 'ada', 'driver', 'car', 'yang', 'mau', 'ambil', 'karena', 'entah', 'bagaimana', 'servernya', 'gojek', 'melempar', 'pesanan', 'pas', 'hujan', 'itu', 'jauh', 'sehingga', 'rata', 'driver', 'minta', 'di', 'batal', 'padahal', 'pas', 'banget', 'baru', 'dapat', 'begitu', 'terus', 'kadang', 'yang', 'goride', 'juga', 'sama', 'benar', 'buruk', 'sekali', 'layanan', 'gojek', 'sekarang']
# After:  ['layanan', 'buruk', 'pas', 'hujan', 'driver', 'car', 'ambil', 'servernya', 'gojek', 'melempar', 'pesanan', 'pas', 'hujan', 'driver', 'batal', 'pas', 'banget', 'kadang', 'goride', 'buruk', 'layanan', 'gojek']
#
# === STOPWORD REMOVAL ===
# Before: ['sangat', 'membantu', 'di', 'saat', 'membutuhkan']
# After:  ['membantu', 'membutuhkan']
#
# Hasil setelah stopword removal:
#                                       after_tokenize  \
# 0  [matikan, fitur, order, ganda, pemesanan, gori...
# 1  [tolong, iya, pleease, buat, customer, yang, p...
# 2  [saya, harap, di, update, kedepanya, saat, pes...
#
#                                      after_stopwords
# 0  [matikan, fitur, order, ganda, pemesanan, gori...
# 1  [tolong, iya, pleease, customer, pesan, gibrid...
# 2  [harap, update, kedepanya, pesan, go, food, mu...

# %%
# Langkah 6: Stemming
print("\n=== Langkah 6: Stemming ===")
def stem_tokens(tokens):
    """Stemming token"""
    if isinstance(tokens, str):  # Handle case if input is string
        tokens = tokens.split()
    before = tokens.copy()
    after = [stemmer.stem(word) for word in tokens]
    print_step("Stemming", before, after)
    return after

df['after_stem'] = df['after_stopwords'].apply(stem_tokens)
print("\nHasil setelah stemming:")
df[['after_stopwords', 'after_stem']].head(3)
# Out:
# === Langkah 6: Stemming ===
#
# === STEMMING ===
# Before: ['matikan', 'fitur', 'order', 'ganda', 'pemesanan', 'goride', 'order', 'goride', 'order', 'goride', 'dibatalkan', 'pesan']
# After:  ['mati', 'fitur', 'order', 'ganda', 'mesan', 'goride', 'order', 'goride', 'order', 'goride', 'batal', 'pesan']
#
# === STEMMING ===
# Before: ['tolong', 'iya', 'pleease', 'customer', 'pesan', 'gibride', 'tolong', 'jempol', 'dikit', 'cansel', 'dikit', 'cansel', 'beratus', 'ratus', 'kali', 'cansel', 'berpengaruh', 'ngefek', 'kitw', 'driver', 'kena', 'ampas', 'aplikator', 'bayar', 'tarif', 'nya', 'super', 'mahal', 'dibpitong', 'gede', 'super', 'gede', 'potongannya', 'tolong', 'kasihani', 'iya', 'driver', 'ojol']
# After:  ['tolong', 'iya', 'pleease', 'customer', 'pesan', 'gibride', 'tolong', 'jempol', 'dikit', 'cansel', 'dikit', 'cansel', 'atus', 'ratus', 'kali', 'cansel', 'pengaruh', 'ngefek', 'kitw', 'driver', 'kena', 'ampas', 'aplikator', 'bayar', 'tarif', 'nya', 'super', 'mahal', 'dibpitong', 'gede', 'super', 'gede', 'potong', 'tolong', 'kasihan', 'iya', 'driver', 'ojol']
#
# === STEMMING ===
# Before: ['harap', 'update', 'kedepanya', 'pesan', 'go', 'food', 'muncul', 'notifikasi', 'go', 'ride', 'muncul']
# After:  ['harap', 'update', 'depa', 'pesan', 'go', 'food', 'muncul', 'notifikasi', 'go', 'ride', 'muncul']
#
# === STEMMING ===
# Before: ['buatku', 'tinggal', 'kota', 'aplikasi', 'cpat', 'dpat', 'driver', 'pesan', 'goride', 'pesan', 'gofood', 'menunggu', 'pakai', 'kendaraan', 'driver', 'nya', 'oke', 'drivernya', 'sopan', 'sukses', 'gojek']
# After:  ['buat', 'tinggal', 'kota', 'aplikasi', 'cpat', 'dpat', 'driver', 'pesan', 'goride', 'pesan', 'gofood', 'tunggu', 'pakai', 'kendara', 'driver', 'nya', 'oke', 'drivernya', 'sopan', 'sukses', 'gojek']
#
# === STEMMING ===
# Before: ['layanan', 'goride', 'membantu', 'aktifitas', 'sehari', 'motor', 'perbaikan', 'bengkel', 'masukan', 'nya', 'mgkin', 'Cuma', 'cuaca', 'hujan', 'situasi', 'urgent', 'butuh', 'transport', 'driver', 'nya']
# After:  ['layan', 'goride', 'bantu', 'aktifitas', 'hari', 'motor', 'baik', 'bengkel', 'masuk', 'nya', 'mgkin', 'cuma', 'cuaca', 'hujan', 'situasi', 'urgent', 'butuh', 'transport', 'driver', 'nya']
#
# === STEMMING ===
# Before: ['gojek', 'iya', 'pakai', 'akun', 'suka', 'voucher', 'voucher', 'goride', 'giliran', 'beralih', 'gocar', 'voucher', 'pas', 'giliran', 'buka', 'voucher', 'voucher', 'bug', 'tolong', 'perbaiki', 'lahi']
# After:  ['gojek', 'iya', 'pakai', 'akun', 'suka', 'voucher', 'voucher', 'goride', 'gilir', 'alih', 'gocar', 'voucher', 'pas', 'gilir', 'buka', 'voucher', 'voucher', 'bug', 'tolong', 'baik', 'lah']
#
# === STEMMING ===
# Before: ['terima', 'rider', 'seleksi', 'gojek', 'rider', 'nya', 'emosian', 'melulu']
# After:  ['terima', 'rider', 'seleksi', 'gojek', 'rider', 'nya', 'emosi', 'melulu']
#
# === STEMMING ===
# Before: ['gojek', 'mahal', 'pakai', 'voucher', 'perjalanan', 'harga', 'pakai', 'voucher', 'go', 'ride', 'pot', 'rb', 'alhasil', 'beralih', 'ojol', 'sebelah']
# After:  ['gojek', 'mahal', 'pakai', 'voucher', 'jalan', 'harga', 'pakai', 'voucher', 'go', 'ride', 'pot', 'rb', 'alhasil', 'alih', 'ojol', 'belah']
#
# === STEMMING ===
# Before: ['cepat', 'murah']
# After:  ['cepat', 'murah']
#
# === STEMMING ===
# Before: ['keren', 'murah']
# After:  ['keren', 'murah']
#
# === STEMMING ===
# Before: ['drivernya', 'alesan', 'bilang', 'bawa', 'helm', 'ambil', 'pesanan', 'goride', 'pas', 'batal', 'dianya', 'dianya', 'ambil', 'helm', 'knapa', 'batal', 'takut', 'poinnya', 'turun', 'ambil', 'pesanan', 'ngajak', 'ribut', 'ajar']
# After:  ['drivernya', 'alesan', 'bilang', 'bawa', 'helm', 'ambil', 'pesan', 'goride', 'pas', 'batal', 'dia', 'dia', 'ambil', 'helm', 'knapa', 'batal', 'takut', 'poin', 'turun', 'ambil', 'pesan', 'ngajak', 'ribut', 'ajar']
#
# === STEMMING ===
# Before: ['rumah', 'beda', 'hp', 'ee', 'pesan', 'go', 'ride', 'dng', 'ttik', 'tujuan', 'nominal', 'beda', 'sya', 'kena', 'pakai', 'hp', 'ponakan', 'tunai', 'gofood', 'klu', 'py', 'mehongg', 'rumah', 'lho', 'setia', 'memakai', 'gojeck', 'order', 'makanan']
# After:  ['rumah', 'beda', 'hp', 'ee', 'pesan', 'go', 'ride', 'dng', 'ttik', 'tuju', 'nominal', 'beda', 'sya', 'kena', 'pakai', 'hp', 'ponakan', 'tunai', 'gofood', 'klu', 'py', 'mehongg', 'rumah', 'lho', 'setia', 'pakai', 'gojeck', 'order', 'makan']
#
# === STEMMING ===
# Before: ['drivernya', 'mengemudikan', 'kendaraan', 'aman', 'nyaman', 'terimakasih']
# After:  ['drivernya', 'kemudi', 'kendara', 'aman', 'nyaman', 'terimakasih']
#
# === STEMMING ===
# Before: ['ok']
# After:  ['ok']
#
# === STEMMING ===
# Before: ['senang']
# After:  ['senang']
#
# === STEMMING ===
# Before: ['aplikasinya', 'sih', 'bagus', 'januari', 'pesan', 'gocar', 'kali', 'goride', 'kali', 'nyantol', 'server', 'sibuk', 'cuaca', 'gerimis', 'pusat', 'kota', 'purwokerto', 'susah', 'butuhkan']
# After:  ['aplikasi', 'sih', 'bagus', 'januari', 'pesan', 'gocar', 'kali', 'goride', 'kali', 'nyantol', 'server', 'sibuk', 'cuaca', 'gerimis', 'pusat', 'kota', 'purwokerto', 'susah', 'butuh']
#
# === STEMMING ===
# Before: ['gila', 'order', 'goride', 'menunggu', 'l', 'banget', 'dspet', 'driver', 'driver', 'kumpul-kumpul', 'malam', 'kerja', 'capek', 'terima', 'kasih', 'gojek', 'langganan', 'aagi']
# After:  ['gila', 'order', 'goride', 'tunggu', 'l', 'banget', 'dspet', 'driver', 'driver', 'kumpul', 'malam', 'kerja', 'capek', 'terima', 'kasih', 'gojek', 'langgan', 'aagi']
#
# === STEMMING ===
# Before: []
# After:  []
#
# === STEMMING ===
# Before: ['driver', 'pesan', 'goride', 'buru', 'kerja', 'dipecat', 'pesan', 'gosend', 'menit', 'jaraknya', 'kilo', 'kasihan', 'drivernya']
# After:  ['driver', 'pesan', 'goride', 'buru', 'kerja', 'pecat', 'pesan', 'gosend', 'menit', 'jarak', 'kilo', 'kasihan', 'drivernya']
#
# === STEMMING ===
# Before: ['the', 'best', 'apps', 'for', 'ride']
# After:  ['the', 'best', 'apps', 'for', 'ride']
#
# === STEMMING ===
# Before: ['alhamdulillah', 'pas', 'pakai', 'goride', 'supirnya', 'bagus', 'sopan']
# After:  ['alhamdulillah', 'pas', 'pakai', 'goride', 'supirnya', 'bagus', 'sopan']
#
# === STEMMING ===
# Before: ['mantap']
# After:  ['mantap']
#
# === STEMMING ===
# Before: ['isi', 'gopay', 'pesan', 'goride', 'tlg', 'bantuannya', 'terima', 'kasih']
# After:  ['isi', 'gopay', 'pesan', 'goride', 'tlg', 'bantu', 'terima', 'kasih']
#
# === STEMMING ===
# Before: ['membantu', 'beraktifitas', 'semoga', 'kasih', 'diskon', 'goridenya']
# After:  ['bantu', 'beraktifitas', 'moga', 'kasih', 'diskon', 'goridenya']
#
# === STEMMING ===
# Before: ['gojek', 'menunggu', 'goride', 'jamm', 'kacau', 'ah', 'ditampung', 'keluhannya', 'ehh', 'perbaikan', 'parah', 'menunggu', 'menit', 'didepan', 'drivernya', 'diambil', 'tolong', 'keperluan']
# After:  ['gojek', 'tunggu', 'goride', 'jamm', 'kacau', 'ah', 'tampung', 'keluh', 'ehh', 'baik', 'parah', 'tunggu', 'menit', 'depan', 'drivernya', 'ambil', 'tolong', 'perlu']
#
# === STEMMING ===
# Before: ['ramah', 'terpercaya']
# After:  ['ramah', 'percaya']
#
# === STEMMING ===
# Before: ['Cuma', 'kadang', 'go', 'ride', 'banget']
# After:  ['cuma', 'kadang', 'go', 'ride', 'banget']
#
# === STEMMING ===
# Before: ['bagus']
# After:  ['bagus']
#
# === STEMMING ===
# Before: ['up', 'gopay', 'plus', 'pikir', 'voucher', 'goride', 'biar', 'murah', 'taunya', 'dipakai']
# After:  ['up', 'gopay', 'plus', 'pikir', 'voucher', 'goride', 'biar', 'murah', 'tau', 'pakai']
#
# === STEMMING ===
# Before: ['mantaf']
# After:  ['mantaf']
#
# === STEMMING ===
# Before: ['kayaknya', 'pakai', 'gocar', 'goride', 'layanan', 'hemat', 'deh', 'x', 'dipake', 'alasan', 'driver']
# After:  ['kayak', 'pakai', 'gocar', 'goride', 'layan', 'hemat', 'deh', 'x', 'dipake', 'alas', 'driver']
#
# === STEMMING ===
# Before: ['terima', 'kasih', 'gojek', 'fitur', 'pohon', 'menanam', 'seribu', 'rupiah', 'fitur', 'berguna', 'berbagi', 'oksigen']
# After:  ['terima', 'kasih', 'gojek', 'fitur', 'pohon', 'tanam', 'ribu', 'rupiah', 'fitur', 'guna', 'bagi', 'oksigen']
#
# === STEMMING ===
# Before: ['bagus']
# After:  ['bagus']
#
# === STEMMING ===
# Before: ['membantu']
# After:  ['bantu']
#
# === STEMMING ===
# Before: ['drivernya', 'ramah']
# After:  ['drivernya', 'ramah']
#
# === STEMMING ===
# Before: ['bagus', 'layanan']
# After:  ['bagus', 'layan']
#
# === STEMMING ===
# Before: ['gojek', 'puas', 'go', 'ride', 'go', 'car', 'nya', 'the', 'best']
# After:  ['gojek', 'puas', 'go', 'ride', 'go', 'car', 'nya', 'the', 'best']
#
# === STEMMING ===
# Before: ['pelanggan', 'setia', 'goride', 'gocar', 'gofood']
# After:  ['langgan', 'setia', 'goride', 'gocar', 'gofood']
#
# === STEMMING ===
# Before: ['bagus', 'pesan', 'goride', 'driver', 'nya', 'salah', 'ambil', 'penumpang', 'chat', 'driver', 'respon']
# After:  ['bagus', 'pesan', 'goride', 'driver', 'nya', 'salah', 'ambil', 'tumpang', 'chat', 'driver', 'respon']
#
# === STEMMING ===
# Before: ['maaf', 'pasar', 'polis', 'goride', 'motong', 'akun', 'customer', 'kaya', 'pasar', 'polis', 'akses', 'motong', 'saldo', 'akun', 'customer', 'kali', 'potongan', 'pasar', 'polis', 'goride', 'akun', 'customer']
# After:  ['maaf', 'pasar', 'polis', 'goride', 'motong', 'akun', 'customer', 'kaya', 'pasar', 'polis', 'akses', 'motong', 'saldo', 'akun', 'customer', 'kali', 'potong', 'pasar', 'polis', 'goride', 'akun', 'customer']
#
# === STEMMING ===
# Before: ['aplikasi', 'tolol', 'pesan', 'goride', 'muncul', 'gocar']
# After:  ['aplikasi', 'tolol', 'pesan', 'goride', 'muncul', 'gocar']
#
# === STEMMING ===
# Before: ['menunggu', 'sejam', 'goride', 'tulisannya', 'sibuk', 'beneran', 'sibuk', 'gojek', 'ny', 'aplikasi', 'nya', 'error']
# After:  ['tunggu', 'jam', 'goride', 'tulis', 'sibuk', 'beneran', 'sibuk', 'gojek', 'ny', 'aplikasi', 'nya', 'error']
#
# === STEMMING ===
# Before: ['pakai', 'gofood', 'jarang', 'goride', 'gocar', 'trauma', 'mengendarai', 'kendaraan', 'celaka', 'masukan', 'promo', 'gofood', 'voucher', 'gratis', 'ongkos', 'kirim', 'potongan', 'ongkos', 'kirim', 'driver', 'oren']
# After:  ['pakai', 'gofood', 'jarang', 'goride', 'gocar', 'trauma', 'kendara', 'kendara', 'celaka', 'masuk', 'promo', 'gofood', 'voucher', 'gratis', 'ongkos', 'kirim', 'potong', 'ongkos', 'kirim', 'driver', 'oren']
#
# === STEMMING ===
# Before: ['top', 'markotop']
# After:  ['top', 'markotop']
#
# === STEMMING ===
# Before: ['penjemputan', 'promo', 'hemat']
# After:  ['jemput', 'promo', 'hemat']
#
# === STEMMING ===
# Before: ['driver', 'goride', 'nya', 'kota', 'depok', 'berangkat', 'kerja', 'terlambat', 'kaya', 'aplikasi', 'sebelah', 'drivernya', 'cepat', 'sekalinya', 'driver', 'jemputnya']
# After:  ['driver', 'goride', 'nya', 'kota', 'depok', 'berangkat', 'kerja', 'lambat', 'kaya', 'aplikasi', 'belah', 'drivernya', 'cepat', 'sekali', 'driver', 'jemput']
#
# === STEMMING ===
# Before: ['aplikasi', 'pesan', 'goride', 'gambar', 'driver', 'terdekat', 'eh', 'nyantol', 'nya', 'jepang', 'saking', 'jauhnya', 'ongkos', 'kirim', 'nya', 'mahal', 'banget', 'maaf', 'kali', 'pindah', 'apk', 'sebelah', 'ribet']
# After:  ['aplikasi', 'pesan', 'goride', 'gambar', 'driver', 'dekat', 'eh', 'nyantol', 'nya', 'jepang', 'saking', 'jauh', 'ongkos', 'kirim', 'nya', 'mahal', 'banget', 'maaf', 'kali', 'pindah', 'apk', 'belah', 'ribet']
#
# === STEMMING ===
# Before: ['mengecewakan', 'order', 'gocar', 'pas', 'hujan', 'driver', 'susah', 'menerima', 'pesanan', 'pakai', 'promo', 'goride', 'alasan', 'orderan', 'ramai']
# After:  ['kecewa', 'order', 'gocar', 'pas', 'hujan', 'driver', 'susah', 'terima', 'pesan', 'pakai', 'promo', 'goride', 'alas', 'order', 'ramai']
#
# === STEMMING ===
# Before: ['aplikasi', 'bodoh', 'ambil', 'goride', 'driver', 'bodoh']
# After:  ['aplikasi', 'bodoh', 'ambil', 'goride', 'driver', 'bodoh']
#
# === STEMMING ===
# Before: ['gojek', 'buruk', 'mencari', 'driver', 'ny', 'padahl', 'membatalkan', 'pesanan', 'menunggu', 'menit', 'order', 'hasilnya', 'bug', 'pesan', 'makanan', 'goride']
# After:  ['gojek', 'buruk', 'cari', 'driver', 'ny', 'padahl', 'batal', 'pesan', 'tunggu', 'menit', 'order', 'hasil', 'bug', 'pesan', 'makan', 'goride']
#
# === STEMMING ===
# Before: ['mantap', 'pokoknya', 'mah']
# After:  ['mantap', 'pokok', 'mah']
#
# === STEMMING ===
# Before: ['goride', 'gocar', 'lumayan', 'voucernya', 'gofood', 'nya', 'jarang', 'pakai', 'aplikasi', 'murah']
# After:  ['goride', 'gocar', 'lumayan', 'voucernya', 'gofood', 'nya', 'jarang', 'pakai', 'aplikasi', 'murah']
#
# === STEMMING ===
# Before: ['mudah']
# After:  ['mudah']
#
# === STEMMING ===
# Before: ['nice']
# After:  ['nice']
#
# === STEMMING ===
# Before: ['aplikasi', 'tolol', 'persen', 'goride', 'kasih', 'driver', 'sekeliling', 'ambilkan', 'korea', 'utara', 'perkiraan', 'menit', 'ditunggu', 'menit', 'update', 'lokasi', 'driver']
# After:  ['aplikasi', 'tolol', 'persen', 'goride', 'kasih', 'driver', 'keliling', 'ambil', 'korea', 'utara', 'kira', 'menit', 'tunggu', 'menit', 'update', 'lokasi', 'driver']
#
# === STEMMING ===
# Before: ['i', 'love', 'gojek', 'sm', 'berangkat', 'pulang', 'sekolah', 'always', 'make', 'gojek', 'gojek', 'fitur', 'goride', 'comfort', 'cocok', 'banget', 'suka', 'bawa', 'barang', 'kesekolah', 'suka', 'bawa', 'tas', 'gede', 'deh', 'kaki', 'nya', 'pnttnya', 'pegel', 'jaya', 'deh', 'yaa', 'gojek']
# After:  ['i', 'love', 'gojek', 'sm', 'berangkat', 'pulang', 'sekolah', 'always', 'make', 'gojek', 'gojek', 'fitur', 'goride', 'comfort', 'cocok', 'banget', 'suka', 'bawa', 'barang', 'seko', 'suka', 'bawa', 'tas', 'gede', 'deh', 'kaki', 'nya', 'pnttnya', 'gel', 'jaya', 'deh', 'yaa', 'gojek']
#
# === STEMMING ===
# Before: ['go', 'ride', 'berubah', 'go', 'car', 'mahal', 'ongkosnya']
# After:  ['go', 'ride', 'ubah', 'go', 'car', 'mahal', 'ongkos']
#
# === STEMMING ===
# Before: ['good']
# After:  ['good']
#
# === STEMMING ===
# Before: ['go', 'transit', 'digabung', 'go', 'ridetransit', 'edit', 'stasiun', 'tujuannya', 'berubah', 'sblum', 'update', 'diupdate', 'nyusahin', 'gausah', 'update', 'tujuannya', 'update', 'memudahkan', 'mempersulit']
# After:  ['go', 'transit', 'gabung', 'go', 'ridetransit', 'edit', 'stasiun', 'tuju', 'ubah', 'sblum', 'update', 'diupdate', 'nyusahin', 'gausah', 'update', 'tuju', 'update', 'mudah', 'sulit']
#
# === STEMMING ===
# Before: ['layanan', 'nya', 'aplikasi', 'sebelah', 'pilihannya']
# After:  ['layan', 'nya', 'aplikasi', 'belah', 'pilih']
#
# === STEMMING ===
# Before: ['mantap']
# After:  ['mantap']
#
# === STEMMING ===
# Before: ['pakai', 'aplikasi', 'bingung', 'pas', 'check', 'goride', 'harganya', 'rb', 'rb', 'eh', 'iseng', 'buka', 'grab', 'Cuma', 'bayar', 'rb']
# After:  ['pakai', 'aplikasi', 'bingung', 'pas', 'check', 'goride', 'harga', 'rb', 'rb', 'eh', 'iseng', 'buka', 'grab', 'cuma', 'bayar', 'rb']
#
# === STEMMING ===
# Before: ['susah', 'driver', 'x', 'pesan', 'tetep', 'pindah', 'menu', 'go', 'ride', 'go', 'car', 'cmn', 'hasilny', 'nihil', 'parah', 'sih']
# After:  ['susah', 'driver', 'x', 'pesan', 'tetep', 'pindah', 'menu', 'go', 'ride', 'go', 'car', 'cmn', 'hasilny', 'nihil', 'parah', 'sih']
#
# === STEMMING ===
# Before: ['suka', 'pakai', 'jasa', 'goride', 'gocar', 'seneng', 'denger', 'curhatan', 'cerita', 'keluh', 'kesah', 'cerita', 'sedih', 'cerita', 'bahagia', 'rangkum', 'motivasi']
# After:  ['suka', 'pakai', 'jasa', 'goride', 'gocar', 'neng', 'denger', 'curhatan', 'cerita', 'keluh', 'kesah', 'cerita', 'sedih', 'cerita', 'bahagia', 'rangkum', 'motivasi']
#
# === STEMMING ===
# Before: ['ok']
# After:  ['ok']
#
# === STEMMING ===
# Before: ['milih', 'go', 'transit', 'dialihkan', 'go', 'ride']
# After:  ['milih', 'go', 'transit', 'alih', 'go', 'ride']
#
# === STEMMING ===
# Before: ['i', 'got', 'safety', 'when', 'i', 'was', 'ride', 'gojek']
# After:  ['i', 'got', 'safety', 'when', 'i', 'was', 'ride', 'gojek']
#
# === STEMMING ===
# Before: ['goride', 'mudah']
# After:  ['goride', 'mudah']
#
# === STEMMING ===
# Before: ['masukkan', 'kode', 'promo', 'goride', 'sukses', 'vocer', 'promonya', 'gada', 'cba', 'update', 'masin', 'sma', 'hpus', 'download', 'bbrapa', 'kli', 'iya', 'eror', 'cba', 'teman', 'mah', 'gada']
# After:  ['masuk', 'kode', 'promo', 'goride', 'sukses', 'vocer', 'promonya', 'gada', 'cba', 'update', 'masin', 'sma', 'hpus', 'download', 'bbrapa', 'kli', 'iya', 'eror', 'cba', 'teman', 'mah', 'gada']
#
# === STEMMING ===
# Before: ['pesan', 'goride', 'posisi', 'driver', 'mengambil', 'kasihnya', 'jaraknya', 'sbagian', 'batal', 'drivernya']
# After:  ['pesan', 'goride', 'posisi', 'driver', 'ambil', 'kasih', 'jarak', 'sbagian', 'batal', 'drivernya']
#
# === STEMMING ===
# Before: ['mohon', 'gojek', 'pembelaan', 'pulang', 'goride', 'perlakuan', 'menyenangkan', 'membantalkan', 'pesanan', 'titik', 'jemput', 'sesuai', 'didatangi', 'driver', 'driver', 'marah', 'orang', 'disitu', 'malu', 'mohon', 'bantuannya', 'menegur', 'driver']
# After:  ['mohon', 'gojek', 'bela', 'pulang', 'goride', 'laku', 'senang', 'bantal', 'pesan', 'titik', 'jemput', 'sesuai', 'datang', 'driver', 'driver', 'marah', 'orang', 'situ', 'malu', 'mohon', 'bantu', 'tegur', 'driver']
#
# === STEMMING ===
# Before: ['layanan', 'memudahkan', 'masyarakat']
# After:  ['layan', 'mudah', 'masyarakat']
#
# === STEMMING ===
# Before: ['tolong', 'goride', 'pisah', 'hemat', 'comfort', 'perhatian', 'gojeknya', 'pengalaman', 'pesan', 'comfort', 'motor', 'beda', 'plat', 'nomor', 'beda', 'jenisnya', 'masuk', 'kategori', 'hemat', 'tolong', 'diperhatikan', 'khusus', 'driver', 'goride', 'nya', 'keselamatan', 'diatas']
# After:  ['tolong', 'goride', 'pisah', 'hemat', 'comfort', 'perhati', 'gojek', 'alam', 'pesan', 'comfort', 'motor', 'beda', 'plat', 'nomor', 'beda', 'jenis', 'masuk', 'kategori', 'hemat', 'tolong', 'perhati', 'khusus', 'driver', 'goride', 'nya', 'selamat', 'atas']
#
# === STEMMING ===
# Before: ['ok']
# After:  ['ok']
#
# === STEMMING ===
# Before: ['membantu', 'goride', 'gocar', 'gofood']
# After:  ['bantu', 'goride', 'gocar', 'gofood']
#
# === STEMMING ===
# Before: ['gofood', 'nya', 'mengecewakan', 'menunggu', 'jam', 'dibatalin', 'alasan', 'gada', 'driver', 'niat', 'bisnis', 'tutup', 'aplikasinya', 'pesan', 'goride', 'lain-lain', 'drivernya', 'gada', 'driver', 'disekitar', 'lokasi', 'banget', 'aplikasi']
# After:  ['gofood', 'nya', 'kecewa', 'tunggu', 'jam', 'dibatalin', 'alas', 'gada', 'driver', 'niat', 'bisnis', 'tutup', 'aplikasi', 'pesan', 'goride', 'lain', 'drivernya', 'gada', 'driver', 'sekitar', 'lokasi', 'banget', 'aplikasi']
#
# === STEMMING ===
# Before: ['voucher', 'goride', 'jompor', 'pakai', 'goride', 'pulang', 'pergi', 'rb', 'gaperna', 'voucher', 'goride']
# After:  ['voucher', 'goride', 'jompor', 'pakai', 'goride', 'pulang', 'pergi', 'rb', 'gaperna', 'voucher', 'goride']
#
# === STEMMING ===
# Before: ['verygood']
# After:  ['verygood']
#
# === STEMMING ===
# Before: ['transaksi', 'gojek', 'toped', 'blibli', 'alfagift', 'gopaylaternya', 'ditulis', 'diblokir', 'limit', 'aman', 'tagihan', 'japo', 'dipakai', 'goride', 'gocar']
# After:  ['transaksi', 'gojek', 'toped', 'blibli', 'alfagift', 'gopaylaternya', 'tulis', 'blokir', 'limit', 'aman', 'tagih', 'japo', 'pakai', 'goride', 'gocar']
#
# === STEMMING ===
# Before: ['order', 'goride', 'menunggu', 'drivernya', 'susah', 'batalin', 'aplikasi', 'tetangga']
# After:  ['order', 'goride', 'tunggu', 'drivernya', 'susah', 'batalin', 'aplikasi', 'tetangga']
#
# === STEMMING ===
# Before: ['bayar', 'tagihan', 'gopay', 'later', 'aplikasi', 'gangguan', 'order', 'goride', 'gocar', 'sring', 'driver', 'tulisannya', 'driver', 'nya', 'bnyak', 'trlihat', 'diaplikasi', 'gojek', 'mkin', 'buruk', 'aplikasinya', 'kyknya', 'diperbaiki', 'cepat']
# After:  ['bayar', 'tagih', 'gopay', 'later', 'aplikasi', 'ganggu', 'order', 'goride', 'gocar', 'sring', 'driver', 'tulis', 'driver', 'nya', 'bnyak', 'trlihat', 'aplikasi', 'gojek', 'mkin', 'buruk', 'aplikasi', 'kyknya', 'baik', 'cepat']
#
# === STEMMING ===
# Before: ['pakai', 'gojek', 'mesen', 'makan', 'goride', 'tetep', 'detik', 'buka', 'gopaylater', 'gopinjam', 'nya', 'kalah', 'daftar', 'order', 'langsung', 'limit', 'gopaylater', 'anehh', 'banget', 'lumayan', 'kecewa', 'si', 'aplikasi', 'adil']
# After:  ['pakai', 'gojek', 'mesen', 'makan', 'goride', 'tetep', 'detik', 'buka', 'gopaylater', 'gopinjam', 'nya', 'kalah', 'daftar', 'order', 'langsung', 'limit', 'gopaylater', 'anehh', 'banget', 'lumayan', 'kecewa', 'si', 'aplikasi', 'adil']
#
# === STEMMING ===
# Before: ['pelanggan', 'goride', 'gosend', 'kecewa', 'go', 'car', 'jogja', 'niat', 'iya', 'milih', 'acak', 'aplikasi', 'dikit', 'dicancel', 'cm', 'jemputnya', 'jarak', 'dianter', 'semoga', 'gojek', 'menyortir', 'driver', 'gocar', 'iseng', 'males', 'an', 'tertawa', 'kacau']
# After:  ['langgan', 'goride', 'gosend', 'kecewa', 'go', 'car', 'jogja', 'niat', 'iya', 'milih', 'acak', 'aplikasi', 'dikit', 'dicancel', 'cm', 'jemput', 'jarak', 'anter', 'moga', 'gojek', 'sortir', 'driver', 'gocar', 'iseng', 'males', 'an', 'tertawa', 'kacau']
#
# === STEMMING ===
# Before: ['tolong', 'pesan', 'goride', 'gocar', 'cari', 'driver', 'lokasinya', 'titik', 'penjemputan', 'banget', 'driver', 'jaraknya', 'driver', 'mangkal', 'lokasi', 'penjemputan', 'bangett', 'tolong', 'perbaiki', 'buang', 'menunggu', 'driver', 'datengnya', 'jaraknya']
# After:  ['tolong', 'pesan', 'goride', 'gocar', 'cari', 'driver', 'lokasi', 'titik', 'jemput', 'banget', 'driver', 'jarak', 'driver', 'mangkal', 'lokasi', 'jemput', 'bangett', 'tolong', 'baik', 'buang', 'tunggu', 'driver', 'datengnya', 'jarak']
#
# === STEMMING ===
# Before: ['car', 'ride', 'food', 'keren']
# After:  ['car', 'ride', 'food', 'keren']
#
# === STEMMING ===
# Before: ['suka', 'gojek', 'kadang', 'pakai', 'go', 'ride', 'hemat', 'diterima', 'driver', 'meringankan', 'pengeluaran', 'tanggal', 'tua', 'pagi', 'susahnya', 'ampun', 'sekalinya', 'jarak', 'menit', 'bilang', 'kejauhan', 'males', 'lokasi', 'tujuan', 'situ', 'jemput', 'bulak']
# After:  ['suka', 'gojek', 'kadang', 'pakai', 'go', 'ride', 'hemat', 'terima', 'driver', 'ringan', 'keluar', 'tanggal', 'tua', 'pagi', 'susah', 'ampun', 'sekali', 'jarak', 'menit', 'bilang', 'jauh', 'males', 'lokasi', 'tuju', 'situ', 'jemput', 'bulak']
#
# === STEMMING ===
# Before: ['kecewa', 'driver', 'goride', 'hujan', 'mengambil', 'orderan', 'alasan', 'bawa', 'jas', 'hujan', 'chat', 'bawa', 'jas', 'hujan', 'ngojek', 'sedia', 'jas', 'hujan']
# After:  ['kecewa', 'driver', 'goride', 'hujan', 'ambil', 'order', 'alas', 'bawa', 'jas', 'hujan', 'chat', 'bawa', 'jas', 'hujan', 'ngojek', 'sedia', 'jas', 'hujan']
#
# === STEMMING ===
# Before: ['mahal', 'goride', 'gofood']
# After:  ['mahal', 'goride', 'gofood']
#
# === STEMMING ===
# Before: ['gampang', 'cari', 'alamat', 'enak']
# After:  ['gampang', 'cari', 'alamat', 'enak']
#
# === STEMMING ===
# Before: ['fitur', 'go', 'pay', 'later', 'go', 'pay', 'pinjam', 'non', 'aktifkan', 'kaya', 'aplikasi', 'pinjol', 'rawan', 'penyalahgunaan', 'ridernya', 'seneng', 'banget', 'batalin', 'menunggu', 'kaya', 'sebelah']
# After:  ['fitur', 'go', 'pay', 'later', 'go', 'pay', 'pinjam', 'non', 'aktif', 'kaya', 'aplikasi', 'pinjol', 'rawan', 'penyalahgunaan', 'ridernya', 'neng', 'banget', 'batalin', 'tunggu', 'kaya', 'belah']
#
# === STEMMING ===
# Before: ['mengunakan', 'gojek', 'benahi', 'driver', 'berbeda', 'aplikasi', 'orang', 'driver', 'memakai', 'akun', 'driver', 'gojek', 'joki', 'mengantarkan', 'pesanan', 'takut', 'makanan', 'apin', 'orang', 'driver', 'gojek', 'joki', 'motor', 'pakai', 'joki', 'plat', 'nya', 'berbeda', 'aplikasi', 'pesan', 'goride', 'sih', 'driver', 'jemput', 'orangnya', 'berbeda', 'aplikasi', 'plat', 'nomor', 'motor', 'nya', 'berbeda', 'was', 'was', 'takut', 'tolong', 'adakan', 'vermuk', 'berwaktu', 'grab']
# After:  ['mengunakan', 'gojek', 'benah', 'driver', 'beda', 'aplikasi', 'orang', 'driver', 'pakai', 'akun', 'driver', 'gojek', 'joki', 'antar', 'pesan', 'takut', 'makan', 'apin', 'orang', 'driver', 'gojek', 'joki', 'motor', 'pakai', 'joki', 'plat', 'nya', 'beda', 'aplikasi', 'pesan', 'goride', 'sih', 'driver', 'jemput', 'orang', 'beda', 'aplikasi', 'plat', 'nomor', 'motor', 'nya', 'beda', 'was', 'was', 'takut', 'tolong', 'adakan', 'vermuk', 'waktu', 'grab']
#
# === STEMMING ===
# Before: ['order', 'goride', 'kendala', 'keterangan', 'internetnya', 'mati', 'padhal', 'kuota', 'melimpahh', 'coba', 'cek', 'gojek', 'adek', 'mesen', 'punyaku', 'biasane', 'pakai', 'tolong', 'diperbaiki']
# After:  ['order', 'goride', 'kendala', 'terang', 'internetnya', 'mati', 'padhal', 'kuota', 'melimpahh', 'coba', 'cek', 'gojek', 'adek', 'mesen', 'punya', 'biasane', 'pakai', 'tolong', 'baik']
#
# === STEMMING ===
# Before: ['woi', 'harga', 'goride', 'nya', 'nambah', 'nya', 'gara', 'gara', 'cuaca', 'panas', 'hujan', 'hujan', 'ok', 'ngotak', 'kali', 'njir', 'oh', 'kualitas', 'nya', 'bikin', 'nambah', 'perasaan', 'deh', 'hemat', 'comfort', 'hoki', 'an', 'lihat', 'maxim', 'iya', 'murah', 'nomor', 'diskon', 'menarik', 'segitu']
# After:  ['woi', 'harga', 'goride', 'nya', 'nambah', 'nya', 'gara', 'gara', 'cuaca', 'panas', 'hujan', 'hujan', 'ok', 'ngotak', 'kali', 'njir', 'oh', 'kualitas', 'nya', 'bikin', 'nambah', 'asa', 'deh', 'hemat', 'comfort', 'hoki', 'an', 'lihat', 'maxim', 'iya', 'murah', 'nomor', 'diskon', 'tarik', 'segitu']
#
# === STEMMING ===
# Before: ['thank', 'you']
# After:  ['thank', 'you']
#
# === STEMMING ===
# Before: ['ok', 'cepat']
# After:  ['ok', 'cepat']
#
# === STEMMING ===
# Before: ['dc', 'nya', 'suka', 'ngancam']
# After:  ['dc', 'nya', 'suka', 'ngancam']
#
# === STEMMING ===
# Before: ['jasa', 'biaya', 'gojek', 'nya', 'mahal', 'pesan', 'go', 'food', 'go', 'ride', 'lain-lain', 'kena', 'double', 'order', 'custumer', 'rugikan', 'rugi', 'bayar', 'mahal', 'rugi', 'menunggu', 'gojek']
# After:  ['jasa', 'biaya', 'gojek', 'nya', 'mahal', 'pesan', 'go', 'food', 'go', 'ride', 'lain', 'kena', 'double', 'order', 'custumer', 'rugi', 'rugi', 'bayar', 'mahal', 'rugi', 'tunggu', 'gojek']
#
# === STEMMING ===
# Before: ['terimakasih']
# After:  ['terimakasih']
#
# === STEMMING ===
# Before: ['banyakin', 'promonya', 'goride', 'and', 'gofood']
# After:  ['banyakin', 'promonya', 'goride', 'and', 'gofood']
#
# === STEMMING ===
# Before: ['akun', 'blokir', 'tolong', 'solusinya', 'ngechat', 'cs', 'responnya', 'laporan', 'ditutup', 'solusi', 'keterangannya', 'blokir', 'voucher', 'goride', 'gofood', 'tolong', 'biar', 'normal']
# After:  ['akun', 'blokir', 'tolong', 'solusi', 'ngechat', 'cs', 'responnya', 'lapor', 'tutup', 'solusi', 'terang', 'blokir', 'voucher', 'goride', 'gofood', 'tolong', 'biar', 'normal']
#
# === STEMMING ===
# Before: ['bagus', 'tolong', 'promo', 'gocar', 'goride', 'comfort', 'menikmati', 'perjalanan', 'hemat', 'nyaman', 'terima', 'kasih']
# After:  ['bagus', 'tolong', 'promo', 'gocar', 'goride', 'comfort', 'nikmat', 'jalan', 'hemat', 'nyaman', 'terima', 'kasih']
#
# === STEMMING ===
# Before: ['gilaa', 'saldo', 'hilang', 'gtu', 'call', 'center', 'ngebantu', 'banget', 'order', 'goride', 'gadapet', 'kali', 'saldonya', 'ketarik', 'nya', 'in', 'gojek']
# After:  ['gilaa', 'saldo', 'hilang', 'gtu', 'call', 'center', 'ngebantu', 'banget', 'order', 'goride', 'gadapet', 'kali', 'saldo', 'tarik', 'nya', 'in', 'gojek']
#
# === STEMMING ===
# Before: ['kemarin', 'siang', 'pesan', 'goride', 'pakai', 'gopaylater', 'pas', 'malam', 'gopaylater', 'blokir', 'tagihan', 'jatuh', 'tempo', 'limit', 'laporan', 'tanggapi', 'kecewa']
# After:  ['kemarin', 'siang', 'pesan', 'goride', 'pakai', 'gopaylater', 'pas', 'malam', 'gopaylater', 'blokir', 'tagih', 'jatuh', 'tempo', 'limit', 'lapor', 'tanggap', 'kecewa']
#
# === STEMMING ===
# Before: ['tukar', 'voucher', 'gorideaja', 'ditukar', 'bilangnya', 'berhasil', 'cek', 'halaman', 'voucher', 'voucher', 'nya', 'kosongg']
# After:  ['tukar', 'voucher', 'gorideaja', 'tukar', 'bilang', 'hasil', 'cek', 'halaman', 'voucher', 'voucher', 'nya', 'kosongg']
#
# === STEMMING ===
# Before: ['membantu']
# After:  ['bantu']
#
# === STEMMING ===
# Before: ['keren', 'gojek', 'driver', 'nya', 'cepat', 'cepat', 'menunggu', 'vocher', 'diskon', 'goride', 'gocar', 'gofood', 'tolong', 'vocher', 'goride', 'nya', 'membantu', 'anak', 'sekolah', 'promo', 'murah', 'dibawah', 'ribu']
# After:  ['keren', 'gojek', 'driver', 'nya', 'cepat', 'cepat', 'tunggu', 'vocher', 'diskon', 'goride', 'gocar', 'gofood', 'tolong', 'vocher', 'goride', 'nya', 'bantu', 'anak', 'sekolah', 'promo', 'murah', 'bawah', 'ribu']
#
# === STEMMING ===
# Before: ['gojek', 'jalan']
# After:  ['gojek', 'jalan']
#
# === STEMMING ===
# Before: ['map', 'goride', 'tol', 'arahi', 'tol', 'tarif', 'sesuai', 'terima', 'kasih']
# After:  ['map', 'goride', 'tol', 'arah', 'tol', 'tarif', 'sesuai', 'terima', 'kasih']
#
# === STEMMING ===
# Before: ['driver', 'go', 'ride', 'min', 'disayangkan', 'orderan', 'susah', 'bensin', 'x', 'pengeluaran', 'akali', 'beli', 'Cuma', 'rb', 'rugi', 'system', 'terdekat', 'diterapkan', 'system', 'goride', 'terdekat', 'diterapkan', 'otomatis', 'pendapatan', 'berkurang', 'drastis', 'costumer', 'gojek', 'membantu', 'orderan', 'belanja', 'tokopedia', 'semoga', 'system', 'update', 'terbaru', 'pendapatan', 'konsisten', 'diatas', 'amin']
# After:  ['driver', 'go', 'ride', 'min', 'sayang', 'order', 'susah', 'bensin', 'x', 'keluar', 'akal', 'beli', 'cuma', 'rb', 'rugi', 'system', 'dekat', 'terap', 'system', 'goride', 'dekat', 'terap', 'otomatis', 'dapat', 'kurang', 'drastis', 'costumer', 'gojek', 'bantu', 'order', 'belanja', 'tokopedia', 'moga', 'system', 'update', 'baru', 'dapat', 'konsisten', 'atas', 'amin']
#
# === STEMMING ===
# Before: ['pelajar', 'turunkan', 'tarif', 'go', 'ride', 'kaum', 'missqueen']
# After:  ['ajar', 'turun', 'tarif', 'go', 'ride', 'kaum', 'missqueen']
#
# === STEMMING ===
# Before: ['good']
# After:  ['good']
#
# === STEMMING ===
# Before: ['memakai', 'aplikasi', 'gojek', 'puas', 'kesini', 'keseringan', 'kecewa', 'order', 'makanan', 'susah', 'driver', 'nya', 'menunggu', 'jam', 'goride', 'mohon', 'diperhatikan', 'ditindaklanjuti', 'kedepannya']
# After:  ['pakai', 'aplikasi', 'gojek', 'puas', 'kesini', 'sering', 'kecewa', 'order', 'makan', 'susah', 'driver', 'nya', 'tunggu', 'jam', 'goride', 'mohon', 'perhati', 'ditindaklanjuti', 'depan']
#
# === STEMMING ===
# Before: ['program', 'bagus', 'pertahankan', 'tingkatkan', 'layanan', 'tolong', 'sejahterakan', 'driver', 'driver', 'nya', 'penghidupan', 'layak']
# After:  ['program', 'bagus', 'tahan', 'tingkat', 'layan', 'tolong', 'sejahtera', 'driver', 'driver', 'nya', 'hidup', 'layak']
#
# === STEMMING ===
# Before: ['membantu']
# After:  ['bantu']
#
# === STEMMING ===
# Before: ['go', 'ride', 'melayani', 'pas', 'hujan', 'gerimis', 'jam', 'order', 'nyangkut', 'berharap', 'sm', 'gojek', 'nyampe', 'kantor', 'terlambat']
# After:  ['go', 'ride', 'layan', 'pas', 'hujan', 'gerimis', 'jam', 'order', 'nyangkut', 'harap', 'sm', 'gojek', 'nyampe', 'kantor', 'lambat']
#
# === STEMMING ===
# Before: ['mantap']
# After:  ['mantap']
#
# === STEMMING ===
# Before: ['mudah', 'an', 'bnyak', 'promonya', 'gofood', 'promo', 'gocar', 'goride', 'lain-lain']
# After:  ['mudah', 'an', 'bnyak', 'promonya', 'gofood', 'promo', 'gocar', 'goride', 'lain']
#
# === STEMMING ===
# Before: ['niatnya', 'top', 'up', 'gopay', 'driver', 'order', 'go', 'ride', 'pas', 'driver', 'top', 'up', 'saldo', 'masuk', 'pergi', 'tuju', 'bayar', 'ongkos', 'trip', 'rugi']
# After:  ['niat', 'top', 'up', 'gopay', 'driver', 'order', 'go', 'ride', 'pas', 'driver', 'top', 'up', 'saldo', 'masuk', 'pergi', 'tuju', 'bayar', 'ongkos', 'trip', 'rugi']
#
# === STEMMING ===
# Before: ['driver', 'driver', 'malas', 'titik', 'nya', 'sesuai', 'banget', 'nya', 'samperin', 'pesan', 'ojol', 'online', 'praktis', 'gosend', 'goride', 'si', 'voucher', 'nya', 'yaa', 'maaf']
# After:  ['driver', 'driver', 'malas', 'titik', 'nya', 'sesuai', 'banget', 'nya', 'samperin', 'pesan', 'ojol', 'online', 'praktis', 'gosend', 'goride', 'si', 'voucher', 'nya', 'yaa', 'maaf']
#
# === STEMMING ===
# Before: ['tampilan', 'aplikasi', 'gojek', 'nyaman', 'menarik', 'penggunaan', 'aplikasi', 'gojek', 'nyaman', 'aman', 'praktis', 'suka', 'order', 'gofood', 'goride', 'aplikasi', 'gojek', 'semoga', 'nambah', 'promo', 'gofood', 'nya', 'he']
# After:  ['tampil', 'aplikasi', 'gojek', 'nyaman', 'tarik', 'guna', 'aplikasi', 'gojek', 'nyaman', 'aman', 'praktis', 'suka', 'order', 'gofood', 'goride', 'aplikasi', 'gojek', 'moga', 'nambah', 'promo', 'gofood', 'nya', 'he']
#
# === STEMMING ===
# Before: ['sediakan', 'versi', 'lite', 'nya', 'goride', 'gocar', 'ukuran', 'aplikasinya', 'besarlah']
# After:  ['sedia', 'versi', 'lite', 'nya', 'goride', 'gocar', 'ukur', 'aplikasi', 'besar']
#
# === STEMMING ===
# Before: ['layanan', 'gocar', 'buruk', 'dicancel', 'x', 'jalan', 'rumah', 'sekalinya', 'sopirnya', 'dilayanin', 'pakai', 'gocar', 'prioritas', 'buruk', 'buruk', 'gocar', 'kecewa', 'pakai', 'goride', 'gofood', 'jrg', 'kendala', 'pakai', 'gocar']
# After:  ['layan', 'gocar', 'buruk', 'dicancel', 'x', 'jalan', 'rumah', 'sekali', 'sopir', 'dilayanin', 'pakai', 'gocar', 'prioritas', 'buruk', 'buruk', 'gocar', 'kecewa', 'pakai', 'goride', 'gofood', 'jrg', 'kendala', 'pakai', 'gocar']
#
# === STEMMING ===
# Before: ['gofood', 'super', 'mahal', 'ongkirnya', 'biaya', 'layanannya', 'sgala', 'promo', 'potongan', 'apapun', 'pakai', 'gojek', 'kebutuhan', 'gocar', 'goride', 'tiket', 'kereta']
# After:  ['gofood', 'super', 'mahal', 'ongkirnya', 'biaya', 'layan', 'sgala', 'promo', 'potong', 'apa', 'pakai', 'gojek', 'butuh', 'gocar', 'goride', 'tiket', 'kereta']
#
# === STEMMING ===
# Before: ['pokok', 'nya', 'top', 'markotop', 'deh']
# After:  ['pokok', 'nya', 'top', 'markotop', 'deh']
#
# === STEMMING ===
# Before: ['good']
# After:  ['good']
#
# === STEMMING ===
# Before: ['pengalaman', 'menyenangkan', 'gojek']
# After:  ['alam', 'senang', 'gojek']
#
# === STEMMING ===
# Before: ['membantu', 'perjalanan']
# After:  ['bantu', 'jalan']
#
# === STEMMING ===
# Before: ['langganan', 'pakai', 'gojek', 'pigi', 'goride', 'menurud', 'drivenya', 'ramah', 'semoga', 'ditingkatkan']
# After:  ['langgan', 'pakai', 'gojek', 'pigi', 'goride', 'menurud', 'drivenya', 'ramah', 'moga', 'tingkat']
#
# === STEMMING ===
# Before: ['driver', 'bik', 'sopan', 'rapi', 'ramah', 'kendaraan', 'terawat', 'dijalan', 'patuh', 'taat', 'peraturan', 'lintas', 'layanan', 'panggilan', 'cepat', 'salam', 'relatif', 'yepay', 'gojek', 'reward', 'driver', 'teladan', 'cistomersetia', 'telafan', 'mengadakan', 'indian', 'voucer', 'berhadiah', 'mobil', 'pengumannya', 'disosialisasikan', 'terimakasih', 'customer', 'gojek', 'go', 'ride', 'go', 'car']
# After:  ['driver', 'bik', 'sopan', 'rapi', 'ramah', 'kendara', 'awat', 'jalan', 'patuh', 'taat', 'atur', 'lintas', 'layan', 'panggil', 'cepat', 'salam', 'relatif', 'yepay', 'gojek', 'reward', 'driver', 'teladan', 'cistomersetia', 'taf', 'ada', 'indian', 'voucer', 'hadiah', 'mobil', 'uman', 'sosialisasi', 'terimakasih', 'customer', 'gojek', 'go', 'ride', 'go', 'car']
#
# === STEMMING ===
# Before: ['promoan', 'driver', 'ambil', 'orderan', 'gocar', 'goride', 'seringkali', 'menunggu', 'ambil', 'coba', 'pakai', 'grab', 'langsung']
# After:  ['promoan', 'driver', 'ambil', 'order', 'gocar', 'goride', 'seringkali', 'tunggu', 'ambil', 'coba', 'pakai', 'grab', 'langsung']
#
# === STEMMING ===
# Before: ['bagus']
# After:  ['bagus']
#
# === STEMMING ===
# Before: ['orderan', 'goride', 'hemat', 'gofood', 'hemat', 'bikin', 'rugi', 'driver', 'tolong', 'hapus', 'orderan', 'hemat', 'nya', 'pakai', 'tarif', 'normal']
# After:  ['order', 'goride', 'hemat', 'gofood', 'hemat', 'bikin', 'rugi', 'driver', 'tolong', 'hapus', 'order', 'hemat', 'nya', 'pakai', 'tarif', 'normal']
#
# === STEMMING ===
# Before: ['beragam', 'aplikasi', 'nya', 'goride', 'gocar', 'go', 'food', 'semoga', 'innovasi', 'nya']
# After:  ['agam', 'aplikasi', 'nya', 'goride', 'gocar', 'go', 'food', 'moga', 'innovasi', 'nya']
#
# === STEMMING ===
# Before: ['nice']
# After:  ['nice']
#
# === STEMMING ===
# Before: ['kadang', 'hujan', 'gada', 'driver', 'go', 'ride', 'ambil', 'pesanan', 'hujan', 'nya', 'redah', 'terpaksa', 'menunggu']
# After:  ['kadang', 'hujan', 'gada', 'driver', 'go', 'ride', 'ambil', 'pesan', 'hujan', 'nya', 'redah', 'paksa', 'tunggu']
#
# === STEMMING ===
# Before: ['order', 'goride', 'stuk', 'map']
# After:  ['order', 'goride', 'stuk', 'map']
#
# === STEMMING ===
# Before: ['kasi', 'promo', 'order', 'gofood', 'goride', 'gocar']
# After:  ['kasi', 'promo', 'order', 'gofood', 'goride', 'gocar']
#
# === STEMMING ===
# Before: ['ditentukan', 'terlambat', 'goride', 'gofood']
# After:  ['tentu', 'lambat', 'goride', 'gofood']
#
# === STEMMING ===
# Before: ['kota', 'bandung', 'go', 'ride', 'gocar', 'instan', 'ngak', 'kedepan', 'banget', 'menjengkelkan', 'pesan', 'drivernya', 'lihat', 'lalang', 'ambil', 'hemat', 'comvort']
# After:  ['kota', 'bandung', 'go', 'ride', 'gocar', 'instan', 'ngak', 'depan', 'banget', 'jengkel', 'pesan', 'drivernya', 'lihat', 'lalang', 'ambil', 'hemat', 'comvort']
#
# === STEMMING ===
# Before: ['gojek', 'keren', 'pesan', 'goride', 'terima', 'kasih', 'gojek']
# After:  ['gojek', 'keren', 'pesan', 'goride', 'terima', 'kasih', 'gojek']
#
# === STEMMING ===
# Before: ['enak', 'sih', 'goride', 'nya', 'Cuma', 'hujan', 'rintik', 'gerimis', 'dikit', 'driver', 'nya', 'ambil', 'orderan', 'gofood', 'jas', 'ujan', 'sih', 'anjing', 'orng', 'laper', 'banget', 'menunggu', 'jam', 'x', 'mesen', 'ngechat', 'ig', 'resto', 'nya', 'anjing', 'banget', 'gojek', 'restonya', 'ss', 'pesan', 'orng', 'driver', 'tolong', 'deh', 'driver', 'nya', 'ujan', 'dikit', 'males', 'gojek', 'anjg']
# After:  ['enak', 'sih', 'goride', 'nya', 'cuma', 'hujan', 'rintik', 'gerimis', 'dikit', 'driver', 'nya', 'ambil', 'order', 'gofood', 'jas', 'ujan', 'sih', 'anjing', 'orng', 'laper', 'banget', 'tunggu', 'jam', 'x', 'mesen', 'ngechat', 'ig', 'resto', 'nya', 'anjing', 'banget', 'gojek', 'restonya', 'ss', 'pesan', 'orng', 'driver', 'tolong', 'deh', 'driver', 'nya', 'ujan', 'dikit', 'males', 'gojek', 'anjg']
#
# === STEMMING ===
# Before: ['tolong', 'hapus', 'goride', 'instan', 'stasiun', 'tangerang', 'menyusahkan', 'jalan', 'kaki', 'jam', 'sibuk', 'macet', 'jalan', 'kaki']
# After:  ['tolong', 'hapus', 'goride', 'instan', 'stasiun', 'tangerang', 'susah', 'jalan', 'kaki', 'jam', 'sibuk', 'macet', 'jalan', 'kaki']
#
# === STEMMING ===
# Before: ['tolong', 'radius', 'driver', 'pesan', 'goride', 'jangkauan', 'bedakan', 'goride', 'hemat', 'goride', 'reguler', 'tunggu', 'nya']
# After:  ['tolong', 'radius', 'driver', 'pesan', 'goride', 'jangkau', 'beda', 'goride', 'hemat', 'goride', 'reguler', 'tunggu', 'nya']
#
# === STEMMING ===
# Before: ['okeh']
# After:  ['okeh']
#
# === STEMMING ===
# Before: ['goride', 'oke', 'gofoodnya', 'sampah', 'banget', 'mencari', 'driver', 'makanan', 'jam', 'menunggu', 'endingnya', 'cancle', 'gadapat', 'driver', 'terlanjur', 'laper', 'php']
# After:  ['goride', 'oke', 'gofoodnya', 'sampah', 'banget', 'cari', 'driver', 'makan', 'jam', 'tunggu', 'endingnya', 'cancle', 'gadapat', 'driver', 'lanjur', 'laper', 'php']
#
# === STEMMING ===
# Before: ['mantap']
# After:  ['mantap']
#
# === STEMMING ===
# Before: ['bagus']
# After:  ['bagus']
#
# === STEMMING ===
# Before: ['cs', 'online', 'kendala', 'susah', 'gopaylater', 'dikasih', 'limit', 'sebulan', 'x', 'pengecekan', 'pembekuan', 'tarif', 'gofood', 'goride', 'masuk', 'akal', 'worth', 'it', 'maaf', 'to', 'sayang', 'bikin', 'muak']
# After:  ['cs', 'online', 'kendala', 'susah', 'gopaylater', 'kasih', 'limit', 'bulan', 'x', 'kece', 'beku', 'tarif', 'gofood', 'goride', 'masuk', 'akal', 'worth', 'it', 'maaf', 'to', 'sayang', 'bikin', 'muak']
#
# === STEMMING ===
# Before: []
# After:  []
#
# === STEMMING ===
# Before: ['goride', 'hemat', 'ko', 'min', 'susah', 'mencari', 'keatasin', 'biar', 'gamapang', 'langsung', 'pesan']
# After:  ['goride', 'hemat', 'ko', 'min', 'susah', 'cari', 'keatasin', 'biar', 'gamapang', 'langsung', 'pesan']
#
# === STEMMING ===
# Before: ['pemakai', 'go', 'box', 'go', 'pulsa', 'go', 'ride', 'go', 'send', 'go', 'car', 'go', 'food', 'go', 'massage', 'aktif', 'terimakasih', 'gojek', 'bermanfaat']
# After:  ['pakai', 'go', 'box', 'go', 'pulsa', 'go', 'ride', 'go', 'send', 'go', 'car', 'go', 'food', 'go', 'massage', 'aktif', 'terimakasih', 'gojek', 'manfaat']
#
# === STEMMING ===
# Before: ['promo', 'diskon', 'nya']
# After:  ['promo', 'diskon', 'nya']
#
# === STEMMING ===
# Before: ['aplikasi', 'bug', 'nya', 'order', 'goride', 'x', 'terpanggil', 'driver', 'tujuan', 'akun', 'order', 'x', 'kali', 'cek', 'aplikasi', 'terorder', 'goridenya', 'saldo', 'gopay', 'terisi']
# After:  ['aplikasi', 'bug', 'nya', 'order', 'goride', 'x', 'panggil', 'driver', 'tuju', 'akun', 'order', 'x', 'kali', 'cek', 'aplikasi', 'order', 'goridenya', 'saldo', 'gopay', 'isi']
#
# === STEMMING ===
# Before: ['mantul']
# After:  ['mantul']
#
# === STEMMING ===
# Before: ['mudah', 'persulit', 'dikasih', 'kadang', 'kadang', 'pakai', 'gojek', 'nya', 'butuh', 'eh', 'kasih', 'driver', 'nya', 'menunggu', 'deh', 'harga', 'murah', 'nya', 'cepat', 'nya', 'terimakasih']
# After:  ['mudah', 'sulit', 'kasih', 'kadang', 'kadang', 'pakai', 'gojek', 'nya', 'butuh', 'eh', 'kasih', 'driver', 'nya', 'tunggu', 'deh', 'harga', 'murah', 'nya', 'cepat', 'nya', 'terimakasih']
#
# === STEMMING ===
# Before: ['go', 'ride', 'instan', 'merugikan', 'jarak', 'nya', 'driver', 'ambil']
# After:  ['go', 'ride', 'instan', 'rugi', 'jarak', 'nya', 'driver', 'ambil']
#
# === STEMMING ===
# Before: ['gojek', 'evaluasi', 'mitranya', 'mencari', 'driver', 'hujan', 'susah', 'banget', 'ordernya', 'gocar', 'goride', 'susah', 'banget', 'dapetnya', 'aplikasinya', 'sih', 'oke', 'oke']
# After:  ['gojek', 'evaluasi', 'mitra', 'cari', 'driver', 'hujan', 'susah', 'banget', 'order', 'gocar', 'goride', 'susah', 'banget', 'dapetnya', 'aplikasi', 'sih', 'oke', 'oke']
#
# === STEMMING ===
# Before: ['tolong', 'perbaikin', 'goride', 'hemat', 'nya', 'hilang', 'an', 'pakai', 'goride', 'hemat', 'membantu', 'kali', 'pakai', 'pulang', 'kerja', 'menghemat', 'ongkos', 'tolong', 'perbaiki']
# After:  ['tolong', 'perbaikin', 'goride', 'hemat', 'nya', 'hilang', 'an', 'pakai', 'goride', 'hemat', 'bantu', 'kali', 'pakai', 'pulang', 'kerja', 'hemat', 'ongkos', 'tolong', 'baik']
#
# === STEMMING ===
# Before: ['kirain', 'langganan', 'gojek', 'plus', 'potongannya', 'beneran', 'ribu', 'goride', 'Cuma', 'potongan', 'ribu', 'anjirlah']
# After:  ['kirain', 'langgan', 'gojek', 'plus', 'potong', 'beneran', 'ribu', 'goride', 'cuma', 'potong', 'ribu', 'anjir']
#
# === STEMMING ===
# Before: ['bermanfaat']
# After:  ['manfaat']
#
# === STEMMING ===
# Before: ['good', 'driver']
# After:  ['good', 'driver']
#
# === STEMMING ===
# Before: ['membantu']
# After:  ['bantu']
#
# === STEMMING ===
# Before: ['ok', 'goride', 'nya']
# After:  ['ok', 'goride', 'nya']
#
# === STEMMING ===
# Before: ['oke', 'ok', 'bgus']
# After:  ['oke', 'ok', 'bgus']
#
# === STEMMING ===
# Before: ['pesan', 'gojek', 'orang', 'sengaja', 'pembayaran', 'pakai', 'go', 'pay', 'ganti', 'metode', 'pembayaran', 'nya', 'pakai', 'cash', 'potongan', 'makan', 'krna', 'saldo', 'go', 'pay', 'kepotong', 'goride', 'terpaksa', 'pakai', 'cash', 'aplikasi']
# After:  ['pesan', 'gojek', 'orang', 'sengaja', 'bayar', 'pakai', 'go', 'pay', 'ganti', 'metode', 'bayar', 'nya', 'pakai', 'cash', 'potong', 'makan', 'krna', 'saldo', 'go', 'pay', 'potong', 'goride', 'paksa', 'pakai', 'cash', 'aplikasi']
#
# === STEMMING ===
# Before: ['jelek', 'gojek', 'pesan', 'goride', 'ambil', 'drive', 'alhasil', 'kali', 'tolak', 'drive', 'alesan', 'alhasil', 'pesan', 'grab', 'menit', 'jemput', 'grab', 'lbh', 'murah', 'ribu', 'gojek', 'ribu', 'pakai', 'voucher', 'kali', 'ngalaminnya', 'pastikan', 'uninstall', 'gojek', 'sistem', 'nya', 'kaya', 'melulu', 'jamin', 'pindah', 'aplikasi']
# After:  ['jelek', 'gojek', 'pesan', 'goride', 'ambil', 'drive', 'alhasil', 'kali', 'tolak', 'drive', 'alesan', 'alhasil', 'pesan', 'grab', 'menit', 'jemput', 'grab', 'lbh', 'murah', 'ribu', 'gojek', 'ribu', 'pakai', 'voucher', 'kali', 'ngalaminnya', 'pasti', 'uninstall', 'gojek', 'sistem', 'nya', 'kaya', 'melulu', 'jamin', 'pindah', 'aplikasi']
#
# === STEMMING ===
# Before: ['pengalaman', 'buruk', 'pagi', 'pesan', 'goride', 'keberangkatan', 'kakak', 'menit', 'driver', 'map', 'jemput', 'menit', 'separuh', 'perjalanan', 'stasiun', 'menit', 'menunggu', 'menit', 'lihat', 'map', 'driver', 'menjauh', 'bilang', 'chat', 'batal', 'kakak', 'alihkan', 'driver', 'layanan', 'dibatalkan', 'driver', 'kena', 'batal', 'kasihan']
# After:  ['alam', 'buruk', 'pagi', 'pesan', 'goride', 'berangkat', 'kakak', 'menit', 'driver', 'map', 'jemput', 'menit', 'paruh', 'jalan', 'stasiun', 'menit', 'tunggu', 'menit', 'lihat', 'map', 'driver', 'jauh', 'bilang', 'chat', 'batal', 'kakak', 'alih', 'driver', 'layan', 'batal', 'driver', 'kena', 'batal', 'kasihan']
#
# === STEMMING ===
# Before: ['oke', 'oke', 'pengguna', 'goride', 'wanita', 'perlakuan', 'cabul', 'driver', 'gojek', 'cari', 'driver', 'interview', 'sih', 'kepribadian', 'nya']
# After:  ['oke', 'oke', 'guna', 'goride', 'wanita', 'laku', 'cabul', 'driver', 'gojek', 'cari', 'driver', 'interview', 'sih', 'pribadi', 'nya']
#
# === STEMMING ===
# Before: ['persen', 'goride', 'batalkan', 'saldonya', 'terpotong', 'kecewa', 'chat', 'cs', 'membantu']
# After:  ['persen', 'goride', 'batal', 'saldo', 'potong', 'kecewa', 'chat', 'cs', 'bantu']
#
# === STEMMING ===
# Before: ['pesan', 'gocar', 'pesan', 'pesawat', 'ambil', 'bayar', 'gopay', 'cash', 'ganti', 'prioritas', 'driver', 'jaraknya', 'astaga', 'banget', 'buang', 'maps', 'driver', 'kumpul-kumpul', 'pilih', 'driver', 'gocar', 'goride', 'nya', 'cepat', 'driver', 'goride', 'gocar', 'tolong', 'gojek', 'perbaiki', 'sistemnya', 'pesan', 'car', 'beralih', 'aplikasi', 'gercep', 'satset', 'driver', 'gocar', 'pilih']
# After:  ['pesan', 'gocar', 'pesan', 'pesawat', 'ambil', 'bayar', 'gopay', 'cash', 'ganti', 'prioritas', 'driver', 'jarak', 'astaga', 'banget', 'buang', 'maps', 'driver', 'kumpul', 'pilih', 'driver', 'gocar', 'goride', 'nya', 'cepat', 'driver', 'goride', 'gocar', 'tolong', 'gojek', 'baik', 'sistem', 'pesan', 'car', 'alih', 'aplikasi', 'gercep', 'satset', 'driver', 'gocar', 'pilih']
#
# === STEMMING ===
# Before: ['pesan', 'go', 'ride', 'sekalinya', 'batal', 'sma', 'driver', 'nya', 'kesel', 'nya', 'jam', 'ambil']
# After:  ['pesan', 'go', 'ride', 'sekali', 'batal', 'sma', 'driver', 'nya', 'kesel', 'nya', 'jam', 'ambil']
#
# === STEMMING ===
# Before: ['goride', 'membawa', 'penumpang', 'orang', 'anak', 'sd', 'semalam']
# After:  ['goride', 'bawa', 'tumpang', 'orang', 'anak', 'sd', 'malam']
#
# === STEMMING ===
# Before: ['jujur', 'gojek', 'bagus', 'Cuma', 'pas', 'pesan', 'goride', 'stengah', 'jam', 'terima', 'terima']
# After:  ['jujur', 'gojek', 'bagus', 'cuma', 'pas', 'pesan', 'goride', 'stengah', 'jam', 'terima', 'terima']
#
# === STEMMING ===
# Before: ['pesan', 'goride', 'mengambil', 'menunggu', 'membantu', 'tolong', 'perbaiki', 'kinerjanya']
# After:  ['pesan', 'goride', 'ambil', 'tunggu', 'bantu', 'tolong', 'baik', 'kerja']
#
# === STEMMING ===
# Before: ['aplikasi', 'nya', 'gampang', 'dipahami', 'goride', 'nya', 'murah']
# After:  ['aplikasi', 'nya', 'gampang', 'paham', 'goride', 'nya', 'murah']
#
# === STEMMING ===
# Before: ['aplikasi', 'nya', 'lancar', 'gangguan', 'kadang', 'pas', 'buka', 'go', 'food', 'pilih', 'resto', 'ngelag', 'bagus']
# After:  ['aplikasi', 'nya', 'lancar', 'ganggu', 'kadang', 'pas', 'buka', 'go', 'food', 'pilih', 'resto', 'ngelag', 'bagus']
#
# === STEMMING ===
# Before: ['semoga', 'menjaga', 'amanah']
# After:  ['moga', 'jaga', 'amanah']
#
# === STEMMING ===
# Before: ['biayanya', 'super', 'mahal', 'khusus', 'gofood', 'anehnya', 'driver', 'minim', 'pickup', 'pesan', 'gosend', 'ongkos', 'murah', 'sisahnya', 'kasih', 'tips', 'driver', 'menyumbang', 'uang', 'gojeknya', 'ngapa', 'in', 'pesan', 'goride', 'menawarkan', 'driver', 'offline', 'online', 'biar', 'uangnya', 'full', 'driver', 'biar', 'kena', 'potongan', 'membantu']
# After:  ['biaya', 'super', 'mahal', 'khusus', 'gofood', 'aneh', 'driver', 'minim', 'pickup', 'pesan', 'gosend', 'ongkos', 'murah', 'sisahnya', 'kasih', 'tips', 'driver', 'sumbang', 'uang', 'gojek', 'ngapa', 'in', 'pesan', 'goride', 'tawar', 'driver', 'offline', 'online', 'biar', 'uang', 'full', 'driver', 'biar', 'kena', 'potong', 'bantu']
#
# === STEMMING ===
# Before: ['good']
# After:  ['good']
#
# === STEMMING ===
# Before: ['promo']
# After:  ['promo']
#
# === STEMMING ===
# Before: ['keren']
# After:  ['keren']
#
# === STEMMING ===
# Before: ['oke']
# After:  ['oke']
#
# === STEMMING ===
# Before: ['mantap']
# After:  ['mantap']
#
# === STEMMING ===
# Before: ['baguss']
# After:  ['baguss']
#
# === STEMMING ===
# Before: ['fitur', 'go', 'transit', 'plus', 'go', 'ride', 'ko', 'si', 'update']
# After:  ['fitur', 'go', 'transit', 'plus', 'go', 'ride', 'ko', 'si', 'update']
#
# === STEMMING ===
# Before: ['mantull']
# After:  ['mantull']
#
# === STEMMING ===
# Before: ['gpsnya', 'auto', 'tracking', 'direct', 'go', 'ride', 'bikin', 'nyaman', 'ngecustom', 'lokasi', 'susahh', 'driver', 'pilih', 'pilih', 'customer', 'rating', 'diskon', 'pakai', 'voucher', 'suka', 'banget', 'ketemu', 'driver', 'suka', 'komplain', 'ngoceh']
# ...
# After:  ['mohon', 'baik', 'sistem', 'masak', 'order', 'goride', 'pesan', 'sengaja', 'dobel', 'klik', 'nyantol', 'driver', 'konsumen', 'enak', 'driver', 'nya', 'aplikasi', 'belah', 'kayak', 'dobel', 'pesan', 'selesai', 'untung', 'drivernya', 'sabar', 'repot', 'tahu', 'dobel', 'drivernya', 'tinggal', 'klik', 'batal', 'aplikasi', 'sih', 'gampang', 'jelas', 'drivernya', 'lho', 'repot']
#
# === STEMMING ===
# Before: ['bagus']
# After:  ['bagus']
#
# === STEMMING ===
# Before: ['layanan', 'bagus', 'kali', 'beli', 'paket', 'voucher', 'diskon', 'nominal', 'voucher', 'voucher', 'goride', 'diskon', 's', 'rb', 'diskon', 'rb', 'keterangannya', 'diskonnya', 'jujur', 'terscam']
# After:  ['layan', 'bagus', 'kali', 'beli', 'paket', 'voucher', 'diskon', 'nominal', 'voucher', 'voucher', 'goride', 'diskon', 's', 'rb', 'diskon', 'rb', 'terang', 'diskon', 'jujur', 'terscam']
#
# === STEMMING ===
# Before: ['disolok', 'gojek', 'pesan', 'goride', 'tanjung', 'bingkung', 'gocar', 'kepadang', 'bukit', 'apk', 'kehapus', 'nomor', 'hp', 'hilang', 'login', 'susah', 'email', 'verivikasi']
# After:  ['solok', 'gojek', 'pesan', 'goride', 'tanjung', 'bingkung', 'gocar', 'padang', 'bukit', 'apk', 'hapus', 'nomor', 'hp', 'hilang', 'login', 'susah', 'email', 'verivikasi']
#
# === STEMMING ===
# Before: ['gopaynya', 'praktis', 'promo', 'gofood', 'goride', 'harganya', 'terjangkau', 'pelajar']
# After:  ['gopaynya', 'praktis', 'promo', 'gofood', 'goride', 'harga', 'jangkau', 'ajar']
#
# === STEMMING ===
# Before: ['mantap', 'keren']
# After:  ['mantap', 'keren']
#
# === STEMMING ===
# Before: ['rating', 'noh', 'bintang', 'urgent', 'gocar', 'goride', 'driver', 'nge', 'batal', 'sepakat', 'ditunggu', 'batal', 'banget']
# After:  ['rating', 'noh', 'bintang', 'urgent', 'gocar', 'goride', 'driver', 'nge', 'batal', 'sepakat', 'tunggu', 'batal', 'banget']
#
# === STEMMING ===
# Before: ['rider', 'gojek', 'nama', 'firial', 'lampung', 'sopan', 'membentak', 'pelanggan', 'kebut', 'kebutan', 'dijalan', 'menabrak', 'orang', 'gojek', 'seleksi', 'rider']
# After:  ['rider', 'gojek', 'nama', 'firial', 'lampung', 'sopan', 'bentak', 'langgan', 'kebut', 'kebut', 'jalan', 'tabrak', 'orang', 'gojek', 'seleksi', 'rider']
#
# === STEMMING ===
# Before: ['bagus']
# After:  ['bagus']
#
# === STEMMING ===
# Before: ['gojek', 'susah', 'banget', 'pesan', 'gocar', 'pakai', 'gocar', 'gocar', 'hemat', 'hapus', 'vitur', 'gocar', 'ny', 'goride']
# After:  ['gojek', 'susah', 'banget', 'pesan', 'gocar', 'pakai', 'gocar', 'gocar', 'hemat', 'hapus', 'vitur', 'gocar', 'ny', 'goride']
#
# === STEMMING ===
# Before: ['berat', 'pesan', 'goride', 'klik', 'alamat', 'tujuan', 'giliran', 'pas', 'drivernya', 'aplikasi', 'ngestuck', 'delay', 'close', 'aplikasi', 'masuk', 'biar', 'normal']
# After:  ['berat', 'pesan', 'goride', 'klik', 'alamat', 'tuju', 'gilir', 'pas', 'drivernya', 'aplikasi', 'ngestuck', 'delay', 'close', 'aplikasi', 'masuk', 'biar', 'normal']
#
# === STEMMING ===
# Before: ['parah', 'mntang', 'habis', 'ujan', 'pesan', 'goride', 'gocar', 'smpe', 'blue', 'bird', 'terima', 'kasih', 'bayar', 'tunai', 'sdang', 'buru']
# After:  ['parah', 'mntang', 'habis', 'ujan', 'pesan', 'goride', 'gocar', 'smpe', 'blue', 'bird', 'terima', 'kasih', 'bayar', 'tunai', 'sdang', 'buru']
#
# === STEMMING ===
# Before: ['jaraknya', 'driver', 'alasan', 'batal', 'bukti', 'chat', 'cari', 'orderan', 'goride', 'bayar', 'ribu', 'Cuma', 'masuk', 'drivernya', 'Cuma', 'ribu']
# After:  ['jarak', 'driver', 'alas', 'batal', 'bukti', 'chat', 'cari', 'order', 'goride', 'bayar', 'ribu', 'cuma', 'masuk', 'drivernya', 'cuma', 'ribu']
#
# === STEMMING ===
# Before: ['tolong', 'driver', 'diajarin', 'layanan', 'pesan', 'goride', 'driver', 'nya', 'didiemin', 'posisi', 'driver', 'diem', 'menunggu', 'jam', 'ujung', 'nya', 'batal', 'ambil', 'orderan', 'suruh', 'bicara', 'pelanggan', 'pelanggan', 'nge', 'batal', 'orderannya', 'biar', 'rating', 'driver', 'minus', 'rugi', 'menunggu', 'hujan', 'an', 'ujung', 'nya', 'batal']
# After:  ['tolong', 'driver', 'diajarin', 'layan', 'pesan', 'goride', 'driver', 'nya', 'didiemin', 'posisi', 'driver', 'diem', 'tunggu', 'jam', 'ujung', 'nya', 'batal', 'ambil', 'order', 'suruh', 'bicara', 'langgan', 'langgan', 'nge', 'batal', 'order', 'biar', 'rating', 'driver', 'minus', 'rugi', 'tunggu', 'hujan', 'an', 'ujung', 'nya', 'batal']
#
# === STEMMING ===
# Before: ['pesan', 'goride', 'batalkan', 'dpn', 'customer', 'motor', 'giliran', 'pesan', 'goride', 'comfort', 'eh', 'dtng', 'motor', 'sih', 'kali', 'goride', 'dtng']
# After:  ['pesan', 'goride', 'batal', 'dpn', 'customer', 'motor', 'gilir', 'pesan', 'goride', 'comfort', 'eh', 'dtng', 'motor', 'sih', 'kali', 'goride', 'dtng']
#
# === STEMMING ===
# Before: ['bangsatt', 'ongkos', 'gofood', 'mahal', 'banget', 'go', 'ride', 'melambung', 'kasihan', 'drivernya', 'diperas', 'mati']
# After:  ['bangsatt', 'ongkos', 'gofood', 'mahal', 'banget', 'go', 'ride', 'lambung', 'kasihan', 'drivernya', 'peras', 'mati']
#
# === STEMMING ===
# Before: ['bagus']
# After:  ['bagus']
#
# === STEMMING ===
# Before: ['pertahankan', 'layanan', 'pelanggan', 'penghargaan', 'besarnya', 'rider', 'driver', 'kurangin', 'potongan', 'perusahaan', 'nya']
# After:  ['tahan', 'layan', 'langgan', 'harga', 'besar', 'rider', 'driver', 'rangin', 'potong', 'usaha', 'nya']
#
# === STEMMING ===
# Before: ['plis', 'promo', 'nya', 'khusus', 'goride', 'pakai', 'goride', 'promo', 'teman', 'slalu', 'potongan', 'beli', 'loh', 'potongan', 'gaadil', 'pls']
# After:  ['plis', 'promo', 'nya', 'khusus', 'goride', 'pakai', 'goride', 'promo', 'teman', 'slalu', 'potong', 'beli', 'loh', 'potong', 'gaadil', 'pls']
#
# === STEMMING ===
# Before: ['bagus', 'aplikasi', 'nya', 'membantu', 'banget']
# After:  ['bagus', 'aplikasi', 'nya', 'bantu', 'banget']
#
# === STEMMING ===
# Before: ['kesel', 'pesan', 'gocar', 'goride', 'pagi', 'pagi', 'driver', 'nya', 'nya', 'ampun', 'pokoknya', 'kecewa', 'deh']
# After:  ['kesel', 'pesan', 'gocar', 'goride', 'pagi', 'pagi', 'driver', 'nya', 'nya', 'ampun', 'pokok', 'kecewa', 'deh']
#
# === STEMMING ===
# Before: ['good', 'apk']
# After:  ['good', 'apk']
#
# === STEMMING ===
# Before: ['hati', 'goride', 'gojek', 'topi', 'tertinggal', 'nyangkut', 'helm', 'ti', 'tilep', 'drivernya', 'kecewa', 'seminggu', 'kejelasan', 'kerjasama', 'coba', 'barang', 'berharga', 'bahaya', 'topi', 'curi']
# After:  ['hati', 'goride', 'gojek', 'topi', 'tinggal', 'nyangkut', 'helm', 'ti', 'tilep', 'drivernya', 'kecewa', 'minggu', 'jelas', 'kerjasama', 'coba', 'barang', 'harga', 'bahaya', 'topi', 'curi']
#
# === STEMMING ===
# Before: ['mudah', 'lancar']
# After:  ['mudah', 'lancar']
#
# === STEMMING ===
# Before: ['si', 'langganan', 'vouch', 'go', 'plus', 'mlh', 'goride', 'nya', 'diskon', 'nyesell']
# After:  ['si', 'langgan', 'vouch', 'go', 'plus', 'mlh', 'goride', 'nya', 'diskon', 'nyesell']
#
# === STEMMING ===
# Before: ['mohon', 'perbaiki', 'drivernya', 'masak', 'hujan', 'narik', 'go', 'ride', 'nya', 'jam', 'pesan', 'peduliin', 'langsung', 'batal', 'driver', 'profesional', 'banget', 'tempatku', 'mobil', 'masuk', 'pesennya', 'go', 'ride']
# After:  ['mohon', 'baik', 'drivernya', 'masak', 'hujan', 'narik', 'go', 'ride', 'nya', 'jam', 'pesan', 'peduliin', 'langsung', 'batal', 'driver', 'profesional', 'banget', 'tempat', 'mobil', 'masuk', 'sen', 'go', 'ride']
#
# === STEMMING ===
# Before: ['mantab']
# After:  ['mantab']
#
# === STEMMING ===
# Before: ['suka', 'pakai', 'gojek', 'sukatani', 'goride', 'terjangkau', 'yaa']
# After:  ['suka', 'pakai', 'gojek', 'sukatani', 'goride', 'jangkau', 'yaa']
#
# === STEMMING ===
# Before: ['mantap', 'pokoknya']
# After:  ['mantap', 'pokok']
#
# === STEMMING ===
# Before: ['terimaksih', 'jaya']
# After:  ['terimaksih', 'jaya']
#
# === STEMMING ===
# Before: ['nyaman']
# After:  ['nyaman']
#
# === STEMMING ===
# Before: ['sekongkol', 'driver', 'go', 'jek', 'order', 'goride', 'pas', 'driver', 'langsung', 'nama', 'alamat', 'tujuan', 'nama', 'tujuan', 'driver', 'driver', 'bilang', 'offline', 'pakai', 'aplikasi', 'cek', 'diaplikasi', 'driver', 'order', 'mengirim', 'foto', 'menunggu', 'dititik', 'jemput', 'ditujuan', 'driver', 'mengantar', 'tarif', 'x', 'lipat', 'tarif', 'diaplikasi']
# After:  ['sekongkol', 'driver', 'go', 'jek', 'order', 'goride', 'pas', 'driver', 'langsung', 'nama', 'alamat', 'tuju', 'nama', 'tuju', 'driver', 'driver', 'bilang', 'offline', 'pakai', 'aplikasi', 'cek', 'aplikasi', 'driver', 'order', 'kirim', 'foto', 'tunggu', 'titik', 'jemput', 'tuju', 'driver', 'antar', 'tarif', 'x', 'lipat', 'tarif', 'aplikasi']
#
# === STEMMING ===
# Before: ['bagus']
# After:  ['bagus']
#
# === STEMMING ===
# Before: ['layanan', 'ramah', 'sopan', 'murah']
# After:  ['layan', 'ramah', 'sopan', 'murah']
#
# === STEMMING ===
# Before: ['aplikasi', 'gojek', 'membantu']
# After:  ['aplikasi', 'gojek', 'bantu']
#
# === STEMMING ===
# Before: ['order', 'goride', 'kali', 'munculnya']
# After:  ['order', 'goride', 'kali', 'muncul']
#
# === STEMMING ===
# Before: ['ok', 'banget']
# After:  ['ok', 'banget']
#
# === STEMMING ===
# Before: ['go', 'ride', 'oke', 'gocar', 'nya']
# After:  ['go', 'ride', 'oke', 'gocar', 'nya']
#
# === STEMMING ===
# Before: ['go', 'ride', 'jembot', 'sombong', 'drivernya', 'jarak', 'gmau', 'tolak', 'map', 'driver', 'nolak', 'app', 'sampah']
# After:  ['go', 'ride', 'jembot', 'sombong', 'drivernya', 'jarak', 'gmau', 'tolak', 'map', 'driver', 'nolak', 'app', 'sampah']
#
# === STEMMING ===
# Before: ['driver', 'nya', 'goride', 'comfort', 'nya', 'aduhai', 'jauhnya', 'juara']
# After:  ['driver', 'nya', 'goride', 'comfort', 'nya', 'aduhai', 'jauh', 'juara']
#
# === STEMMING ===
# Before: ['bintang', 'bintang', 'rutenya', 'sinting', 'dibikin', 'muter', 'muter', 'kemarin', 'goride', 'go', 'bluebird', 'rute', 'buang', 'buang', 'uang', 'konsumen']
# After:  ['bintang', 'bintang', 'rute', 'sinting', 'bikin', 'muter', 'muter', 'kemarin', 'goride', 'go', 'bluebird', 'rute', 'buang', 'buang', 'uang', 'konsumen']
#
# === STEMMING ===
# Before: ['njemput', 'cepat', 'sopirannya', 'enak', 'tenang', 'sopirnya', 'sopan', 'ramsh', 'rute', 'nya', 'langsing', 'tujuan', 'dlsb']
# After:  ['njemput', 'cepat', 'sopir', 'enak', 'tenang', 'sopir', 'sopan', 'ramsh', 'rute', 'nya', 'langsing', 'tuju', 'dlsb']
#
# === STEMMING ===
# Before: ['top', 'markotop']
# After:  ['top', 'markotop']
#
# === STEMMING ===
# Before: ['membantu', 'semoga', 'voucher', 'goride', 'gofood']
# After:  ['bantu', 'moga', 'voucher', 'goride', 'gofood']
#
# === STEMMING ===
# Before: ['mesen', 'goride', 'or', 'gocar', 'slalu', 'milih', 'peta', 'manual', 'simpen', 'lokasi', 'favorit', 'mencari', 'manual', 'menyusahkan']
# After:  ['mesen', 'goride', 'or', 'gocar', 'slalu', 'milih', 'peta', 'manual', 'simpen', 'lokasi', 'favorit', 'cari', 'manual', 'susah']
#
# === STEMMING ===
# Before: ['mrasa', 'adil', 'tmn', 'otomatis', 'voucher', 'promo', 'goride', 'gd', 'sm', 'ishh', 'dimasukin', 'kode', 'sgala', 'hargany', 'nromal']
# After:  ['mrasa', 'adil', 'tmn', 'otomatis', 'voucher', 'promo', 'goride', 'gd', 'sm', 'ishh', 'dimasukin', 'kode', 'sgala', 'hargany', 'nromal']
#
# === STEMMING ===
# Before: ['goridenya', 'bagus', 'gofoodnya', 'bermasalah', 'driver', 'menunggu', 'jam', 'driver', 'makanan', 'driver', 'g', 'kasian', 'restonya', 'makananya']
# After:  ['goridenya', 'bagus', 'gofoodnya', 'masalah', 'driver', 'tunggu', 'jam', 'driver', 'makan', 'driver', 'g', 'kasi', 'restonya', 'makananya']
#
# === STEMMING ===
# Before: ['susah', 'iya', 'pesan', 'gojek', 'goride', 'gocar', 'buka', 'aplikasi', 'pakai', 'indrive', 'cpt', 'banget', 'peningkatan', 'kemunduran', 'sori', 'udate', 'review', 'jujur', 'iya', 'gojek', 'ketinggalan', 'ma']
# After:  ['susah', 'iya', 'pesan', 'gojek', 'goride', 'gocar', 'buka', 'aplikasi', 'pakai', 'indrive', 'cpt', 'banget', 'tingkat', 'mundur', 'sori', 'udate', 'review', 'jujur', 'iya', 'gojek', 'tinggal', 'ma']
#
# === STEMMING ===
# Before: ['gojek', 'sih', 'pesan', 'goride', 'tulisannya', 'pakai', 'metode', 'metode']
# After:  ['gojek', 'sih', 'pesan', 'goride', 'tulis', 'pakai', 'metode', 'metode']
#
# === STEMMING ===
# Before: ['senang', 'belanja', 'gomart', 'pas', 'promo']
# After:  ['senang', 'belanja', 'gomart', 'pas', 'promo']
#
# === STEMMING ===
# Before: ['semangaat', 'pagii', 'pejuang', 'keluarga', 'cerita', 'kekecewaan', 'pakai', 'gojek', 'pesan', 'goride', 'banget', 'driver', 'driver', 'posisi', 'nya', 'banget', 'lihat', 'sekitr', 'driver', 'rekan', 'driver', 'orderan', 'menunggu', 'beralihlah', 'grabbike', 'menit', 'driver', 'driver']
# After:  ['semangaat', 'pagi', 'juang', 'keluarga', 'cerita', 'kecewa', 'pakai', 'gojek', 'pesan', 'goride', 'banget', 'driver', 'driver', 'posisi', 'nya', 'banget', 'lihat', 'sekitr', 'driver', 'rekan', 'driver', 'order', 'tunggu', 'alih', 'grabbike', 'menit', 'driver', 'driver']
#
# === STEMMING ===
# Before: ['diskon']
# After:  ['diskon']
#
# === STEMMING ===
# Before: ['woi', 'pakai', 'goride', 'plus', 'titik', 'jemputnya', 'ngaco', 'pakai', 'plus']
# After:  ['woi', 'pakai', 'goride', 'plus', 'titik', 'jemput', 'ngaco', 'pakai', 'plus']
#
# === STEMMING ===
# Before: ['mantab']
# After:  ['mantab']
#
# === STEMMING ===
# Before: ['mengambil', 'orderan', 'go', 'ride', 'pakai', 'diskon', 'ribu']
# After:  ['ambil', 'order', 'go', 'ride', 'pakai', 'diskon', 'ribu']
#
# === STEMMING ===
# Before: ['berguna', 'bett', 'sumpah']
# After:  ['guna', 'bett', 'sumpah']
#
# === STEMMING ===
# Before: ['hallo', 'gojek', 'pengguna', 'gojek', 'senang', 'app', 'voucher', 'goride', 'murah', 'terimakasih', 'gojek', 'jasa', 'jasa', 'mu', 'terima', 'kasih']
# After:  ['hallo', 'gojek', 'guna', 'gojek', 'senang', 'app', 'voucher', 'goride', 'murah', 'terimakasih', 'gojek', 'jasa', 'jasa', 'mu', 'terima', 'kasih']
#
# === STEMMING ===
# Before: ['i', 'love', 'gojek', 'so', 'much', 'klu', 'voucher', 'berlaku', 'voucher', 'go', 'ride', 'nya', 'lumayan', 'voucher', 'voucher', 'go', 'car', 'voucher', 'masak', 'wira', 'wiri', 'kecuali', 'klu', 'asrama', 'anak', 'pakaikan', 'voucher', 'tlg', 'dunk', 'it', 'klu', 'suruh', 'marketing', 'buatin', 'program', 'absurd']
# After:  ['i', 'love', 'gojek', 'so', 'much', 'klu', 'voucher', 'laku', 'voucher', 'go', 'ride', 'nya', 'lumayan', 'voucher', 'voucher', 'go', 'car', 'voucher', 'masak', 'wira', 'wiri', 'kecuali', 'klu', 'asrama', 'anak', 'pakai', 'voucher', 'tlg', 'dunk', 'it', 'klu', 'suruh', 'marketing', 'buatin', 'program', 'absurd']
#
# === STEMMING ===
# Before: ['gojek', 'blunder', 'customer', 'pesan', 'go', 'ride', 'prioritas', 'driver', 'prioritas', 'dapatnya', 'driver', 'prioritas', 'kena', 'biaya', 'tambahan', 'customer', 'pindah', 'aplikasi', 'kocak', 'driver', 'suspen', 'gara', 'gara', 'nglewatin', 'order', 'orang', 'kantor', 'gojek', 'salah', 'penjemputan', 'kebijakan', 'suspen', 'castamer', 'susah', 'driver']
# After:  ['gojek', 'blunder', 'customer', 'pesan', 'go', 'ride', 'prioritas', 'driver', 'prioritas', 'dapat', 'driver', 'prioritas', 'kena', 'biaya', 'tambah', 'customer', 'pindah', 'aplikasi', 'kocak', 'driver', 'suspen', 'gara', 'gara', 'nglewatin', 'order', 'orang', 'kantor', 'gojek', 'salah', 'jemput', 'bijak', 'suspen', 'castamer', 'susah', 'driver']
#
# === STEMMING ===
# Before: ['layanan', 'buruk', 'pas', 'hujan', 'driver', 'car', 'ambil', 'servernya', 'gojek', 'melempar', 'pesanan', 'pas', 'hujan', 'driver', 'batal', 'pas', 'banget', 'kadang', 'goride', 'buruk', 'layanan', 'gojek']
# After:  ['layan', 'buruk', 'pas', 'hujan', 'driver', 'car', 'ambil', 'servernya', 'gojek', 'lempar', 'pesan', 'pas', 'hujan', 'driver', 'batal', 'pas', 'banget', 'kadang', 'goride', 'buruk', 'layan', 'gojek']
#
# === STEMMING ===
# Before: ['membantu', 'membutuhkan']
# After:  ['bantu', 'butuh']
#
# Hasil setelah stemming:
#                                      after_stopwords  \
# 0  [matikan, fitur, order, ganda, pemesanan, gori...
# 1  [tolong, iya, pleease, customer, pesan, gibrid...
# 2  [harap, update, kedepanya, pesan, go, food, mu...
#
#                                           after_stem
# 0  [mati, fitur, order, ganda, mesan, goride, ord...
# 1  [tolong, iya, pleease, customer, pesan, gibrid...
# 2  [harap, update, depa, pesan, go, food, muncul,...

# %%
# Langkah 7: Rejoin Tokens
print("\n=== Langkah 7: Rejoin Tokens ===")
def rejoin_tokens(tokens):
    """Menggabungkan token kembali menjadi teks"""
    if isinstance(tokens, str):  # Handle case if input is string
        return tokens
    before = tokens.copy()
    after = ' '.join(tokens)
    print_step("Rejoin Tokens", before, after)
    return after

df['clean_text'] = df['after_stem'].apply(rejoin_tokens)
print("\nHasil final:")
df[['ulasan', 'clean_text']].head(10)
# Out:
# === Langkah 7: Rejoin Tokens ===
#
# === REJOIN TOKENS ===
# Before: ['mati', 'fitur', 'order', 'ganda', 'mesan', 'goride', 'order', 'goride', 'order', 'goride', 'batal', 'pesan']
# After:  mati fitur order ganda mesan goride order goride order goride batal pesan
#
# === REJOIN TOKENS ===
# Before: ['tolong', 'iya', 'pleease', 'customer', 'pesan', 'gibride', 'tolong', 'jempol', 'dikit', 'cansel', 'dikit', 'cansel', 'atus', 'ratus', 'kali', 'cansel', 'pengaruh', 'ngefek', 'kitw', 'driver', 'kena', 'ampas', 'aplikator', 'bayar', 'tarif', 'nya', 'super', 'mahal', 'dibpitong', 'gede', 'super', 'gede', 'potong', 'tolong', 'kasihan', 'iya', 'driver', 'ojol']
# After:  tolong iya pleease customer pesan gibride tolong jempol dikit cansel dikit cansel atus ratus kali cansel pengaruh ngefek kitw driver kena ampas aplikator bayar tarif nya super mahal dibpitong gede super gede potong tolong kasihan iya driver ojol
#
# === REJOIN TOKENS ===
# Before: ['harap', 'update', 'depa', 'pesan', 'go', 'food', 'muncul', 'notifikasi', 'go', 'ride', 'muncul']
# After:  harap update depa pesan go food muncul notifikasi go ride muncul
#
# === REJOIN TOKENS ===
# Before: ['buat', 'tinggal', 'kota', 'aplikasi', 'cpat', 'dpat', 'driver', 'pesan', 'goride', 'pesan', 'gofood', 'tunggu', 'pakai', 'kendara', 'driver', 'nya', 'oke', 'drivernya', 'sopan', 'sukses', 'gojek']
# After:  buat tinggal kota aplikasi cpat dpat driver pesan goride pesan gofood tunggu pakai kendara driver nya oke drivernya sopan sukses gojek
#
# === REJOIN TOKENS ===
# Before: ['layan', 'goride', 'bantu', 'aktifitas', 'hari', 'motor', 'baik', 'bengkel', 'masuk', 'nya', 'mgkin', 'cuma', 'cuaca', 'hujan', 'situasi', 'urgent', 'butuh', 'transport', 'driver', 'nya']
# After:  layan goride bantu aktifitas hari motor baik bengkel masuk nya mgkin cuma cuaca hujan situasi urgent butuh transport driver nya
#
# === REJOIN TOKENS ===
# Before: ['gojek', 'iya', 'pakai', 'akun', 'suka', 'voucher', 'voucher', 'goride', 'gilir', 'alih', 'gocar', 'voucher', 'pas', 'gilir', 'buka', 'voucher', 'voucher', 'bug', 'tolong', 'baik', 'lah']
# After:  gojek iya pakai akun suka voucher voucher goride gilir alih gocar voucher pas gilir buka voucher voucher bug tolong baik lah
#
# === REJOIN TOKENS ===
# Before: ['terima', 'rider', 'seleksi', 'gojek', 'rider', 'nya', 'emosi', 'melulu']
# After:  terima rider seleksi gojek rider nya emosi melulu
#
# === REJOIN TOKENS ===
# Before: ['gojek', 'mahal', 'pakai', 'voucher', 'jalan', 'harga', 'pakai', 'voucher', 'go', 'ride', 'pot', 'rb', 'alhasil', 'alih', 'ojol', 'belah']
# After:  gojek mahal pakai voucher jalan harga pakai voucher go ride pot rb alhasil alih ojol belah
#
# === REJOIN TOKENS ===
# Before: ['cepat', 'murah']
# After:  cepat murah
#
# === REJOIN TOKENS ===
# Before: ['keren', 'murah']
# After:  keren murah
#
# === REJOIN TOKENS ===
# Before: ['drivernya', 'alesan', 'bilang', 'bawa', 'helm', 'ambil', 'pesan', 'goride', 'pas', 'batal', 'dia', 'dia', 'ambil', 'helm', 'knapa', 'batal', 'takut', 'poin', 'turun', 'ambil', 'pesan', 'ngajak', 'ribut', 'ajar']
# After:  drivernya alesan bilang bawa helm ambil pesan goride pas batal dia dia ambil helm knapa batal takut poin turun ambil pesan ngajak ribut ajar
#
# === REJOIN TOKENS ===
# Before: ['rumah', 'beda', 'hp', 'ee', 'pesan', 'go', 'ride', 'dng', 'ttik', 'tuju', 'nominal', 'beda', 'sya', 'kena', 'pakai', 'hp', 'ponakan', 'tunai', 'gofood', 'klu', 'py', 'mehongg', 'rumah', 'lho', 'setia', 'pakai', 'gojeck', 'order', 'makan']
# After:  rumah beda hp ee pesan go ride dng ttik tuju nominal beda sya kena pakai hp ponakan tunai gofood klu py mehongg rumah lho setia pakai gojeck order makan
#
# === REJOIN TOKENS ===
# Before: ['drivernya', 'kemudi', 'kendara', 'aman', 'nyaman', 'terimakasih']
# After:  drivernya kemudi kendara aman nyaman terimakasih
#
# === REJOIN TOKENS ===
# Before: ['ok']
# After:  ok
#
# === REJOIN TOKENS ===
# Before: ['senang']
# After:  senang
#
# === REJOIN TOKENS ===
# Before: ['aplikasi', 'sih', 'bagus', 'januari', 'pesan', 'gocar', 'kali', 'goride', 'kali', 'nyantol', 'server', 'sibuk', 'cuaca', 'gerimis', 'pusat', 'kota', 'purwokerto', 'susah', 'butuh']
# After:  aplikasi sih bagus januari pesan gocar kali goride kali nyantol server sibuk cuaca gerimis pusat kota purwokerto susah butuh
#
# === REJOIN TOKENS ===
# Before: ['gila', 'order', 'goride', 'tunggu', 'l', 'banget', 'dspet', 'driver', 'driver', 'kumpul', 'malam', 'kerja', 'capek', 'terima', 'kasih', 'gojek', 'langgan', 'aagi']
# After:  gila order goride tunggu l banget dspet driver driver kumpul malam kerja capek terima kasih gojek langgan aagi
#
# === REJOIN TOKENS ===
# Before: []
# After:
#
# === REJOIN TOKENS ===
# Before: ['driver', 'pesan', 'goride', 'buru', 'kerja', 'pecat', 'pesan', 'gosend', 'menit', 'jarak', 'kilo', 'kasihan', 'drivernya']
# After:  driver pesan goride buru kerja pecat pesan gosend menit jarak kilo kasihan drivernya
#
# === REJOIN TOKENS ===
# Before: ['the', 'best', 'apps', 'for', 'ride']
# After:  the best apps for ride
#
# === REJOIN TOKENS ===
# Before: ['alhamdulillah', 'pas', 'pakai', 'goride', 'supirnya', 'bagus', 'sopan']
# After:  alhamdulillah pas pakai goride supirnya bagus sopan
#
# === REJOIN TOKENS ===
# Before: ['mantap']
# After:  mantap
#
# === REJOIN TOKENS ===
# Before: ['isi', 'gopay', 'pesan', 'goride', 'tlg', 'bantu', 'terima', 'kasih']
# After:  isi gopay pesan goride tlg bantu terima kasih
#
# === REJOIN TOKENS ===
# Before: ['bantu', 'beraktifitas', 'moga', 'kasih', 'diskon', 'goridenya']
# After:  bantu beraktifitas moga kasih diskon goridenya
#
# === REJOIN TOKENS ===
# Before: ['gojek', 'tunggu', 'goride', 'jamm', 'kacau', 'ah', 'tampung', 'keluh', 'ehh', 'baik', 'parah', 'tunggu', 'menit', 'depan', 'drivernya', 'ambil', 'tolong', 'perlu']
# After:  gojek tunggu goride jamm kacau ah tampung keluh ehh baik parah tunggu menit depan drivernya ambil tolong perlu
#
# === REJOIN TOKENS ===
# Before: ['ramah', 'percaya']
# After:  ramah percaya
#
# === REJOIN TOKENS ===
# Before: ['cuma', 'kadang', 'go', 'ride', 'banget']
# After:  cuma kadang go ride banget
#
# === REJOIN TOKENS ===
# Before: ['bagus']
# After:  bagus
#
# === REJOIN TOKENS ===
# Before: ['up', 'gopay', 'plus', 'pikir', 'voucher', 'goride', 'biar', 'murah', 'tau', 'pakai']
# After:  up gopay plus pikir voucher goride biar murah tau pakai
#
# === REJOIN TOKENS ===
# Before: ['mantaf']
# After:  mantaf
#
# === REJOIN TOKENS ===
# Before: ['kayak', 'pakai', 'gocar', 'goride', 'layan', 'hemat', 'deh', 'x', 'dipake', 'alas', 'driver']
# After:  kayak pakai gocar goride layan hemat deh x dipake alas driver
#
# === REJOIN TOKENS ===
# Before: ['terima', 'kasih', 'gojek', 'fitur', 'pohon', 'tanam', 'ribu', 'rupiah', 'fitur', 'guna', 'bagi', 'oksigen']
# After:  terima kasih gojek fitur pohon tanam ribu rupiah fitur guna bagi oksigen
#
# === REJOIN TOKENS ===
# Before: ['bagus']
# After:  bagus
#
# === REJOIN TOKENS ===
# Before: ['bantu']
# After:  bantu
#
# === REJOIN TOKENS ===
# Before: ['drivernya', 'ramah']
# After:  drivernya ramah
#
# === REJOIN TOKENS ===
# Before: ['bagus', 'layan']
# After:  bagus layan
#
# === REJOIN TOKENS ===
# Before: ['gojek', 'puas', 'go', 'ride', 'go', 'car', 'nya', 'the', 'best']
# After:  gojek puas go ride go car nya the best
#
# === REJOIN TOKENS ===
# Before: ['langgan', 'setia', 'goride', 'gocar', 'gofood']
# After:  langgan setia goride gocar gofood
#
# === REJOIN TOKENS ===
# Before: ['bagus', 'pesan', 'goride', 'driver', 'nya', 'salah', 'ambil', 'tumpang', 'chat', 'driver', 'respon']
# After:  bagus pesan goride driver nya salah ambil tumpang chat driver respon
#
# === REJOIN TOKENS ===
# Before: ['maaf', 'pasar', 'polis', 'goride', 'motong', 'akun', 'customer', 'kaya', 'pasar', 'polis', 'akses', 'motong', 'saldo', 'akun', 'customer', 'kali', 'potong', 'pasar', 'polis', 'goride', 'akun', 'customer']
# After:  maaf pasar polis goride motong akun customer kaya pasar polis akses motong saldo akun customer kali potong pasar polis goride akun customer
#
# === REJOIN TOKENS ===
# Before: ['aplikasi', 'tolol', 'pesan', 'goride', 'muncul', 'gocar']
# After:  aplikasi tolol pesan goride muncul gocar
#
# === REJOIN TOKENS ===
# Before: ['tunggu', 'jam', 'goride', 'tulis', 'sibuk', 'beneran', 'sibuk', 'gojek', 'ny', 'aplikasi', 'nya', 'error']
# After:  tunggu jam goride tulis sibuk beneran sibuk gojek ny aplikasi nya error
#
# === REJOIN TOKENS ===
# Before: ['pakai', 'gofood', 'jarang', 'goride', 'gocar', 'trauma', 'kendara', 'kendara', 'celaka', 'masuk', 'promo', 'gofood', 'voucher', 'gratis', 'ongkos', 'kirim', 'potong', 'ongkos', 'kirim', 'driver', 'oren']
# After:  pakai gofood jarang goride gocar trauma kendara kendara celaka masuk promo gofood voucher gratis ongkos kirim potong ongkos kirim driver oren
#
# === REJOIN TOKENS ===
# Before: ['top', 'markotop']
# After:  top markotop
#
# === REJOIN TOKENS ===
# Before: ['jemput', 'promo', 'hemat']
# After:  jemput promo hemat
#
# === REJOIN TOKENS ===
# Before: ['driver', 'goride', 'nya', 'kota', 'depok', 'berangkat', 'kerja', 'lambat', 'kaya', 'aplikasi', 'belah', 'drivernya', 'cepat', 'sekali', 'driver', 'jemput']
# After:  driver goride nya kota depok berangkat kerja lambat kaya aplikasi belah drivernya cepat sekali driver jemput
#
# === REJOIN TOKENS ===
# Before: ['aplikasi', 'pesan', 'goride', 'gambar', 'driver', 'dekat', 'eh', 'nyantol', 'nya', 'jepang', 'saking', 'jauh', 'ongkos', 'kirim', 'nya', 'mahal', 'banget', 'maaf', 'kali', 'pindah', 'apk', 'belah', 'ribet']
# After:  aplikasi pesan goride gambar driver dekat eh nyantol nya jepang saking jauh ongkos kirim nya mahal banget maaf kali pindah apk belah ribet
#
# === REJOIN TOKENS ===
# Before: ['kecewa', 'order', 'gocar', 'pas', 'hujan', 'driver', 'susah', 'terima', 'pesan', 'pakai', 'promo', 'goride', 'alas', 'order', 'ramai']
# After:  kecewa order gocar pas hujan driver susah terima pesan pakai promo goride alas order ramai
#
# === REJOIN TOKENS ===
# Before: ['aplikasi', 'bodoh', 'ambil', 'goride', 'driver', 'bodoh']
# After:  aplikasi bodoh ambil goride driver bodoh
#
# === REJOIN TOKENS ===
# Before: ['gojek', 'buruk', 'cari', 'driver', 'ny', 'padahl', 'batal', 'pesan', 'tunggu', 'menit', 'order', 'hasil', 'bug', 'pesan', 'makan', 'goride']
# After:  gojek buruk cari driver ny padahl batal pesan tunggu menit order hasil bug pesan makan goride
#
# === REJOIN TOKENS ===
# Before: ['mantap', 'pokok', 'mah']
# After:  mantap pokok mah
#
# === REJOIN TOKENS ===
# Before: ['goride', 'gocar', 'lumayan', 'voucernya', 'gofood', 'nya', 'jarang', 'pakai', 'aplikasi', 'murah']
# After:  goride gocar lumayan voucernya gofood nya jarang pakai aplikasi murah
#
# === REJOIN TOKENS ===
# Before: ['mudah']
# After:  mudah
#
# === REJOIN TOKENS ===
# Before: ['nice']
# After:  nice
#
# === REJOIN TOKENS ===
# Before: ['aplikasi', 'tolol', 'persen', 'goride', 'kasih', 'driver', 'keliling', 'ambil', 'korea', 'utara', 'kira', 'menit', 'tunggu', 'menit', 'update', 'lokasi', 'driver']
# After:  aplikasi tolol persen goride kasih driver keliling ambil korea utara kira menit tunggu menit update lokasi driver
#
# === REJOIN TOKENS ===
# Before: ['i', 'love', 'gojek', 'sm', 'berangkat', 'pulang', 'sekolah', 'always', 'make', 'gojek', 'gojek', 'fitur', 'goride', 'comfort', 'cocok', 'banget', 'suka', 'bawa', 'barang', 'seko', 'suka', 'bawa', 'tas', 'gede', 'deh', 'kaki', 'nya', 'pnttnya', 'gel', 'jaya', 'deh', 'yaa', 'gojek']
# After:  i love gojek sm berangkat pulang sekolah always make gojek gojek fitur goride comfort cocok banget suka bawa barang seko suka bawa tas gede deh kaki nya pnttnya gel jaya deh yaa gojek
#
# === REJOIN TOKENS ===
# Before: ['go', 'ride', 'ubah', 'go', 'car', 'mahal', 'ongkos']
# After:  go ride ubah go car mahal ongkos
#
# === REJOIN TOKENS ===
# Before: ['good']
# After:  good
#
# === REJOIN TOKENS ===
# Before: ['go', 'transit', 'gabung', 'go', 'ridetransit', 'edit', 'stasiun', 'tuju', 'ubah', 'sblum', 'update', 'diupdate', 'nyusahin', 'gausah', 'update', 'tuju', 'update', 'mudah', 'sulit']
# After:  go transit gabung go ridetransit edit stasiun tuju ubah sblum update diupdate nyusahin gausah update tuju update mudah sulit
#
# === REJOIN TOKENS ===
# Before: ['layan', 'nya', 'aplikasi', 'belah', 'pilih']
# After:  layan nya aplikasi belah pilih
#
# === REJOIN TOKENS ===
# Before: ['mantap']
# After:  mantap
#
# === REJOIN TOKENS ===
# Before: ['pakai', 'aplikasi', 'bingung', 'pas', 'check', 'goride', 'harga', 'rb', 'rb', 'eh', 'iseng', 'buka', 'grab', 'cuma', 'bayar', 'rb']
# After:  pakai aplikasi bingung pas check goride harga rb rb eh iseng buka grab cuma bayar rb
#
# === REJOIN TOKENS ===
# Before: ['susah', 'driver', 'x', 'pesan', 'tetep', 'pindah', 'menu', 'go', 'ride', 'go', 'car', 'cmn', 'hasilny', 'nihil', 'parah', 'sih']
# After:  susah driver x pesan tetep pindah menu go ride go car cmn hasilny nihil parah sih
#
# === REJOIN TOKENS ===
# Before: ['suka', 'pakai', 'jasa', 'goride', 'gocar', 'neng', 'denger', 'curhatan', 'cerita', 'keluh', 'kesah', 'cerita', 'sedih', 'cerita', 'bahagia', 'rangkum', 'motivasi']
# After:  suka pakai jasa goride gocar neng denger curhatan cerita keluh kesah cerita sedih cerita bahagia rangkum motivasi
#
# === REJOIN TOKENS ===
# Before: ['ok']
# After:  ok
#
# === REJOIN TOKENS ===
# Before: ['milih', 'go', 'transit', 'alih', 'go', 'ride']
# After:  milih go transit alih go ride
#
# === REJOIN TOKENS ===
# Before: ['i', 'got', 'safety', 'when', 'i', 'was', 'ride', 'gojek']
# After:  i got safety when i was ride gojek
#
# === REJOIN TOKENS ===
# Before: ['goride', 'mudah']
# After:  goride mudah
#
# === REJOIN TOKENS ===
# Before: ['masuk', 'kode', 'promo', 'goride', 'sukses', 'vocer', 'promonya', 'gada', 'cba', 'update', 'masin', 'sma', 'hpus', 'download', 'bbrapa', 'kli', 'iya', 'eror', 'cba', 'teman', 'mah', 'gada']
# After:  masuk kode promo goride sukses vocer promonya gada cba update masin sma hpus download bbrapa kli iya eror cba teman mah gada
#
# === REJOIN TOKENS ===
# Before: ['pesan', 'goride', 'posisi', 'driver', 'ambil', 'kasih', 'jarak', 'sbagian', 'batal', 'drivernya']
# After:  pesan goride posisi driver ambil kasih jarak sbagian batal drivernya
#
# === REJOIN TOKENS ===
# Before: ['mohon', 'gojek', 'bela', 'pulang', 'goride', 'laku', 'senang', 'bantal', 'pesan', 'titik', 'jemput', 'sesuai', 'datang', 'driver', 'driver', 'marah', 'orang', 'situ', 'malu', 'mohon', 'bantu', 'tegur', 'driver']
# After:  mohon gojek bela pulang goride laku senang bantal pesan titik jemput sesuai datang driver driver marah orang situ malu mohon bantu tegur driver
#
# === REJOIN TOKENS ===
# Before: ['layan', 'mudah', 'masyarakat']
# After:  layan mudah masyarakat
#
# === REJOIN TOKENS ===
# Before: ['tolong', 'goride', 'pisah', 'hemat', 'comfort', 'perhati', 'gojek', 'alam', 'pesan', 'comfort', 'motor', 'beda', 'plat', 'nomor', 'beda', 'jenis', 'masuk', 'kategori', 'hemat', 'tolong', 'perhati', 'khusus', 'driver', 'goride', 'nya', 'selamat', 'atas']
# After:  tolong goride pisah hemat comfort perhati gojek alam pesan comfort motor beda plat nomor beda jenis masuk kategori hemat tolong perhati khusus driver goride nya selamat atas
#
# === REJOIN TOKENS ===
# Before: ['ok']
# After:  ok
#
# === REJOIN TOKENS ===
# Before: ['bantu', 'goride', 'gocar', 'gofood']
# After:  bantu goride gocar gofood
#
# === REJOIN TOKENS ===
# Before: ['gofood', 'nya', 'kecewa', 'tunggu', 'jam', 'dibatalin', 'alas', 'gada', 'driver', 'niat', 'bisnis', 'tutup', 'aplikasi', 'pesan', 'goride', 'lain', 'drivernya', 'gada', 'driver', 'sekitar', 'lokasi', 'banget', 'aplikasi']
# After:  gofood nya kecewa tunggu jam dibatalin alas gada driver niat bisnis tutup aplikasi pesan goride lain drivernya gada driver sekitar lokasi banget aplikasi
#
# === REJOIN TOKENS ===
# Before: ['voucher', 'goride', 'jompor', 'pakai', 'goride', 'pulang', 'pergi', 'rb', 'gaperna', 'voucher', 'goride']
# After:  voucher goride jompor pakai goride pulang pergi rb gaperna voucher goride
#
# === REJOIN TOKENS ===
# Before: ['verygood']
# After:  verygood
#
# === REJOIN TOKENS ===
# Before: ['transaksi', 'gojek', 'toped', 'blibli', 'alfagift', 'gopaylaternya', 'tulis', 'blokir', 'limit', 'aman', 'tagih', 'japo', 'pakai', 'goride', 'gocar']
# After:  transaksi gojek toped blibli alfagift gopaylaternya tulis blokir limit aman tagih japo pakai goride gocar
#
# === REJOIN TOKENS ===
# Before: ['order', 'goride', 'tunggu', 'drivernya', 'susah', 'batalin', 'aplikasi', 'tetangga']
# After:  order goride tunggu drivernya susah batalin aplikasi tetangga
#
# === REJOIN TOKENS ===
# Before: ['bayar', 'tagih', 'gopay', 'later', 'aplikasi', 'ganggu', 'order', 'goride', 'gocar', 'sring', 'driver', 'tulis', 'driver', 'nya', 'bnyak', 'trlihat', 'aplikasi', 'gojek', 'mkin', 'buruk', 'aplikasi', 'kyknya', 'baik', 'cepat']
# After:  bayar tagih gopay later aplikasi ganggu order goride gocar sring driver tulis driver nya bnyak trlihat aplikasi gojek mkin buruk aplikasi kyknya baik cepat
#
# === REJOIN TOKENS ===
# Before: ['pakai', 'gojek', 'mesen', 'makan', 'goride', 'tetep', 'detik', 'buka', 'gopaylater', 'gopinjam', 'nya', 'kalah', 'daftar', 'order', 'langsung', 'limit', 'gopaylater', 'anehh', 'banget', 'lumayan', 'kecewa', 'si', 'aplikasi', 'adil']
# After:  pakai gojek mesen makan goride tetep detik buka gopaylater gopinjam nya kalah daftar order langsung limit gopaylater anehh banget lumayan kecewa si aplikasi adil
#
# === REJOIN TOKENS ===
# Before: ['langgan', 'goride', 'gosend', 'kecewa', 'go', 'car', 'jogja', 'niat', 'iya', 'milih', 'acak', 'aplikasi', 'dikit', 'dicancel', 'cm', 'jemput', 'jarak', 'anter', 'moga', 'gojek', 'sortir', 'driver', 'gocar', 'iseng', 'males', 'an', 'tertawa', 'kacau']
# After:  langgan goride gosend kecewa go car jogja niat iya milih acak aplikasi dikit dicancel cm jemput jarak anter moga gojek sortir driver gocar iseng males an tertawa kacau
#
# === REJOIN TOKENS ===
# Before: ['tolong', 'pesan', 'goride', 'gocar', 'cari', 'driver', 'lokasi', 'titik', 'jemput', 'banget', 'driver', 'jarak', 'driver', 'mangkal', 'lokasi', 'jemput', 'bangett', 'tolong', 'baik', 'buang', 'tunggu', 'driver', 'datengnya', 'jarak']
# After:  tolong pesan goride gocar cari driver lokasi titik jemput banget driver jarak driver mangkal lokasi jemput bangett tolong baik buang tunggu driver datengnya jarak
#
# === REJOIN TOKENS ===
# Before: ['car', 'ride', 'food', 'keren']
# After:  car ride food keren
#
# === REJOIN TOKENS ===
# Before: ['suka', 'gojek', 'kadang', 'pakai', 'go', 'ride', 'hemat', 'terima', 'driver', 'ringan', 'keluar', 'tanggal', 'tua', 'pagi', 'susah', 'ampun', 'sekali', 'jarak', 'menit', 'bilang', 'jauh', 'males', 'lokasi', 'tuju', 'situ', 'jemput', 'bulak']
# After:  suka gojek kadang pakai go ride hemat terima driver ringan keluar tanggal tua pagi susah ampun sekali jarak menit bilang jauh males lokasi tuju situ jemput bulak
#
# === REJOIN TOKENS ===
# Before: ['kecewa', 'driver', 'goride', 'hujan', 'ambil', 'order', 'alas', 'bawa', 'jas', 'hujan', 'chat', 'bawa', 'jas', 'hujan', 'ngojek', 'sedia', 'jas', 'hujan']
# After:  kecewa driver goride hujan ambil order alas bawa jas hujan chat bawa jas hujan ngojek sedia jas hujan
#
# === REJOIN TOKENS ===
# Before: ['mahal', 'goride', 'gofood']
# After:  mahal goride gofood
#
# === REJOIN TOKENS ===
# Before: ['gampang', 'cari', 'alamat', 'enak']
# After:  gampang cari alamat enak
#
# === REJOIN TOKENS ===
# Before: ['fitur', 'go', 'pay', 'later', 'go', 'pay', 'pinjam', 'non', 'aktif', 'kaya', 'aplikasi', 'pinjol', 'rawan', 'penyalahgunaan', 'ridernya', 'neng', 'banget', 'batalin', 'tunggu', 'kaya', 'belah']
# After:  fitur go pay later go pay pinjam non aktif kaya aplikasi pinjol rawan penyalahgunaan ridernya neng banget batalin tunggu kaya belah
#
# === REJOIN TOKENS ===
# Before: ['mengunakan', 'gojek', 'benah', 'driver', 'beda', 'aplikasi', 'orang', 'driver', 'pakai', 'akun', 'driver', 'gojek', 'joki', 'antar', 'pesan', 'takut', 'makan', 'apin', 'orang', 'driver', 'gojek', 'joki', 'motor', 'pakai', 'joki', 'plat', 'nya', 'beda', 'aplikasi', 'pesan', 'goride', 'sih', 'driver', 'jemput', 'orang', 'beda', 'aplikasi', 'plat', 'nomor', 'motor', 'nya', 'beda', 'was', 'was', 'takut', 'tolong', 'adakan', 'vermuk', 'waktu', 'grab']
# After:  mengunakan gojek benah driver beda aplikasi orang driver pakai akun driver gojek joki antar pesan takut makan apin orang driver gojek joki motor pakai joki plat nya beda aplikasi pesan goride sih driver jemput orang beda aplikasi plat nomor motor nya beda was was takut tolong adakan vermuk waktu grab
#
# === REJOIN TOKENS ===
# Before: ['order', 'goride', 'kendala', 'terang', 'internetnya', 'mati', 'padhal', 'kuota', 'melimpahh', 'coba', 'cek', 'gojek', 'adek', 'mesen', 'punya', 'biasane', 'pakai', 'tolong', 'baik']
# After:  order goride kendala terang internetnya mati padhal kuota melimpahh coba cek gojek adek mesen punya biasane pakai tolong baik
#
# === REJOIN TOKENS ===
# Before: ['woi', 'harga', 'goride', 'nya', 'nambah', 'nya', 'gara', 'gara', 'cuaca', 'panas', 'hujan', 'hujan', 'ok', 'ngotak', 'kali', 'njir', 'oh', 'kualitas', 'nya', 'bikin', 'nambah', 'asa', 'deh', 'hemat', 'comfort', 'hoki', 'an', 'lihat', 'maxim', 'iya', 'murah', 'nomor', 'diskon', 'tarik', 'segitu']
# After:  woi harga goride nya nambah nya gara gara cuaca panas hujan hujan ok ngotak kali njir oh kualitas nya bikin nambah asa deh hemat comfort hoki an lihat maxim iya murah nomor diskon tarik segitu
#
# === REJOIN TOKENS ===
# Before: ['thank', 'you']
# After:  thank you
#
# === REJOIN TOKENS ===
# Before: ['ok', 'cepat']
# After:  ok cepat
#
# === REJOIN TOKENS ===
# Before: ['dc', 'nya', 'suka', 'ngancam']
# After:  dc nya suka ngancam
#
# === REJOIN TOKENS ===
# Before: ['jasa', 'biaya', 'gojek', 'nya', 'mahal', 'pesan', 'go', 'food', 'go', 'ride', 'lain', 'kena', 'double', 'order', 'custumer', 'rugi', 'rugi', 'bayar', 'mahal', 'rugi', 'tunggu', 'gojek']
# After:  jasa biaya gojek nya mahal pesan go food go ride lain kena double order custumer rugi rugi bayar mahal rugi tunggu gojek
#
# === REJOIN TOKENS ===
# Before: ['terimakasih']
# After:  terimakasih
#
# === REJOIN TOKENS ===
# Before: ['banyakin', 'promonya', 'goride', 'and', 'gofood']
# After:  banyakin promonya goride and gofood
#
# === REJOIN TOKENS ===
# Before: ['akun', 'blokir', 'tolong', 'solusi', 'ngechat', 'cs', 'responnya', 'lapor', 'tutup', 'solusi', 'terang', 'blokir', 'voucher', 'goride', 'gofood', 'tolong', 'biar', 'normal']
# After:  akun blokir tolong solusi ngechat cs responnya lapor tutup solusi terang blokir voucher goride gofood tolong biar normal
#
# === REJOIN TOKENS ===
# Before: ['bagus', 'tolong', 'promo', 'gocar', 'goride', 'comfort', 'nikmat', 'jalan', 'hemat', 'nyaman', 'terima', 'kasih']
# After:  bagus tolong promo gocar goride comfort nikmat jalan hemat nyaman terima kasih
#
# === REJOIN TOKENS ===
# Before: ['gilaa', 'saldo', 'hilang', 'gtu', 'call', 'center', 'ngebantu', 'banget', 'order', 'goride', 'gadapet', 'kali', 'saldo', 'tarik', 'nya', 'in', 'gojek']
# After:  gilaa saldo hilang gtu call center ngebantu banget order goride gadapet kali saldo tarik nya in gojek
#
# === REJOIN TOKENS ===
# Before: ['kemarin', 'siang', 'pesan', 'goride', 'pakai', 'gopaylater', 'pas', 'malam', 'gopaylater', 'blokir', 'tagih', 'jatuh', 'tempo', 'limit', 'lapor', 'tanggap', 'kecewa']
# After:  kemarin siang pesan goride pakai gopaylater pas malam gopaylater blokir tagih jatuh tempo limit lapor tanggap kecewa
#
# === REJOIN TOKENS ===
# Before: ['tukar', 'voucher', 'gorideaja', 'tukar', 'bilang', 'hasil', 'cek', 'halaman', 'voucher', 'voucher', 'nya', 'kosongg']
# After:  tukar voucher gorideaja tukar bilang hasil cek halaman voucher voucher nya kosongg
#
# === REJOIN TOKENS ===
# Before: ['bantu']
# After:  bantu
#
# === REJOIN TOKENS ===
# Before: ['keren', 'gojek', 'driver', 'nya', 'cepat', 'cepat', 'tunggu', 'vocher', 'diskon', 'goride', 'gocar', 'gofood', 'tolong', 'vocher', 'goride', 'nya', 'bantu', 'anak', 'sekolah', 'promo', 'murah', 'bawah', 'ribu']
# After:  keren gojek driver nya cepat cepat tunggu vocher diskon goride gocar gofood tolong vocher goride nya bantu anak sekolah promo murah bawah ribu
#
# === REJOIN TOKENS ===
# Before: ['gojek', 'jalan']
# After:  gojek jalan
#
# === REJOIN TOKENS ===
# Before: ['map', 'goride', 'tol', 'arah', 'tol', 'tarif', 'sesuai', 'terima', 'kasih']
# After:  map goride tol arah tol tarif sesuai terima kasih
#
# === REJOIN TOKENS ===
# Before: ['driver', 'go', 'ride', 'min', 'sayang', 'order', 'susah', 'bensin', 'x', 'keluar', 'akal', 'beli', 'cuma', 'rb', 'rugi', 'system', 'dekat', 'terap', 'system', 'goride', 'dekat', 'terap', 'otomatis', 'dapat', 'kurang', 'drastis', 'costumer', 'gojek', 'bantu', 'order', 'belanja', 'tokopedia', 'moga', 'system', 'update', 'baru', 'dapat', 'konsisten', 'atas', 'amin']
# After:  driver go ride min sayang order susah bensin x keluar akal beli cuma rb rugi system dekat terap system goride dekat terap otomatis dapat kurang drastis costumer gojek bantu order belanja tokopedia moga system update baru dapat konsisten atas amin
#
# === REJOIN TOKENS ===
# Before: ['ajar', 'turun', 'tarif', 'go', 'ride', 'kaum', 'missqueen']
# After:  ajar turun tarif go ride kaum missqueen
#
# === REJOIN TOKENS ===
# Before: ['good']
# After:  good
#
# === REJOIN TOKENS ===
# Before: ['pakai', 'aplikasi', 'gojek', 'puas', 'kesini', 'sering', 'kecewa', 'order', 'makan', 'susah', 'driver', 'nya', 'tunggu', 'jam', 'goride', 'mohon', 'perhati', 'ditindaklanjuti', 'depan']
# After:  pakai aplikasi gojek puas kesini sering kecewa order makan susah driver nya tunggu jam goride mohon perhati ditindaklanjuti depan
#
# === REJOIN TOKENS ===
# Before: ['program', 'bagus', 'tahan', 'tingkat', 'layan', 'tolong', 'sejahtera', 'driver', 'driver', 'nya', 'hidup', 'layak']
# After:  program bagus tahan tingkat layan tolong sejahtera driver driver nya hidup layak
#
# === REJOIN TOKENS ===
# Before: ['bantu']
# After:  bantu
#
# === REJOIN TOKENS ===
# Before: ['go', 'ride', 'layan', 'pas', 'hujan', 'gerimis', 'jam', 'order', 'nyangkut', 'harap', 'sm', 'gojek', 'nyampe', 'kantor', 'lambat']
# After:  go ride layan pas hujan gerimis jam order nyangkut harap sm gojek nyampe kantor lambat
#
# === REJOIN TOKENS ===
# Before: ['mantap']
# After:  mantap
#
# === REJOIN TOKENS ===
# Before: ['mudah', 'an', 'bnyak', 'promonya', 'gofood', 'promo', 'gocar', 'goride', 'lain']
# After:  mudah an bnyak promonya gofood promo gocar goride lain
#
# === REJOIN TOKENS ===
# Before: ['niat', 'top', 'up', 'gopay', 'driver', 'order', 'go', 'ride', 'pas', 'driver', 'top', 'up', 'saldo', 'masuk', 'pergi', 'tuju', 'bayar', 'ongkos', 'trip', 'rugi']
# After:  niat top up gopay driver order go ride pas driver top up saldo masuk pergi tuju bayar ongkos trip rugi
#
# === REJOIN TOKENS ===
# Before: ['driver', 'driver', 'malas', 'titik', 'nya', 'sesuai', 'banget', 'nya', 'samperin', 'pesan', 'ojol', 'online', 'praktis', 'gosend', 'goride', 'si', 'voucher', 'nya', 'yaa', 'maaf']
# After:  driver driver malas titik nya sesuai banget nya samperin pesan ojol online praktis gosend goride si voucher nya yaa maaf
#
# === REJOIN TOKENS ===
# Before: ['tampil', 'aplikasi', 'gojek', 'nyaman', 'tarik', 'guna', 'aplikasi', 'gojek', 'nyaman', 'aman', 'praktis', 'suka', 'order', 'gofood', 'goride', 'aplikasi', 'gojek', 'moga', 'nambah', 'promo', 'gofood', 'nya', 'he']
# After:  tampil aplikasi gojek nyaman tarik guna aplikasi gojek nyaman aman praktis suka order gofood goride aplikasi gojek moga nambah promo gofood nya he
#
# === REJOIN TOKENS ===
# Before: ['sedia', 'versi', 'lite', 'nya', 'goride', 'gocar', 'ukur', 'aplikasi', 'besar']
# After:  sedia versi lite nya goride gocar ukur aplikasi besar
#
# === REJOIN TOKENS ===
# Before: ['layan', 'gocar', 'buruk', 'dicancel', 'x', 'jalan', 'rumah', 'sekali', 'sopir', 'dilayanin', 'pakai', 'gocar', 'prioritas', 'buruk', 'buruk', 'gocar', 'kecewa', 'pakai', 'goride', 'gofood', 'jrg', 'kendala', 'pakai', 'gocar']
# After:  layan gocar buruk dicancel x jalan rumah sekali sopir dilayanin pakai gocar prioritas buruk buruk gocar kecewa pakai goride gofood jrg kendala pakai gocar
#
# === REJOIN TOKENS ===
# Before: ['gofood', 'super', 'mahal', 'ongkirnya', 'biaya', 'layan', 'sgala', 'promo', 'potong', 'apa', 'pakai', 'gojek', 'butuh', 'gocar', 'goride', 'tiket', 'kereta']
# After:  gofood super mahal ongkirnya biaya layan sgala promo potong apa pakai gojek butuh gocar goride tiket kereta
#
# === REJOIN TOKENS ===
# Before: ['pokok', 'nya', 'top', 'markotop', 'deh']
# After:  pokok nya top markotop deh
#
# === REJOIN TOKENS ===
# Before: ['good']
# After:  good
#
# === REJOIN TOKENS ===
# Before: ['alam', 'senang', 'gojek']
# After:  alam senang gojek
#
# === REJOIN TOKENS ===
# Before: ['bantu', 'jalan']
# After:  bantu jalan
#
# === REJOIN TOKENS ===
# Before: ['langgan', 'pakai', 'gojek', 'pigi', 'goride', 'menurud', 'drivenya', 'ramah', 'moga', 'tingkat']
# After:  langgan pakai gojek pigi goride menurud drivenya ramah moga tingkat
#
# === REJOIN TOKENS ===
# Before: ['driver', 'bik', 'sopan', 'rapi', 'ramah', 'kendara', 'awat', 'jalan', 'patuh', 'taat', 'atur', 'lintas', 'layan', 'panggil', 'cepat', 'salam', 'relatif', 'yepay', 'gojek', 'reward', 'driver', 'teladan', 'cistomersetia', 'taf', 'ada', 'indian', 'voucer', 'hadiah', 'mobil', 'uman', 'sosialisasi', 'terimakasih', 'customer', 'gojek', 'go', 'ride', 'go', 'car']
# After:  driver bik sopan rapi ramah kendara awat jalan patuh taat atur lintas layan panggil cepat salam relatif yepay gojek reward driver teladan cistomersetia taf ada indian voucer hadiah mobil uman sosialisasi terimakasih customer gojek go ride go car
#
# === REJOIN TOKENS ===
# Before: ['promoan', 'driver', 'ambil', 'order', 'gocar', 'goride', 'seringkali', 'tunggu', 'ambil', 'coba', 'pakai', 'grab', 'langsung']
# After:  promoan driver ambil order gocar goride seringkali tunggu ambil coba pakai grab langsung
#
# === REJOIN TOKENS ===
# Before: ['bagus']
# After:  bagus
#
# === REJOIN TOKENS ===
# Before: ['order', 'goride', 'hemat', 'gofood', 'hemat', 'bikin', 'rugi', 'driver', 'tolong', 'hapus', 'order', 'hemat', 'nya', 'pakai', 'tarif', 'normal']
# After:  order goride hemat gofood hemat bikin rugi driver tolong hapus order hemat nya pakai tarif normal
#
# === REJOIN TOKENS ===
# Before: ['agam', 'aplikasi', 'nya', 'goride', 'gocar', 'go', 'food', 'moga', 'innovasi', 'nya']
# After:  agam aplikasi nya goride gocar go food moga innovasi nya
#
# === REJOIN TOKENS ===
# Before: ['nice']
# After:  nice
#
# === REJOIN TOKENS ===
# Before: ['kadang', 'hujan', 'gada', 'driver', 'go', 'ride', 'ambil', 'pesan', 'hujan', 'nya', 'redah', 'paksa', 'tunggu']
# After:  kadang hujan gada driver go ride ambil pesan hujan nya redah paksa tunggu
#
# === REJOIN TOKENS ===
# Before: ['order', 'goride', 'stuk', 'map']
# After:  order goride stuk map
#
# === REJOIN TOKENS ===
# Before: ['kasi', 'promo', 'order', 'gofood', 'goride', 'gocar']
# After:  kasi promo order gofood goride gocar
#
# === REJOIN TOKENS ===
# Before: ['tentu', 'lambat', 'goride', 'gofood']
# After:  tentu lambat goride gofood
#
# === REJOIN TOKENS ===
# Before: ['kota', 'bandung', 'go', 'ride', 'gocar', 'instan', 'ngak', 'depan', 'banget', 'jengkel', 'pesan', 'drivernya', 'lihat', 'lalang', 'ambil', 'hemat', 'comvort']
# After:  kota bandung go ride gocar instan ngak depan banget jengkel pesan drivernya lihat lalang ambil hemat comvort
#
# === REJOIN TOKENS ===
# Before: ['gojek', 'keren', 'pesan', 'goride', 'terima', 'kasih', 'gojek']
# After:  gojek keren pesan goride terima kasih gojek
#
# === REJOIN TOKENS ===
# Before: ['enak', 'sih', 'goride', 'nya', 'cuma', 'hujan', 'rintik', 'gerimis', 'dikit', 'driver', 'nya', 'ambil', 'order', 'gofood', 'jas', 'ujan', 'sih', 'anjing', 'orng', 'laper', 'banget', 'tunggu', 'jam', 'x', 'mesen', 'ngechat', 'ig', 'resto', 'nya', 'anjing', 'banget', 'gojek', 'restonya', 'ss', 'pesan', 'orng', 'driver', 'tolong', 'deh', 'driver', 'nya', 'ujan', 'dikit', 'males', 'gojek', 'anjg']
# After:  enak sih goride nya cuma hujan rintik gerimis dikit driver nya ambil order gofood jas ujan sih anjing orng laper banget tunggu jam x mesen ngechat ig resto nya anjing banget gojek restonya ss pesan orng driver tolong deh driver nya ujan dikit males gojek anjg
#
# === REJOIN TOKENS ===
# Before: ['tolong', 'hapus', 'goride', 'instan', 'stasiun', 'tangerang', 'susah', 'jalan', 'kaki', 'jam', 'sibuk', 'macet', 'jalan', 'kaki']
# After:  tolong hapus goride instan stasiun tangerang susah jalan kaki jam sibuk macet jalan kaki
#
# === REJOIN TOKENS ===
# Before: ['tolong', 'radius', 'driver', 'pesan', 'goride', 'jangkau', 'beda', 'goride', 'hemat', 'goride', 'reguler', 'tunggu', 'nya']
# After:  tolong radius driver pesan goride jangkau beda goride hemat goride reguler tunggu nya
#
# === REJOIN TOKENS ===
# Before: ['okeh']
# After:  okeh
#
# === REJOIN TOKENS ===
# Before: ['goride', 'oke', 'gofoodnya', 'sampah', 'banget', 'cari', 'driver', 'makan', 'jam', 'tunggu', 'endingnya', 'cancle', 'gadapat', 'driver', 'lanjur', 'laper', 'php']
# After:  goride oke gofoodnya sampah banget cari driver makan jam tunggu endingnya cancle gadapat driver lanjur laper php
#
# === REJOIN TOKENS ===
# Before: ['mantap']
# After:  mantap
#
# === REJOIN TOKENS ===
# Before: ['bagus']
# After:  bagus
#
# === REJOIN TOKENS ===
# Before: ['cs', 'online', 'kendala', 'susah', 'gopaylater', 'kasih', 'limit', 'bulan', 'x', 'kece', 'beku', 'tarif', 'gofood', 'goride', 'masuk', 'akal', 'worth', 'it', 'maaf', 'to', 'sayang', 'bikin', 'muak']
# After:  cs online kendala susah gopaylater kasih limit bulan x kece beku tarif gofood goride masuk akal worth it maaf to sayang bikin muak
#
# === REJOIN TOKENS ===
# Before: []
# After:
#
# === REJOIN TOKENS ===
# Before: ['goride', 'hemat', 'ko', 'min', 'susah', 'cari', 'keatasin', 'biar', 'gamapang', 'langsung', 'pesan']
# After:  goride hemat ko min susah cari keatasin biar gamapang langsung pesan
#
# === REJOIN TOKENS ===
# Before: ['pakai', 'go', 'box', 'go', 'pulsa', 'go', 'ride', 'go', 'send', 'go', 'car', 'go', 'food', 'go', 'massage', 'aktif', 'terimakasih', 'gojek', 'manfaat']
# After:  pakai go box go pulsa go ride go send go car go food go massage aktif terimakasih gojek manfaat
#
# === REJOIN TOKENS ===
# Before: ['promo', 'diskon', 'nya']
# After:  promo diskon nya
#
# === REJOIN TOKENS ===
# Before: ['aplikasi', 'bug', 'nya', 'order', 'goride', 'x', 'panggil', 'driver', 'tuju', 'akun', 'order', 'x', 'kali', 'cek', 'aplikasi', 'order', 'goridenya', 'saldo', 'gopay', 'isi']
# After:  aplikasi bug nya order goride x panggil driver tuju akun order x kali cek aplikasi order goridenya saldo gopay isi
#
# === REJOIN TOKENS ===
# Before: ['mantul']
# After:  mantul
#
# === REJOIN TOKENS ===
# Before: ['mudah', 'sulit', 'kasih', 'kadang', 'kadang', 'pakai', 'gojek', 'nya', 'butuh', 'eh', 'kasih', 'driver', 'nya', 'tunggu', 'deh', 'harga', 'murah', 'nya', 'cepat', 'nya', 'terimakasih']
# After:  mudah sulit kasih kadang kadang pakai gojek nya butuh eh kasih driver nya tunggu deh harga murah nya cepat nya terimakasih
#
# === REJOIN TOKENS ===
# Before: ['go', 'ride', 'instan', 'rugi', 'jarak', 'nya', 'driver', 'ambil']
# After:  go ride instan rugi jarak nya driver ambil
#
# === REJOIN TOKENS ===
# Before: ['gojek', 'evaluasi', 'mitra', 'cari', 'driver', 'hujan', 'susah', 'banget', 'order', 'gocar', 'goride', 'susah', 'banget', 'dapetnya', 'aplikasi', 'sih', 'oke', 'oke']
# After:  gojek evaluasi mitra cari driver hujan susah banget order gocar goride susah banget dapetnya aplikasi sih oke oke
#
# === REJOIN TOKENS ===
# Before: ['tolong', 'perbaikin', 'goride', 'hemat', 'nya', 'hilang', 'an', 'pakai', 'goride', 'hemat', 'bantu', 'kali', 'pakai', 'pulang', 'kerja', 'hemat', 'ongkos', 'tolong', 'baik']
# After:  tolong perbaikin goride hemat nya hilang an pakai goride hemat bantu kali pakai pulang kerja hemat ongkos tolong baik
#
# === REJOIN TOKENS ===
# Before: ['kirain', 'langgan', 'gojek', 'plus', 'potong', 'beneran', 'ribu', 'goride', 'cuma', 'potong', 'ribu', 'anjir']
# After:  kirain langgan gojek plus potong beneran ribu goride cuma potong ribu anjir
#
# === REJOIN TOKENS ===
# Before: ['manfaat']
# After:  manfaat
#
# === REJOIN TOKENS ===
# Before: ['good', 'driver']
# After:  good driver
#
# === REJOIN TOKENS ===
# Before: ['bantu']
# After:  bantu
#
# === REJOIN TOKENS ===
# Before: ['ok', 'goride', 'nya']
# After:  ok goride nya
#
# === REJOIN TOKENS ===
# Before: ['oke', 'ok', 'bgus']
# After:  oke ok bgus
#
# === REJOIN TOKENS ===
# Before: ['pesan', 'gojek', 'orang', 'sengaja', 'bayar', 'pakai', 'go', 'pay', 'ganti', 'metode', 'bayar', 'nya', 'pakai', 'cash', 'potong', 'makan', 'krna', 'saldo', 'go', 'pay', 'potong', 'goride', 'paksa', 'pakai', 'cash', 'aplikasi']
# After:  pesan gojek orang sengaja bayar pakai go pay ganti metode bayar nya pakai cash potong makan krna saldo go pay potong goride paksa pakai cash aplikasi
#
# === REJOIN TOKENS ===
# Before: ['jelek', 'gojek', 'pesan', 'goride', 'ambil', 'drive', 'alhasil', 'kali', 'tolak', 'drive', 'alesan', 'alhasil', 'pesan', 'grab', 'menit', 'jemput', 'grab', 'lbh', 'murah', 'ribu', 'gojek', 'ribu', 'pakai', 'voucher', 'kali', 'ngalaminnya', 'pasti', 'uninstall', 'gojek', 'sistem', 'nya', 'kaya', 'melulu', 'jamin', 'pindah', 'aplikasi']
# After:  jelek gojek pesan goride ambil drive alhasil kali tolak drive alesan alhasil pesan grab menit jemput grab lbh murah ribu gojek ribu pakai voucher kali ngalaminnya pasti uninstall gojek sistem nya kaya melulu jamin pindah aplikasi
#
# === REJOIN TOKENS ===
# Before: ['alam', 'buruk', 'pagi', 'pesan', 'goride', 'berangkat', 'kakak', 'menit', 'driver', 'map', 'jemput', 'menit', 'paruh', 'jalan', 'stasiun', 'menit', 'tunggu', 'menit', 'lihat', 'map', 'driver', 'jauh', 'bilang', 'chat', 'batal', 'kakak', 'alih', 'driver', 'layan', 'batal', 'driver', 'kena', 'batal', 'kasihan']
# After:  alam buruk pagi pesan goride berangkat kakak menit driver map jemput menit paruh jalan stasiun menit tunggu menit lihat map driver jauh bilang chat batal kakak alih driver layan batal driver kena batal kasihan
#
# === REJOIN TOKENS ===
# Before: ['oke', 'oke', 'guna', 'goride', 'wanita', 'laku', 'cabul', 'driver', 'gojek', 'cari', 'driver', 'interview', 'sih', 'pribadi', 'nya']
# After:  oke oke guna goride wanita laku cabul driver gojek cari driver interview sih pribadi nya
#
# === REJOIN TOKENS ===
# Before: ['persen', 'goride', 'batal', 'saldo', 'potong', 'kecewa', 'chat', 'cs', 'bantu']
# After:  persen goride batal saldo potong kecewa chat cs bantu
#
# === REJOIN TOKENS ===
# Before: ['pesan', 'gocar', 'pesan', 'pesawat', 'ambil', 'bayar', 'gopay', 'cash', 'ganti', 'prioritas', 'driver', 'jarak', 'astaga', 'banget', 'buang', 'maps', 'driver', 'kumpul', 'pilih', 'driver', 'gocar', 'goride', 'nya', 'cepat', 'driver', 'goride', 'gocar', 'tolong', 'gojek', 'baik', 'sistem', 'pesan', 'car', 'alih', 'aplikasi', 'gercep', 'satset', 'driver', 'gocar', 'pilih']
# After:  pesan gocar pesan pesawat ambil bayar gopay cash ganti prioritas driver jarak astaga banget buang maps driver kumpul pilih driver gocar goride nya cepat driver goride gocar tolong gojek baik sistem pesan car alih aplikasi gercep satset driver gocar pilih
#
# === REJOIN TOKENS ===
# Before: ['pesan', 'go', 'ride', 'sekali', 'batal', 'sma', 'driver', 'nya', 'kesel', 'nya', 'jam', 'ambil']
# After:  pesan go ride sekali batal sma driver nya kesel nya jam ambil
#
# === REJOIN TOKENS ===
# Before: ['goride', 'bawa', 'tumpang', 'orang', 'anak', 'sd', 'malam']
# After:  goride bawa tumpang orang anak sd malam
#
# === REJOIN TOKENS ===
# Before: ['jujur', 'gojek', 'bagus', 'cuma', 'pas', 'pesan', 'goride', 'stengah', 'jam', 'terima', 'terima']
# After:  jujur gojek bagus cuma pas pesan goride stengah jam terima terima
#
# === REJOIN TOKENS ===
# Before: ['pesan', 'goride', 'ambil', 'tunggu', 'bantu', 'tolong', 'baik', 'kerja']
# After:  pesan goride ambil tunggu bantu tolong baik kerja
#
# === REJOIN TOKENS ===
# Before: ['aplikasi', 'nya', 'gampang', 'paham', 'goride', 'nya', 'murah']
# After:  aplikasi nya gampang paham goride nya murah
#
# === REJOIN TOKENS ===
# Before: ['aplikasi', 'nya', 'lancar', 'ganggu', 'kadang', 'pas', 'buka', 'go', 'food', 'pilih', 'resto', 'ngelag', 'bagus']
# After:  aplikasi nya lancar ganggu kadang pas buka go food pilih resto ngelag bagus
#
# === REJOIN TOKENS ===
# Before: ['moga', 'jaga', 'amanah']
# After:  moga jaga amanah
#
# === REJOIN TOKENS ===
# Before: ['biaya', 'super', 'mahal', 'khusus', 'gofood', 'aneh', 'driver', 'minim', 'pickup', 'pesan', 'gosend', 'ongkos', 'murah', 'sisahnya', 'kasih', 'tips', 'driver', 'sumbang', 'uang', 'gojek', 'ngapa', 'in', 'pesan', 'goride', 'tawar', 'driver', 'offline', 'online', 'biar', 'uang', 'full', 'driver', 'biar', 'kena', 'potong', 'bantu']
# After:  biaya super mahal khusus gofood aneh driver minim pickup pesan gosend ongkos murah sisahnya kasih tips driver sumbang uang gojek ngapa in pesan goride tawar driver offline online biar uang full driver biar kena potong bantu
#
# === REJOIN TOKENS ===
# Before: ['good']
# After:  good
#
# === REJOIN TOKENS ===
# Before: ['promo']
# After:  promo
#
# === REJOIN TOKENS ===
# Before: ['keren']
# After:  keren
#
# === REJOIN TOKENS ===
# Before: ['oke']
# After:  oke
#
# === REJOIN TOKENS ===
# Before: ['mantap']
# After:  mantap
#
# === REJOIN TOKENS ===
# Before: ['baguss']
# After:  baguss
#
# === REJOIN TOKENS ===
# Before: ['fitur', 'go', 'transit', 'plus', 'go', 'ride', 'ko', 'si', 'update']
# After:  fitur go transit plus go ride ko si update
#
# === REJOIN TOKENS ===
# Before: ['mantull']
# After:  mantull
#
# === REJOIN TOKENS ===
# Before: ['gpsnya', 'auto', 'tracking', 'direct', 'go', 'ride', 'bikin', 'nyaman', 'ngecustom', 'lokasi', 'susahh', 'driver', 'pilih', 'pilih', 'customer', 'rating', 'diskon', 'pakai', 'voucher', 'suka', 'banget', 'ketemu', 'driver', 'suka', 'komplain', 'ngoceh']
# After:  gpsnya auto tracking direct go ride bikin nyaman ngecustom lokasi susahh driver pilih pilih customer rating diskon pakai voucher suka banget ketemu driver suka komplain ngoceh
#
# === REJOIN TOKENS ===
# Before: ['maaf', 'lebih', 'aplikator', 'gojek', 'cabang', 'surabaya', 'tolong', 'aplikator', 'gojek', 'tengah', 'bantu', 'kawan', 'rider', 'lapang', 'perihal', 'rider', 'ojol', 'hilang', 'apartemen', 'puncak', 'kertajaya', 'surabaya', 'aman', 'rider', 'kirim', 'makan', 'kirim', 'paket', 'gosend', 'menit', 'parkir', 'dalam', 'apartemen', 'rider', 'parkir', 'luar']
# After:  maaf lebih aplikator gojek cabang surabaya tolong aplikator gojek tengah bantu kawan rider lapang perihal rider ojol hilang apartemen puncak kertajaya surabaya aman rider kirim makan kirim paket gosend menit parkir dalam apartemen rider parkir luar
#
# === REJOIN TOKENS ===
# Before: ['ok']
# After:  ok
#
# === REJOIN TOKENS ===
# Before: ['bagus', 'fitur', 'sayang', 'goride', 'comfort', 'sebar', 'luas', 'daerah', 'kota', 'kota', 'huhu']
# After:  bagus fitur sayang goride comfort sebar luas daerah kota kota huhu
#
# === REJOIN TOKENS ===
# Before: ['langgan', 'go', 'ride', 'plus', 'ttp', 'mahal', 'pot', 'makan', 'cma', 'biaya', 'tangan', 'mksh', 'ah', 'terkahir', 'brlnganan', 'mahal', 'tarif']
# After:  langgan go ride plus ttp mahal pot makan cma biaya tangan mksh ah terkahir brlnganan mahal tarif
#
# === REJOIN TOKENS ===
# Before: ['gojek', 'bingung', 'pakai', 'jasa', 'gojek', 'mapping', 'jalan', 'utama', 'kota', 'mapping', 'klu', 'goride', 'jemput', 'putar', 'jalan', 'setapak', 'daerah', 'pinggir', 'jarak', 'aman', 'rute', 'mohon', 'kembali', 'mapping', 'jalan', 'utama', 'iya', 'guna', 'gojek']
# After:  gojek bingung pakai jasa gojek mapping jalan utama kota mapping klu goride jemput putar jalan setapak daerah pinggir jarak aman rute mohon kembali mapping jalan utama iya guna gojek
#
# === REJOIN TOKENS ===
# Before: ['go', 'club', 'jamin', 'prioritas', 'pesan', 'layan', 'aplikasi', 'jalan', 'bagus', 'kota', 'bandung', 'kota', 'bandung', 'go', 'ride', 'fungsi', 'subuh', 'macet', 'hujan', 'mitra', 'driver', 'layan', 'grab', 'maxim', 'aplikasi', 'saat']
# After:  go club jamin prioritas pesan layan aplikasi jalan bagus kota bandung kota bandung go ride fungsi subuh macet hujan mitra driver layan grab maxim aplikasi saat
#
# === REJOIN TOKENS ===
# Before: ['pesan', 'cuma', 'buka', 'pesan', 'goride', 'sampek', 'driver']
# After:  pesan cuma buka pesan goride sampek driver
#
# === REJOIN TOKENS ===
# Before: ['nice', 'and', 'good', 'driver', 'very', 'modest', 'with', 'deeppurple', 's', 'all', 'the', 'way', 'nostalgic', 'the', 'ride', 'why', 'not', 'renault', 'sometime']
# After:  nice and good driver very modest with deeppurple s all the way nostalgic the ride why not renault sometime
#
# === REJOIN TOKENS ===
# Before: ['pas', 'urgent', 'pesan', 'goride', 'gocar', 'akun', 'gojek', 'blokir', 'langgar', 'apa', 'coba', 'layan', 'cs', 'solusi', 'buka', 'balas', 'bot', 'chat', 'tutup', 'blokir', 'uninstall', 'aplikasi', 'langgan', 'aplikasi', 'gojek']
# After:  pas urgent pesan goride gocar akun gojek blokir langgar apa coba layan cs solusi buka balas bot chat tutup blokir uninstall aplikasi langgan aplikasi gojek
#
# === REJOIN TOKENS ===
# Before: ['keren', 'mntap']
# After:  keren mntap
#
# === REJOIN TOKENS ===
# Before: ['deh', 'saldo', 'isi', 'order', 'goride', 'harga', 'murah', 'gilir', 'habis', 'top', 'up', 'harga', 'voucher', 'gratis', 'ongkos', 'kirim', 'min', 'belanja', 'rb', 'rb', 'barang', 'kosong', 'ganti', 'barang', 'harga', 'otomatis', 'total', 'belanja', 'rb', 'rb', 'barang', 'kosong', 'out', 'of', 'stock']
# After:  deh saldo isi order goride harga murah gilir habis top up harga voucher gratis ongkos kirim min belanja rb rb barang kosong ganti barang harga otomatis total belanja rb rb barang kosong out of stock
#
# === REJOIN TOKENS ===
# Before: ['oke']
# After:  oke
#
# === REJOIN TOKENS ===
# Before: ['senang', 'aplikasi', 'mudah']
# After:  senang aplikasi mudah
#
# === REJOIN TOKENS ===
# Before: ['mantap', 'bantu']
# After:  mantap bantu
#
# === REJOIN TOKENS ===
# Before: ['susah', 'banget', 'driver', 'sekali', 'pick', 'up', 'lokasi', 'cari', 'rating', 'gojek', 'tumpang', 'jelek', 'asa', 'driver', 'perkara', 'tips', 'suka', 'nilai', 'busuk', 'tolong', 'sistim', 'gojek', 'hapus', 'nilai', 'rating', 'customer', 'driver', 'suka', 'milih', 'milih', 'kerja', 'pickup', 'gosend', 'tunggu', 'jam', 'pickup', 'goride', 'menit', 'tunggu']
# After:  susah banget driver sekali pick up lokasi cari rating gojek tumpang jelek asa driver perkara tips suka nilai busuk tolong sistim gojek hapus nilai rating customer driver suka milih milih kerja pickup gosend tunggu jam pickup goride menit tunggu
#
# === REJOIN TOKENS ===
# Before: ['goride', 'hemat', 'sih', 'asyik', 'sakit', 'hati', 'promo', 'serius', 'tahan']
# After:  goride hemat sih asyik sakit hati promo serius tahan
#
# === REJOIN TOKENS ===
# Before: ['praktis', 'banyakin', 'diskon', 'goride', 'gofood', 'nya', 'min']
# After:  praktis banyakin diskon goride gofood nya min
#
# === REJOIN TOKENS ===
# Before: ['aplikasi', 'bagus', 'pesan', 'goride', 'saldo', 'gopay', 'jaring', 'internet', 'bagus', 'tolong', 'baik', 'depan']
# After:  aplikasi bagus pesan goride saldo gopay jaring internet bagus tolong baik depan
#
# === REJOIN TOKENS ===
# Before: []
# After:
#
# === REJOIN TOKENS ===
# Before: ['good', 'luck']
# After:  good luck
#
# === REJOIN TOKENS ===
# Before: ['goride', 'bantu', 'bawa', 'sepeda', 'motor', 'bonceng', 'terimakasih', 'gojek', 'moga', 'diskon', 'iya']
# After:  goride bantu bawa sepeda motor bonceng terimakasih gojek moga diskon iya
#
# === REJOIN TOKENS ===
# Before: ['okeh', 'mambantu']
# After:  okeh mambantu
#
# === REJOIN TOKENS ===
# Before: ['langgan', 'go', 'ride', 'jarak', 'pendek', 'nyaman', 'rekomendasi', 'driver', 'jarak', 'jemput', 'banget', 'kadang', 'lebih', 'paruh', 'jarak', 'nganternya', 'agregat', 'rugi', 'bahan', 'bakar', 'tunggu']
# After:  langgan go ride jarak pendek nyaman rekomendasi driver jarak jemput banget kadang lebih paruh jarak nganternya agregat rugi bahan bakar tunggu
#
# === REJOIN TOKENS ===
# Before: ['goride', 'top', 'markotop', 'gocar', 'daerah', 'karawang', 'timur', 'minim', 'pesan', 'menit', 'bari']
# After:  goride top markotop gocar daerah karawang timur minim pesan menit bari
#
# === REJOIN TOKENS ===
# Before: ['bantu']
# After:  bantu
#
# === REJOIN TOKENS ===
# Before: ['aplikasi', 'bagus', 'promo', 'promonya', 'rider', 'driver', 'go', 'food', 'go', 'send']
# After:  aplikasi bagus promo promonya rider driver go food go send
#
# === REJOIN TOKENS ===
# Before: ['tolong', 'bina', 'driver', 'go', 'ridenya', 'driver', 'sombong', 'pilih', 'pilih', 'order']
# After:  tolong bina driver go ridenya driver sombong pilih pilih order
#
# === REJOIN TOKENS ===
# Before: ['gojek', 'percaya', 'goride', 'gocar', 'gosen', 'gofood', 'kurir', 'sopan', 'ramah', 'terimakasih', 'gojek', 'sukses']
# After:  gojek percaya goride gocar gosen gofood kurir sopan ramah terimakasih gojek sukses
#
# === REJOIN TOKENS ===
# Before: ['pesan', 'goride', 'comfort', 'nyaman', 'jalan', 'aplikasi', 'si', 'tulis', 'motor', 'vario', 'beat', 'kecewa', 'mas', 'ramah', 'iya', 'beda', 'harga', 'nya', 'sm', 'goride']
# ...
#
# === REJOIN TOKENS ===
# Before: ['mudah']
# After:  mudah
#
# === REJOIN TOKENS ===
# Before: ['oke']
# After:  oke
#
# === REJOIN TOKENS ===
# Before: ['jelass', 'isi', 'gopay', 'pesan', 'goride', 'out', 'saldo', 'gopay', 'sedot', 'anjingg']
# After:  jelass isi gopay pesan goride out saldo gopay sedot anjingg
#
# === REJOIN TOKENS ===
# Before: ['the', 'first', 'time', 'i', 'downloaded', 'this', 'app', 'i', 'gave', 'you', 'stars', 'second', 'i', 'gave', 'you', 'lately', 'i', 'drop', 'it', 'too', 'star', 'so', 'sick', 'of', 'this', 'app', 'lately', 'i', 'didn', 't', 'use', 'this', 'app', 'and', 'sometimes', 'my', 'app', 'giving', 'me', 'a', 'notification', 'that', 'i', 'order', 'using', 'go', 'food', 'service', 'then', 'double', 'order', 'ride', 'and', 'now', 'a', 'false', 'order', 'again', 'on', 'go', 'mart', 'the', 'heck', 'i', 'dont', 'want', 'to', 'install', 'it', 'anymore', 'you', 'betray', 'my', 'trust']
# After:  the first time i downloaded this app i gave you stars second i gave you lately i drop it too star so sick of this app lately i didn t use this app and sometimes my app giving me a notification that i order using go food service then double order ride and now a false order again on go mart the heck i dont want to install it anymore you betray my trust
#
# === REJOIN TOKENS ===
# Before: ['mohon', 'baik', 'sistem', 'masak', 'order', 'goride', 'pesan', 'sengaja', 'dobel', 'klik', 'nyantol', 'driver', 'konsumen', 'enak', 'driver', 'nya', 'aplikasi', 'belah', 'kayak', 'dobel', 'pesan', 'selesai', 'untung', 'drivernya', 'sabar', 'repot', 'tahu', 'dobel', 'drivernya', 'tinggal', 'klik', 'batal', 'aplikasi', 'sih', 'gampang', 'jelas', 'drivernya', 'lho', 'repot']
# After:  mohon baik sistem masak order goride pesan sengaja dobel klik nyantol driver konsumen enak driver nya aplikasi belah kayak dobel pesan selesai untung drivernya sabar repot tahu dobel drivernya tinggal klik batal aplikasi sih gampang jelas drivernya lho repot
#
# === REJOIN TOKENS ===
# Before: ['bagus']
# After:  bagus
#
# === REJOIN TOKENS ===
# Before: ['layan', 'bagus', 'kali', 'beli', 'paket', 'voucher', 'diskon', 'nominal', 'voucher', 'voucher', 'goride', 'diskon', 's', 'rb', 'diskon', 'rb', 'terang', 'diskon', 'jujur', 'terscam']
# After:  layan bagus kali beli paket voucher diskon nominal voucher voucher goride diskon s rb diskon rb terang diskon jujur terscam
#
# === REJOIN TOKENS ===
# Before: ['solok', 'gojek', 'pesan', 'goride', 'tanjung', 'bingkung', 'gocar', 'padang', 'bukit', 'apk', 'hapus', 'nomor', 'hp', 'hilang', 'login', 'susah', 'email', 'verivikasi']
# After:  solok gojek pesan goride tanjung bingkung gocar padang bukit apk hapus nomor hp hilang login susah email verivikasi
#
# === REJOIN TOKENS ===
# Before: ['gopaynya', 'praktis', 'promo', 'gofood', 'goride', 'harga', 'jangkau', 'ajar']
# After:  gopaynya praktis promo gofood goride harga jangkau ajar
#
# === REJOIN TOKENS ===
# Before: ['mantap', 'keren']
# After:  mantap keren
#
# === REJOIN TOKENS ===
# Before: ['rating', 'noh', 'bintang', 'urgent', 'gocar', 'goride', 'driver', 'nge', 'batal', 'sepakat', 'tunggu', 'batal', 'banget']
# After:  rating noh bintang urgent gocar goride driver nge batal sepakat tunggu batal banget
#
# === REJOIN TOKENS ===
# Before: ['rider', 'gojek', 'nama', 'firial', 'lampung', 'sopan', 'bentak', 'langgan', 'kebut', 'kebut', 'jalan', 'tabrak', 'orang', 'gojek', 'seleksi', 'rider']
# After:  rider gojek nama firial lampung sopan bentak langgan kebut kebut jalan tabrak orang gojek seleksi rider
#
# === REJOIN TOKENS ===
# Before: ['bagus']
# After:  bagus
#
# === REJOIN TOKENS ===
# Before: ['gojek', 'susah', 'banget', 'pesan', 'gocar', 'pakai', 'gocar', 'gocar', 'hemat', 'hapus', 'vitur', 'gocar', 'ny', 'goride']
# After:  gojek susah banget pesan gocar pakai gocar gocar hemat hapus vitur gocar ny goride
#
# === REJOIN TOKENS ===
# Before: ['berat', 'pesan', 'goride', 'klik', 'alamat', 'tuju', 'gilir', 'pas', 'drivernya', 'aplikasi', 'ngestuck', 'delay', 'close', 'aplikasi', 'masuk', 'biar', 'normal']
# After:  berat pesan goride klik alamat tuju gilir pas drivernya aplikasi ngestuck delay close aplikasi masuk biar normal
#
# === REJOIN TOKENS ===
# Before: ['parah', 'mntang', 'habis', 'ujan', 'pesan', 'goride', 'gocar', 'smpe', 'blue', 'bird', 'terima', 'kasih', 'bayar', 'tunai', 'sdang', 'buru']
# After:  parah mntang habis ujan pesan goride gocar smpe blue bird terima kasih bayar tunai sdang buru
#
# === REJOIN TOKENS ===
# Before: ['jarak', 'driver', 'alas', 'batal', 'bukti', 'chat', 'cari', 'order', 'goride', 'bayar', 'ribu', 'cuma', 'masuk', 'drivernya', 'cuma', 'ribu']
# After:  jarak driver alas batal bukti chat cari order goride bayar ribu cuma masuk drivernya cuma ribu
#
# === REJOIN TOKENS ===
# Before: ['tolong', 'driver', 'diajarin', 'layan', 'pesan', 'goride', 'driver', 'nya', 'didiemin', 'posisi', 'driver', 'diem', 'tunggu', 'jam', 'ujung', 'nya', 'batal', 'ambil', 'order', 'suruh', 'bicara', 'langgan', 'langgan', 'nge', 'batal', 'order', 'biar', 'rating', 'driver', 'minus', 'rugi', 'tunggu', 'hujan', 'an', 'ujung', 'nya', 'batal']
# After:  tolong driver diajarin layan pesan goride driver nya didiemin posisi driver diem tunggu jam ujung nya batal ambil order suruh bicara langgan langgan nge batal order biar rating driver minus rugi tunggu hujan an ujung nya batal
#
# === REJOIN TOKENS ===
# Before: ['pesan', 'goride', 'batal', 'dpn', 'customer', 'motor', 'gilir', 'pesan', 'goride', 'comfort', 'eh', 'dtng', 'motor', 'sih', 'kali', 'goride', 'dtng']
# After:  pesan goride batal dpn customer motor gilir pesan goride comfort eh dtng motor sih kali goride dtng
#
# === REJOIN TOKENS ===
# Before: ['bangsatt', 'ongkos', 'gofood', 'mahal', 'banget', 'go', 'ride', 'lambung', 'kasihan', 'drivernya', 'peras', 'mati']
# After:  bangsatt ongkos gofood mahal banget go ride lambung kasihan drivernya peras mati
#
# === REJOIN TOKENS ===
# Before: ['bagus']
# After:  bagus
#
# === REJOIN TOKENS ===
# Before: ['tahan', 'layan', 'langgan', 'harga', 'besar', 'rider', 'driver', 'rangin', 'potong', 'usaha', 'nya']
# After:  tahan layan langgan harga besar rider driver rangin potong usaha nya
#
# === REJOIN TOKENS ===
# Before: ['plis', 'promo', 'nya', 'khusus', 'goride', 'pakai', 'goride', 'promo', 'teman', 'slalu', 'potong', 'beli', 'loh', 'potong', 'gaadil', 'pls']
# After:  plis promo nya khusus goride pakai goride promo teman slalu potong beli loh potong gaadil pls
#
# === REJOIN TOKENS ===
# Before: ['bagus', 'aplikasi', 'nya', 'bantu', 'banget']
# After:  bagus aplikasi nya bantu banget
#
# === REJOIN TOKENS ===
# Before: ['kesel', 'pesan', 'gocar', 'goride', 'pagi', 'pagi', 'driver', 'nya', 'nya', 'ampun', 'pokok', 'kecewa', 'deh']
# After:  kesel pesan gocar goride pagi pagi driver nya nya ampun pokok kecewa deh
#
# === REJOIN TOKENS ===
# Before: ['good', 'apk']
# After:  good apk
#
# === REJOIN TOKENS ===
# Before: ['hati', 'goride', 'gojek', 'topi', 'tinggal', 'nyangkut', 'helm', 'ti', 'tilep', 'drivernya', 'kecewa', 'minggu', 'jelas', 'kerjasama', 'coba', 'barang', 'harga', 'bahaya', 'topi', 'curi']
# After:  hati goride gojek topi tinggal nyangkut helm ti tilep drivernya kecewa minggu jelas kerjasama coba barang harga bahaya topi curi
#
# === REJOIN TOKENS ===
# Before: ['mudah', 'lancar']
# After:  mudah lancar
#
# === REJOIN TOKENS ===
# Before: ['si', 'langgan', 'vouch', 'go', 'plus', 'mlh', 'goride', 'nya', 'diskon', 'nyesell']
# After:  si langgan vouch go plus mlh goride nya diskon nyesell
#
# === REJOIN TOKENS ===
# Before: ['mohon', 'baik', 'drivernya', 'masak', 'hujan', 'narik', 'go', 'ride', 'nya', 'jam', 'pesan', 'peduliin', 'langsung', 'batal', 'driver', 'profesional', 'banget', 'tempat', 'mobil', 'masuk', 'sen', 'go', 'ride']
# After:  mohon baik drivernya masak hujan narik go ride nya jam pesan peduliin langsung batal driver profesional banget tempat mobil masuk sen go ride
#
# === REJOIN TOKENS ===
# Before: ['mantab']
# After:  mantab
#
# === REJOIN TOKENS ===
# Before: ['suka', 'pakai', 'gojek', 'sukatani', 'goride', 'jangkau', 'yaa']
# After:  suka pakai gojek sukatani goride jangkau yaa
#
# === REJOIN TOKENS ===
# Before: ['mantap', 'pokok']
# After:  mantap pokok
#
# === REJOIN TOKENS ===
# Before: ['terimaksih', 'jaya']
# After:  terimaksih jaya
#
# === REJOIN TOKENS ===
# Before: ['nyaman']
# After:  nyaman
#
# === REJOIN TOKENS ===
# Before: ['sekongkol', 'driver', 'go', 'jek', 'order', 'goride', 'pas', 'driver', 'langsung', 'nama', 'alamat', 'tuju', 'nama', 'tuju', 'driver', 'driver', 'bilang', 'offline', 'pakai', 'aplikasi', 'cek', 'aplikasi', 'driver', 'order', 'kirim', 'foto', 'tunggu', 'titik', 'jemput', 'tuju', 'driver', 'antar', 'tarif', 'x', 'lipat', 'tarif', 'aplikasi']
# After:  sekongkol driver go jek order goride pas driver langsung nama alamat tuju nama tuju driver driver bilang offline pakai aplikasi cek aplikasi driver order kirim foto tunggu titik jemput tuju driver antar tarif x lipat tarif aplikasi
#
# === REJOIN TOKENS ===
# Before: ['bagus']
# After:  bagus
#
# === REJOIN TOKENS ===
# Before: ['layan', 'ramah', 'sopan', 'murah']
# After:  layan ramah sopan murah
#
# === REJOIN TOKENS ===
# Before: ['aplikasi', 'gojek', 'bantu']
# After:  aplikasi gojek bantu
#
# === REJOIN TOKENS ===
# Before: ['order', 'goride', 'kali', 'muncul']
# After:  order goride kali muncul
#
# === REJOIN TOKENS ===
# Before: ['ok', 'banget']
# After:  ok banget
#
# === REJOIN TOKENS ===
# Before: ['go', 'ride', 'oke', 'gocar', 'nya']
# After:  go ride oke gocar nya
#
# === REJOIN TOKENS ===
# Before: ['go', 'ride', 'jembot', 'sombong', 'drivernya', 'jarak', 'gmau', 'tolak', 'map', 'driver', 'nolak', 'app', 'sampah']
# After:  go ride jembot sombong drivernya jarak gmau tolak map driver nolak app sampah
#
# === REJOIN TOKENS ===
# Before: ['driver', 'nya', 'goride', 'comfort', 'nya', 'aduhai', 'jauh', 'juara']
# After:  driver nya goride comfort nya aduhai jauh juara
#
# === REJOIN TOKENS ===
# Before: ['bintang', 'bintang', 'rute', 'sinting', 'bikin', 'muter', 'muter', 'kemarin', 'goride', 'go', 'bluebird', 'rute', 'buang', 'buang', 'uang', 'konsumen']
# After:  bintang bintang rute sinting bikin muter muter kemarin goride go bluebird rute buang buang uang konsumen
#
# === REJOIN TOKENS ===
# Before: ['njemput', 'cepat', 'sopir', 'enak', 'tenang', 'sopir', 'sopan', 'ramsh', 'rute', 'nya', 'langsing', 'tuju', 'dlsb']
# After:  njemput cepat sopir enak tenang sopir sopan ramsh rute nya langsing tuju dlsb
#
# === REJOIN TOKENS ===
# Before: ['top', 'markotop']
# After:  top markotop
#
# === REJOIN TOKENS ===
# Before: ['bantu', 'moga', 'voucher', 'goride', 'gofood']
# After:  bantu moga voucher goride gofood
#
# === REJOIN TOKENS ===
# Before: ['mesen', 'goride', 'or', 'gocar', 'slalu', 'milih', 'peta', 'manual', 'simpen', 'lokasi', 'favorit', 'cari', 'manual', 'susah']
# After:  mesen goride or gocar slalu milih peta manual simpen lokasi favorit cari manual susah
#
# === REJOIN TOKENS ===
# Before: ['mrasa', 'adil', 'tmn', 'otomatis', 'voucher', 'promo', 'goride', 'gd', 'sm', 'ishh', 'dimasukin', 'kode', 'sgala', 'hargany', 'nromal']
# After:  mrasa adil tmn otomatis voucher promo goride gd sm ishh dimasukin kode sgala hargany nromal
#
# === REJOIN TOKENS ===
# Before: ['goridenya', 'bagus', 'gofoodnya', 'masalah', 'driver', 'tunggu', 'jam', 'driver', 'makan', 'driver', 'g', 'kasi', 'restonya', 'makananya']
# After:  goridenya bagus gofoodnya masalah driver tunggu jam driver makan driver g kasi restonya makananya
#
# === REJOIN TOKENS ===
# Before: ['susah', 'iya', 'pesan', 'gojek', 'goride', 'gocar', 'buka', 'aplikasi', 'pakai', 'indrive', 'cpt', 'banget', 'tingkat', 'mundur', 'sori', 'udate', 'review', 'jujur', 'iya', 'gojek', 'tinggal', 'ma']
# After:  susah iya pesan gojek goride gocar buka aplikasi pakai indrive cpt banget tingkat mundur sori udate review jujur iya gojek tinggal ma
#
# === REJOIN TOKENS ===
# Before: ['gojek', 'sih', 'pesan', 'goride', 'tulis', 'pakai', 'metode', 'metode']
# After:  gojek sih pesan goride tulis pakai metode metode
#
# === REJOIN TOKENS ===
# Before: ['senang', 'belanja', 'gomart', 'pas', 'promo']
# After:  senang belanja gomart pas promo
#
# === REJOIN TOKENS ===
# Before: ['semangaat', 'pagi', 'juang', 'keluarga', 'cerita', 'kecewa', 'pakai', 'gojek', 'pesan', 'goride', 'banget', 'driver', 'driver', 'posisi', 'nya', 'banget', 'lihat', 'sekitr', 'driver', 'rekan', 'driver', 'order', 'tunggu', 'alih', 'grabbike', 'menit', 'driver', 'driver']
# After:  semangaat pagi juang keluarga cerita kecewa pakai gojek pesan goride banget driver driver posisi nya banget lihat sekitr driver rekan driver order tunggu alih grabbike menit driver driver
#
# === REJOIN TOKENS ===
# Before: ['diskon']
# After:  diskon
#
# === REJOIN TOKENS ===
# Before: ['woi', 'pakai', 'goride', 'plus', 'titik', 'jemput', 'ngaco', 'pakai', 'plus']
# After:  woi pakai goride plus titik jemput ngaco pakai plus
#
# === REJOIN TOKENS ===
# Before: ['mantab']
# After:  mantab
#
# === REJOIN TOKENS ===
# Before: ['ambil', 'order', 'go', 'ride', 'pakai', 'diskon', 'ribu']
# After:  ambil order go ride pakai diskon ribu
#
# === REJOIN TOKENS ===
# Before: ['guna', 'bett', 'sumpah']
# After:  guna bett sumpah
#
# === REJOIN TOKENS ===
# Before: ['hallo', 'gojek', 'guna', 'gojek', 'senang', 'app', 'voucher', 'goride', 'murah', 'terimakasih', 'gojek', 'jasa', 'jasa', 'mu', 'terima', 'kasih']
# After:  hallo gojek guna gojek senang app voucher goride murah terimakasih gojek jasa jasa mu terima kasih
#
# === REJOIN TOKENS ===
# Before: ['i', 'love', 'gojek', 'so', 'much', 'klu', 'voucher', 'laku', 'voucher', 'go', 'ride', 'nya', 'lumayan', 'voucher', 'voucher', 'go', 'car', 'voucher', 'masak', 'wira', 'wiri', 'kecuali', 'klu', 'asrama', 'anak', 'pakai', 'voucher', 'tlg', 'dunk', 'it', 'klu', 'suruh', 'marketing', 'buatin', 'program', 'absurd']
# After:  i love gojek so much klu voucher laku voucher go ride nya lumayan voucher voucher go car voucher masak wira wiri kecuali klu asrama anak pakai voucher tlg dunk it klu suruh marketing buatin program absurd
#
# === REJOIN TOKENS ===
# Before: ['gojek', 'blunder', 'customer', 'pesan', 'go', 'ride', 'prioritas', 'driver', 'prioritas', 'dapat', 'driver', 'prioritas', 'kena', 'biaya', 'tambah', 'customer', 'pindah', 'aplikasi', 'kocak', 'driver', 'suspen', 'gara', 'gara', 'nglewatin', 'order', 'orang', 'kantor', 'gojek', 'salah', 'jemput', 'bijak', 'suspen', 'castamer', 'susah', 'driver']
# After:  gojek blunder customer pesan go ride prioritas driver prioritas dapat driver prioritas kena biaya tambah customer pindah aplikasi kocak driver suspen gara gara nglewatin order orang kantor gojek salah jemput bijak suspen castamer susah driver
#
# === REJOIN TOKENS ===
# Before: ['layan', 'buruk', 'pas', 'hujan', 'driver', 'car', 'ambil', 'servernya', 'gojek', 'lempar', 'pesan', 'pas', 'hujan', 'driver', 'batal', 'pas', 'banget', 'kadang', 'goride', 'buruk', 'layan', 'gojek']
# After:  layan buruk pas hujan driver car ambil servernya gojek lempar pesan pas hujan driver batal pas banget kadang goride buruk layan gojek
#
# === REJOIN TOKENS ===
# Before: ['bantu', 'butuh']
# After:  bantu butuh
#
# Hasil final:
#                                               ulasan  \
# 0  Matikan Fitur Order ganda pemesanan GoRide. Se...
# 1  Tolong ya..Pleeeeease...buat CUSTOMER yg Pesen...
# 2  Saya harap di update kedepanya saat pesan go f...
# 3  Buatku yg tinggal agak jauh dr kota,ini aplika...
# 4  Layanan Goride sangat membantu untuk aktifitas...
# 5  ini gojek kenapa ya sekarang, saya pakai akun ...
# 6  Kalau terima rider seleksi dulu lah, setiap na...
# 7  Gojek sekarang mahal meskipun pakai voucher, p...
# 8                                    cepat dan murah
# 9                                    Keren dah murah
#
#                                           clean_text
# 0  mati fitur order ganda mesan goride order gori...
# 1  tolong iya pleease customer pesan gibride tolo...
# 2  harap update depa pesan go food muncul notifik...
# 3  buat tinggal kota aplikasi cpat dpat driver pe...
# 4  layan goride bantu aktifitas hari motor baik b...
# 5  gojek iya pakai akun suka voucher voucher gori...
# 6  terima rider seleksi gojek rider nya emosi melulu
# 7  gojek mahal pakai voucher jalan harga pakai vo...
# 8                                        cepat murah
# 9                                        keren murah

# %%
# Lihat hasil
df[['ulasan', 'clean_text']].head()
# # 7. Simpan Hasil Preprocessing
df.to_csv('ulasan_goride_bersihhh.csv', index=False)
